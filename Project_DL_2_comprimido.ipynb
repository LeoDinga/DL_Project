# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoDinga/DL_Project/blob/main/Project_DL_2_comprimido.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/THETIS-dataset/dataset.git
# !mv dataset data
# Out:
# Cloning into 'dataset'...
# remote: Enumerating objects: 8471, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 8471 (delta 0), reused 5 (delta 0), pack-reused 8465 (from 1)
# Receiving objects: 100% (8471/8471), 12.70 GiB | 35.51 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# Updating files: 100% (8379/8379), done.

# %%
import os
import cv2
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as T
import torchvision.models as models
from PIL import Image
import numpy as np
from sklearn.metrics import accuracy_score
import shutil
import random

# %%
print("CUDA available:", torch.cuda.is_available())
print("Device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA available: True
# Device name: Tesla T4

# %%
#shows the videos in each folder
data_path = 'data'

# Print out the directory structure
for root, dirs, files in os.walk(data_path):
    print(f"Root: {root}")
    print(f"Dirs: {dirs}")
    print(f"Files: {files}")
    print("-" * 40)
# Out:
# Root: data
# Dirs: ['VIDEO_Mask', 'VIDEO_Skelet3D', 'VIDEO_Skelet2D', 'VIDEO_Depth', 'papers', '.git', 'VIDEO_RGB']
# Files: ['README.md']
# ----------------------------------------
# Root: data/VIDEO_Mask
# Dirs: ['backhand_volley', 'kick_service', 'forehand_flat', 'forehand_openstands', 'slice_service', 'forehand_volley', 'backhand_slice', 'flat_service', 'smash', 'backhand2hands', 'backhand', 'forehand_slice']
# Files: []
# ----------------------------------------
# Root: data/VIDEO_Mask/backhand_volley
# Dirs: []
# Files: ['p14_bvolley_mask_s3.avi', 'p39_bvolley_mask_s2.avi', 'p41_bvolley_mask_s3.avi', 'p27_bvolley_mask_s3.avi', 'p15_bvolley_mask_s2.avi', 'p55_bvolley_mask_s3.avi', 'p48_bvolley_mask_s3.avi', 'p11_bvolley_mask_s2.avi', 'p28_bvolley_mask_s2.avi', 'p18_bvolley_mask_s2.avi', 'p32_bvolley_mask_s1.avi', 'p48_bvolley_mask_s2.avi', 'p34_bvolley_mask_s3.avi', 'p2_bvolley_mask_s2.avi', 'p47_bvolley_mask_s2.avi', 'p36_bvolley_mask_s1.avi', 'p35_bvolley_mask_s2.avi', 'p37_bvolley_mask_s2.avi', 'p22_bvolley_mask_s3.avi', 'p3_bvolley_mask_s2.avi', 'p30_bvolley_mask_s1.avi', 'p28_bvolley_mask_s1.avi', 'p44_bvolley_mask_s2.avi', 'p49_bvolley_mask_s3.avi', 'p9_bvolley_mask_s3.avi', 'p29_bvolley_mask_s3.avi', 'p1_bvolley_mask_s3.avi', 'p26_bvolley_mask_s3.avi', 'p42_bvolley_mask_s1.avi', 'p9_bvolley_mask_s2.avi', 'p33_bvolley_mask_s2.avi', 'p4_bvolley_mask_s2.avi', 'p17_bvolley_mask_s3.avi', 'p14_bvolley_mask_s1.avi', 'p13_bvolley_mask_s2.avi', 'p10_bvolley_mask_s3.avi', 'p45_bvolley_mask_s1.avi', 'p16_bvolley_mask_s3.avi', 'p21_bvolley_mask_s2.avi', 'p50_bvolley_mask_s1.avi', 'p48_bvolley_mask_s1.avi', 'p11_bvolley_mask_s3.avi', 'p35_bvolley_mask_s1.avi', 'p31_bvolley_mask_s3.avi', 'p46_bvolley_mask_s3.avi', 'p16_bvolley_mask_s2.avi', 'p22_bvolley_mask_s2.avi', 'p12_bvolley_mask_s1.avi', 'p49_bvolley_mask_s2.avi', 'p1_bvolley_mask_s1.avi', 'p21_bvolley_mask_s3.avi', 'p51_bvolley_mask_s2.avi', 'p23_bvolley_mask_s1.avi', 'p50_bvolley_mask_s2.avi', 'p25_bvolley_mask_s1.avi', 'p34_bvolley_mask_s1.avi', 'p8_bvolley_mask_s2.avi', 'p38_bvolley_mask_s3.avi', 'p30_bvolley_mask_s3.avi', 'p33_bvolley_mask_s3.avi', 'p3_bvolley_mask_s3.avi', 'p10_bvolley_mask_s2.avi', 'p19_bvolley_mask_s3.avi', 'p41_bvolley_mask_s1.avi', 'p39_bvolley_mask_s3.avi', 'p5_bvolley_mask_s1.avi', 'p36_bvolley_mask_s2.avi', 'p1_bvolley_mask_s2.avi', 'p39_bvolley_mask_s1.avi', 'p53_bvolley_mask_s1.avi', 'p51_bvolley_mask_s1.avi', 'p51_bvolley_mask_s3.avi', 'p12_bvolley_mask_s2.avi', 'p23_bvolley_mask_s2.avi', 'p44_bvolley_mask_s1.avi', 'p43_bvolley_mask_s3.avi', 'p45_bvolley_mask_s2.avi', 'p13_bvolley_mask_s1.avi', 'p25_bvolley_mask_s2.avi', 'p35_bvolley_mask_s3.avi', 'p54_bvolley_mask_s3.avi', 'p40_bvolley_mask_s3.avi', 'p12_bvolley_mask_s3.avi', 'p46_bvolley_mask_s2.avi', 'p10_bvolley_mask_s1.avi', 'p20_bvolley_mask_s3.avi', 'p27_bvolley_mask_s1.avi', 'p7_bvolley_mask_s3.avi', 'p55_bvolley_mask_s1.avi', 'p43_bvolley_mask_s1.avi', 'p26_bvolley_mask_s1.avi', 'p45_bvolley_mask_s3.avi', 'p43_bvolley_mask_s2.avi', 'p8_bvolley_mask_s1.avi', 'p6_bvolley_mask_s2.avi', 'p7_bvolley_mask_s2.avi', 'p11_bvolley_mask_s1.avi', 'p34_bvolley_mask_s2.avi', 'p2_bvolley_mask_s1.avi', 'p4_bvolley_mask_s3.avi', 'p25_bvolley_mask_s3.avi', 'p16_bvolley_mask_s1.avi', 'p46_bvolley_mask_s1.avi', 'p26_bvolley_mask_s2.avi', 'p47_bvolley_mask_s1.avi', 'p29_bvolley_mask_s1.avi', 'p20_bvolley_mask_s2.avi', 'p47_bvolley_mask_s3.avi', 'p18_bvolley_mask_s3.avi', 'p31_bvolley_mask_s2.avi', 'p44_bvolley_mask_s3.avi', 'p17_bvolley_mask_s2.avi', 'p42_bvolley_mask_s3.avi', 'p37_bvolley_mask_s1.avi', 'p38_bvolley_mask_s2.avi', 'p15_bvolley_mask_s1.avi', 'p32_bvolley_mask_s3.avi', 'p41_bvolley_mask_s2.avi', 'p5_bvolley_mask_s2.avi', 'p2_bvolley_mask_s3.avi', 'p27_bvolley_mask_s2.avi', 'p55_bvolley_mask_s2.avi', 'p33_bvolley_mask_s1.avi', 'p23_bvolley_mask_s3.avi', 'p6_bvolley_mask_s1.avi', 'p7_bvolley_mask_s1.avi', 'p22_bvolley_mask_s1.avi', 'p3_bvolley_mask_s1.avi', 'p14_bvolley_mask_s2.avi', 'p6_bvolley_mask_s3.avi', 'p30_bvolley_mask_s2.avi', 'p37_bvolley_mask_s3.avi', 'p13_bvolley_mask_s3.avi', 'p53_bvolley_mask_s3.avi', 'p38_bvolley_mask_s1.avi', 'p52_bvolley_mask_s1.avi', 'p40_bvolley_mask_s2.avi', 'p31_bvolley_mask_s1.avi', 'p54_bvolley_mask_s2.avi', 'p36_bvolley_mask_s3.avi', 'p5_bvolley_mask_s3.avi', 'p24_bvolley_mask_s3.avi', 'p15_bvolley_mask_s3.avi', 'p52_bvolley_mask_s2.avi', 'p21_bvolley_mask_s1.avi', 'p49_bvolley_mask_s1.avi', 'p24_bvolley_mask_s1.avi', 'p19_bvolley_mask_s2.avi', 'p18_bvolley_mask_s1 ...
# ----------------------------------------
# Root: data/VIDEO_Mask/kick_service
# Dirs: []
# Files: ['p12_serkick_mask_s1.avi', 'p41_serkick_mask_s2.avi', 'p43_serkick_mask_s2.avi', 'p48_serkick_mask_s2.avi', 'p43_serkick_mask_s1.avi', 'p54_serkick_mask_s1.avi', 'p53_serkick_mask_s1.avi', 'p35_serkick_mask_s2.avi', 'p7_serkick_mask_s1.avi', 'p4_serkick_mask_s2.avi', 'p55_serkick_mask_s2.avi', 'p43_serkick_mask_s3.avi', 'p15_serkick_mask_s1.avi', 'p16_serkick_mask_s3.avi', 'p19_serkick_mask_s1.avi', 'p4_serkick_mask_s1.avi', 'p1_serkick_mask_s1.avi', 'p51_serkick_mask_s3.avi', 'p51_serkick_mask_s1.avi', 'p14_serkick_mask_s2.avi', 'p53_serkick_mask_s2.avi', 'p40_serkick_mask_s2.avi', 'p53_serkick_mask_s3.avi', 'p17_serkick_mask_s1.avi', 'p14_serkick_mask_s3.avi', 'p40_serkick_mask_s3.avi', 'p23_serkick_mask_s1.avi', 'p50_serkick_mask_s2.avi', 'p20_serkick_mask_s1.avi', 'p27_serkick_mask_s1.avi', 'p31_serkick_mask_s2.avi', 'p15_serkick_mask_s3.avi', 'p2_serkick_mask_s1.avi', 'p42_serkick_mask_s3.avi', 'p35_serkick_mask_s1.avi', 'p25_serkick_mask_s2.avi', 'p34_serkick_mask_s3.avi', 'p37_serkick_mask_s2.avi', 'p19_serkick_mask_s2.avi', 'p11_serkick_mask_s2.avi', 'p3_serkick_mask_s2.avi', 'p26_serkick_mask_s2.avi', 'p11_serkick_mask_s3.avi', 'p46_serkick_mask_s3.avi', 'p1_serkick_mask_s3.avi', 'p13_serkick_mask_s1.avi', 'p3_serkick_mask_s3.avi', 'p20_serkick_mask_s3.avi', 'p17_serkick_mask_s2.avi', 'p39_serkick_mask_s2.avi', 'p21_serkick_mask_s2.avi', 'p37_serkick_mask_s1.avi', 'p37_serkick_mask_s3.avi', 'p5_serkick_mask_s3.avi', 'p32_serkick_mask_s2.avi', 'p32_serkick_mask_s3.avi', 'p22_serkick_mask_s1.avi', 'p41_serkick_mask_s3.avi', 'p17_serkick_mask_s3.avi', 'p5_serkick_mask_s2.avi', 'p23_serkick_mask_s3.avi', 'p38_serkick_mask_s2.avi', 'p8_serkick_mask_s3.avi', 'p51_serkick_mask_s2.avi', 'p54_serkick_mask_s2.avi', 'p26_serkick_mask_s3.avi', 'p18_serkick_mask_s1.avi', 'p2_serkick_mask_s3.avi', 'p14_serkick_mask_s1.avi', 'p7_serkick_mask_s3.avi', 'p45_serkick_mask_s3.avi', 'p23_serkick_mask_s2.avi', 'p10_serkick_mask_s2.avi', 'p1_serkick_mask_s2.avi', 'p30_serkick_mask_s2.avi', 'p46_serkick_mask_s1.avi', 'p24_serkick_mask_s1.avi', 'p15_serkick_mask_s2.avi', 'p52_serkick_mask_s1.avi', 'p8_serkick_mask_s1.avi', 'p36_serkick_mask_s3.avi', 'p31_serkick_mask_s1.avi', 'p6_serkick_mask_s2.avi', 'p30_serkick_mask_s1.avi', 'p9_serkick_mask_s3.avi', 'p45_serkick_mask_s2.avi', 'p36_serkick_mask_s1.avi', 'p52_serkick_mask_s3.avi', 'p9_serkick_mask_s2.avi', 'p32_serkick_mask_s1.avi', 'p44_serkick_mask_s2.avi', 'p47_serkick_mask_s3.avi', 'p30_serkick_mask_s3.avi', 'p12_serkick_mask_s2.avi', 'p27_serkick_mask_s3.avi', 'p7_serkick_mask_s2.avi', 'p22_serkick_mask_s3.avi', 'p24_serkick_mask_s3.avi', 'p29_serkick_mask_s1.avi', 'p20_serkick_mask_s2.avi', 'p27_serkick_mask_s2.avi', 'p8_serkick_mask_s2.avi', 'p45_serkick_mask_s1.avi', 'p38_serkick_mask_s1.avi', 'p55_serkick_mask_s1.avi', 'p5_serkick_mask_s1.avi', 'p55_serkick_mask_s3.avi', 'p19_serkick_mask_s3.avi', 'p49_serkick_mask_s1.avi', 'p28_serkick_mask_s1.avi', 'p34_serkick_mask_s2.avi', 'p41_serkick_mask_s1.avi', 'p18_serkick_mask_s3.avi', 'p21_serkick_mask_s1.avi', 'p52_serkick_mask_s2.avi', 'p38_serkick_mask_s3.avi', 'p24_serkick_mask_s2.avi', 'p46_serkick_mask_s2.avi', 'p29_serkick_mask_s2.avi', 'p10_serkick_mask_s1.avi', 'p34_serkick_mask_s1.avi', 'p33_serkick_mask_s2.avi', 'p39_serkick_mask_s3.avi', 'p22_serkick_mask_s2.avi', 'p25_serkick_mask_s1.avi', 'p47_serkick_mask_s2.avi', 'p6_serkick_mask_s3.avi', 'p9_serkick_mask_s1.avi', 'p33_serkick_mask_s3.avi', 'p28_serkick_mask_s2.avi', 'p36_serkick_mask_s2.avi', 'p44_serkick_mask_s1.avi', 'p44_serkick_mask_s3.avi', 'p42_serkick_mask_s2.avi', 'p49_serkick_mask_s3.avi', 'p16_serkick_mask_s1.avi', 'p47_serkick_mask_s1.avi', 'p13_serkick_mask_s2.avi', 'p10_serkick_mask_s3.avi', 'p35_serkick_mask_s3.avi', 'p21_serkick_mask_s3.avi', 'p50_serkick_mask_s1.avi', 'p18_serkick_mask_s2.avi', 'p26_serkick_mask_s1.avi', 'p48_serkick_mask_s3.avi', 'p12_serkick_mask_s3.avi', 'p54_serkick_mask_s3.avi', 'p4_serkick_mask_s3.avi', 'p28_serkick_mask_s3 ...
# ----------------------------------------
# Root: data/VIDEO_Mask/forehand_flat
# Dirs: []
# Files: ['p9_foreflat_mask_s1.avi', 'p25_foreflat_mask_s1.avi', 'p29_foreflat_mask_s3.avi', 'p7_foreflat_mask_s3.avi', 'p41_foreflat_mask_s3.avi', 'p25_foreflat_mask_s2.avi', 'p39_foreflat_mask_s1.avi', 'p17_foreflat_mask_s1.avi', 'p13_foreflat_mask_s2.avi', 'p3_foreflat_mask_s1.avi', 'p15_foreflat_mask_s1.avi', 'p35_foreflat_mask_s3.avi', 'p43_foreflat_mask_s2.avi', 'p46_foreflat_mask_s3.avi', 'p16_foreflat_mask_s3.avi', 'p45_foreflat_mask_s1.avi', 'p45_foreflat_mask_s2.avi', 'p46_foreflat_mask_s2.avi', 'p1_foreflat_mask_s3.avi', 'p26_foreflat_mask_s3.avi', 'p30_foreflat_mask_s2.avi', 'p18_foreflat_mask_s1.avi', 'p31_foreflat_mask_s3.avi', 'p22_foreflat_mask_s1.avi', 'p44_foreflat_mask_s2.avi', 'p51_foreflat_mask_s2.avi', 'p37_foreflat_mask_s3.avi', 'p51_foreflat_mask_s1.avi', 'p3_foreflat_mask_s2.avi', 'p53_foreflat_mask_s3.avi', 'p22_foreflat_mask_s2.avi', 'p29_foreflat_mask_s2.avi', 'p14_foreflat_mask_s3.avi', 'p44_foreflat_mask_s1.avi', 'p54_foreflat_mask_s1.avi', 'p4_foreflat_mask_s1.avi', 'p13_foreflat_mask_s3.avi', 'p10_foreflat_mask_s2.avi', 'p28_foreflat_mask_s3.avi', 'p36_foreflat_mask_s1.avi', 'p35_foreflat_mask_s1.avi', 'p52_foreflat_mask_s2.avi', 'p26_foreflat_mask_s1.avi', 'p12_foreflat_mask_s2.avi', 'p20_foreflat_mask_s1.avi', 'p34_foreflat_mask_s3.avi', 'p32_foreflat_mask_s3.avi', 'p30_foreflat_mask_s1.avi', 'p24_foreflat_mask_s1.avi', 'p17_foreflat_mask_s3.avi', 'p35_foreflat_mask_s2.avi', 'p55_foreflat_mask_s1.avi', 'p11_foreflat_mask_s1.avi', 'p40_foreflat_mask_s1.avi', 'p31_foreflat_mask_s2.avi', 'p40_foreflat_mask_s3.avi', 'p21_foreflat_mask_s3.avi', 'p49_foreflat_mask_s2.avi', 'p33_foreflat_mask_s3.avi', 'p46_foreflat_mask_s1.avi', 'p20_foreflat_mask_s2.avi', 'p1_foreflat_mask_s1.avi', 'p36_foreflat_mask_s2.avi', 'p10_foreflat_mask_s3.avi', 'p31_foreflat_mask_s1.avi', 'p2_foreflat_mask_s1.avi', 'p23_foreflat_mask_s2.avi', 'p18_foreflat_mask_s3.avi', 'p51_foreflat_mask_s3.avi', 'p21_foreflat_mask_s1.avi', 'p33_foreflat_mask_s2.avi', 'p5_foreflat_mask_s3.avi', 'p44_foreflat_mask_s3.avi', 'p39_foreflat_mask_s3.avi', 'p37_foreflat_mask_s2.avi', 'p3_foreflat_mask_s3.avi', 'p52_foreflat_mask_s3.avi', 'p53_foreflat_mask_s1.avi', 'p55_foreflat_mask_s3.avi', 'p38_foreflat_mask_s3.avi', 'p48_foreflat_mask_s2.avi', 'p32_foreflat_mask_s2.avi', 'p19_foreflat_mask_s1.avi', 'p29_foreflat_mask_s1.avi', 'p24_foreflat_mask_s2.avi', 'p27_foreflat_mask_s1.avi', 'p38_foreflat_mask_s1.avi', 'p11_foreflat_mask_s3.avi', 'p55_foreflat_mask_s2.avi', 'p17_foreflat_mask_s2.avi', 'p8_foreflat_mask_s2.avi', 'p34_foreflat_mask_s1.avi', 'p50_foreflat_mask_s3.avi', 'p49_foreflat_mask_s1.avi', 'p4_foreflat_mask_s3.avi', 'p20_foreflat_mask_s3.avi', 'p43_foreflat_mask_s3.avi', 'p4_foreflat_mask_s2.avi', 'p14_foreflat_mask_s2.avi', 'p34_foreflat_mask_s2.avi', 'p18_foreflat_mask_s2.avi', 'p28_foreflat_mask_s1.avi', 'p12_foreflat_mask_s3.avi', 'p23_foreflat_mask_s1.avi', 'p49_foreflat_mask_s3.avi', 'p48_foreflat_mask_s1.avi', 'p27_foreflat_mask_s2.avi', 'p23_foreflat_mask_s3.avi', 'p38_foreflat_mask_s2.avi', 'p50_foreflat_mask_s2.avi', 'p37_foreflat_mask_s1.avi', 'p12_foreflat_mask_s1.avi', 'p26_foreflat_mask_s2.avi', 'p39_foreflat_mask_s2.avi', 'p52_foreflat_mask_s1.avi', 'p32_foreflat_mask_s1.avi', 'p2_foreflat_mask_s2.avi', 'p43_foreflat_mask_s1.avi', 'p16_foreflat_mask_s2.avi', 'p47_foreflat_mask_s3.avi', 'p45_foreflat_mask_s3.avi', 'p21_foreflat_mask_s2.avi', 'p15_foreflat_mask_s2.avi', 'p6_foreflat_mask_s2.avi', 'p19_foreflat_mask_s3.avi', 'p6_foreflat_mask_s3.avi', 'p13_foreflat_mask_s1.avi', 'p11_foreflat_mask_s2.avi', 'p41_foreflat_mask_s1.avi', 'p24_foreflat_mask_s3.avi', 'p27_foreflat_mask_s3.avi', 'p41_foreflat_mask_s2.avi', 'p30_foreflat_mask_s3.avi', 'p40_foreflat_mask_s2.avi', 'p47_foreflat_mask_s2.avi', 'p42_foreflat_mask_s3.avi', 'p53_foreflat_mask_s2.avi', 'p28_foreflat_mask_s2.avi', 'p2_foreflat_mask_s3.avi', 'p15_foreflat_mask_s3.avi', 'p7_foreflat_mask_s1.avi', 'p47_foreflat_mask_s1.avi', 'p54_foreflat_mask_s3.avi', 'p42_f ...
# ----------------------------------------
# Root: data/VIDEO_Mask/forehand_openstands
# Dirs: []
# Files: ['p27_foreopen_mask_s1.avi', 'p45_foreopen_mask_s3.avi', 'p9_foreopen_mask_s2.avi', 'p17_foreopen_mask_s2.avi', 'p37_foreopen_mask_s3.avi', 'p37_foreopen_mask_s2.avi', 'p46_foreopen_mask_s2.avi', 'p11_foreopen_mask_s1.avi', 'p13_foreopen_mask_s3.avi', 'p31_foreopen_mask_s2.avi', 'p24_foreopen_mask_s1.avi', 'p30_foreopen_mask_s3.avi', 'p55_foreopen_mask_s1.avi', 'p7_foreopen_mask_s2.avi', 'p54_foreopen_mask_s3.avi', 'p6_foreopen_mask_s3.avi', 'p2_foreopen_mask_s1.avi', 'p4_foreopen_mask_s1.avi', 'p5_foreopen_mask_s3.avi', 'p41_foreopen_mask_s3.avi', 'p39_foreopen_mask_s2.avi', 'p34_foreopen_mask_s3.avi', 'p11_foreopen_mask_s3.avi', 'p8_foreopen_mask_s1.avi', 'p14_foreopen_mask_s3.avi', 'p47_foreopen_mask_s3.avi', 'p3_foreopen_mask_s3.avi', 'p8_foreopen_mask_s2.avi', 'p1_foreopen_mask_s1.avi', 'p44_foreopen_mask_s2.avi', 'p9_foreopen_mask_s3.avi', 'p20_foreopen_mask_s1.avi', 'p32_foreopen_mask_s3.avi', 'p49_foreopen_mask_s3.avi', 'p22_foreopen_mask_s3.avi', 'p36_foreopen_mask_s2.avi', 'p45_foreopen_mask_s2.avi', 'p42_foreopen_mask_s1.avi', 'p5_foreopen_mask_s2.avi', 'p53_foreopen_mask_s2.avi', 'p27_foreopen_mask_s2.avi', 'p25_foreopen_mask_s1.avi', 'p51_foreopen_mask_s1.avi', 'p25_foreopen_mask_s3.avi', 'p45_foreopen_mask_s1.avi', 'p30_foreopen_mask_s1.avi', 'p12_foreopen_mask_s2.avi', 'p43_foreopen_mask_s1.avi', 'p42_foreopen_mask_s2.avi', 'p49_foreopen_mask_s1.avi', 'p50_foreopen_mask_s3.avi', 'p20_foreopen_mask_s3.avi', 'p33_foreopen_mask_s1.avi', 'p31_foreopen_mask_s3.avi', 'p53_foreopen_mask_s3.avi', 'p41_foreopen_mask_s2.avi', 'p54_foreopen_mask_s2.avi', 'p21_foreopen_mask_s3.avi', 'p19_foreopen_mask_s3.avi', 'p48_foreopen_mask_s2.avi', 'p14_foreopen_mask_s2.avi', 'p25_foreopen_mask_s2.avi', 'p33_foreopen_mask_s3.avi', 'p16_foreopen_mask_s3.avi', 'p42_foreopen_mask_s3.avi', 'p44_foreopen_mask_s1.avi', 'p10_foreopen_mask_s1.avi', 'p14_foreopen_mask_s1.avi', 'p36_foreopen_mask_s3.avi', 'p26_foreopen_mask_s3.avi', 'p49_foreopen_mask_s2.avi', 'p51_foreopen_mask_s3.avi', 'p22_foreopen_mask_s1.avi', 'p33_foreopen_mask_s2.avi', 'p53_foreopen_mask_s1.avi', 'p16_foreopen_mask_s2.avi', 'p23_foreopen_mask_s3.avi', 'p4_foreopen_mask_s3.avi', 'p6_foreopen_mask_s2.avi', 'p3_foreopen_mask_s2.avi', 'p43_foreopen_mask_s3.avi', 'p1_foreopen_mask_s3.avi', 'p1_foreopen_mask_s2.avi', 'p15_foreopen_mask_s3.avi', 'p32_foreopen_mask_s1.avi', 'p39_foreopen_mask_s1.avi', 'p40_foreopen_mask_s2.avi', 'p41_foreopen_mask_s1.avi', 'p26_foreopen_mask_s2.avi', 'p28_foreopen_mask_s3.avi', 'p2_foreopen_mask_s2.avi', 'p17_foreopen_mask_s3.avi', 'p47_foreopen_mask_s1.avi', 'p5_foreopen_mask_s1.avi', 'p55_foreopen_mask_s3.avi', 'p29_foreopen_mask_s1.avi', 'p44_foreopen_mask_s3.avi', 'p10_foreopen_mask_s2.avi', 'p4_foreopen_mask_s2.avi', 'p34_foreopen_mask_s1.avi', 'p20_foreopen_mask_s2.avi', 'p52_foreopen_mask_s1.avi', 'p39_foreopen_mask_s3.avi', 'p43_foreopen_mask_s2.avi', 'p10_foreopen_mask_s3.avi', 'p11_foreopen_mask_s2.avi', 'p47_foreopen_mask_s2.avi', 'p29_foreopen_mask_s3.avi', 'p19_foreopen_mask_s1.avi', 'p46_foreopen_mask_s3.avi', 'p8_foreopen_mask_s3.avi', 'p35_foreopen_mask_s1.avi', 'p55_foreopen_mask_s2.avi', 'p7_foreopen_mask_s3.avi', 'p27_foreopen_mask_s3.avi', 'p35_foreopen_mask_s3.avi', 'p40_foreopen_mask_s1.avi', 'p2_foreopen_mask_s3.avi', 'p29_foreopen_mask_s2.avi', 'p9_foreopen_mask_s1.avi', 'p19_foreopen_mask_s2.avi', 'p18_foreopen_mask_s3.avi', 'p12_foreopen_mask_s3.avi', 'p28_foreopen_mask_s1.avi', 'p37_foreopen_mask_s1.avi', 'p38_foreopen_mask_s3.avi', 'p23_foreopen_mask_s2.avi', 'p52_foreopen_mask_s2.avi', 'p50_foreopen_mask_s2.avi', 'p15_foreopen_mask_s1.avi', 'p6_foreopen_mask_s1.avi', 'p48_foreopen_mask_s1.avi', 'p16_foreopen_mask_s1.avi', 'p34_foreopen_mask_s2.avi', 'p3_foreopen_mask_s1.avi', 'p26_foreopen_mask_s1.avi', 'p36_foreopen_mask_s1.avi', 'p46_foreopen_mask_s1.avi', 'p30_foreopen_mask_s2.avi', 'p54_foreopen_mask_s1.avi', 'p13_foreopen_mask_s1.avi', 'p40_foreopen_mask_s3.avi', 'p23_foreopen_mask_s1.avi', 'p18_foreopen_ ...
# ----------------------------------------
# Root: data/VIDEO_Mask/slice_service
# Dirs: []
# Files: ['p33_serslice_mask_s1.avi', 'p2_serslice_mask_s2.avi', 'p39_serslice_mask_s1.avi', 'p46_serslice_mask_s3.avi', 'p48_serslice_mask_s2.avi', 'p36_serslice_mask_s1.avi', 'p38_serslice_mask_s1.avi', 'p42_serslice_mask_s1.avi', 'p12_serslice_mask_s2.avi', 'p5_serslice_mask_s1.avi', 'p49_serslice_mask_s2.avi', 'p42_serslice_mask_s2.avi', 'p3_serslice_mask_s2.avi', 'p23_serslice_mask_s3.avi', 'p45_serslice_mask_s1.avi', 'p7_serslice_mask_s1.avi', 'p20_serslice_mask_s3.avi', 'p2_serslice_mask_s1.avi', 'p6_serslice_mask_s3.avi', 'p10_serslice_mask_s3.avi', 'p54_serslice_mask_s3.avi', 'p54_serslice_mask_s2.avi', 'p43_serslice_mask_s3.avi', 'p31_serslice_mask_s3.avi', 'p29_serslice_mask_s2.avi', 'p13_serslice_mask_s1.avi', 'p20_serslice_mask_s2.avi', 'p47_serslice_mask_s2.avi', 'p15_serslice_mask_s1.avi', 'p30_serslice_mask_s1.avi', 'p24_serslice_mask_s2.avi', 'p11_serslice_mask_s2.avi', 'p35_serslice_mask_s3.avi', 'p12_serslice_mask_s3.avi', 'p42_serslice_mask_s3.avi', 'p11_serslice_mask_s3.avi', 'p25_serslice_mask_s3.avi', 'p27_serslice_mask_s1.avi', 'p5_serslice_mask_s3.avi', 'p41_serslice_mask_s3.avi', 'p53_serslice_mask_s1.avi', 'p33_serslice_mask_s2.avi', 'p26_serslice_mask_s1.avi', 'p24_serslice_mask_s1.avi', 'p7_serslice_mask_s3.avi', 'p11_serslice_mask_s1.avi', 'p15_serslice_mask_s2.avi', 'p8_serslice_mask_s1.avi', 'p8_serslice_mask_s3.avi', 'p17_serslice_mask_s2.avi', 'p41_serslice_mask_s2.avi', 'p47_serslice_mask_s1.avi', 'p45_serslice_mask_s3.avi', 'p46_serslice_mask_s1.avi', 'p37_serslice_mask_s2.avi', 'p38_serslice_mask_s2.avi', 'p32_serslice_mask_s2.avi', 'p1_serslice_mask_s3.avi', 'p10_serslice_mask_s2.avi', 'p23_serslice_mask_s2.avi', 'p43_serslice_mask_s1.avi', 'p37_serslice_mask_s3.avi', 'p48_serslice_mask_s3.avi', 'p55_serslice_mask_s1.avi', 'p40_serslice_mask_s3.avi', 'p3_serslice_mask_s1.avi', 'p40_serslice_mask_s2.avi', 'p44_serslice_mask_s3.avi', 'p13_serslice_mask_s2.avi', 'p28_serslice_mask_s3.avi', 'p39_serslice_mask_s2.avi', 'p26_serslice_mask_s2.avi', 'p22_serslice_mask_s2.avi', 'p34_serslice_mask_s1.avi', 'p23_serslice_mask_s1.avi', 'p53_serslice_mask_s2.avi', 'p39_serslice_mask_s3.avi', 'p4_serslice_mask_s3.avi', 'p49_serslice_mask_s3.avi', 'p9_serslice_mask_s2.avi', 'p24_serslice_mask_s3.avi', 'p50_serslice_mask_s3.avi', 'p30_serslice_mask_s3.avi', 'p48_serslice_mask_s1.avi', 'p33_serslice_mask_s3.avi', 'p26_serslice_mask_s3.avi', 'p51_serslice_mask_s3.avi', 'p15_serslice_mask_s3.avi', 'p16_serslice_mask_s1.avi', 'p46_serslice_mask_s2.avi', 'p35_serslice_mask_s1.avi', 'p27_serslice_mask_s2.avi', 'p16_serslice_mask_s2.avi', 'p6_serslice_mask_s2.avi', 'p16_serslice_mask_s3.avi', 'p52_serslice_mask_s3.avi', 'p19_serslice_mask_s2.avi', 'p4_serslice_mask_s1.avi', 'p19_serslice_mask_s3.avi', 'p14_serslice_mask_s1.avi', 'p35_serslice_mask_s2.avi', 'p21_serslice_mask_s1.avi', 'p25_serslice_mask_s1.avi', 'p7_serslice_mask_s2.avi', 'p5_serslice_mask_s2.avi', 'p32_serslice_mask_s3.avi', 'p53_serslice_mask_s3.avi', 'p51_serslice_mask_s1.avi', 'p34_serslice_mask_s3.avi', 'p50_serslice_mask_s2.avi', 'p1_serslice_mask_s2.avi', 'p36_serslice_mask_s2.avi', 'p28_serslice_mask_s1.avi', 'p34_serslice_mask_s2.avi', 'p22_serslice_mask_s3.avi', 'p31_serslice_mask_s1.avi', 'p44_serslice_mask_s1.avi', 'p4_serslice_mask_s2.avi', 'p50_serslice_mask_s1.avi', 'p37_serslice_mask_s1.avi', 'p17_serslice_mask_s3.avi', 'p51_serslice_mask_s2.avi', 'p19_serslice_mask_s1.avi', 'p29_serslice_mask_s1.avi', 'p17_serslice_mask_s1.avi', 'p31_serslice_mask_s2.avi', 'p25_serslice_mask_s2.avi', 'p27_serslice_mask_s3.avi', 'p47_serslice_mask_s3.avi', 'p9_serslice_mask_s3.avi', 'p13_serslice_mask_s3.avi', 'p20_serslice_mask_s1.avi', 'p14_serslice_mask_s3.avi', 'p21_serslice_mask_s3.avi', 'p41_serslice_mask_s1.avi', 'p28_serslice_mask_s2.avi', 'p40_serslice_mask_s1.avi', 'p43_serslice_mask_s2.avi', 'p3_serslice_mask_s3.avi', 'p21_serslice_mask_s2.avi', 'p29_serslice_mask_s3.avi', 'p55_serslice_mask_s3.avi', 'p36_serslice_mask_s3.avi', 'p52_sersl ...
# ----------------------------------------
# Root: data/VIDEO_Mask/forehand_volley
# Dirs: []
# Files: ['p30_fvolley_mask_s1.avi', 'p16_fvolley_mask_s2.avi', 'p37_fvolley_mask_s3.avi', 'p17_fvolley_mask_s2.avi', 'p51_fvolley_mask_s2.avi', 'p14_fvolley_mask_s1.avi', 'p11_fvolley_mask_s1.avi', 'p43_fvolley_mask_s3.avi', 'p20_fvolley_mask_s2.avi', 'p23_fvolley_mask_s3.avi', 'p21_fvolley_mask_s3.avi', 'p1_fvolley_mask_s2.avi', 'p4_fvolley_mask_s1.avi', 'p15_fvolley_mask_s2.avi', 'p46_fvolley_mask_s1.avi', 'p9_fvolley_mask_s2.avi', 'p22_fvolley_mask_s2.avi', 'p2_fvolley_mask_s1.avi', 'p18_fvolley_mask_s2.avi', 'p12_fvolley_mask_s1.avi', 'p17_fvolley_mask_s1.avi', 'p38_fvolley_mask_s2.avi', 'p53_fvolley_mask_s2.avi', 'p50_fvolley_mask_s1.avi', 'p28_fvolley_mask_s1.avi', 'p24_fvolley_mask_s1.avi', 'p44_fvolley_mask_s1.avi', 'p39_fvolley_mask_s1.avi', 'p16_fvolley_mask_s3.avi', 'p11_fvolley_mask_s3.avi', 'p25_fvolley_mask_s1.avi', 'p3_fvolley_mask_s2.avi', 'p10_fvolley_mask_s1.avi', 'p45_fvolley_mask_s1.avi', 'p14_fvolley_mask_s3.avi', 'p29_fvolley_mask_s3.avi', 'p48_fvolley_mask_s1.avi', 'p7_fvolley_mask_s1.avi', 'p19_fvolley_mask_s2.avi', 'p29_fvolley_mask_s1.avi', 'p43_fvolley_mask_s1.avi', 'p41_fvolley_mask_s2.avi', 'p8_fvolley_mask_s3.avi', 'p33_fvolley_mask_s2.avi', 'p13_fvolley_mask_s3.avi', 'p24_fvolley_mask_s3.avi', 'p47_fvolley_mask_s2.avi', 'p21_fvolley_mask_s1.avi', 'p31_fvolley_mask_s3.avi', 'p49_fvolley_mask_s3.avi', 'p46_fvolley_mask_s2.avi', 'p39_fvolley_mask_s3.avi', 'p18_fvolley_mask_s3.avi', 'p27_fvolley_mask_s3.avi', 'p38_fvolley_mask_s1.avi', 'p5_fvolley_mask_s1.avi', 'p42_fvolley_mask_s3.avi', 'p8_fvolley_mask_s2.avi', 'p45_fvolley_mask_s3.avi', 'p22_fvolley_mask_s1.avi', 'p43_fvolley_mask_s2.avi', 'p52_fvolley_mask_s1.avi', 'p2_fvolley_mask_s2.avi', 'p30_fvolley_mask_s2.avi', 'p33_fvolley_mask_s3.avi', 'p19_fvolley_mask_s1.avi', 'p1_fvolley_mask_s1.avi', 'p10_fvolley_mask_s2.avi', 'p20_fvolley_mask_s3.avi', 'p7_fvolley_mask_s2.avi', 'p9_fvolley_mask_s1.avi', 'p35_fvolley_mask_s3.avi', 'p34_fvolley_mask_s2.avi', 'p47_fvolley_mask_s3.avi', 'p36_fvolley_mask_s3.avi', 'p10_fvolley_mask_s3.avi', 'p27_fvolley_mask_s2.avi', 'p40_fvolley_mask_s2.avi', 'p26_fvolley_mask_s2.avi', 'p42_fvolley_mask_s2.avi', 'p26_fvolley_mask_s1.avi', 'p6_fvolley_mask_s1.avi', 'p5_fvolley_mask_s3.avi', 'p23_fvolley_mask_s1.avi', 'p22_fvolley_mask_s3.avi', 'p11_fvolley_mask_s2.avi', 'p38_fvolley_mask_s3.avi', 'p54_fvolley_mask_s2.avi', 'p41_fvolley_mask_s1.avi', 'p51_fvolley_mask_s1.avi', 'p30_fvolley_mask_s3.avi', 'p33_fvolley_mask_s1.avi', 'p44_fvolley_mask_s3.avi', 'p37_fvolley_mask_s2.avi', 'p25_fvolley_mask_s3.avi', 'p35_fvolley_mask_s2.avi', 'p53_fvolley_mask_s3.avi', 'p34_fvolley_mask_s3.avi', 'p32_fvolley_mask_s2.avi', 'p34_fvolley_mask_s1.avi', 'p32_fvolley_mask_s1.avi', 'p16_fvolley_mask_s1.avi', 'p21_fvolley_mask_s2.avi', 'p27_fvolley_mask_s1.avi', 'p12_fvolley_mask_s3.avi', 'p1_fvolley_mask_s3.avi', 'p46_fvolley_mask_s3.avi', 'p13_fvolley_mask_s1.avi', 'p55_fvolley_mask_s1.avi', 'p45_fvolley_mask_s2.avi', 'p55_fvolley_mask_s2.avi', 'p26_fvolley_mask_s3.avi', 'p4_fvolley_mask_s3.avi', 'p36_fvolley_mask_s1.avi', 'p37_fvolley_mask_s1.avi', 'p23_fvolley_mask_s2.avi', 'p54_fvolley_mask_s1.avi', 'p9_fvolley_mask_s3.avi', 'p28_fvolley_mask_s3.avi', 'p48_fvolley_mask_s3.avi', 'p48_fvolley_mask_s2.avi', 'p13_fvolley_mask_s2.avi', 'p54_fvolley_mask_s3.avi', 'p44_fvolley_mask_s2.avi', 'p2_fvolley_mask_s3.avi', 'p47_fvolley_mask_s1.avi', 'p7_fvolley_mask_s3.avi', 'p41_fvolley_mask_s3.avi', 'p24_fvolley_mask_s2.avi', 'p50_fvolley_mask_s2.avi', 'p31_fvolley_mask_s2.avi', 'p6_fvolley_mask_s3.avi', 'p53_fvolley_mask_s1.avi', 'p40_fvolley_mask_s3.avi', 'p18_fvolley_mask_s1.avi', 'p28_fvolley_mask_s2.avi', 'p12_fvolley_mask_s2.avi', 'p36_fvolley_mask_s2.avi', 'p25_fvolley_mask_s2.avi', 'p49_fvolley_mask_s2.avi', 'p55_fvolley_mask_s3.avi', 'p17_fvolley_mask_s3.avi', 'p3_fvolley_mask_s1.avi', 'p40_fvolley_mask_s1.avi', 'p15_fvolley_mask_s3.avi', 'p42_fvolley_mask_s1.avi', 'p6_fvolley_mask_s2.avi', 'p29_fvolley_mask_s2.avi', 'p52_fvolley_mask_s ...
# ----------------------------------------
# Root: data/VIDEO_Mask/backhand_slice
# Dirs: []
# Files: ['p23_bslice_mask_s3.avi', 'p55_bslice_mask_s3.avi', 'p9_bslice_mask_s1.avi', 'p3_bslice_mask_s1.avi', 'p45_bslice_mask_s1.avi', 'p51_bslice_mask_s1.avi', 'p23_bslice_mask_s2.avi', 'p36_bslice_mask_s1.avi', 'p19_bslice_mask_s1.avi', 'p46_bslice_mask_s3.avi', 'p55_bslice_mask_s2.avi', 'p43_bslice_mask_s1.avi', 'p38_bslice_mask_s1.avi', 'p32_bslice_mask_s3.avi', 'p13_bslice_mask_s3.avi', 'p54_bslice_mask_s3.avi', 'p37_bslice_mask_s2.avi', 'p35_bslice_mask_s2.avi', 'p47_bslice_mask_s3.avi', 'p48_bslice_mask_s3.avi', 'p10_bslice_mask_s3.avi', 'p35_bslice_mask_s1.avi', 'p40_bslice_mask_s2.avi', 'p42_bslice_mask_s2.avi', 'p34_bslice_mask_s2.avi', 'p35_bslice_mask_s3.avi', 'p39_bslice_mask_s1.avi', 'p38_bslice_mask_s3.avi', 'p25_bslice_mask_s3.avi', 'p17_bslice_mask_s1.avi', 'p12_bslice_mask_s2.avi', 'p31_bslice_mask_s2.avi', 'p43_bslice_mask_s3.avi', 'p47_bslice_mask_s2.avi', 'p22_bslice_mask_s3.avi', 'p44_bslice_mask_s1.avi', 'p28_bslice_mask_s1.avi', 'p22_bslice_mask_s2.avi', 'p43_bslice_mask_s2.avi', 'p37_bslice_mask_s3.avi', 'p9_bslice_mask_s3.avi', 'p30_bslice_mask_s1.avi', 'p42_bslice_mask_s1.avi', 'p7_bslice_mask_s3.avi', 'p44_bslice_mask_s3.avi', 'p7_bslice_mask_s1.avi', 'p36_bslice_mask_s3.avi', 'p46_bslice_mask_s1.avi', 'p33_bslice_mask_s2.avi', 'p39_bslice_mask_s2.avi', 'p2_bslice_mask_s1.avi', 'p32_bslice_mask_s2.avi', 'p18_bslice_mask_s3.avi', 'p20_bslice_mask_s3.avi', 'p10_bslice_mask_s2.avi', 'p11_bslice_mask_s1.avi', 'p15_bslice_mask_s3.avi', 'p5_bslice_mask_s2.avi', 'p14_bslice_mask_s1.avi', 'p41_bslice_mask_s3.avi', 'p53_bslice_mask_s1.avi', 'p32_bslice_mask_s1.avi', 'p21_bslice_mask_s2.avi', 'p9_bslice_mask_s2.avi', 'p1_bslice_mask_s1.avi', 'p49_bslice_mask_s3.avi', 'p15_bslice_mask_s2.avi', 'p49_bslice_mask_s2.avi', 'p54_bslice_mask_s1.avi', 'p27_bslice_mask_s1.avi', 'p17_bslice_mask_s2.avi', 'p30_bslice_mask_s2.avi', 'p7_bslice_mask_s2.avi', 'p11_bslice_mask_s3.avi', 'p10_bslice_mask_s1.avi', 'p8_bslice_mask_s3.avi', 'p44_bslice_mask_s2.avi', 'p19_bslice_mask_s3.avi', 'p6_bslice_mask_s2.avi', 'p34_bslice_mask_s1.avi', 'p19_bslice_mask_s2.avi', 'p31_bslice_mask_s1.avi', 'p39_bslice_mask_s3.avi', 'p1_bslice_mask_s3.avi', 'p8_bslice_mask_s1.avi', 'p24_bslice_mask_s3.avi', 'p45_bslice_mask_s2.avi', 'p4_bslice_mask_s1.avi', 'p28_bslice_mask_s2.avi', 'p16_bslice_mask_s1.avi', 'p41_bslice_mask_s2.avi', 'p42_bslice_mask_s3.avi', 'p1_bslice_mask_s2.avi', 'p24_bslice_mask_s2.avi', 'p27_bslice_mask_s2.avi', 'p17_bslice_mask_s3.avi', 'p37_bslice_mask_s1.avi', 'p6_bslice_mask_s3.avi', 'p26_bslice_mask_s2.avi', 'p6_bslice_mask_s1.avi', 'p49_bslice_mask_s1.avi', 'p21_bslice_mask_s1.avi', 'p29_bslice_mask_s3.avi', 'p24_bslice_mask_s1.avi', 'p13_bslice_mask_s1.avi', 'p20_bslice_mask_s1.avi', 'p54_bslice_mask_s2.avi', 'p36_bslice_mask_s2.avi', 'p4_bslice_mask_s3.avi', 'p52_bslice_mask_s3.avi', 'p46_bslice_mask_s2.avi', 'p15_bslice_mask_s1.avi', 'p25_bslice_mask_s2.avi', 'p12_bslice_mask_s1.avi', 'p51_bslice_mask_s3.avi', 'p14_bslice_mask_s2.avi', 'p34_bslice_mask_s3.avi', 'p38_bslice_mask_s2.avi', 'p40_bslice_mask_s3.avi', 'p2_bslice_mask_s2.avi', 'p29_bslice_mask_s1.avi', 'p18_bslice_mask_s2.avi', 'p13_bslice_mask_s2.avi', 'p50_bslice_mask_s1.avi', 'p5_bslice_mask_s3.avi', 'p53_bslice_mask_s3.avi', 'p5_bslice_mask_s1.avi', 'p52_bslice_mask_s1.avi', 'p8_bslice_mask_s2.avi', 'p16_bslice_mask_s3.avi', 'p48_bslice_mask_s1.avi', 'p31_bslice_mask_s3.avi', 'p30_bslice_mask_s3.avi', 'p16_bslice_mask_s2.avi', 'p28_bslice_mask_s3.avi', 'p51_bslice_mask_s2.avi', 'p33_bslice_mask_s3.avi', 'p4_bslice_mask_s2.avi', 'p12_bslice_mask_s3.avi', 'p26_bslice_mask_s3.avi', 'p20_bslice_mask_s2.avi', 'p11_bslice_mask_s2.avi', 'p14_bslice_mask_s3.avi', 'p55_bslice_mask_s1.avi', 'p26_bslice_mask_s1.avi', 'p23_bslice_mask_s1.avi', 'p18_bslice_mask_s1.avi', 'p45_bslice_mask_s3.avi', 'p41_bslice_mask_s1.avi', 'p3_bslice_mask_s3.avi', 'p47_bslice_mask_s1.avi', 'p50_bslice_mask_s3.avi', 'p40_bslice_mask_s1.avi', 'p52_bslice_mask_s2.avi', 'p53_bslice_m ...
# ----------------------------------------
# Root: data/VIDEO_Mask/flat_service
# Dirs: []
# Files: ['p2_serflat_mask_s2.avi', 'p44_serflat_mask_s3.avi', 'p32_serflat_mask_s2.avi', 'p46_serflat_mask_s2.avi', 'p18_serflat_mask_s3.avi', 'p29_serflat_mask_s1.avi', 'p34_serflat_mask_s2.avi', 'p22_serflat_mask_s2.avi', 'p13_serflat_mask_s2.avi', 'p23_serflat_mask_s2.avi', 'p38_serflat_mask_s3.avi', 'p35_serflat_mask_s2.avi', 'p54_serflat_mask_s2.avi', 'p43_serflat_mask_s3.avi', 'p1_serflat_mask_s2.avi', 'p7_serflat_mask_s1.avi', 'p40_serflat_mask_s1.avi', 'p6_serflat_mask_s3.avi', 'p2_serflat_mask_s3.avi', 'p39_serflat_mask_s2.avi', 'p49_serflat_mask_s3.avi', 'p19_serflat_mask_s1.avi', 'p8_serflat_mask_s3.avi', 'p11_serflat_mask_s1.avi', 'p33_serflat_mask_s1.avi', 'p35_serflat_mask_s3.avi', 'p9_serflat_mask_s2.avi', 'p8_serflat_mask_s2.avi', 'p36_serflat_mask_s2.avi', 'p45_serflat_mask_s2.avi', 'p20_serflat_mask_s1.avi', 'p10_serflat_mask_s3.avi', 'p45_serflat_mask_s1.avi', 'p5_serflat_mask_s2.avi', 'p2_serflat_mask_s1.avi', 'p20_serflat_mask_s2.avi', 'p21_serflat_mask_s2.avi', 'p11_serflat_mask_s3.avi', 'p26_serflat_mask_s3.avi', 'p4_serflat_mask_s1.avi', 'p6_serflat_mask_s2.avi', 'p38_serflat_mask_s2.avi', 'p14_serflat_mask_s3.avi', 'p34_serflat_mask_s3.avi', 'p16_serflat_mask_s1.avi', 'p49_serflat_mask_s2.avi', 'p18_serflat_mask_s1.avi', 'p52_serflat_mask_s2.avi', 'p51_serflat_mask_s1.avi', 'p42_serflat_mask_s1.avi', 'p55_serflat_mask_s2.avi', 'p50_serflat_mask_s3.avi', 'p19_serflat_mask_s3.avi', 'p25_serflat_mask_s2.avi', 'p29_serflat_mask_s3.avi', 'p17_serflat_mask_s2.avi', 'p27_serflat_mask_s3.avi', 'p36_serflat_mask_s3.avi', 'p11_serflat_mask_s2.avi', 'p22_serflat_mask_s3.avi', 'p54_serflat_mask_s3.avi', 'p28_serflat_mask_s2.avi', 'p53_serflat_mask_s1.avi', 'p43_serflat_mask_s2.avi', 'p44_serflat_mask_s2.avi', 'p33_serflat_mask_s3.avi', 'p45_serflat_mask_s3.avi', 'p44_serflat_mask_s1.avi', 'p32_serflat_mask_s1.avi', 'p14_serflat_mask_s1.avi', 'p3_serflat_mask_s3.avi', 'p25_serflat_mask_s3.avi', 'p3_serflat_mask_s2.avi', 'p47_serflat_mask_s3.avi', 'p37_serflat_mask_s1.avi', 'p27_serflat_mask_s1.avi', 'p51_serflat_mask_s3.avi', 'p30_serflat_mask_s3.avi', 'p15_serflat_mask_s2.avi', 'p32_serflat_mask_s3.avi', 'p5_serflat_mask_s1.avi', 'p30_serflat_mask_s2.avi', 'p24_serflat_mask_s1.avi', 'p26_serflat_mask_s2.avi', 'p17_serflat_mask_s3.avi', 'p1_serflat_mask_s1.avi', 'p48_serflat_mask_s1.avi', 'p55_serflat_mask_s1.avi', 'p8_serflat_mask_s1.avi', 'p42_serflat_mask_s2.avi', 'p28_serflat_mask_s1.avi', 'p18_serflat_mask_s2.avi', 'p48_serflat_mask_s3.avi', 'p36_serflat_mask_s1.avi', 'p41_serflat_mask_s3.avi', 'p49_serflat_mask_s1.avi', 'p23_serflat_mask_s3.avi', 'p3_serflat_mask_s1.avi', 'p39_serflat_mask_s1.avi', 'p1_serflat_mask_s3.avi', 'p43_serflat_mask_s1.avi', 'p46_serflat_mask_s3.avi', 'p31_serflat_mask_s3.avi', 'p14_serflat_mask_s2.avi', 'p7_serflat_mask_s2.avi', 'p22_serflat_mask_s1.avi', 'p6_serflat_mask_s1.avi', 'p10_serflat_mask_s1.avi', 'p31_serflat_mask_s1.avi', 'p4_serflat_mask_s2.avi', 'p50_serflat_mask_s2.avi', 'p41_serflat_mask_s1.avi', 'p37_serflat_mask_s3.avi', 'p12_serflat_mask_s1.avi', 'p23_serflat_mask_s1.avi', 'p15_serflat_mask_s3.avi', 'p9_serflat_mask_s3.avi', 'p12_serflat_mask_s2.avi', 'p50_serflat_mask_s1.avi', 'p26_serflat_mask_s1.avi', 'p55_serflat_mask_s3.avi', 'p40_serflat_mask_s2.avi', 'p16_serflat_mask_s2.avi', 'p46_serflat_mask_s1.avi', 'p13_serflat_mask_s1.avi', 'p28_serflat_mask_s3.avi', 'p31_serflat_mask_s2.avi', 'p39_serflat_mask_s3.avi', 'p35_serflat_mask_s1.avi', 'p21_serflat_mask_s3.avi', 'p33_serflat_mask_s2.avi', 'p41_serflat_mask_s2.avi', 'p47_serflat_mask_s1.avi', 'p5_serflat_mask_s3.avi', 'p40_serflat_mask_s3.avi', 'p21_serflat_mask_s1.avi', 'p54_serflat_mask_s1.avi', 'p52_serflat_mask_s3.avi', 'p17_serflat_mask_s1.avi', 'p25_serflat_mask_s1.avi', 'p12_serflat_mask_s3.avi', 'p16_serflat_mask_s3.avi', 'p38_serflat_mask_s1.avi', 'p4_serflat_mask_s3.avi', 'p7_serflat_mask_s3.avi', 'p24_serflat_mask_s2.avi', 'p27_serflat_mask_s2.avi', 'p51_serflat_mask_s2.avi', 'p47_serflat_mask_s2.a ...
# ----------------------------------------
# Root: data/VIDEO_Mask/smash
# Dirs: []
# Files: ['p21_smash_mask_s3.avi', 'p28_smash_mask_s1.avi', 'p14_smash_mask_s3.avi', 'p1_smash_mask_s2.avi', 'p23_smash_mask_s2.avi', 'p3_smash_mask_s3.avi', 'p8_smash_mask_s3.avi', 'p12_smash_mask_s2.avi', 'p52_smash_mask_s2.avi', 'p42_smash_mask_s3.avi', 'p49_smash_mask_s1.avi', 'p12_smash_mask_s1.avi', 'p47_smash_mask_s2.avi', 'p22_smash_mask_s1.avi', 'p37_smash_mask_s3.avi', 'p38_smash_mask_s2.avi', 'p9_smash_mask_s3.avi', 'p47_smash_mask_s1.avi', 'p55_smash_mask_s2.avi', 'p27_smash_mask_s3.avi', 'p35_smash_mask_s3.avi', 'p32_smash_mask_s2.avi', 'p3_smash_mask_s1.avi', 'p26_smash_mask_s3.avi', 'p53_smash_mask_s1.avi', 'p45_smash_mask_s1.avi', 'p30_smash_mask_s3.avi', 'p31_smash_mask_s2.avi', 'p6_smash_mask_s1.avi', 'p6_smash_mask_s3.avi', 'p22_smash_mask_s2.avi', 'p50_smash_mask_s2.avi', 'p17_smash_mask_s2.avi', 'p45_smash_mask_s3.avi', 'p36_smash_mask_s2.avi', 'p43_smash_mask_s1.avi', 'p36_smash_mask_s3.avi', 'p5_smash_mask_s1.avi', 'p41_smash_mask_s2.avi', 'p10_smash_mask_s1.avi', 'p54_smash_mask_s3.avi', 'p53_smash_mask_s3.avi', 'p50_smash_mask_s1.avi', 'p12_smash_mask_s3.avi', 'p2_smash_mask_s1.avi', 'p17_smash_mask_s3.avi', 'p4_smash_mask_s1.avi', 'p22_smash_mask_s3.avi', 'p27_smash_mask_s1.avi', 'p51_smash_mask_s2.avi', 'p24_smash_mask_s2.avi', 'p48_smash_mask_s3.avi', 'p42_smash_mask_s2.avi', 'p45_smash_mask_s2.avi', 'p21_smash_mask_s2.avi', 'p50_smash_mask_s3.avi', 'p31_smash_mask_s1.avi', 'p17_smash_mask_s1.avi', 'p43_smash_mask_s3.avi', 'p35_smash_mask_s1.avi', 'p2_smash_mask_s2.avi', 'p39_smash_mask_s1.avi', 'p25_smash_mask_s3.avi', 'p11_smash_mask_s1.avi', 'p48_smash_mask_s2.avi', 'p25_smash_mask_s1.avi', 'p40_smash_mask_s3.avi', 'p43_smash_mask_s2.avi', 'p33_smash_mask_s2.avi', 'p2_smash_mask_s3.avi', 'p9_smash_mask_s2.avi', 'p30_smash_mask_s2.avi', 'p37_smash_mask_s1.avi', 'p8_smash_mask_s2.avi', 'p19_smash_mask_s1.avi', 'p16_smash_mask_s3.avi', 'p34_smash_mask_s1.avi', 'p30_smash_mask_s1.avi', 'p26_smash_mask_s2.avi', 'p18_smash_mask_s2.avi', 'p24_smash_mask_s3.avi', 'p18_smash_mask_s3.avi', 'p15_smash_mask_s2.avi', 'p13_smash_mask_s3.avi', 'p55_smash_mask_s3.avi', 'p28_smash_mask_s2.avi', 'p29_smash_mask_s3.avi', 'p7_smash_mask_s3.avi', 'p10_smash_mask_s2.avi', 'p53_smash_mask_s2.avi', 'p41_smash_mask_s1.avi', 'p27_smash_mask_s2.avi', 'p23_smash_mask_s3.avi', 'p33_smash_mask_s1.avi', 'p46_smash_mask_s1.avi', 'p26_smash_mask_s1.avi', 'p14_smash_mask_s1.avi', 'p35_smash_mask_s2.avi', 'p5_smash_mask_s2.avi', 'p19_smash_mask_s3.avi', 'p33_smash_mask_s3.avi', 'p39_smash_mask_s3.avi', 'p49_smash_mask_s3.avi', 'p54_smash_mask_s2.avi', 'p3_smash_mask_s2.avi', 'p5_smash_mask_s3.avi', 'p52_smash_mask_s1.avi', 'p51_smash_mask_s3.avi', 'p42_smash_mask_s1.avi', 'p34_smash_mask_s2.avi', 'p21_smash_mask_s1.avi', 'p7_smash_mask_s2.avi', 'p13_smash_mask_s2.avi', 'p1_smash_mask_s3.avi', 'p7_smash_mask_s1.avi', 'p23_smash_mask_s1.avi', 'p20_smash_mask_s3.avi', 'p1_smash_mask_s1.avi', 'p29_smash_mask_s1.avi', 'p14_smash_mask_s2.avi', 'p16_smash_mask_s2.avi', 'p34_smash_mask_s3.avi', 'p38_smash_mask_s3.avi', 'p46_smash_mask_s2.avi', 'p55_smash_mask_s1.avi', 'p52_smash_mask_s3.avi', 'p10_smash_mask_s3.avi', 'p37_smash_mask_s2.avi', 'p39_smash_mask_s2.avi', 'p54_smash_mask_s1.avi', 'p36_smash_mask_s1.avi', 'p15_smash_mask_s1.avi', 'p4_smash_mask_s2.avi', 'p20_smash_mask_s2.avi', 'p19_smash_mask_s2.avi', 'p46_smash_mask_s3.avi', 'p40_smash_mask_s1.avi', 'p44_smash_mask_s3.avi', 'p49_smash_mask_s2.avi', 'p6_smash_mask_s2.avi', 'p24_smash_mask_s1.avi', 'p51_smash_mask_s1.avi', 'p16_smash_mask_s1.avi', 'p44_smash_mask_s1.avi', 'p15_smash_mask_s3.avi', 'p11_smash_mask_s2.avi', 'p32_smash_mask_s3.avi', 'p9_smash_mask_s1.avi', 'p47_smash_mask_s3.avi', 'p32_smash_mask_s1.avi', 'p25_smash_mask_s2.avi', 'p11_smash_mask_s3.avi', 'p13_smash_mask_s1.avi', 'p29_smash_mask_s2.avi', 'p44_smash_mask_s2.avi', 'p31_smash_mask_s3.avi', 'p18_smash_mask_s1.avi', 'p28_smash_mask_s3.avi', 'p20_smash_mask_s1.avi', 'p8_smash_mask_s1.avi', 'p38_smash_mask_s1 ...
# ----------------------------------------
# Root: data/VIDEO_Mask/backhand2hands
# Dirs: []
# Files: ['p6_backhand2h_mask_s3.avi', 'p42_backhand2h_mask_s1.avi', 'p55_backhand2h_mask_s1.avi', 'p48_backhand2h_mask_s3.avi', 'p1_backhand2h_mask_s3.avi', 'p11_backhand2h_mask_s2.avi', 'p40_backhand2h_mask_s2.avi', 'p49_backhand2h_mask_s3.avi', 'p25_backhand2h_mask_s3.avi', 'p7_backhand2h_mask_s3.avi', 'p55_backhand2h_mask_s2.avi', 'p32_backhand2h_mask_s2.avi', 'p39_backhand2h_mask_s1.avi', 'p1_backhand2h_mask_s2.avi', 'p45_backhand2h_mask_s1.avi', 'p4_backhand2h_mask_s2.avi', 'p43_backhand2h_mask_s2.avi', 'p34_backhand2h_mask_s1.avi', 'p45_backhand2h_mask_s2.avi', 'p27_backhand2h_mask_s2.avi', 'p14_backhand2h_mask_s1.avi', 'p41_backhand2h_mask_s3.avi', 'p15_backhand2h_mask_s3.avi', 'p41_backhand2h_mask_s2.avi', 'p41_backhand2h_mask_s1.avi', 'p13_backhand2h_mask_s2.avi', 'p40_backhand2h_mask_s1.avi', 'p36_backhand2h_mask_s2.avi', 'p13_backhand2h_mask_s1.avi', 'p7_backhand2h_mask_s2.avi', 'p9_backhand2h_mask_s1.avi', 'p35_backhand2h_mask_s3.avi', 'p5_backhand2h_mask_s1.avi', 'p14_backhand2h_mask_s3.avi', 'p11_backhand2h_mask_s3.avi', 'p23_backhand2h_mask_s3.avi', 'p2_backhand2h_mask_s3.avi', 'p54_backhand2h_mask_s1.avi', 'p19_backhand2h_mask_s1.avi', 'p1_backhand2h_mask_s1.avi', 'p14_backhand2h_mask_s2.avi', 'p19_backhand2h_mask_s3.avi', 'p53_backhand2h_mask_s3.avi', 'p52_backhand2h_mask_s1.avi', 'p29_backhand2h_mask_s2.avi', 'p39_backhand2h_mask_s3.avi', 'p43_backhand2h_mask_s3.avi', 'p11_backhand2h_mask_s1.avi', 'p49_backhand2h_mask_s1.avi', 'p31_backhand2h_mask_s1.avi', 'p13_backhand2h_mask_s3.avi', 'p23_backhand2h_mask_s1.avi', 'p28_backhand2h_mask_s3.avi', 'p29_backhand2h_mask_s3.avi', 'p3_backhand2h_mask_s3.avi', 'p17_backhand2h_mask_s2.avi', 'p36_backhand2h_mask_s3.avi', 'p22_backhand2h_mask_s2.avi', 'p32_backhand2h_mask_s3.avi', 'p15_backhand2h_mask_s2.avi', 'p24_backhand2h_mask_s2.avi', 'p4_backhand2h_mask_s3.avi', 'p34_backhand2h_mask_s3.avi', 'p37_backhand2h_mask_s1.avi', 'p3_backhand2h_mask_s1.avi', 'p25_backhand2h_mask_s1.avi', 'p12_backhand2h_mask_s3.avi', 'p27_backhand2h_mask_s3.avi', 'p47_backhand2h_mask_s1.avi', 'p42_backhand2h_mask_s3.avi', 'p10_backhand2h_mask_s1.avi', 'p20_backhand2h_mask_s2.avi', 'p34_backhand2h_mask_s2.avi', 'p20_backhand2h_mask_s1.avi', 'p27_backhand2h_mask_s1.avi', 'p21_backhand2h_mask_s3.avi', 'p24_backhand2h_mask_s3.avi', 'p16_backhand2h_mask_s1.avi', 'p5_backhand2h_mask_s2.avi', 'p44_backhand2h_mask_s2.avi', 'p10_backhand2h_mask_s2.avi', 'p12_backhand2h_mask_s2.avi', 'p46_backhand2h_mask_s2.avi', 'p33_backhand2h_mask_s3.avi', 'p38_backhand2h_mask_s3.avi', 'p25_backhand2h_mask_s2.avi', 'p49_backhand2h_mask_s2.avi', 'p26_backhand2h_mask_s2.avi', 'p45_backhand2h_mask_s3.avi', 'p50_backhand2h_mask_s2.avi', 'p17_backhand2h_mask_s1.avi', 'p8_backhand2h_mask_s1.avi', 'p16_backhand2h_mask_s2.avi', 'p48_backhand2h_mask_s1.avi', 'p44_backhand2h_mask_s3.avi', 'p52_backhand2h_mask_s3.avi', 'p54_backhand2h_mask_s3.avi', 'p50_backhand2h_mask_s1.avi', 'p55_backhand2h_mask_s3.avi', 'p40_backhand2h_mask_s3.avi', 'p18_backhand2h_mask_s2.avi', 'p5_backhand2h_mask_s3.avi', 'p31_backhand2h_mask_s3.avi', 'p21_backhand2h_mask_s2.avi', 'p24_backhand2h_mask_s1.avi', 'p51_backhand2h_mask_s1.avi', 'p6_backhand2h_mask_s2.avi', 'p18_backhand2h_mask_s1.avi', 'p36_backhand2h_mask_s1.avi', 'p12_backhand2h_mask_s1.avi', 'p50_backhand2h_mask_s3.avi', 'p30_backhand2h_mask_s2.avi', 'p22_backhand2h_mask_s3.avi', 'p53_backhand2h_mask_s2.avi', 'p35_backhand2h_mask_s1.avi', 'p20_backhand2h_mask_s3.avi', 'p52_backhand2h_mask_s2.avi', 'p21_backhand2h_mask_s1.avi', 'p44_backhand2h_mask_s1.avi', 'p38_backhand2h_mask_s2.avi', 'p22_backhand2h_mask_s1.avi', 'p6_backhand2h_mask_s1.avi', 'p10_backhand2h_mask_s3.avi', 'p43_backhand2h_mask_s1.avi', 'p30_backhand2h_mask_s1.avi', 'p28_backhand2h_mask_s1.avi', 'p17_backhand2h_mask_s3.avi', 'p37_backhand2h_mask_s3.avi', 'p15_backhand2h_mask_s1.avi', 'p42_backhand2h_mask_s2.avi', 'p46_backhand2h_mask_s1.avi', 'p33_backhand2h_mask_s1.avi', 'p23_backhand2h_mask_s2.avi', 'p53_backhand2h_mask ...
# ----------------------------------------
# Root: data/VIDEO_Mask/backhand
# Dirs: []
# Files: ['p16_backhand_mask_s3.avi', 'p14_backhand_mask_s2.avi', 'p3_backhand_mask_s1.avi', 'p49_backhand_mask_s3.avi', 'p8_backhand_mask_s3.avi', 'p14_backhand_mask_s1.avi', 'p24_backhand_mask_s1.avi', 'p6_backhand_mask_s3.avi', 'p38_backhand_mask_s3.avi', 'p19_backhand_mask_s1.avi', 'p27_backhand_mask_s3.avi', 'p53_backhand_mask_s1.avi', 'p19_backhand_mask_s3.avi', 'p51_backhand_mask_s1.avi', 'p32_backhand_mask_s1.avi', 'p28_backhand_mask_s1.avi', 'p17_backhand_mask_s2.avi', 'p52_backhand_mask_s1.avi', 'p36_backhand_mask_s3.avi', 'p51_backhand_mask_s2.avi', 'p42_backhand_mask_s2.avi', 'p55_backhand_mask_s2.avi', 'p28_backhand_mask_s2.avi', 'p8_backhand_mask_s1.avi', 'p11_backhand_mask_s2.avi', 'p51_backhand_mask_s3.avi', 'p37_backhand_mask_s2.avi', 'p4_backhand_mask_s1.avi', 'p20_backhand_mask_s2.avi', 'p16_backhand_mask_s1.avi', 'p7_backhand_mask_s3.avi', 'p22_backhand_mask_s2.avi', 'p37_backhand_mask_s3.avi', 'p5_backhand_mask_s3.avi', 'p48_backhand_mask_s3.avi', 'p46_backhand_mask_s2.avi', 'p31_backhand_mask_s1.avi', 'p13_backhand_mask_s1.avi', 'p28_backhand_mask_s3.avi', 'p34_backhand_mask_s3.avi', 'p9_backhand_mask_s2.avi', 'p2_backhand_mask_s2.avi', 'p9_backhand_mask_s3.avi', 'p5_backhand_mask_s1.avi', 'p21_backhand_mask_s2.avi', 'p32_backhand_mask_s2.avi', 'p26_backhand_mask_s2.avi', 'p1_backhand_mask_s3.avi', 'p20_backhand_mask_s1.avi', 'p12_backhand_mask_s2.avi', 'p24_backhand_mask_s3.avi', 'p54_backhand_mask_s2.avi', 'p40_backhand_mask_s2.avi', 'p36_backhand_mask_s1.avi', 'p11_backhand_mask_s3.avi', 'p2_backhand_mask_s3.avi', 'p55_backhand_mask_s3.avi', 'p34_backhand_mask_s1.avi', 'p15_backhand_mask_s2.avi', 'p25_backhand_mask_s2.avi', 'p46_backhand_mask_s1.avi', 'p50_backhand_mask_s2.avi', 'p29_backhand_mask_s3.avi', 'p24_backhand_mask_s2.avi', 'p45_backhand_mask_s3.avi', 'p22_backhand_mask_s3.avi', 'p43_backhand_mask_s2.avi', 'p52_backhand_mask_s3.avi', 'p53_backhand_mask_s2.avi', 'p52_backhand_mask_s2.avi', 'p27_backhand_mask_s2.avi', 'p54_backhand_mask_s3.avi', 'p6_backhand_mask_s2.avi', 'p38_backhand_mask_s1.avi', 'p26_backhand_mask_s3.avi', 'p39_backhand_mask_s2.avi', 'p12_backhand_mask_s1.avi', 'p7_backhand_mask_s2.avi', 'p11_backhand_mask_s1.avi', 'p25_backhand_mask_s3.avi', 'p41_backhand_mask_s2.avi', 'p10_backhand_mask_s3.avi', 'p18_backhand_mask_s3.avi', 'p17_backhand_mask_s3.avi', 'p3_backhand_mask_s2.avi', 'p41_backhand_mask_s3.avi', 'p32_backhand_mask_s3.avi', 'p29_backhand_mask_s2.avi', 'p22_backhand_mask_s1.avi', 'p44_backhand_mask_s3.avi', 'p38_backhand_mask_s2.avi', 'p48_backhand_mask_s2.avi', 'p10_backhand_mask_s1.avi', 'p18_backhand_mask_s1.avi', 'p42_backhand_mask_s1.avi', 'p31_backhand_mask_s2.avi', 'p30_backhand_mask_s2.avi', 'p47_backhand_mask_s1.avi', 'p43_backhand_mask_s1.avi', 'p26_backhand_mask_s1.avi', 'p16_backhand_mask_s2.avi', 'p34_backhand_mask_s2.avi', 'p39_backhand_mask_s1.avi', 'p31_backhand_mask_s3.avi', 'p25_backhand_mask_s1.avi', 'p23_backhand_mask_s1.avi', 'p47_backhand_mask_s3.avi', 'p3_backhand_mask_s3.avi', 'p15_backhand_mask_s1.avi', 'p10_backhand_mask_s2.avi', 'p45_backhand_mask_s1.avi', 'p45_backhand_mask_s2.avi', 'p9_backhand_mask_s1.avi', 'p6_backhand_mask_s1.avi', 'p33_backhand_mask_s2.avi', 'p35_backhand_mask_s1.avi', 'p35_backhand_mask_s2.avi', 'p40_backhand_mask_s1.avi', 'p5_backhand_mask_s2.avi', 'p40_backhand_mask_s3.avi', 'p21_backhand_mask_s1.avi', 'p30_backhand_mask_s1.avi', 'p49_backhand_mask_s2.avi', 'p14_backhand_mask_s3.avi', 'p23_backhand_mask_s2.avi', 'p17_backhand_mask_s1.avi', 'p35_backhand_mask_s3.avi', 'p42_backhand_mask_s3.avi', 'p23_backhand_mask_s3.avi', 'p20_backhand_mask_s3.avi', 'p19_backhand_mask_s2.avi', 'p39_backhand_mask_s3.avi', 'p12_backhand_mask_s3.avi', 'p41_backhand_mask_s1.avi', 'p44_backhand_mask_s2.avi', 'p30_backhand_mask_s3.avi', 'p33_backhand_mask_s1.avi', 'p1_backhand_mask_s1.avi', 'p7_backhand_mask_s1.avi', 'p46_backhand_mask_s3.avi', 'p37_backhand_mask_s1.avi', 'p18_backhand_mask_s2.avi', 'p50_backhand_mask_s3.avi', 'p43_backh ...
# ----------------------------------------
# Root: data/VIDEO_Mask/forehand_slice
# Dirs: []
# ...
# ----------------------------------------
# Root: data/VIDEO_RGB/smash
# Dirs: []
# Files: ['p51_smash_s3.avi', 'p35_smash_s2.avi', 'p34_smash_s2.avi', 'p10_smash_s1.avi', 'p15_smash_s2.avi', 'p40_smash_s3.avi', 'p47_smash_s1.avi', 'p14_smash_s1.avi', 'p36_smash_s3.avi', 'p21_smash_s1.avi', 'p16_smash_s3.avi', 'p52_smash_s2.avi', 'p11_smash_s2.avi', 'p50_smash_s1.avi', 'p48_smash_s3.avi', 'p23_smash_s3.avi', 'p49_smash_s3.avi', 'p25_smash_s3.avi', 'p32_smash_s3.avi', 'p11_smash_s1.avi', 'p42_smash_s2.avi', 'p43_smash_s2.avi', 'p24_smash_s2.avi', 'p12_smash_s1.avi', 'p14_smash_s2.avi', 'p23_smash_s2.avi', 'p30_smash_s2.avi', 'p6_smash_s2.avi', 'p13_smash_s1.avi', 'p47_smash_s3.avi', 'p45_smash_s1.avi', 'p51_smash_s2.avi', 'p26_smash_s1.avi', 'p54_smash_s2.avi', 'p18_smash_s3.avi', 'p12_smash_s2.avi', 'p51_smash_s1.avi', 'p17_smash_s1.avi', 'p31_smash_s2.avi', 'p28_smash_s2.avi', 'p48_smash_s2.avi', 'p11_smash_s3.avi', 'p29_smash_s2.avi', 'p25_smash_s1.avi', 'p31_smash_s1.avi', 'p15_smash_s3.avi', 'p1_smash_s1.avi', 'p34_smash_s3.avi', 'p19_smash_s2.avi', 'p54_smash_s1.avi', 'p8_smash_s2.avi', 'p29_smash_s1.avi', 'p18_smash_s1.avi', 'p1_smash_s3.avi', 'p9_smash_s2.avi', 'p26_smash_s3.avi', 'p53_smash_s1.avi', 'p42_smash_s1.avi', 'p16_smash_s2.avi', 'p20_smash_s2.avi', 'p22_smash_s3.avi', 'p25_smash_s2.avi', 'p33_smash_s3.avi', 'p53_smash_s3.avi', 'p10_smash_s3.avi', 'p29_smash_s3.avi', 'p6_smash_s1.avi', 'p39_smash_s2.avi', 'p54_smash_s3.avi', 'p7_smash_s1.avi', 'p4_smash_s1.avi', 'p3_smash_s1.avi', 'p37_smash_s2.avi', 'p26_smash_s2.avi', 'p43_smash_s3.avi', 'p49_smash_s2.avi', 'p14_smash_s3.avi', 'p30_smash_s3.avi', 'p15_smash_s1.avi', 'p19_smash_s1.avi', 'p1_smash_s2.avi', 'p16_smash_s1.avi', 'p7_smash_s2.avi', 'p9_smash_s1.avi', 'p36_smash_s1.avi', 'p22_smash_s2.avi', 'p40_smash_s1.avi', 'p28_smash_s3.avi', 'p39_smash_s1.avi', 'p38_smash_s1.avi', 'p38_smash_s2.avi', 'p38_smash_s3.avi', 'p27_smash_s1.avi', 'p7_smash_s3.avi', 'p55_smash_s1.avi', 'p18_smash_s2.avi', 'p17_smash_s3.avi', 'p3_smash_s2.avi', 'p4_smash_s2.avi', 'p55_smash_s3.avi', 'p5_smash_s2.avi', 'p27_smash_s3.avi', 'p8_smash_s3.avi', 'p24_smash_s1.avi', 'p48_smash_s1.avi', 'p2_smash_s2.avi', 'p44_smash_s3.avi', 'p22_smash_s1.avi', 'p23_smash_s1.avi', 'p19_smash_s3.avi', 'p3_smash_s3.avi', 'p6_smash_s3.avi', 'p37_smash_s3.avi', 'p44_smash_s2.avi', 'p4_smash_s3.avi', 'p21_smash_s3.avi', 'p41_smash_s1.avi', 'p35_smash_s1.avi', 'p34_smash_s1.avi', 'p55_smash_s2.avi', 'p31_smash_s3.avi', 'p36_smash_s2.avi', 'p49_smash_s1.avi', 'p32_smash_s1.avi', 'p45_smash_s3.avi', 'p9_smash_s3.avi', 'p35_smash_s3.avi', 'p13_smash_s3.avi', 'p42_smash_s3.avi', 'p32_smash_s2.avi', 'p13_smash_s2.avi', 'p30_smash_s1.avi', 'p2_smash_s3.avi', 'p37_smash_s1.avi', 'p2_smash_s1.avi', 'p10_smash_s2.avi', 'p50_smash_s2.avi', 'p24_smash_s3.avi', 'p46_smash_s2.avi', 'p28_smash_s1.avi', 'p33_smash_s1.avi', 'p41_smash_s3.avi', 'p20_smash_s1.avi', 'p46_smash_s1.avi', 'p17_smash_s2.avi', 'p8_smash_s1.avi', 'p53_smash_s2.avi', 'p12_smash_s3.avi', 'p50_smash_s3.avi', 'p20_smash_s3.avi', 'p5_smash_s1.avi', 'p44_smash_s1.avi', 'p41_smash_s2.avi', 'p45_smash_s2.avi', 'p46_smash_s3.avi', 'p40_smash_s2.avi', 'p43_smash_s1.avi', 'p27_smash_s2.avi', 'p39_smash_s3.avi', 'p21_smash_s2.avi', 'p52_smash_s3.avi', 'p5_smash_s3.avi', 'p47_smash_s2.avi', 'p33_smash_s2.avi', 'p52_smash_s1.avi']
# ----------------------------------------
# Root: data/VIDEO_RGB/backhand2hands
# Dirs: []
# Files: ['p17_backhand2h_s1.avi', 'p35_backhand2h_s1.avi', 'p54_backhand2h_s3.avi', 'p53_backhand2h_s1.avi', 'p1_backhand2h_s1.avi', 'p35_backhand2h_s2.avi', 'p6_backhand2h_s1.avi', 'p2_backhand2h_s2.avi', 'p29_backhand2h_s3.avi', 'p30_backhand2h_s2.avi', 'p22_backhand2h_s3.avi', 'p24_backhand2h_s1.avi', 'p41_backhand2h_s1.avi', 'p25_backhand2h_s2.avi', 'p52_backhand2h_s1.avi', 'p52_backhand2h_s2.avi', 'p36_backhand2h_s1.avi', 'p47_backhand2h_s2.avi', 'p4_backhand2h_s3.avi', 'p7_backhand2h_s2.avi', 'p36_backhand2h_s2.avi', 'p34_backhand2h_s3.avi', 'p12_backhand2h_s1.avi', 'p37_backhand2h_s2.avi', 'p18_backhand2h_s1.avi', 'p55_backhand2h_s3.avi', 'p21_backhand2h_s1.avi', 'p11_backhand2h_s3.avi', 'p30_backhand2h_s3.avi', 'p38_backhand2h_s2.avi', 'p14_backhand2h_s2.avi', 'p10_backhand2h_s2.avi', 'p33_backhand2h_s3.avi', 'p11_backhand2h_s1.avi', 'p13_backhand2h_s3.avi', 'p3_backhand2h_s2.avi', 'p25_backhand2h_s1.avi', 'p37_backhand2h_s3.avi', 'p29_backhand2h_s1.avi', 'p35_backhand2h_s3.avi', 'p20_backhand2h_s1.avi', 'p54_backhand2h_s2.avi', 'p41_backhand2h_s3.avi', 'p43_backhand2h_s1.avi', 'p16_backhand2h_s3.avi', 'p46_backhand2h_s1.avi', 'p51_backhand2h_s1.avi', 'p33_backhand2h_s1.avi', 'p28_backhand2h_s1.avi', 'p5_backhand2h_s2.avi', 'p19_backhand2h_s2.avi', 'p31_backhand2h_s3.avi', 'p27_backhand2h_s3.avi', 'p49_backhand2h_s1.avi', 'p41_backhand2h_s2.avi', 'p53_backhand2h_s3.avi', 'p27_backhand2h_s1.avi', 'p50_backhand2h_s3.avi', 'p32_backhand2h_s3.avi', 'p53_backhand2h_s2.avi', 'p20_backhand2h_s3.avi', 'p45_backhand2h_s1.avi', 'p38_backhand2h_s1.avi', 'p9_backhand2h_s2.avi', 'p24_backhand2h_s3.avi', 'p4_backhand2h_s2.avi', 'p7_backhand2h_s1.avi', 'p49_backhand2h_s3.avi', 'p51_backhand2h_s3.avi', 'p42_backhand2h_s2.avi', 'p31_backhand2h_s2.avi', 'p55_backhand2h_s2.avi', 'p50_backhand2h_s2.avi', 'p43_backhand2h_s2.avi', 'p18_backhand2h_s3.avi', 'p26_backhand2h_s2.avi', 'p10_backhand2h_s1.avi', 'p26_backhand2h_s3.avi', 'p37_backhand2h_s1.avi', 'p2_backhand2h_s3.avi', 'p15_backhand2h_s3.avi', 'p5_backhand2h_s3.avi', 'p13_backhand2h_s2.avi', 'p2_backhand2h_s1.avi', 'p6_backhand2h_s2.avi', 'p47_backhand2h_s1.avi', 'p44_backhand2h_s3.avi', 'p18_backhand2h_s2.avi', 'p22_backhand2h_s2.avi', 'p14_backhand2h_s1.avi', 'p9_backhand2h_s1.avi', 'p8_backhand2h_s3.avi', 'p21_backhand2h_s2.avi', 'p28_backhand2h_s2.avi', 'p12_backhand2h_s2.avi', 'p33_backhand2h_s2.avi', 'p42_backhand2h_s1.avi', 'p3_backhand2h_s1.avi', 'p49_backhand2h_s2.avi', 'p46_backhand2h_s3.avi', 'p52_backhand2h_s3.avi', 'p17_backhand2h_s2.avi', 'p50_backhand2h_s1.avi', 'p32_backhand2h_s1.avi', 'p3_backhand2h_s3.avi', 'p23_backhand2h_s2.avi', 'p14_backhand2h_s3.avi', 'p51_backhand2h_s2.avi', 'p45_backhand2h_s3.avi', 'p48_backhand2h_s1.avi', 'p22_backhand2h_s1.avi', 'p45_backhand2h_s2.avi', 'p1_backhand2h_s2.avi', 'p42_backhand2h_s3.avi', 'p26_backhand2h_s1.avi', 'p40_backhand2h_s2.avi', 'p13_backhand2h_s1.avi', 'p44_backhand2h_s2.avi', 'p15_backhand2h_s2.avi', 'p4_backhand2h_s1.avi', 'p34_backhand2h_s1.avi', 'p17_backhand2h_s3.avi', 'p46_backhand2h_s2.avi', 'p23_backhand2h_s1.avi', 'p24_backhand2h_s2.avi', 'p16_backhand2h_s2.avi', 'p27_backhand2h_s2.avi', 'p31_backhand2h_s1.avi', 'p15_backhand2h_s1.avi', 'p20_backhand2h_s2.avi', 'p48_backhand2h_s2.avi', 'p6_backhand2h_s3.avi', 'p30_backhand2h_s1.avi', 'p38_backhand2h_s3.avi', 'p25_backhand2h_s3.avi', 'p44_backhand2h_s1.avi', 'p10_backhand2h_s3.avi', 'p32_backhand2h_s2.avi', 'p47_backhand2h_s3.avi', 'p36_backhand2h_s3.avi', 'p21_backhand2h_s3.avi', 'p54_backhand2h_s1.avi', 'p12_backhand2h_s3.avi', 'p43_backhand2h_s3.avi', 'p39_backhand2h_s2.avi', 'p5_backhand2h_s1.avi', 'p11_backhand2h_s2.avi', 'p8_backhand2h_s1.avi', 'p9_backhand2h_s3.avi', 'p29_backhand2h_s2.avi', 'p1_backhand2h_s3.avi', 'p23_backhand2h_s3.avi', 'p34_backhand2h_s2.avi', 'p39_backhand2h_s1.avi', 'p7_backhand2h_s3.avi', 'p16_backhand2h_s1.avi', 'p39_backhand2h_s3.avi', 'p48_backhand2h_s3.avi', 'p19_backhand2h_s3.avi', 'p40_backhand2h_s3.avi', 'p40_backhand2h_s1 ...
# ----------------------------------------
# Root: data/VIDEO_RGB/backhand
# Dirs: []
# Files: ['p8_backhand_s1.avi', 'p29_backhand_s1.avi', 'p37_backhand_s3.avi', 'p41_backhand_s2.avi', 'p15_backhand_s1.avi', 'p20_backhand_s3.avi', 'p25_backhand_s3.avi', 'p4_backhand_s3.avi', 'p3_backhand_s3.avi', 'p27_backhand_s2.avi', 'p55_backhand_s1.avi', 'p22_backhand_s3.avi', 'p16_backhand_s2.avi', 'p10_backhand_s2.avi', 'p27_backhand_s3.avi', 'p19_backhand_s3.avi', 'p1_backhand_s3.avi', 'p34_backhand_s1.avi', 'p53_backhand_s3.avi', 'p29_backhand_s2.avi', 'p52_backhand_s3.avi', 'p50_backhand_s1.avi', 'p48_backhand_s1.avi', 'p7_backhand_s1.avi', 'p24_backhand_s1.avi', 'p33_backhand_s3.avi', 'p50_backhand_s3.avi', 'p46_backhand_s2.avi', 'p1_backhand_s2.avi', 'p39_backhand_s3.avi', 'p30_backhand_s3.avi', 'p1_backhand_s1.avi', 'p42_backhand_s2.avi', 'p5_backhand_s2.avi', 'p35_backhand_s2.avi', 'p18_backhand_s1.avi', 'p39_backhand_s1.avi', 'p12_backhand_s3.avi', 'p6_backhand_s3.avi', 'p54_backhand_s2.avi', 'p40_backhand_s3.avi', 'p38_backhand_s3.avi', 'p19_backhand_s2.avi', 'p3_backhand_s2.avi', 'p9_backhand_s1.avi', 'p6_backhand_s1.avi', 'p53_backhand_s1.avi', 'p21_backhand_s2.avi', 'p7_backhand_s3.avi', 'p46_backhand_s3.avi', 'p29_backhand_s3.avi', 'p14_backhand_s3.avi', 'p38_backhand_s2.avi', 'p32_backhand_s1.avi', 'p44_backhand_s2.avi', 'p26_backhand_s2.avi', 'p26_backhand_s1.avi', 'p31_backhand_s2.avi', 'p4_backhand_s2.avi', 'p45_backhand_s2.avi', 'p52_backhand_s1.avi', 'p50_backhand_s2.avi', 'p55_backhand_s2.avi', 'p51_backhand_s1.avi', 'p36_backhand_s1.avi', 'p31_backhand_s1.avi', 'p24_backhand_s3.avi', 'p11_backhand_s1.avi', 'p15_backhand_s3.avi', 'p22_backhand_s1.avi', 'p13_backhand_s3.avi', 'p44_backhand_s1.avi', 'p4_backhand_s1.avi', 'p15_backhand_s2.avi', 'p35_backhand_s1.avi', 'p24_backhand_s2.avi', 'p14_backhand_s2.avi', 'p32_backhand_s3.avi', 'p51_backhand_s3.avi', 'p32_backhand_s2.avi', 'p5_backhand_s3.avi', 'p25_backhand_s2.avi', 'p33_backhand_s2.avi', 'p30_backhand_s1.avi', 'p28_backhand_s1.avi', 'p9_backhand_s2.avi', 'p47_backhand_s2.avi', 'p47_backhand_s1.avi', 'p41_backhand_s1.avi', 'p35_backhand_s3.avi', 'p43_backhand_s2.avi', 'p6_backhand_s2.avi', 'p9_backhand_s3.avi', 'p8_backhand_s2.avi', 'p28_backhand_s3.avi', 'p5_backhand_s1.avi', 'p37_backhand_s1.avi', 'p51_backhand_s2.avi', 'p41_backhand_s3.avi', 'p21_backhand_s3.avi', 'p45_backhand_s1.avi', 'p16_backhand_s1.avi', 'p22_backhand_s2.avi', 'p49_backhand_s1.avi', 'p34_backhand_s2.avi', 'p36_backhand_s3.avi', 'p39_backhand_s2.avi', 'p2_backhand_s1.avi', 'p26_backhand_s3.avi', 'p53_backhand_s2.avi', 'p21_backhand_s1.avi', 'p10_backhand_s3.avi', 'p38_backhand_s1.avi', 'p17_backhand_s3.avi', 'p49_backhand_s3.avi', 'p49_backhand_s2.avi', 'p23_backhand_s3.avi', 'p19_backhand_s1.avi', 'p17_backhand_s2.avi', 'p52_backhand_s2.avi', 'p7_backhand_s2.avi', 'p54_backhand_s1.avi', 'p18_backhand_s2.avi', 'p47_backhand_s3.avi', 'p42_backhand_s1.avi', 'p2_backhand_s3.avi', 'p44_backhand_s3.avi', 'p34_backhand_s3.avi', 'p28_backhand_s2.avi', 'p25_backhand_s1.avi', 'p27_backhand_s1.avi', 'p40_backhand_s1.avi', 'p20_backhand_s2.avi', 'p48_backhand_s3.avi', 'p30_backhand_s2.avi', 'p20_backhand_s1.avi', 'p11_backhand_s2.avi', 'p2_backhand_s2.avi', 'p40_backhand_s2.avi', 'p11_backhand_s3.avi', 'p3_backhand_s1.avi', 'p45_backhand_s3.avi', 'p43_backhand_s3.avi', 'p13_backhand_s2.avi', 'p42_backhand_s3.avi', 'p54_backhand_s3.avi', 'p43_backhand_s1.avi', 'p13_backhand_s1.avi', 'p23_backhand_s2.avi', 'p14_backhand_s1.avi', 'p23_backhand_s1.avi', 'p55_backhand_s3.avi', 'p37_backhand_s2.avi', 'p36_backhand_s2.avi', 'p12_backhand_s2.avi', 'p18_backhand_s3.avi', 'p10_backhand_s1.avi', 'p31_backhand_s3.avi', 'p48_backhand_s2.avi', 'p8_backhand_s3.avi', 'p16_backhand_s3.avi', 'p17_backhand_s1.avi', 'p46_backhand_s1.avi', 'p33_backhand_s1.avi', 'p12_backhand_s1.avi']
# ----------------------------------------
# Root: data/VIDEO_RGB/forehand_slice
# Dirs: []
# Files: ['p43_fslice_s3.avi', 'p22_fslice_s3.avi', 'p12_fslice_s2.avi', 'p10_fslice_s3.avi', 'p5_fslice_s1.avi', 'p49_fslice_s1.avi', 'p39_fslice_s2.avi', 'p22_fslice_s2.avi', 'p37_fslice_s3.avi', 'p20_fslice_s2.avi', 'p51_fslice_s1.avi', 'p46_fslice_s1.avi', 'p19_fslice_s3.avi', 'p50_fslice_s3.avi', 'p17_fslice_s1.avi', 'p54_fslice_s3.avi', 'p1_fslice_s1.avi', 'p40_fslice_s1.avi', 'p31_fslice_s2.avi', 'p21_fslice_s3.avi', 'p50_fslice_s2.avi', 'p36_fslice_s2.avi', 'p25_fslice_s3.avi', 'p42_fslice_s2.avi', 'p24_fslice_s3.avi', 'p25_fslice_s2.avi', 'p42_fslice_s1.avi', 'p41_fslice_s2.avi', 'p25_fslice_s1.avi', 'p21_fslice_s1.avi', 'p2_fslice_s3.avi', 'p3_fslice_s3.avi', 'p13_fslice_s3.avi', 'p9_fslice_s3.avi', 'p49_fslice_s3.avi', 'p7_fslice_s3.avi', 'p2_fslice_s2.avi', 'p9_fslice_s2.avi', 'p26_fslice_s1.avi', 'p28_fslice_s2.avi', 'p24_fslice_s1.avi', 'p27_fslice_s3.avi', 'p7_fslice_s1.avi', 'p22_fslice_s1.avi', 'p45_fslice_s1.avi', 'p4_fslice_s2.avi', 'p1_fslice_s3.avi', 'p27_fslice_s1.avi', 'p46_fslice_s2.avi', 'p32_fslice_s2.avi', 'p47_fslice_s2.avi', 'p18_fslice_s1.avi', 'p15_fslice_s3.avi', 'p44_fslice_s1.avi', 'p19_fslice_s2.avi', 'p50_fslice_s1.avi', 'p23_fslice_s1.avi', 'p24_fslice_s2.avi', 'p33_fslice_s1.avi', 'p12_fslice_s1.avi', 'p49_fslice_s2.avi', 'p16_fslice_s2.avi', 'p53_fslice_s2.avi', 'p4_fslice_s1.avi', 'p28_fslice_s1.avi', 'p21_fslice_s2.avi', 'p13_fslice_s2.avi', 'p54_fslice_s1.avi', 'p43_fslice_s1.avi', 'p35_fslice_s1.avi', 'p53_fslice_s3.avi', 'p1_fslice_s2.avi', 'p9_fslice_s1.avi', 'p33_fslice_s2.avi', 'p44_fslice_s2.avi', 'p18_fslice_s2.avi', 'p13_fslice_s1.avi', 'p4_fslice_s3.avi', 'p6_fslice_s2.avi', 'p55_fslice_s1.avi', 'p30_fslice_s1.avi', 'p14_fslice_s2.avi', 'p41_fslice_s3.avi', 'p16_fslice_s3.avi', 'p11_fslice_s1.avi', 'p29_fslice_s2.avi', 'p39_fslice_s3.avi', 'p6_fslice_s3.avi', 'p51_fslice_s2.avi', 'p39_fslice_s1.avi', 'p18_fslice_s3.avi', 'p2_fslice_s1.avi', 'p31_fslice_s3.avi', 'p55_fslice_s2.avi', 'p33_fslice_s3.avi', 'p26_fslice_s3.avi', 'p15_fslice_s1.avi', 'p34_fslice_s2.avi', 'p53_fslice_s1.avi', 'p38_fslice_s1.avi', 'p20_fslice_s3.avi', 'p32_fslice_s3.avi', 'p19_fslice_s1.avi', 'p11_fslice_s2.avi', 'p47_fslice_s3.avi', 'p3_fslice_s1.avi', 'p35_fslice_s3.avi', 'p12_fslice_s3.avi', 'p15_fslice_s2.avi', 'p3_fslice_s2.avi', 'p5_fslice_s3.avi', 'p45_fslice_s2.avi', 'p36_fslice_s3.avi', 'p35_fslice_s2.avi', 'p11_fslice_s3.avi', 'p52_fslice_s2.avi', 'p36_fslice_s1.avi', 'p51_fslice_s3.avi', 'p48_fslice_s2.avi', 'p48_fslice_s1.avi', 'p45_fslice_s3.avi', 'p8_fslice_s3.avi', 'p10_fslice_s1.avi', 'p29_fslice_s3.avi', 'p46_fslice_s3.avi', 'p30_fslice_s2.avi', 'p42_fslice_s3.avi', 'p31_fslice_s1.avi', 'p40_fslice_s3.avi', 'p40_fslice_s2.avi', 'p38_fslice_s3.avi', 'p8_fslice_s1.avi', 'p54_fslice_s2.avi', 'p30_fslice_s3.avi', 'p41_fslice_s1.avi', 'p44_fslice_s3.avi', 'p32_fslice_s1.avi', 'p37_fslice_s2.avi', 'p14_fslice_s1.avi', 'p52_fslice_s1.avi', 'p10_fslice_s2.avi', 'p6_fslice_s1.avi', 'p26_fslice_s2.avi', 'p38_fslice_s2.avi', 'p17_fslice_s2.avi', 'p17_fslice_s3.avi', 'p8_fslice_s2.avi', 'p52_fslice_s3.avi', 'p20_fslice_s1.avi', 'p34_fslice_s3.avi', 'p43_fslice_s2.avi', 'p48_fslice_s3.avi', 'p27_fslice_s2.avi', 'p47_fslice_s1.avi', 'p7_fslice_s2.avi', 'p5_fslice_s2.avi', 'p55_fslice_s3.avi', 'p28_fslice_s3.avi', 'p23_fslice_s2.avi', 'p23_fslice_s3.avi', 'p37_fslice_s1.avi', 'p16_fslice_s1.avi', 'p34_fslice_s1.avi', 'p29_fslice_s1.avi', 'p14_fslice_s3.avi']
# ----------------------------------------

# %%
def convert_video_to_npy(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        # Resize frames if needed (e.g., 224x224)
        frame = cv2.resize(frame, (224, 224))
        frames.append(frame)

    cap.release()

    # Convert list of frames into a numpy array
    frames_array = np.array(frames)
    return frames_array

def create_subfolders(pastas_dir, output_dir):

    for pastas_filename in os.listdir(pastas_dir):
        origem_path = os.path.join(pastas_dir, pastas_filename)

    # Verifica se é uma pasta (ignora arquivos)
        if os.path.isdir(origem_path):
            nova_pasta_path = os.path.join(output_dir, pastas_filename)
            os.makedirs(nova_pasta_path, exist_ok=True)
            #print(f"Criada pasta: {nova_pasta_path}")
        videos_dir = pastas_dir+'/'+pastas_filename
        folder_path = output_dir +'/'+pastas_filename

        for video_filename in os.listdir(videos_dir):
            #print(video_filename)
            if video_filename.endswith(".avi"):  # Process only .avi files

                video_path = os.path.join(videos_dir, video_filename)
                video_name = os.path.splitext(video_filename)[0]

                # Convert the video to numpy array
                frames_array = convert_video_to_npy(video_path)

                # Save the numpy array to a .npy file
                output_filename = os.path.join(folder_path, f"{video_name}.npy")
                np.save(output_filename, frames_array)
                #print(f"Saved {video_filename} as {output_filename}")



#####Não usa esta função
def process_videos_to_npy(pastas_dir, output_dir):
    for video_filename in os.listdir(pastas_dir):

        print(video_filename.endswith(".avi")== True)
        if video_filename.endswith(".avi"):  # Process only .avi files
            video_path = os.path.join(pastas_dir, video_filename)
            video_name = os.path.splitext(video_filename)[0]

            # Convert the video to numpy array
            frames_array = convert_video_to_npy(video_path)

            # Save the numpy array to a .npy file
            output_filename = os.path.join(output_dir, f"{video_name}.npy")
            np.save(output_filename, frames_array)
            #print(f"Saved {video_filename} as {output_filename}")


pastas_dir = 'data/VIDEO_Skelet3D'  # Directory with .avi videos
npy_dir = 'data/npy_videos'  # Directory to save .npy files
os.makedirs(npy_dir, exist_ok=True)
create_subfolders(pastas_dir, npy_dir)

# %%
# def extract_frames_from_npy(npy_file, num_frames=120):
#     # Load the numpy array (which contains all frames of the video)
#     frames = np.load(npy_file)

#     # Calculate indices to extract 120 evenly spaced frames
#     total_frames = frames.shape[0]
#     frame_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)

#     # Extract the frames
#     extracted_frames = frames[frame_indices]

#     return extracted_frames

def extract_frames_from_npy(npy_file, num_frames=120):
  frames = np.load(npy_file)
  total_frames = frames.shape[0]

  if total_frames < num_frames: #padding
      # Padding com o último frame
      pad_frames = np.repeat(frames[-1:], num_frames - total_frames, axis=0)
      frames = np.concatenate([frames, pad_frames], axis=0)
      #total_frames = frames.shape[0]

  elif total_frames > num_frames: #truncate
      # Random selection of frames
      frames = frames[:num_frames]

  return frames

def process_npy_videos_to_frames(npy_dir, output_dir, num_frames=120):

    for npy_subfiles in os.listdir(npy_dir):
       for npy_filename in os.listdir(npy_dir+"/"+npy_subfiles):


          if npy_filename.endswith(".npy"):  # Process only .npy files
              npy_file = os.path.join(npy_dir+'/'+npy_subfiles, npy_filename)
              #video_name = os.path.splitext(npy_filename)[0]

              # Extract 120 frames from the .npy file
              extracted_frames = extract_frames_from_npy(npy_file, num_frames)

              # Save the extracted frames as a new .npy file
              output_filename = os.path.join(output_dir, npy_filename)
              #np.save(output_filename, extracted_frames)
              output_filename = os.path.join(output_dir, npy_filename)
              compressed_filename = output_filename.replace('.npy', '.npz')
              #comprimir ficheiros .npy que contem os frames
              np.savez_compressed(output_filename.replace('.npy', '.npz'), frames=extracted_frames)
              #print(f"Saved 120 frames from {npy_filename} as {output_filename}")
              print(f"Saved 120 frames from {npy_filename} as {compressed_filename}")

# Example usage:
npy_dir = 'data/npy_videos'  # Directory with .npy files
output_dir = 'data/120_frames'  # Directory to save 120 frames
os.makedirs(output_dir, exist_ok=True)

process_npy_videos_to_frames(npy_dir, output_dir)
# Out:
# Saved 120 frames from p30_bvolley_skelet3D_s2.npy as data/120_frames/p30_bvolley_skelet3D_s2.npz
# Saved 120 frames from p55_bvolley_skelet3D_s3.npy as data/120_frames/p55_bvolley_skelet3D_s3.npz
# Saved 120 frames from p25_bvolley_skelet3D_s3.npy as data/120_frames/p25_bvolley_skelet3D_s3.npz
# Saved 120 frames from p3_bvolley_skelet3D_s3.npy as data/120_frames/p3_bvolley_skelet3D_s3.npz
# Saved 120 frames from p26_bvolley_skelet3D_s2.npy as data/120_frames/p26_bvolley_skelet3D_s2.npz
# Saved 120 frames from p13_bvolley_skelet3D_s1.npy as data/120_frames/p13_bvolley_skelet3D_s1.npz
# Saved 120 frames from p33_bvolley_skelet3D_s3.npy as data/120_frames/p33_bvolley_skelet3D_s3.npz
# Saved 120 frames from p55_bvolley_skelet3D_s2.npy as data/120_frames/p55_bvolley_skelet3D_s2.npz
# Saved 120 frames from p48_bvolley_skelet3D_s3.npy as data/120_frames/p48_bvolley_skelet3D_s3.npz
# Saved 120 frames from p39_bvolley_skelet3D_s2.npy as data/120_frames/p39_bvolley_skelet3D_s2.npz
# Saved 120 frames from p35_bvolley_skelet3D_s3.npy as data/120_frames/p35_bvolley_skelet3D_s3.npz
# Saved 120 frames from p18_bvolley_skelet3D_s3.npy as data/120_frames/p18_bvolley_skelet3D_s3.npz
# Saved 120 frames from p41_bvolley_skelet3D_s2.npy as data/120_frames/p41_bvolley_skelet3D_s2.npz
# Saved 120 frames from p6_bvolley_skelet3D_s2.npy as data/120_frames/p6_bvolley_skelet3D_s2.npz
# Saved 120 frames from p1_bvolley_skelet3D_s2.npy as data/120_frames/p1_bvolley_skelet3D_s2.npz
# Saved 120 frames from p3_bvolley_skelet3D_s2.npy as data/120_frames/p3_bvolley_skelet3D_s2.npz
# Saved 120 frames from p4_bvolley_skelet3D_s2.npy as data/120_frames/p4_bvolley_skelet3D_s2.npz
# Saved 120 frames from p2_bvolley_skelet3D_s2.npy as data/120_frames/p2_bvolley_skelet3D_s2.npz
# Saved 120 frames from p14_bvolley_skelet3D_s3.npy as data/120_frames/p14_bvolley_skelet3D_s3.npz
# Saved 120 frames from p44_bvolley_skelet3D_s3.npy as data/120_frames/p44_bvolley_skelet3D_s3.npz
# Saved 120 frames from p5_bvolley_skelet3D_s3.npy as data/120_frames/p5_bvolley_skelet3D_s3.npz
# Saved 120 frames from p36_bvolley_skelet3D_s2.npy as data/120_frames/p36_bvolley_skelet3D_s2.npz
# Saved 120 frames from p13_bvolley_skelet3D_s2.npy as data/120_frames/p13_bvolley_skelet3D_s2.npz
# Saved 120 frames from p34_bvolley_skelet3D_s3.npy as data/120_frames/p34_bvolley_skelet3D_s3.npz
# Saved 120 frames from p2_bvolley_skelet3D_s3.npy as data/120_frames/p2_bvolley_skelet3D_s3.npz
# Saved 120 frames from p50_bvolley_skelet3D_s3.npy as data/120_frames/p50_bvolley_skelet3D_s3.npz
# Saved 120 frames from p48_bvolley_skelet3D_s1.npy as data/120_frames/p48_bvolley_skelet3D_s1.npz
# Saved 120 frames from p39_bvolley_skelet3D_s3.npy as data/120_frames/p39_bvolley_skelet3D_s3.npz
# Saved 120 frames from p11_bvolley_skelet3D_s2.npy as data/120_frames/p11_bvolley_skelet3D_s2.npz
# Saved 120 frames from p54_bvolley_skelet3D_s3.npy as data/120_frames/p54_bvolley_skelet3D_s3.npz
# Saved 120 frames from p16_bvolley_skelet3D_s2.npy as data/120_frames/p16_bvolley_skelet3D_s2.npz
# Saved 120 frames from p48_bvolley_skelet3D_s2.npy as data/120_frames/p48_bvolley_skelet3D_s2.npz
# Saved 120 frames from p18_bvolley_skelet3D_s2.npy as data/120_frames/p18_bvolley_skelet3D_s2.npz
# Saved 120 frames from p40_bvolley_skelet3D_s3.npy as data/120_frames/p40_bvolley_skelet3D_s3.npz
# Saved 120 frames from p51_bvolley_skelet3D_s1.npy as data/120_frames/p51_bvolley_skelet3D_s1.npz
# Saved 120 frames from p10_bvolley_skelet3D_s3.npy as data/120_frames/p10_bvolley_skelet3D_s3.npz
# Saved 120 frames from p7_bvolley_skelet3D_s3.npy as data/120_frames/p7_bvolley_skelet3D_s3.npz
# Saved 120 frames from p31_bvolley_skelet3D_s2.npy as data/120_frames/p31_bvolley_skelet3D_s2.npz
# Saved 120 frames from p24_bvolley_skelet3D_s3.npy as data/120_frames/p24_bvolley_skelet3D_s3.npz
# Saved 120 frames from p4_bvolley_skelet3D_s3.npy as data/120_frames/p4_bvolley_skelet3D_s3.npz
# Saved 120 frames from p13_bvolley_skelet3D_s3.npy as data/120_frames/p13_bvolley_skelet3D_s3.npz
# Saved 120 frames from p16_bvolley_skelet3D_s3.npy as data/120_frames/p16_bvolley_skelet3D_s3.npz
# Saved 120 frames from p22_bvolley_skelet3D_s3.npy as data/120_frames/p22_bvolley_skelet3D_s3.npz
# Saved 120 frames from p17_bvolley_skelet3D_s3.npy as data/120_frames/p17_bvolley_skelet3D_s3.npz
# Saved 120 frames from p53_bvolley_skelet3D_s2.npy as data/120_frames/p53_bvolley_skelet3D_s2.npz
# Saved 120 frames from p28_bvolley_skelet3D_s3.npy as data/120_frames/p28_bvolley_skelet3D_s3.npz
# Saved 120 frames from p1_bvolley_skelet3D_s3.npy as data/120_frames/p1_bvolley_skelet3D_s3.npz
# Saved 120 frames from p46_bvolley_skelet3D_s2.npy as data/120_frames/p46_bvolley_skelet3D_s2.npz
# Saved 120 frames from p52_bvolley_skelet3D_s3.npy as data/120_frames/p52_bvolley_skelet3D_s3.npz
# Saved 120 frames from p54_bvolley_skelet3D_s2.npy as data/120_frames/p54_bvolley_skelet3D_s2.npz
# Saved 120 frames from p53_bvolley_skelet3D_s3.npy as data/120_frames/p53_bvolley_skelet3D_s3.npz
# Saved 120 frames from p43_bvolley_skelet3D_s2.npy as data/120_frames/p43_bvolley_skelet3D_s2.npz
# Saved 120 frames from p14_bvolley_skelet3D_s2.npy as data/120_frames/p14_bvolley_skelet3D_s2.npz
# Saved 120 frames from p25_bvolley_skelet3D_s2.npy as data/120_frames/p25_bvolley_skelet3D_s2.npz
# Saved 120 frames from p41_bvolley_skelet3D_s3.npy as data/120_frames/p41_bvolley_skelet3D_s3.npz
# Saved 120 frames from p47_bvolley_skelet3D_s3.npy as data/120_frames/p47_bvolley_skelet3D_s3.npz
# Saved 120 frames from p51_bvolley_skelet3D_s3.npy as data/120_frames/p51_bvolley_skelet3D_s3.npz
# Saved 120 frames from p29_bvolley_skelet3D_s2.npy as data/120_frames/p29_bvolley_skelet3D_s2.npz
# Saved 120 frames from p10_bvolley_skelet3D_s2.npy as data/120_frames/p10_bvolley_skelet3D_s2.npz
# Saved 120 frames from p28_bvolley_skelet3D_s2.npy as data/120_frames/p28_bvolley_skelet3D_s2.npz
# Saved 120 frames from p31_bvolley_skelet3D_s3.npy as data/120_frames/p31_bvolley_skelet3D_s3.npz
# Saved 120 frames from p9_bvolley_skelet3D_s2.npy as data/120_frames/p9_bvolley_skelet3D_s2.npz
# Saved 120 frames from p36_bvolley_skelet3D_s3.npy as data/120_frames/p36_bvolley_skelet3D_s3.npz
# Saved 120 frames from p20_bvolley_skelet3D_s2.npy as data/120_frames/p20_bvolley_skelet3D_s2.npz
# Saved 120 frames from p43_bvolley_skelet3D_s3.npy as data/120_frames/p43_bvolley_skelet3D_s3.npz
# Saved 120 frames from p12_bvolley_skelet3D_s2.npy as data/120_frames/p12_bvolley_skelet3D_s2.npz
# Saved 120 frames from p20_bvolley_skelet3D_s3.npy as data/120_frames/p20_bvolley_skelet3D_s3.npz
# Saved 120 frames from p17_bvolley_skelet3D_s2.npy as data/120_frames/p17_bvolley_skelet3D_s2.npz
# Saved 120 frames from p26_bvolley_skelet3D_s3.npy as data/120_frames/p26_bvolley_skelet3D_s3.npz
# Saved 120 frames from p45_bvolley_skelet3D_s3.npy as data/120_frames/p45_bvolley_skelet3D_s3.npz
# Saved 120 frames from p24_bvolley_skelet3D_s2.npy as data/120_frames/p24_bvolley_skelet3D_s2.npz
# Saved 120 frames from p33_bvolley_skelet3D_s2.npy as data/120_frames/p33_bvolley_skelet3D_s2.npz
# Saved 120 frames from p29_bvolley_skelet3D_s3.npy as data/120_frames/p29_bvolley_skelet3D_s3.npz
# Saved 120 frames from p38_bvolley_skelet3D_s2.npy as data/120_frames/p38_bvolley_skelet3D_s2.npz
# Saved 120 frames from p23_bvolley_skelet3D_s2.npy as data/120_frames/p23_bvolley_skelet3D_s2.npz
# Saved 120 frames from p52_bvolley_skelet3D_s2.npy as data/120_frames/p52_bvolley_skelet3D_s2.npz
# Saved 120 frames from p7_bvolley_skelet3D_s2.npy as data/120_frames/p7_bvolley_skelet3D_s2.npz
# Saved 120 frames from p15_bvolley_skelet3D_s2.npy as data/120_frames/p15_bvolley_skelet3D_s2.npz
# Saved 120 frames from p12_bvolley_skelet3D_s3.npy as data/120_frames/p12_bvolley_skelet3D_s3.npz
# Saved 120 frames from p38_bvolley_skelet3D_s3.npy as data/120_frames/p38_bvolley_skelet3D_s3.npz
# Saved 120 frames from p30_bvolley_skelet3D_s3.npy as data/120_frames/p30_bvolley_skelet3D_s3.npz
# Saved 120 frames from p42_bvolley_skelet3D_s2.npy as data/120_frames/p42_bvolley_skelet3D_s2.npz
# Saved 120 frames from p27_bvolley_skelet3D_s3.npy as data/120_frames/p27_bvolley_skelet3D_s3.npz
# Saved 120 frames from p8_bvolley_skelet3D_s3.npy as data/120_frames/p8_bvolley_skelet3D_s3.npz
# Saved 120 frames from p41_bvolley_skelet3D_s1.npy as data/120_frames/p41_bvolley_skelet3D_s1.npz
# Saved 120 frames from p6_bvolley_skelet3D_s3.npy as data/120_frames/p6_bvolley_skelet3D_s3.npz
# Saved 120 frames from p19_bvolley_skelet3D_s2.npy as data/120_frames/p19_bvolley_skelet3D_s2.npz
# Saved 120 frames from p21_bvolley_skelet3D_s3.npy as data/120_frames/p21_bvolley_skelet3D_s3.npz
# Saved 120 frames from p42_bvolley_skelet3D_s3.npy as data/120_frames/p42_bvolley_skelet3D_s3.npz
# Saved 120 frames from p15_bvolley_skelet3D_s3.npy as data/120_frames/p15_bvolley_skelet3D_s3.npz
# Saved 120 frames from p23_bvolley_skelet3D_s3.npy as data/120_frames/p23_bvolley_skelet3D_s3.npz
# Saved 120 frames from p40_bvolley_skelet3D_s2.npy as data/120_frames/p40_bvolley_skelet3D_s2.npz
# Saved 120 frames from p49_bvolley_skelet3D_s3.npy as data/120_frames/p49_bvolley_skelet3D_s3.npz
# Saved 120 frames from p11_bvolley_skelet3D_s3.npy as data/120_frames/p11_bvolley_skelet3D_s3.npz
# Saved 120 frames from p51_bvolley_skelet3D_s2.npy as data/120_frames/p51_bvolley_skelet3D_s2.npz
# Saved 120 frames from p8_bvolley_skelet3D_s2.npy as data/120_frames/p8_bvolley_skelet3D_s2.npz
# Saved 120 frames from p46_bvolley_skelet3D_s3.npy as data/120_frames/p46_bvolley_skelet3D_s3.npz
# Saved 120 frames from p44_bvolley_skelet3D_s2.npy as data/120_frames/p44_bvolley_skelet3D_s2.npz
# Saved 120 frames from p34_bvolley_skelet3D_s2.npy as data/120_frames/p34_bvolley_skelet3D_s2.npz
# Saved 120 frames from p47_bvolley_skelet3D_s2.npy as data/120_frames/p47_bvolley_skelet3D_s2.npz
# Saved 120 frames from p9_bvolley_skelet3D_s3.npy as data/120_frames/p9_bvolley_skelet3D_s3.npz
# Saved 120 frames from p19_bvolley_skelet3D_s3.npy as data/120_frames/p19_bvolley_skelet3D_s3.npz
# Saved 120 frames from p2_bvolley_skelet3D_s1.npy as data/120_frames/p2_bvolley_skelet3D_s1.npz
# Saved 120 frames from p12_serkick_skelet3D_s3.npy as data/120_frames/p12_serkick_skelet3D_s3.npz
# Saved 120 frames from p21_serkick_skelet3D_s3.npy as data/120_frames/p21_serkick_skelet3D_s3.npz
# Saved 120 frames from p39_serkick_skelet3D_s3.npy as data/120_frames/p39_serkick_skelet3D_s3.npz
# Saved 120 frames from p12_serkick_skelet3D_s2.npy as data/120_frames/p12_serkick_skelet3D_s2.npz
# Saved 120 frames from p47_serkick_skelet3D_s3.npy as data/120_frames/p47_serkick_skelet3D_s3.npz
# Saved 120 frames from p7_serkick_skelet3D_s2.npy as data/120_frames/p7_serkick_skelet3D_s2.npz
# Saved 120 frames from p54_serkick_skelet3D_s3.npy as data/120_frames/p54_serkick_skelet3D_s3.npz
# Saved 120 frames from p49_serkick_skelet3D_s2.npy as data/120_frames/p49_serkick_skelet3D_s2.npz
# Saved 120 frames from p38_serkick_skelet3D_s3.npy as data/120_frames/p38_serkick_skelet3D_s3.npz
# Saved 120 frames from p23_serkick_skelet3D_s3.npy as data/120_frames/p23_serkick_skelet3D_s3.npz
# Saved 120 frames from p50_serkick_skelet3D_s3.npy as data/120_frames/p50_serkick_skelet3D_s3.npz
# Saved 120 frames from p40_serkick_skelet3D_s3.npy as data/120_frames/p40_serkick_skelet3D_s3.npz
# Saved 120 frames from p1_serkick_skelet3D_s1.npy as data/120_frames/p1_serkick_skelet3D_s1.npz
# Saved 120 frames from p33_serkick_skelet3D_s3.npy as data/120_frames/p33_serkick_skelet3D_s3.npz
# Saved 120 frames from p28_serkick_skelet3D_s3.npy as data/120_frames/p28_serkick_skelet3D_s3.npz
# Saved 120 frames from p46_serkick_skelet3D_s3.npy as data/120_frames/p46_serkick_skelet3D_s3.npz
# Saved 120 frames from p27_serkick_skelet3D_s3.npy as data/120_frames/p27_serkick_skelet3D_s3.npz
# Saved 120 frames from p3_serkick_skelet3D_s2.npy as data/120_frames/p3_serkick_skelet3D_s2.npz
# Saved 120 frames from p3_serkick_skelet3D_s3.npy as data/120_frames/p3_serkick_skelet3D_s3.npz
# Saved 120 frames from p19_serkick_skelet3D_s2.npy as data/120_frames/p19_serkick_skelet3D_s2.npz
# Saved 120 frames from p25_serkick_skelet3D_s3.npy as data/120_frames/p25_serkick_skelet3D_s3.npz
# Saved 120 frames from p25_serkick_skelet3D_s2.npy as data/120_frames/p25_serkick_skelet3D_s2.npz
# Saved 120 frames from p26_serkick_skelet3D_s3.npy as data/120_frames/p26_serkick_skelet3D_s3.npz
# Saved 120 frames from p10_serkick_skelet3D_s3.npy as data/120_frames/p10_serkick_skelet3D_s3.npz
# Saved 120 frames from p14_serkick_skelet3D_s2.npy as data/120_frames/p14_serkick_skelet3D_s2.npz
# Saved 120 frames from p31_serkick_skelet3D_s1.npy as data/120_frames/p31_serkick_skelet3D_s1.npz
# Saved 120 frames from p29_serkick_skelet3D_s2.npy as data/120_frames/p29_serkick_skelet3D_s2.npz
# Saved 120 frames from p1_serkick_skelet3D_s2.npy as data/120_frames/p1_serkick_skelet3D_s2.npz
# Saved 120 frames from p52_serkick_skelet3D_s2.npy as data/120_frames/p52_serkick_skelet3D_s2.npz
# Saved 120 frames from p13_serkick_skelet3D_s3.npy as data/120_frames/p13_serkick_skelet3D_s3.npz
# Saved 120 frames from p5_serkick_skelet3D_s3.npy as data/120_frames/p5_serkick_skelet3D_s3.npz
# Saved 120 frames from p11_serkick_skelet3D_s3.npy as data/120_frames/p11_serkick_skelet3D_s3.npz
# Saved 120 frames from p52_serkick_skelet3D_s3.npy as data/120_frames/p52_serkick_skelet3D_s3.npz
# Saved 120 frames from p24_serkick_skelet3D_s2.npy as data/120_frames/p24_serkick_skelet3D_s2.npz
# Saved 120 frames from p32_serkick_skelet3D_s3.npy as data/120_frames/p32_serkick_skelet3D_s3.npz
# Saved 120 frames from p18_serkick_skelet3D_s3.npy as data/120_frames/p18_serkick_skelet3D_s3.npz
# Saved 120 frames from p48_serkick_skelet3D_s3.npy as data/120_frames/p48_serkick_skelet3D_s3.npz
# Saved 120 frames from p9_serkick_skelet3D_s3.npy as data/120_frames/p9_serkick_skelet3D_s3.npz
# Saved 120 frames from p49_serkick_skelet3D_s1.npy as data/120_frames/p49_serkick_skelet3D_s1.npz
# Saved 120 frames from p29_serkick_skelet3D_s3.npy as data/120_frames/p29_serkick_skelet3D_s3.npz
# Saved 120 frames from p36_serkick_skelet3D_s2.npy as data/120_frames/p36_serkick_skelet3D_s2.npz
# Saved 120 frames from p49_serkick_skelet3D_s3.npy as data/120_frames/p49_serkick_skelet3D_s3.npz
# Saved 120 frames from p2_serkick_skelet3D_s3.npy as data/120_frames/p2_serkick_skelet3D_s3.npz
# Saved 120 frames from p35_serkick_skelet3D_s3.npy as data/120_frames/p35_serkick_skelet3D_s3.npz
# Saved 120 frames from p17_serkick_skelet3D_s2.npy as data/120_frames/p17_serkick_skelet3D_s2.npz
# Saved 120 frames from p44_serkick_skelet3D_s1.npy as data/120_frames/p44_serkick_skelet3D_s1.npz
# Saved 120 frames from p44_serkick_skelet3D_s3.npy as data/120_frames/p44_serkick_skelet3D_s3.npz
# Saved 120 frames from p38_serkick_skelet3D_s2.npy as data/120_frames/p38_serkick_skelet3D_s2.npz
# Saved 120 frames from p30_serkick_skelet3D_s3.npy as data/120_frames/p30_serkick_skelet3D_s3.npz
# Saved 120 frames from p23_serkick_skelet3D_s2.npy as data/120_frames/p23_serkick_skelet3D_s2.npz
# Saved 120 frames from p4_serkick_skelet3D_s3.npy as data/120_frames/p4_serkick_skelet3D_s3.npz
# Saved 120 frames from p13_serkick_skelet3D_s2.npy as data/120_frames/p13_serkick_skelet3D_s2.npz
# Saved 120 frames from p11_serkick_skelet3D_s1.npy as data/120_frames/p11_serkick_skelet3D_s1.npz
# Saved 120 frames from p7_serkick_skelet3D_s1.npy as data/120_frames/p7_serkick_skelet3D_s1.npz
# Saved 120 frames from p34_serkick_skelet3D_s3.npy as data/120_frames/p34_serkick_skelet3D_s3.npz
# Saved 120 frames from p16_serkick_skelet3D_s2.npy as data/120_frames/p16_serkick_skelet3D_s2.npz
# Saved 120 frames from p53_serkick_skelet3D_s2.npy as data/120_frames/p53_serkick_skelet3D_s2.npz
# Saved 120 frames from p51_serkick_skelet3D_s2.npy as data/120_frames/p51_serkick_skelet3D_s2.npz
# Saved 120 frames from p53_serkick_skelet3D_s3.npy as data/120_frames/p53_serkick_skelet3D_s3.npz
# Saved 120 frames from p1_serkick_skelet3D_s3.npy as data/120_frames/p1_serkick_skelet3D_s3.npz
# Saved 120 frames from p11_serkick_skelet3D_s2.npy as data/120_frames/p11_serkick_skelet3D_s2.npz
# Saved 120 frames from p55_serkick_skelet3D_s2.npy as data/120_frames/p55_serkick_skelet3D_s2.npz
# Saved 120 frames from p45_serkick_skelet3D_s3.npy as data/120_frames/p45_serkick_skelet3D_s3.npz
# Saved 120 frames from p17_serkick_skelet3D_s1.npy as data/120_frames/p17_serkick_skelet3D_s1.npz
# Saved 120 frames from p34_serkick_skelet3D_s2.npy as data/120_frames/p34_serkick_skelet3D_s2.npz
# Saved 120 frames from p43_serkick_skelet3D_s3.npy as data/120_frames/p43_serkick_skelet3D_s3.npz
# Saved 120 frames from p18_serkick_skelet3D_s2.npy as data/120_frames/p18_serkick_skelet3D_s2.npz
# Saved 120 frames from p43_serkick_skelet3D_s2.npy as data/120_frames/p43_serkick_skelet3D_s2.npz
# Saved 120 frames from p4_serkick_skelet3D_s2.npy as data/120_frames/p4_serkick_skelet3D_s2.npz
# Saved 120 frames from p32_serkick_skelet3D_s2.npy as data/120_frames/p32_serkick_skelet3D_s2.npz
# Saved 120 frames from p20_serkick_skelet3D_s2.npy as data/120_frames/p20_serkick_skelet3D_s2.npz
# Saved 120 frames from p14_serkick_skelet3D_s3.npy as data/120_frames/p14_serkick_skelet3D_s3.npz
# Saved 120 frames from p42_serkick_skelet3D_s3.npy as data/120_frames/p42_serkick_skelet3D_s3.npz
# Saved 120 frames from p15_serkick_skelet3D_s2.npy as data/120_frames/p15_serkick_skelet3D_s2.npz
# Saved 120 frames from p31_serkick_skelet3D_s2.npy as data/120_frames/p31_serkick_skelet3D_s2.npz
# Saved 120 frames from p26_serkick_skelet3D_s2.npy as data/120_frames/p26_serkick_skelet3D_s2.npz
# Saved 120 frames from p46_serkick_skelet3D_s2.npy as data/120_frames/p46_serkick_skelet3D_s2.npz
# Saved 120 frames from p39_serkick_skelet3D_s2.npy as data/120_frames/p39_serkick_skelet3D_s2.npz
# Saved 120 frames from p55_serkick_skelet3D_s3.npy as data/120_frames/p55_serkick_skelet3D_s3.npz
# Saved 120 frames from p7_serkick_skelet3D_s3.npy as data/120_frames/p7_serkick_skelet3D_s3.npz
# Saved 120 frames from p50_serkick_skelet3D_s2.npy as data/120_frames/p50_serkick_skelet3D_s2.npz
# Saved 120 frames from p9_serkick_skelet3D_s2.npy as data/120_frames/p9_serkick_skelet3D_s2.npz
# Saved 120 frames from p6_serkick_skelet3D_s2.npy as data/120_frames/p6_serkick_skelet3D_s2.npz
# Saved 120 frames from p17_serkick_skelet3D_s3.npy as data/120_frames/p17_serkick_skelet3D_s3.npz
# Saved 120 frames from p42_serkick_skelet3D_s2.npy as data/120_frames/p42_serkick_skelet3D_s2.npz
# Saved 120 frames from p19_serkick_skelet3D_s3.npy as data/120_frames/p19_serkick_skelet3D_s3.npz
# Saved 120 frames from p47_serkick_skelet3D_s2.npy as data/120_frames/p47_serkick_skelet3D_s2.npz
# Saved 120 frames from p16_serkick_skelet3D_s3.npy as data/120_frames/p16_serkick_skelet3D_s3.npz
# Saved 120 frames from p24_serkick_skelet3D_s3.npy as data/120_frames/p24_serkick_skelet3D_s3.npz
# Saved 120 frames from p6_serkick_skelet3D_s3.npy as data/120_frames/p6_serkick_skelet3D_s3.npz
# Saved 120 frames from p5_serkick_skelet3D_s2.npy as data/120_frames/p5_serkick_skelet3D_s2.npz
# Saved 120 frames from p51_serkick_skelet3D_s3.npy as data/120_frames/p51_serkick_skelet3D_s3.npz
# Saved 120 frames from p44_serkick_skelet3D_s2.npy as data/120_frames/p44_serkick_skelet3D_s2.npz
# Saved 120 frames from p54_serkick_skelet3D_s2.npy as data/120_frames/p54_serkick_skelet3D_s2.npz
# Saved 120 frames from p22_serkick_skelet3D_s3.npy as data/120_frames/p22_serkick_skelet3D_s3.npz
# Saved 120 frames from p40_serkick_skelet3D_s2.npy as data/120_frames/p40_serkick_skelet3D_s2.npz
# Saved 120 frames from p41_serkick_skelet3D_s3.npy as data/120_frames/p41_serkick_skelet3D_s3.npz
# Saved 120 frames from p48_serkick_skelet3D_s2.npy as data/120_frames/p48_serkick_skelet3D_s2.npz
# Saved 120 frames from p10_serkick_skelet3D_s2.npy as data/120_frames/p10_serkick_skelet3D_s2.npz
# Saved 120 frames from p2_serkick_skelet3D_s2.npy as data/120_frames/p2_serkick_skelet3D_s2.npz
# Saved 120 frames from p48_serkick_skelet3D_s1.npy as data/120_frames/p48_serkick_skelet3D_s1.npz
# Saved 120 frames from p53_serkick_skelet3D_s1.npy as data/120_frames/p53_serkick_skelet3D_s1.npz
# Saved 120 frames from p31_serkick_skelet3D_s3.npy as data/120_frames/p31_serkick_skelet3D_s3.npz
# Saved 120 frames from p30_serkick_skelet3D_s2.npy as data/120_frames/p30_serkick_skelet3D_s2.npz
# Saved 120 frames from p8_serkick_skelet3D_s3.npy as data/120_frames/p8_serkick_skelet3D_s3.npz
# Saved 120 frames from p35_serkick_skelet3D_s2.npy as data/120_frames/p35_serkick_skelet3D_s2.npz
# Saved 120 frames from p36_serkick_skelet3D_s3.npy as data/120_frames/p36_serkick_skelet3D_s3.npz
# Saved 120 frames from p15_serkick_skelet3D_s3.npy as data/120_frames/p15_serkick_skelet3D_s3.npz
# Saved 120 frames from p20_serkick_skelet3D_s3.npy as data/120_frames/p20_serkick_skelet3D_s3.npz
# Saved 120 frames from p44_foreflat_skelet3D_s2.npy as data/120_frames/p44_foreflat_skelet3D_s2.npz
# Saved 120 frames from p42_foreflat_skelet3D_s3.npy as data/120_frames/p42_foreflat_skelet3D_s3.npz
# Saved 120 frames from p53_foreflat_skelet3D_s3.npy as data/120_frames/p53_foreflat_skelet3D_s3.npz
# Saved 120 frames from p28_foreflat_skelet3D_s2.npy as data/120_frames/p28_foreflat_skelet3D_s2.npz
# Saved 120 frames from p54_foreflat_skelet3D_s3.npy as data/120_frames/p54_foreflat_skelet3D_s3.npz
# Saved 120 frames from p18_foreflat_skelet3D_s3.npy as data/120_frames/p18_foreflat_skelet3D_s3.npz
# Saved 120 frames from p36_foreflat_skelet3D_s3.npy as data/120_frames/p36_foreflat_skelet3D_s3.npz
# Saved 120 frames from p14_foreflat_skelet3D_s3.npy as data/120_frames/p14_foreflat_skelet3D_s3.npz
# Saved 120 frames from p31_foreflat_skelet3D_s3.npy as data/120_frames/p31_foreflat_skelet3D_s3.npz
# Saved 120 frames from p24_foreflat_skelet3D_s3.npy as data/120_frames/p24_foreflat_skelet3D_s3.npz
# Saved 120 frames from p40_foreflat_skelet3D_s3.npy as data/120_frames/p40_foreflat_skelet3D_s3.npz
# Saved 120 frames from p4_foreflat_skelet3D_s1.npy as data/120_frames/p4_foreflat_skelet3D_s1.npz
# Saved 120 frames from p22_foreflat_skelet3D_s3.npy as data/120_frames/p22_foreflat_skelet3D_s3.npz
# Saved 120 frames from p37_foreflat_skelet3D_s2.npy as data/120_frames/p37_foreflat_skelet3D_s2.npz
# Saved 120 frames from p9_foreflat_skelet3D_s2.npy as data/120_frames/p9_foreflat_skelet3D_s2.npz
# Saved 120 frames from p15_foreflat_skelet3D_s2.npy as data/120_frames/p15_foreflat_skelet3D_s2.npz
# Saved 120 frames from p44_foreflat_skelet3D_s3.npy as data/120_frames/p44_foreflat_skelet3D_s3.npz
# Saved 120 frames from p38_foreflat_skelet3D_s2.npy as data/120_frames/p38_foreflat_skelet3D_s2.npz
# Saved 120 frames from p1_foreflat_skelet3D_s2.npy as data/120_frames/p1_foreflat_skelet3D_s2.npz
# Saved 120 frames from p16_foreflat_skelet3D_s3.npy as data/120_frames/p16_foreflat_skelet3D_s3.npz
# Saved 120 frames from p8_foreflat_skelet3D_s2.npy as data/120_frames/p8_foreflat_skelet3D_s2.npz
# Saved 120 frames from p17_foreflat_skelet3D_s2.npy as data/120_frames/p17_foreflat_skelet3D_s2.npz
# Saved 120 frames from p48_foreflat_skelet3D_s3.npy as data/120_frames/p48_foreflat_skelet3D_s3.npz
# Saved 120 frames from p2_foreflat_skelet3D_s3.npy as data/120_frames/p2_foreflat_skelet3D_s3.npz
# Saved 120 frames from p1_foreflat_skelet3D_s3.npy as data/120_frames/p1_foreflat_skelet3D_s3.npz
# Saved 120 frames from p33_foreflat_skelet3D_s3.npy as data/120_frames/p33_foreflat_skelet3D_s3.npz
# Saved 120 frames from p27_foreflat_skelet3D_s3.npy as data/120_frames/p27_foreflat_skelet3D_s3.npz
# Saved 120 frames from p54_foreflat_skelet3D_s2.npy as data/120_frames/p54_foreflat_skelet3D_s2.npz
# Saved 120 frames from p9_foreflat_skelet3D_s3.npy as data/120_frames/p9_foreflat_skelet3D_s3.npz
# Saved 120 frames from p16_foreflat_skelet3D_s2.npy as data/120_frames/p16_foreflat_skelet3D_s2.npz
# Saved 120 frames from p53_foreflat_skelet3D_s2.npy as data/120_frames/p53_foreflat_skelet3D_s2.npz
# Saved 120 frames from p46_foreflat_skelet3D_s3.npy as data/120_frames/p46_foreflat_skelet3D_s3.npz
# Saved 120 frames from p42_foreflat_skelet3D_s2.npy as data/120_frames/p42_foreflat_skelet3D_s2.npz
# Saved 120 frames from p5_foreflat_skelet3D_s3.npy as data/120_frames/p5_foreflat_skelet3D_s3.npz
# Saved 120 frames from p35_foreflat_skelet3D_s3.npy as data/120_frames/p35_foreflat_skelet3D_s3.npz
# Saved 120 frames from p12_foreflat_skelet3D_s2.npy as data/120_frames/p12_foreflat_skelet3D_s2.npz
# Saved 120 frames from p40_foreflat_skelet3D_s2.npy as data/120_frames/p40_foreflat_skelet3D_s2.npz
# Saved 120 frames from p37_foreflat_skelet3D_s3.npy as data/120_frames/p37_foreflat_skelet3D_s3.npz
# Saved 120 frames from p17_foreflat_skelet3D_s3.npy as data/120_frames/p17_foreflat_skelet3D_s3.npz
# Saved 120 frames from p48_foreflat_skelet3D_s2.npy as data/120_frames/p48_foreflat_skelet3D_s2.npz
# Saved 120 frames from p3_foreflat_skelet3D_s3.npy as data/120_frames/p3_foreflat_skelet3D_s3.npz
# Saved 120 frames from p47_foreflat_skelet3D_s2.npy as data/120_frames/p47_foreflat_skelet3D_s2.npz
# Saved 120 frames from p20_foreflat_skelet3D_s2.npy as data/120_frames/p20_foreflat_skelet3D_s2.npz
# Saved 120 frames from p21_foreflat_skelet3D_s3.npy as data/120_frames/p21_foreflat_skelet3D_s3.npz
# Saved 120 frames from p34_foreflat_skelet3D_s2.npy as data/120_frames/p34_foreflat_skelet3D_s2.npz
# Saved 120 frames from p49_foreflat_skelet3D_s2.npy as data/120_frames/p49_foreflat_skelet3D_s2.npz
# Saved 120 frames from p7_foreflat_skelet3D_s3.npy as data/120_frames/p7_foreflat_skelet3D_s3.npz
# Saved 120 frames from p23_foreflat_skelet3D_s2.npy as data/120_frames/p23_foreflat_skelet3D_s2.npz
# Saved 120 frames from p13_foreflat_skelet3D_s3.npy as data/120_frames/p13_foreflat_skelet3D_s3.npz
# Saved 120 frames from p28_foreflat_skelet3D_s3.npy as data/120_frames/p28_foreflat_skelet3D_s3.npz
# Saved 120 frames from p25_foreflat_skelet3D_s2.npy as data/120_frames/p25_foreflat_skelet3D_s2.npz
# Saved 120 frames from p19_foreflat_skelet3D_s3.npy as data/120_frames/p19_foreflat_skelet3D_s3.npz
# Saved 120 frames from p4_foreflat_skelet3D_s2.npy as data/120_frames/p4_foreflat_skelet3D_s2.npz
# Saved 120 frames from p49_foreflat_skelet3D_s1.npy as data/120_frames/p49_foreflat_skelet3D_s1.npz
# Saved 120 frames from p14_foreflat_skelet3D_s2.npy as data/120_frames/p14_foreflat_skelet3D_s2.npz
# Saved 120 frames from p10_foreflat_skelet3D_s2.npy as data/120_frames/p10_foreflat_skelet3D_s2.npz
# Saved 120 frames from p27_foreflat_skelet3D_s2.npy as data/120_frames/p27_foreflat_skelet3D_s2.npz
# Saved 120 frames from p55_foreflat_skelet3D_s2.npy as data/120_frames/p55_foreflat_skelet3D_s2.npz
# Saved 120 frames from p20_foreflat_skelet3D_s3.npy as data/120_frames/p20_foreflat_skelet3D_s3.npz
# Saved 120 frames from p38_foreflat_skelet3D_s3.npy as data/120_frames/p38_foreflat_skelet3D_s3.npz
# Saved 120 frames from p6_foreflat_skelet3D_s3.npy as data/120_frames/p6_foreflat_skelet3D_s3.npz
# Saved 120 frames from p24_foreflat_skelet3D_s2.npy as data/120_frames/p24_foreflat_skelet3D_s2.npz
# Saved 120 frames from p10_foreflat_skelet3D_s3.npy as data/120_frames/p10_foreflat_skelet3D_s3.npz
# Saved 120 frames from p30_foreflat_skelet3D_s3.npy as data/120_frames/p30_foreflat_skelet3D_s3.npz
# Saved 120 frames from p31_foreflat_skelet3D_s1.npy as data/120_frames/p31_foreflat_skelet3D_s1.npz
# Saved 120 frames from p3_foreflat_skelet3D_s1.npy as data/120_frames/p3_foreflat_skelet3D_s1.npz
# Saved 120 frames from p18_foreflat_skelet3D_s2.npy as data/120_frames/p18_foreflat_skelet3D_s2.npz
# Saved 120 frames from p49_foreflat_skelet3D_s3.npy as data/120_frames/p49_foreflat_skelet3D_s3.npz
# Saved 120 frames from p29_foreflat_skelet3D_s2.npy as data/120_frames/p29_foreflat_skelet3D_s2.npz
# Saved 120 frames from p52_foreflat_skelet3D_s3.npy as data/120_frames/p52_foreflat_skelet3D_s3.npz
# Saved 120 frames from p51_foreflat_skelet3D_s3.npy as data/120_frames/p51_foreflat_skelet3D_s3.npz
# Saved 120 frames from p11_foreflat_skelet3D_s1.npy as data/120_frames/p11_foreflat_skelet3D_s1.npz
# Saved 120 frames from p45_foreflat_skelet3D_s3.npy as data/120_frames/p45_foreflat_skelet3D_s3.npz
# Saved 120 frames from p15_foreflat_skelet3D_s3.npy as data/120_frames/p15_foreflat_skelet3D_s3.npz
# Saved 120 frames from p31_foreflat_skelet3D_s2.npy as data/120_frames/p31_foreflat_skelet3D_s2.npz
# Saved 120 frames from p33_foreflat_skelet3D_s2.npy as data/120_frames/p33_foreflat_skelet3D_s2.npz
# Saved 120 frames from p41_foreflat_skelet3D_s3.npy as data/120_frames/p41_foreflat_skelet3D_s3.npz
# Saved 120 frames from p36_foreflat_skelet3D_s2.npy as data/120_frames/p36_foreflat_skelet3D_s2.npz
# Saved 120 frames from p23_foreflat_skelet3D_s3.npy as data/120_frames/p23_foreflat_skelet3D_s3.npz
# Saved 120 frames from p26_foreflat_skelet3D_s3.npy as data/120_frames/p26_foreflat_skelet3D_s3.npz
# Saved 120 frames from p26_foreflat_skelet3D_s2.npy as data/120_frames/p26_foreflat_skelet3D_s2.npz
# Saved 120 frames from p41_foreflat_skelet3D_s2.npy as data/120_frames/p41_foreflat_skelet3D_s2.npz
# Saved 120 frames from p30_foreflat_skelet3D_s2.npy as data/120_frames/p30_foreflat_skelet3D_s2.npz
# Saved 120 frames from p5_foreflat_skelet3D_s2.npy as data/120_frames/p5_foreflat_skelet3D_s2.npz
# Saved 120 frames from p45_foreflat_skelet3D_s2.npy as data/120_frames/p45_foreflat_skelet3D_s2.npz
# Saved 120 frames from p11_foreflat_skelet3D_s3.npy as data/120_frames/p11_foreflat_skelet3D_s3.npz
# Saved 120 frames from p43_foreflat_skelet3D_s3.npy as data/120_frames/p43_foreflat_skelet3D_s3.npz
# Saved 120 frames from p29_foreflat_skelet3D_s3.npy as data/120_frames/p29_foreflat_skelet3D_s3.npz
# Saved 120 frames from p43_foreflat_skelet3D_s2.npy as data/120_frames/p43_foreflat_skelet3D_s2.npz
# Saved 120 frames from p7_foreflat_skelet3D_s2.npy as data/120_frames/p7_foreflat_skelet3D_s2.npz
# Saved 120 frames from p47_foreflat_skelet3D_s3.npy as data/120_frames/p47_foreflat_skelet3D_s3.npz
# Saved 120 frames from p25_foreflat_skelet3D_s3.npy as data/120_frames/p25_foreflat_skelet3D_s3.npz
# Saved 120 frames from p13_foreflat_skelet3D_s2.npy as data/120_frames/p13_foreflat_skelet3D_s2.npz
# Saved 120 frames from p39_foreflat_skelet3D_s2.npy as data/120_frames/p39_foreflat_skelet3D_s2.npz
# Saved 120 frames from p4_foreflat_skelet3D_s3.npy as data/120_frames/p4_foreflat_skelet3D_s3.npz
# Saved 120 frames from p35_foreflat_skelet3D_s2.npy as data/120_frames/p35_foreflat_skelet3D_s2.npz
# Saved 120 frames from p8_foreflat_skelet3D_s3.npy as data/120_frames/p8_foreflat_skelet3D_s3.npz
# Saved 120 frames from p8_foreflat_skelet3D_s1.npy as data/120_frames/p8_foreflat_skelet3D_s1.npz
# Saved 120 frames from p3_foreflat_skelet3D_s2.npy as data/120_frames/p3_foreflat_skelet3D_s2.npz
# Saved 120 frames from p39_foreflat_skelet3D_s3.npy as data/120_frames/p39_foreflat_skelet3D_s3.npz
# Saved 120 frames from p46_foreflat_skelet3D_s2.npy as data/120_frames/p46_foreflat_skelet3D_s2.npz
# Saved 120 frames from p32_foreflat_skelet3D_s3.npy as data/120_frames/p32_foreflat_skelet3D_s3.npz
# Saved 120 frames from p12_foreflat_skelet3D_s3.npy as data/120_frames/p12_foreflat_skelet3D_s3.npz
# Saved 120 frames from p11_foreflat_skelet3D_s2.npy as data/120_frames/p11_foreflat_skelet3D_s2.npz
# Saved 120 frames from p50_foreflat_skelet3D_s3.npy as data/120_frames/p50_foreflat_skelet3D_s3.npz
# Saved 120 frames from p51_foreflat_skelet3D_s2.npy as data/120_frames/p51_foreflat_skelet3D_s2.npz
# Saved 120 frames from p52_foreflat_skelet3D_s2.npy as data/120_frames/p52_foreflat_skelet3D_s2.npz
# Saved 120 frames from p2_foreflat_skelet3D_s2.npy as data/120_frames/p2_foreflat_skelet3D_s2.npz
# Saved 120 frames from p22_foreflat_skelet3D_s2.npy as data/120_frames/p22_foreflat_skelet3D_s2.npz
# Saved 120 frames from p34_foreflat_skelet3D_s3.npy as data/120_frames/p34_foreflat_skelet3D_s3.npz
# Saved 120 frames from p32_foreopen_skelet3D_s3.npy as data/120_frames/p32_foreopen_skelet3D_s3.npz
# Saved 120 frames from p45_foreopen_skelet3D_s3.npy as data/120_frames/p45_foreopen_skelet3D_s3.npz
# Saved 120 frames from p18_foreopen_skelet3D_s3.npy as data/120_frames/p18_foreopen_skelet3D_s3.npz
# Saved 120 frames from p41_foreopen_skelet3D_s2.npy as data/120_frames/p41_foreopen_skelet3D_s2.npz
# Saved 120 frames from p4_foreopen_skelet3D_s1.npy as data/120_frames/p4_foreopen_skelet3D_s1.npz
# Saved 120 frames from p9_foreopen_skelet3D_s1.npy as data/120_frames/p9_foreopen_skelet3D_s1.npz
# Saved 120 frames from p54_foreopen_skelet3D_s3.npy as data/120_frames/p54_foreopen_skelet3D_s3.npz
# Saved 120 frames from p9_foreopen_skelet3D_s2.npy as data/120_frames/p9_foreopen_skelet3D_s2.npz
# Saved 120 frames from p34_foreopen_skelet3D_s3.npy as data/120_frames/p34_foreopen_skelet3D_s3.npz
# Saved 120 frames from p20_foreopen_skelet3D_s3.npy as data/120_frames/p20_foreopen_skelet3D_s3.npz
# Saved 120 frames from p24_foreopen_skelet3D_s2.npy as data/120_frames/p24_foreopen_skelet3D_s2.npz
# Saved 120 frames from p29_foreopen_skelet3D_s3.npy as data/120_frames/p29_foreopen_skelet3D_s3.npz
# Saved 120 frames from p35_foreopen_skelet3D_s3.npy as data/120_frames/p35_foreopen_skelet3D_s3.npz
# Saved 120 frames from p17_foreopen_skelet3D_s2.npy as data/120_frames/p17_foreopen_skelet3D_s2.npz
# Saved 120 frames from p5_foreopen_skelet3D_s2.npy as data/120_frames/p5_foreopen_skelet3D_s2.npz
# Saved 120 frames from p19_foreopen_skelet3D_s2.npy as data/120_frames/p19_foreopen_skelet3D_s2.npz
# Saved 120 frames from p40_foreopen_skelet3D_s3.npy as data/120_frames/p40_foreopen_skelet3D_s3.npz
# Saved 120 frames from p30_foreopen_skelet3D_s2.npy as data/120_frames/p30_foreopen_skelet3D_s2.npz
# Saved 120 frames from p39_foreopen_skelet3D_s3.npy as data/120_frames/p39_foreopen_skelet3D_s3.npz
# Saved 120 frames from p23_foreopen_skelet3D_s3.npy as data/120_frames/p23_foreopen_skelet3D_s3.npz
# Saved 120 frames from p41_foreopen_skelet3D_s3.npy as data/120_frames/p41_foreopen_skelet3D_s3.npz
# Saved 120 frames from p14_foreopen_skelet3D_s2.npy as data/120_frames/p14_foreopen_skelet3D_s2.npz
# Saved 120 frames from p49_foreopen_skelet3D_s2.npy as data/120_frames/p49_foreopen_skelet3D_s2.npz
# Saved 120 frames from p32_foreopen_skelet3D_s2.npy as data/120_frames/p32_foreopen_skelet3D_s2.npz
# Saved 120 frames from p16_foreopen_skelet3D_s3.npy as data/120_frames/p16_foreopen_skelet3D_s3.npz
# Saved 120 frames from p2_foreopen_skelet3D_s3.npy as data/120_frames/p2_foreopen_skelet3D_s3.npz
# Saved 120 frames from p18_foreopen_skelet3D_s2.npy as data/120_frames/p18_foreopen_skelet3D_s2.npz
# Saved 120 frames from p4_foreopen_skelet3D_s3.npy as data/120_frames/p4_foreopen_skelet3D_s3.npz
# Saved 120 frames from p26_foreopen_skelet3D_s2.npy as data/120_frames/p26_foreopen_skelet3D_s2.npz
# Saved 120 frames from p12_foreopen_skelet3D_s3.npy as data/120_frames/p12_foreopen_skelet3D_s3.npz
# Saved 120 frames from p53_foreopen_skelet3D_s2.npy as data/120_frames/p53_foreopen_skelet3D_s2.npz
# Saved 120 frames from p54_foreopen_skelet3D_s2.npy as data/120_frames/p54_foreopen_skelet3D_s2.npz
# Saved 120 frames from p55_foreopen_skelet3D_s2.npy as data/120_frames/p55_foreopen_skelet3D_s2.npz
# Saved 120 frames from p3_foreopen_skelet3D_s1.npy as data/120_frames/p3_foreopen_skelet3D_s1.npz
# Saved 120 frames from p31_foreopen_skelet3D_s2.npy as data/120_frames/p31_foreopen_skelet3D_s2.npz
# Saved 120 frames from p8_foreopen_skelet3D_s3.npy as data/120_frames/p8_foreopen_skelet3D_s3.npz
# Saved 120 frames from p39_foreopen_skelet3D_s2.npy as data/120_frames/p39_foreopen_skelet3D_s2.npz
# Saved 120 frames from p5_foreopen_skelet3D_s3.npy as data/120_frames/p5_foreopen_skelet3D_s3.npz
# Saved 120 frames from p45_foreopen_skelet3D_s2.npy as data/120_frames/p45_foreopen_skelet3D_s2.npz
# Saved 120 frames from p25_foreopen_skelet3D_s2.npy as data/120_frames/p25_foreopen_skelet3D_s2.npz
# Saved 120 frames from p42_foreopen_skelet3D_s2.npy as data/120_frames/p42_foreopen_skelet3D_s2.npz
# Saved 120 frames from p51_foreopen_skelet3D_s2.npy as data/120_frames/p51_foreopen_skelet3D_s2.npz
# Saved 120 frames from p30_foreopen_skelet3D_s3.npy as data/120_frames/p30_foreopen_skelet3D_s3.npz
# Saved 120 frames from p43_foreopen_skelet3D_s3.npy as data/120_frames/p43_foreopen_skelet3D_s3.npz
# Saved 120 frames from p16_foreopen_skelet3D_s2.npy as data/120_frames/p16_foreopen_skelet3D_s2.npz
# Saved 120 frames from p10_foreopen_skelet3D_s2.npy as data/120_frames/p10_foreopen_skelet3D_s2.npz
# Saved 120 frames from p53_foreopen_skelet3D_s3.npy as data/120_frames/p53_foreopen_skelet3D_s3.npz
# Saved 120 frames from p3_foreopen_skelet3D_s3.npy as data/120_frames/p3_foreopen_skelet3D_s3.npz
# Saved 120 frames from p21_foreopen_skelet3D_s3.npy as data/120_frames/p21_foreopen_skelet3D_s3.npz
# Saved 120 frames from p44_foreopen_skelet3D_s3.npy as data/120_frames/p44_foreopen_skelet3D_s3.npz
# Saved 120 frames from p53_foreopen_skelet3D_s1.npy as data/120_frames/p53_foreopen_skelet3D_s1.npz
# Saved 120 frames from p19_foreopen_skelet3D_s3.npy as data/120_frames/p19_foreopen_skelet3D_s3.npz
# Saved 120 frames from p10_foreopen_skelet3D_s3.npy as data/120_frames/p10_foreopen_skelet3D_s3.npz
# Saved 120 frames from p4_foreopen_skelet3D_s2.npy as data/120_frames/p4_foreopen_skelet3D_s2.npz
# Saved 120 frames from p38_foreopen_skelet3D_s2.npy as data/120_frames/p38_foreopen_skelet3D_s2.npz
# Saved 120 frames from p52_foreopen_skelet3D_s3.npy as data/120_frames/p52_foreopen_skelet3D_s3.npz
# Saved 120 frames from p3_foreopen_skelet3D_s2.npy as data/120_frames/p3_foreopen_skelet3D_s2.npz
# Saved 120 frames from p1_foreopen_skelet3D_s3.npy as data/120_frames/p1_foreopen_skelet3D_s3.npz
# Saved 120 frames from p28_foreopen_skelet3D_s3.npy as data/120_frames/p28_foreopen_skelet3D_s3.npz
# Saved 120 frames from p15_foreopen_skelet3D_s3.npy as data/120_frames/p15_foreopen_skelet3D_s3.npz
# Saved 120 frames from p55_foreopen_skelet3D_s1.npy as data/120_frames/p55_foreopen_skelet3D_s1.npz
# Saved 120 frames from p20_foreopen_skelet3D_s2.npy as data/120_frames/p20_foreopen_skelet3D_s2.npz
# Saved 120 frames from p47_foreopen_skelet3D_s3.npy as data/120_frames/p47_foreopen_skelet3D_s3.npz
# Saved 120 frames from p51_foreopen_skelet3D_s3.npy as data/120_frames/p51_foreopen_skelet3D_s3.npz
# Saved 120 frames from p9_foreopen_skelet3D_s3.npy as data/120_frames/p9_foreopen_skelet3D_s3.npz
# Saved 120 frames from p14_foreopen_skelet3D_s3.npy as data/120_frames/p14_foreopen_skelet3D_s3.npz
# Saved 120 frames from p40_foreopen_skelet3D_s2.npy as data/120_frames/p40_foreopen_skelet3D_s2.npz
# Saved 120 frames from p36_foreopen_skelet3D_s3.npy as data/120_frames/p36_foreopen_skelet3D_s3.npz
# Saved 120 frames from p27_foreopen_skelet3D_s3.npy as data/120_frames/p27_foreopen_skelet3D_s3.npz
# Saved 120 frames from p48_foreopen_skelet3D_s3.npy as data/120_frames/p48_foreopen_skelet3D_s3.npz
# Saved 120 frames from p29_foreopen_skelet3D_s2.npy as data/120_frames/p29_foreopen_skelet3D_s2.npz
# Saved 120 frames from p37_foreopen_skelet3D_s2.npy as data/120_frames/p37_foreopen_skelet3D_s2.npz
# Saved 120 frames from p13_foreopen_skelet3D_s2.npy as data/120_frames/p13_foreopen_skelet3D_s2.npz
# Saved 120 frames from p7_foreopen_skelet3D_s3.npy as data/120_frames/p7_foreopen_skelet3D_s3.npz
# Saved 120 frames from p49_foreopen_skelet3D_s3.npy as data/120_frames/p49_foreopen_skelet3D_s3.npz
# Saved 120 frames from p8_foreopen_skelet3D_s2.npy as data/120_frames/p8_foreopen_skelet3D_s2.npz
# Saved 120 frames from p46_foreopen_skelet3D_s2.npy as data/120_frames/p46_foreopen_skelet3D_s2.npz
# Saved 120 frames from p6_foreopen_skelet3D_s3.npy as data/120_frames/p6_foreopen_skelet3D_s3.npz
# Saved 120 frames from p25_foreopen_skelet3D_s3.npy as data/120_frames/p25_foreopen_skelet3D_s3.npz
# Saved 120 frames from p22_foreopen_skelet3D_s3.npy as data/120_frames/p22_foreopen_skelet3D_s3.npz
# Saved 120 frames from p46_foreopen_skelet3D_s3.npy as data/120_frames/p46_foreopen_skelet3D_s3.npz
# Saved 120 frames from p43_foreopen_skelet3D_s2.npy as data/120_frames/p43_foreopen_skelet3D_s2.npz
# Saved 120 frames from p6_foreopen_skelet3D_s2.npy as data/120_frames/p6_foreopen_skelet3D_s2.npz
# Saved 120 frames from p27_foreopen_skelet3D_s2.npy as data/120_frames/p27_foreopen_skelet3D_s2.npz
# Saved 120 frames from p38_foreopen_skelet3D_s3.npy as data/120_frames/p38_foreopen_skelet3D_s3.npz
# Saved 120 frames from p31_foreopen_skelet3D_s3.npy as data/120_frames/p31_foreopen_skelet3D_s3.npz
# Saved 120 frames from p34_foreopen_skelet3D_s2.npy as data/120_frames/p34_foreopen_skelet3D_s2.npz
# Saved 120 frames from p11_foreopen_skelet3D_s3.npy as data/120_frames/p11_foreopen_skelet3D_s3.npz
# Saved 120 frames from p17_foreopen_skelet3D_s3.npy as data/120_frames/p17_foreopen_skelet3D_s3.npz
# Saved 120 frames from p13_foreopen_skelet3D_s3.npy as data/120_frames/p13_foreopen_skelet3D_s3.npz
# Saved 120 frames from p50_foreopen_skelet3D_s3.npy as data/120_frames/p50_foreopen_skelet3D_s3.npz
# Saved 120 frames from p33_foreopen_skelet3D_s3.npy as data/120_frames/p33_foreopen_skelet3D_s3.npz
# Saved 120 frames from p44_foreopen_skelet3D_s2.npy as data/120_frames/p44_foreopen_skelet3D_s2.npz
# Saved 120 frames from p1_foreopen_skelet3D_s2.npy as data/120_frames/p1_foreopen_skelet3D_s2.npz
# Saved 120 frames from p26_foreopen_skelet3D_s3.npy as data/120_frames/p26_foreopen_skelet3D_s3.npz
# Saved 120 frames from p23_foreopen_skelet3D_s2.npy as data/120_frames/p23_foreopen_skelet3D_s2.npz
# Saved 120 frames from p37_foreopen_skelet3D_s3.npy as data/120_frames/p37_foreopen_skelet3D_s3.npz
# Saved 120 frames from p24_foreopen_skelet3D_s3.npy as data/120_frames/p24_foreopen_skelet3D_s3.npz
# Saved 120 frames from p11_foreopen_skelet3D_s2.npy as data/120_frames/p11_foreopen_skelet3D_s2.npz
# Saved 120 frames from p2_foreopen_skelet3D_s2.npy as data/120_frames/p2_foreopen_skelet3D_s2.npz
# Saved 120 frames from p42_foreopen_skelet3D_s3.npy as data/120_frames/p42_foreopen_skelet3D_s3.npz
# Saved 120 frames from p29_serslice_skelet3D_s2.npy as data/120_frames/p29_serslice_skelet3D_s2.npz
# Saved 120 frames from p24_serslice_skelet3D_s3.npy as data/120_frames/p24_serslice_skelet3D_s3.npz
# Saved 120 frames from p9_serslice_skelet3D_s1.npy as data/120_frames/p9_serslice_skelet3D_s1.npz
# Saved 120 frames from p32_serslice_skelet3D_s2.npy as data/120_frames/p32_serslice_skelet3D_s2.npz
# Saved 120 frames from p55_serslice_skelet3D_s3.npy as data/120_frames/p55_serslice_skelet3D_s3.npz
# Saved 120 frames from p51_serslice_skelet3D_s3.npy as data/120_frames/p51_serslice_skelet3D_s3.npz
# Saved 120 frames from p45_serslice_skelet3D_s3.npy as data/120_frames/p45_serslice_skelet3D_s3.npz
# Saved 120 frames from p28_serslice_skelet3D_s2.npy as data/120_frames/p28_serslice_skelet3D_s2.npz
# Saved 120 frames from p43_serslice_skelet3D_s3.npy as data/120_frames/p43_serslice_skelet3D_s3.npz
# Saved 120 frames from p43_serslice_skelet3D_s2.npy as data/120_frames/p43_serslice_skelet3D_s2.npz
# Saved 120 frames from p20_serslice_skelet3D_s2.npy as data/120_frames/p20_serslice_skelet3D_s2.npz
# Saved 120 frames from p9_serslice_skelet3D_s2.npy as data/120_frames/p9_serslice_skelet3D_s2.npz
# Saved 120 frames from p44_serslice_skelet3D_s2.npy as data/120_frames/p44_serslice_skelet3D_s2.npz
# Saved 120 frames from p36_serslice_skelet3D_s3.npy as data/120_frames/p36_serslice_skelet3D_s3.npz
# Saved 120 frames from p39_serslice_skelet3D_s2.npy as data/120_frames/p39_serslice_skelet3D_s2.npz
# Saved 120 frames from p17_serslice_skelet3D_s2.npy as data/120_frames/p17_serslice_skelet3D_s2.npz
# Saved 120 frames from p3_serslice_skelet3D_s2.npy as data/120_frames/p3_serslice_skelet3D_s2.npz
# Saved 120 frames from p38_serslice_skelet3D_s3.npy as data/120_frames/p38_serslice_skelet3D_s3.npz
# Saved 120 frames from p40_serslice_skelet3D_s2.npy as data/120_frames/p40_serslice_skelet3D_s2.npz
# Saved 120 frames from p51_serslice_skelet3D_s1.npy as data/120_frames/p51_serslice_skelet3D_s1.npz
# Saved 120 frames from p20_serslice_skelet3D_s3.npy as data/120_frames/p20_serslice_skelet3D_s3.npz
# Saved 120 frames from p11_serslice_skelet3D_s3.npy as data/120_frames/p11_serslice_skelet3D_s3.npz
# Saved 120 frames from p25_serslice_skelet3D_s2.npy as data/120_frames/p25_serslice_skelet3D_s2.npz
# Saved 120 frames from p6_serslice_skelet3D_s3.npy as data/120_frames/p6_serslice_skelet3D_s3.npz
# Saved 120 frames from p33_serslice_skelet3D_s2.npy as data/120_frames/p33_serslice_skelet3D_s2.npz
# Saved 120 frames from p19_serslice_skelet3D_s3.npy as data/120_frames/p19_serslice_skelet3D_s3.npz
# Saved 120 frames from p26_serslice_skelet3D_s3.npy as data/120_frames/p26_serslice_skelet3D_s3.npz
# Saved 120 frames from p10_serslice_skelet3D_s3.npy as data/120_frames/p10_serslice_skelet3D_s3.npz
# Saved 120 frames from p53_serslice_skelet3D_s2.npy as data/120_frames/p53_serslice_skelet3D_s2.npz
# Saved 120 frames from p49_serslice_skelet3D_s3.npy as data/120_frames/p49_serslice_skelet3D_s3.npz
# Saved 120 frames from p18_serslice_skelet3D_s2.npy as data/120_frames/p18_serslice_skelet3D_s2.npz
# Saved 120 frames from p1_serslice_skelet3D_s3.npy as data/120_frames/p1_serslice_skelet3D_s3.npz
# Saved 120 frames from p21_serslice_skelet3D_s3.npy as data/120_frames/p21_serslice_skelet3D_s3.npz
# Saved 120 frames from p33_serslice_skelet3D_s3.npy as data/120_frames/p33_serslice_skelet3D_s3.npz
# Saved 120 frames from p1_serslice_skelet3D_s2.npy as data/120_frames/p1_serslice_skelet3D_s2.npz
# Saved 120 frames from p4_serslice_skelet3D_s2.npy as data/120_frames/p4_serslice_skelet3D_s2.npz
# Saved 120 frames from p30_serslice_skelet3D_s3.npy as data/120_frames/p30_serslice_skelet3D_s3.npz
# Saved 120 frames from p9_serslice_skelet3D_s3.npy as data/120_frames/p9_serslice_skelet3D_s3.npz
# Saved 120 frames from p21_serslice_skelet3D_s2.npy as data/120_frames/p21_serslice_skelet3D_s2.npz
# Saved 120 frames from p47_serslice_skelet3D_s2.npy as data/120_frames/p47_serslice_skelet3D_s2.npz
# Saved 120 frames from p15_serslice_skelet3D_s3.npy as data/120_frames/p15_serslice_skelet3D_s3.npz
# Saved 120 frames from p16_serslice_skelet3D_s2.npy as data/120_frames/p16_serslice_skelet3D_s2.npz
# Saved 120 frames from p46_serslice_skelet3D_s2.npy as data/120_frames/p46_serslice_skelet3D_s2.npz
# Saved 120 frames from p48_serslice_skelet3D_s2.npy as data/120_frames/p48_serslice_skelet3D_s2.npz
# Saved 120 frames from p48_serslice_skelet3D_s3.npy as data/120_frames/p48_serslice_skelet3D_s3.npz
# Saved 120 frames from p13_serslice_skelet3D_s2.npy as data/120_frames/p13_serslice_skelet3D_s2.npz
# Saved 120 frames from p44_serslice_skelet3D_s3.npy as data/120_frames/p44_serslice_skelet3D_s3.npz
# Saved 120 frames from p10_serslice_skelet3D_s2.npy as data/120_frames/p10_serslice_skelet3D_s2.npz
# Saved 120 frames from p41_serslice_skelet3D_s3.npy as data/120_frames/p41_serslice_skelet3D_s3.npz
# Saved 120 frames from p29_serslice_skelet3D_s3.npy as data/120_frames/p29_serslice_skelet3D_s3.npz
# Saved 120 frames from p50_serslice_skelet3D_s2.npy as data/120_frames/p50_serslice_skelet3D_s2.npz
# Saved 120 frames from p38_serslice_skelet3D_s2.npy as data/120_frames/p38_serslice_skelet3D_s2.npz
# Saved 120 frames from p17_serslice_skelet3D_s3.npy as data/120_frames/p17_serslice_skelet3D_s3.npz
# Saved 120 frames from p16_serslice_skelet3D_s1.npy as data/120_frames/p16_serslice_skelet3D_s1.npz
# Saved 120 frames from p16_serslice_skelet3D_s3.npy as data/120_frames/p16_serslice_skelet3D_s3.npz
# Saved 120 frames from p32_serslice_skelet3D_s3.npy as data/120_frames/p32_serslice_skelet3D_s3.npz
# Saved 120 frames from p8_serslice_skelet3D_s2.npy as data/120_frames/p8_serslice_skelet3D_s2.npz
# Saved 120 frames from p42_serslice_skelet3D_s3.npy as data/120_frames/p42_serslice_skelet3D_s3.npz
# Saved 120 frames from p4_serslice_skelet3D_s3.npy as data/120_frames/p4_serslice_skelet3D_s3.npz
# Saved 120 frames from p14_serslice_skelet3D_s2.npy as data/120_frames/p14_serslice_skelet3D_s2.npz
# Saved 120 frames from p35_serslice_skelet3D_s2.npy as data/120_frames/p35_serslice_skelet3D_s2.npz
# Saved 120 frames from p34_serslice_skelet3D_s3.npy as data/120_frames/p34_serslice_skelet3D_s3.npz
# Saved 120 frames from p21_serslice_skelet3D_s1.npy as data/120_frames/p21_serslice_skelet3D_s1.npz
# Saved 120 frames from p26_serslice_skelet3D_s2.npy as data/120_frames/p26_serslice_skelet3D_s2.npz
# Saved 120 frames from p31_serslice_skelet3D_s3.npy as data/120_frames/p31_serslice_skelet3D_s3.npz
# Saved 120 frames from p42_serslice_skelet3D_s2.npy as data/120_frames/p42_serslice_skelet3D_s2.npz
# Saved 120 frames from p6_serslice_skelet3D_s2.npy as data/120_frames/p6_serslice_skelet3D_s2.npz
# ...
# Saved 120 frames from p39_backhand_skelet3D_s3.npy as data/120_frames/p39_backhand_skelet3D_s3.npz
# Saved 120 frames from p36_backhand_skelet3D_s2.npy as data/120_frames/p36_backhand_skelet3D_s2.npz
# Saved 120 frames from p22_backhand_skelet3D_s3.npy as data/120_frames/p22_backhand_skelet3D_s3.npz
# Saved 120 frames from p48_backhand_skelet3D_s2.npy as data/120_frames/p48_backhand_skelet3D_s2.npz
# Saved 120 frames from p24_backhand_skelet3D_s3.npy as data/120_frames/p24_backhand_skelet3D_s3.npz
# Saved 120 frames from p47_backhand_skelet3D_s2.npy as data/120_frames/p47_backhand_skelet3D_s2.npz
# Saved 120 frames from p30_backhand_skelet3D_s3.npy as data/120_frames/p30_backhand_skelet3D_s3.npz
# Saved 120 frames from p23_backhand_skelet3D_s2.npy as data/120_frames/p23_backhand_skelet3D_s2.npz
# Saved 120 frames from p26_backhand_skelet3D_s1.npy as data/120_frames/p26_backhand_skelet3D_s1.npz
# Saved 120 frames from p29_backhand_skelet3D_s3.npy as data/120_frames/p29_backhand_skelet3D_s3.npz
# Saved 120 frames from p6_backhand_skelet3D_s2.npy as data/120_frames/p6_backhand_skelet3D_s2.npz
# Saved 120 frames from p11_backhand_skelet3D_s2.npy as data/120_frames/p11_backhand_skelet3D_s2.npz
# Saved 120 frames from p54_backhand_skelet3D_s1.npy as data/120_frames/p54_backhand_skelet3D_s1.npz
# Saved 120 frames from p19_backhand_skelet3D_s2.npy as data/120_frames/p19_backhand_skelet3D_s2.npz
# Saved 120 frames from p54_backhand_skelet3D_s2.npy as data/120_frames/p54_backhand_skelet3D_s2.npz
# Saved 120 frames from p36_backhand_skelet3D_s3.npy as data/120_frames/p36_backhand_skelet3D_s3.npz
# Saved 120 frames from p31_backhand_skelet3D_s3.npy as data/120_frames/p31_backhand_skelet3D_s3.npz
# Saved 120 frames from p18_backhand_skelet3D_s3.npy as data/120_frames/p18_backhand_skelet3D_s3.npz
# Saved 120 frames from p53_backhand_skelet3D_s3.npy as data/120_frames/p53_backhand_skelet3D_s3.npz
# Saved 120 frames from p43_backhand_skelet3D_s3.npy as data/120_frames/p43_backhand_skelet3D_s3.npz
# Saved 120 frames from p52_backhand_skelet3D_s2.npy as data/120_frames/p52_backhand_skelet3D_s2.npz
# Saved 120 frames from p37_backhand_skelet3D_s3.npy as data/120_frames/p37_backhand_skelet3D_s3.npz
# Saved 120 frames from p42_backhand_skelet3D_s3.npy as data/120_frames/p42_backhand_skelet3D_s3.npz
# Saved 120 frames from p30_backhand_skelet3D_s2.npy as data/120_frames/p30_backhand_skelet3D_s2.npz
# Saved 120 frames from p10_backhand_skelet3D_s2.npy as data/120_frames/p10_backhand_skelet3D_s2.npz
# Saved 120 frames from p48_backhand_skelet3D_s3.npy as data/120_frames/p48_backhand_skelet3D_s3.npz
# Saved 120 frames from p42_backhand_skelet3D_s2.npy as data/120_frames/p42_backhand_skelet3D_s2.npz
# Saved 120 frames from p49_backhand_skelet3D_s3.npy as data/120_frames/p49_backhand_skelet3D_s3.npz
# Saved 120 frames from p24_backhand_skelet3D_s2.npy as data/120_frames/p24_backhand_skelet3D_s2.npz
# Saved 120 frames from p50_backhand_skelet3D_s3.npy as data/120_frames/p50_backhand_skelet3D_s3.npz
# Saved 120 frames from p23_backhand_skelet3D_s3.npy as data/120_frames/p23_backhand_skelet3D_s3.npz
# Saved 120 frames from p27_backhand_skelet3D_s2.npy as data/120_frames/p27_backhand_skelet3D_s2.npz
# Saved 120 frames from p55_backhand_skelet3D_s2.npy as data/120_frames/p55_backhand_skelet3D_s2.npz
# Saved 120 frames from p20_backhand_skelet3D_s2.npy as data/120_frames/p20_backhand_skelet3D_s2.npz
# Saved 120 frames from p44_backhand_skelet3D_s3.npy as data/120_frames/p44_backhand_skelet3D_s3.npz
# Saved 120 frames from p14_backhand_skelet3D_s2.npy as data/120_frames/p14_backhand_skelet3D_s2.npz
# Saved 120 frames from p2_backhand_skelet3D_s3.npy as data/120_frames/p2_backhand_skelet3D_s3.npz
# Saved 120 frames from p38_backhand_skelet3D_s2.npy as data/120_frames/p38_backhand_skelet3D_s2.npz
# Saved 120 frames from p19_backhand_skelet3D_s3.npy as data/120_frames/p19_backhand_skelet3D_s3.npz
# Saved 120 frames from p21_backhand_skelet3D_s2.npy as data/120_frames/p21_backhand_skelet3D_s2.npz
# Saved 120 frames from p21_backhand_skelet3D_s3.npy as data/120_frames/p21_backhand_skelet3D_s3.npz
# Saved 120 frames from p10_backhand_skelet3D_s3.npy as data/120_frames/p10_backhand_skelet3D_s3.npz
# Saved 120 frames from p4_backhand_skelet3D_s3.npy as data/120_frames/p4_backhand_skelet3D_s3.npz
# Saved 120 frames from p51_backhand_skelet3D_s2.npy as data/120_frames/p51_backhand_skelet3D_s2.npz
# Saved 120 frames from p3_backhand_skelet3D_s2.npy as data/120_frames/p3_backhand_skelet3D_s2.npz
# Saved 120 frames from p37_backhand_skelet3D_s2.npy as data/120_frames/p37_backhand_skelet3D_s2.npz
# Saved 120 frames from p23_backhand_skelet3D_s1.npy as data/120_frames/p23_backhand_skelet3D_s1.npz
# Saved 120 frames from p4_backhand_skelet3D_s2.npy as data/120_frames/p4_backhand_skelet3D_s2.npz
# Saved 120 frames from p40_backhand_skelet3D_s3.npy as data/120_frames/p40_backhand_skelet3D_s3.npz
# Saved 120 frames from p26_backhand_skelet3D_s2.npy as data/120_frames/p26_backhand_skelet3D_s2.npz
# Saved 120 frames from p17_backhand_skelet3D_s3.npy as data/120_frames/p17_backhand_skelet3D_s3.npz
# Saved 120 frames from p38_backhand_skelet3D_s3.npy as data/120_frames/p38_backhand_skelet3D_s3.npz
# Saved 120 frames from p39_backhand_skelet3D_s2.npy as data/120_frames/p39_backhand_skelet3D_s2.npz
# Saved 120 frames from p2_backhand_skelet3D_s1.npy as data/120_frames/p2_backhand_skelet3D_s1.npz
# Saved 120 frames from p16_backhand_skelet3D_s2.npy as data/120_frames/p16_backhand_skelet3D_s2.npz
# Saved 120 frames from p54_backhand_skelet3D_s3.npy as data/120_frames/p54_backhand_skelet3D_s3.npz
# Saved 120 frames from p25_backhand_skelet3D_s2.npy as data/120_frames/p25_backhand_skelet3D_s2.npz
# Saved 120 frames from p2_backhand_skelet3D_s2.npy as data/120_frames/p2_backhand_skelet3D_s2.npz
# Saved 120 frames from p55_backhand_skelet3D_s3.npy as data/120_frames/p55_backhand_skelet3D_s3.npz
# Saved 120 frames from p9_backhand_skelet3D_s3.npy as data/120_frames/p9_backhand_skelet3D_s3.npz
# Saved 120 frames from p1_backhand_skelet3D_s3.npy as data/120_frames/p1_backhand_skelet3D_s3.npz
# Saved 120 frames from p34_backhand_skelet3D_s2.npy as data/120_frames/p34_backhand_skelet3D_s2.npz
# Saved 120 frames from p25_backhand_skelet3D_s3.npy as data/120_frames/p25_backhand_skelet3D_s3.npz
# Saved 120 frames from p15_backhand_skelet3D_s2.npy as data/120_frames/p15_backhand_skelet3D_s2.npz
# Saved 120 frames from p41_backhand_skelet3D_s3.npy as data/120_frames/p41_backhand_skelet3D_s3.npz
# Saved 120 frames from p11_backhand_skelet3D_s3.npy as data/120_frames/p11_backhand_skelet3D_s3.npz
# Saved 120 frames from p8_backhand_skelet3D_s2.npy as data/120_frames/p8_backhand_skelet3D_s2.npz
# Saved 120 frames from p53_backhand_skelet3D_s2.npy as data/120_frames/p53_backhand_skelet3D_s2.npz
# Saved 120 frames from p44_backhand_skelet3D_s2.npy as data/120_frames/p44_backhand_skelet3D_s2.npz
# Saved 120 frames from p20_fslice_skelet3D_s2.npy as data/120_frames/p20_fslice_skelet3D_s2.npz
# Saved 120 frames from p45_fslice_skelet3D_s3.npy as data/120_frames/p45_fslice_skelet3D_s3.npz
# Saved 120 frames from p29_fslice_skelet3D_s3.npy as data/120_frames/p29_fslice_skelet3D_s3.npz
# Saved 120 frames from p19_fslice_skelet3D_s3.npy as data/120_frames/p19_fslice_skelet3D_s3.npz
# Saved 120 frames from p36_fslice_skelet3D_s2.npy as data/120_frames/p36_fslice_skelet3D_s2.npz
# Saved 120 frames from p54_fslice_skelet3D_s2.npy as data/120_frames/p54_fslice_skelet3D_s2.npz
# Saved 120 frames from p46_fslice_skelet3D_s3.npy as data/120_frames/p46_fslice_skelet3D_s3.npz
# Saved 120 frames from p1_fslice_skelet3D_s1.npy as data/120_frames/p1_fslice_skelet3D_s1.npz
# Saved 120 frames from p52_fslice_skelet3D_s2.npy as data/120_frames/p52_fslice_skelet3D_s2.npz
# Saved 120 frames from p53_fslice_skelet3D_s3.npy as data/120_frames/p53_fslice_skelet3D_s3.npz
# Saved 120 frames from p15_fslice_skelet3D_s2.npy as data/120_frames/p15_fslice_skelet3D_s2.npz
# Saved 120 frames from p39_fslice_skelet3D_s3.npy as data/120_frames/p39_fslice_skelet3D_s3.npz
# Saved 120 frames from p23_fslice_skelet3D_s3.npy as data/120_frames/p23_fslice_skelet3D_s3.npz
# Saved 120 frames from p41_fslice_skelet3D_s2.npy as data/120_frames/p41_fslice_skelet3D_s2.npz
# Saved 120 frames from p24_fslice_skelet3D_s3.npy as data/120_frames/p24_fslice_skelet3D_s3.npz
# Saved 120 frames from p41_fslice_skelet3D_s3.npy as data/120_frames/p41_fslice_skelet3D_s3.npz
# Saved 120 frames from p11_fslice_skelet3D_s2.npy as data/120_frames/p11_fslice_skelet3D_s2.npz
# Saved 120 frames from p5_fslice_skelet3D_s2.npy as data/120_frames/p5_fslice_skelet3D_s2.npz
# Saved 120 frames from p4_fslice_skelet3D_s2.npy as data/120_frames/p4_fslice_skelet3D_s2.npz
# Saved 120 frames from p44_fslice_skelet3D_s3.npy as data/120_frames/p44_fslice_skelet3D_s3.npz
# Saved 120 frames from p22_fslice_skelet3D_s3.npy as data/120_frames/p22_fslice_skelet3D_s3.npz
# Saved 120 frames from p36_fslice_skelet3D_s3.npy as data/120_frames/p36_fslice_skelet3D_s3.npz
# Saved 120 frames from p53_fslice_skelet3D_s2.npy as data/120_frames/p53_fslice_skelet3D_s2.npz
# Saved 120 frames from p19_fslice_skelet3D_s2.npy as data/120_frames/p19_fslice_skelet3D_s2.npz
# Saved 120 frames from p20_fslice_skelet3D_s3.npy as data/120_frames/p20_fslice_skelet3D_s3.npz
# Saved 120 frames from p47_fslice_skelet3D_s3.npy as data/120_frames/p47_fslice_skelet3D_s3.npz
# Saved 120 frames from p28_fslice_skelet3D_s3.npy as data/120_frames/p28_fslice_skelet3D_s3.npz
# Saved 120 frames from p13_fslice_skelet3D_s3.npy as data/120_frames/p13_fslice_skelet3D_s3.npz
# Saved 120 frames from p2_fslice_skelet3D_s3.npy as data/120_frames/p2_fslice_skelet3D_s3.npz
# Saved 120 frames from p10_fslice_skelet3D_s3.npy as data/120_frames/p10_fslice_skelet3D_s3.npz
# Saved 120 frames from p51_fslice_skelet3D_s2.npy as data/120_frames/p51_fslice_skelet3D_s2.npz
# Saved 120 frames from p37_fslice_skelet3D_s2.npy as data/120_frames/p37_fslice_skelet3D_s2.npz
# Saved 120 frames from p12_fslice_skelet3D_s3.npy as data/120_frames/p12_fslice_skelet3D_s3.npz
# Saved 120 frames from p52_fslice_skelet3D_s3.npy as data/120_frames/p52_fslice_skelet3D_s3.npz
# Saved 120 frames from p43_fslice_skelet3D_s3.npy as data/120_frames/p43_fslice_skelet3D_s3.npz
# Saved 120 frames from p42_fslice_skelet3D_s2.npy as data/120_frames/p42_fslice_skelet3D_s2.npz
# Saved 120 frames from p7_fslice_skelet3D_s3.npy as data/120_frames/p7_fslice_skelet3D_s3.npz
# Saved 120 frames from p2_fslice_skelet3D_s2.npy as data/120_frames/p2_fslice_skelet3D_s2.npz
# Saved 120 frames from p31_fslice_skelet3D_s2.npy as data/120_frames/p31_fslice_skelet3D_s2.npz
# Saved 120 frames from p13_fslice_skelet3D_s2.npy as data/120_frames/p13_fslice_skelet3D_s2.npz
# Saved 120 frames from p8_fslice_skelet3D_s2.npy as data/120_frames/p8_fslice_skelet3D_s2.npz
# Saved 120 frames from p33_fslice_skelet3D_s3.npy as data/120_frames/p33_fslice_skelet3D_s3.npz
# Saved 120 frames from p38_fslice_skelet3D_s2.npy as data/120_frames/p38_fslice_skelet3D_s2.npz
# Saved 120 frames from p48_fslice_skelet3D_s3.npy as data/120_frames/p48_fslice_skelet3D_s3.npz
# Saved 120 frames from p42_fslice_skelet3D_s3.npy as data/120_frames/p42_fslice_skelet3D_s3.npz
# Saved 120 frames from p23_fslice_skelet3D_s2.npy as data/120_frames/p23_fslice_skelet3D_s2.npz
# Saved 120 frames from p31_fslice_skelet3D_s3.npy as data/120_frames/p31_fslice_skelet3D_s3.npz
# Saved 120 frames from p1_fslice_skelet3D_s2.npy as data/120_frames/p1_fslice_skelet3D_s2.npz
# Saved 120 frames from p34_fslice_skelet3D_s3.npy as data/120_frames/p34_fslice_skelet3D_s3.npz
# Saved 120 frames from p32_fslice_skelet3D_s3.npy as data/120_frames/p32_fslice_skelet3D_s3.npz
# Saved 120 frames from p50_fslice_skelet3D_s3.npy as data/120_frames/p50_fslice_skelet3D_s3.npz
# Saved 120 frames from p3_fslice_skelet3D_s3.npy as data/120_frames/p3_fslice_skelet3D_s3.npz
# Saved 120 frames from p5_fslice_skelet3D_s3.npy as data/120_frames/p5_fslice_skelet3D_s3.npz
# Saved 120 frames from p15_fslice_skelet3D_s3.npy as data/120_frames/p15_fslice_skelet3D_s3.npz
# Saved 120 frames from p10_fslice_skelet3D_s2.npy as data/120_frames/p10_fslice_skelet3D_s2.npz
# Saved 120 frames from p6_fslice_skelet3D_s3.npy as data/120_frames/p6_fslice_skelet3D_s3.npz
# Saved 120 frames from p37_fslice_skelet3D_s3.npy as data/120_frames/p37_fslice_skelet3D_s3.npz
# Saved 120 frames from p43_fslice_skelet3D_s2.npy as data/120_frames/p43_fslice_skelet3D_s2.npz
# Saved 120 frames from p1_fslice_skelet3D_s3.npy as data/120_frames/p1_fslice_skelet3D_s3.npz
# Saved 120 frames from p7_fslice_skelet3D_s2.npy as data/120_frames/p7_fslice_skelet3D_s2.npz
# Saved 120 frames from p14_fslice_skelet3D_s2.npy as data/120_frames/p14_fslice_skelet3D_s2.npz
# Saved 120 frames from p8_fslice_skelet3D_s3.npy as data/120_frames/p8_fslice_skelet3D_s3.npz
# Saved 120 frames from p17_fslice_skelet3D_s2.npy as data/120_frames/p17_fslice_skelet3D_s2.npz
# Saved 120 frames from p18_fslice_skelet3D_s3.npy as data/120_frames/p18_fslice_skelet3D_s3.npz
# Saved 120 frames from p35_fslice_skelet3D_s3.npy as data/120_frames/p35_fslice_skelet3D_s3.npz
# Saved 120 frames from p30_fslice_skelet3D_s3.npy as data/120_frames/p30_fslice_skelet3D_s3.npz
# Saved 120 frames from p3_fslice_skelet3D_s2.npy as data/120_frames/p3_fslice_skelet3D_s2.npz
# Saved 120 frames from p18_fslice_skelet3D_s2.npy as data/120_frames/p18_fslice_skelet3D_s2.npz
# Saved 120 frames from p25_fslice_skelet3D_s3.npy as data/120_frames/p25_fslice_skelet3D_s3.npz
# Saved 120 frames from p49_fslice_skelet3D_s3.npy as data/120_frames/p49_fslice_skelet3D_s3.npz
# Saved 120 frames from p17_fslice_skelet3D_s3.npy as data/120_frames/p17_fslice_skelet3D_s3.npz
# Saved 120 frames from p30_fslice_skelet3D_s2.npy as data/120_frames/p30_fslice_skelet3D_s2.npz
# Saved 120 frames from p54_fslice_skelet3D_s3.npy as data/120_frames/p54_fslice_skelet3D_s3.npz
# Saved 120 frames from p25_fslice_skelet3D_s2.npy as data/120_frames/p25_fslice_skelet3D_s2.npz
# Saved 120 frames from p21_fslice_skelet3D_s2.npy as data/120_frames/p21_fslice_skelet3D_s2.npz
# Saved 120 frames from p46_fslice_skelet3D_s2.npy as data/120_frames/p46_fslice_skelet3D_s2.npz
# Saved 120 frames from p21_fslice_skelet3D_s3.npy as data/120_frames/p21_fslice_skelet3D_s3.npz
# Saved 120 frames from p22_fslice_skelet3D_s2.npy as data/120_frames/p22_fslice_skelet3D_s2.npz
# Saved 120 frames from p9_fslice_skelet3D_s3.npy as data/120_frames/p9_fslice_skelet3D_s3.npz
# Saved 120 frames from p9_fslice_skelet3D_s2.npy as data/120_frames/p9_fslice_skelet3D_s2.npz
# Saved 120 frames from p4_fslice_skelet3D_s3.npy as data/120_frames/p4_fslice_skelet3D_s3.npz
# Saved 120 frames from p16_fslice_skelet3D_s2.npy as data/120_frames/p16_fslice_skelet3D_s2.npz
# Saved 120 frames from p38_fslice_skelet3D_s3.npy as data/120_frames/p38_fslice_skelet3D_s3.npz
# Saved 120 frames from p51_fslice_skelet3D_s3.npy as data/120_frames/p51_fslice_skelet3D_s3.npz
# Saved 120 frames from p29_fslice_skelet3D_s2.npy as data/120_frames/p29_fslice_skelet3D_s2.npz
# Saved 120 frames from p55_fslice_skelet3D_s1.npy as data/120_frames/p55_fslice_skelet3D_s1.npz
# Saved 120 frames from p12_fslice_skelet3D_s2.npy as data/120_frames/p12_fslice_skelet3D_s2.npz
# Saved 120 frames from p16_fslice_skelet3D_s3.npy as data/120_frames/p16_fslice_skelet3D_s3.npz
# Saved 120 frames from p11_fslice_skelet3D_s3.npy as data/120_frames/p11_fslice_skelet3D_s3.npz
# Saved 120 frames from p26_fslice_skelet3D_s3.npy as data/120_frames/p26_fslice_skelet3D_s3.npz
# Saved 120 frames from p26_fslice_skelet3D_s2.npy as data/120_frames/p26_fslice_skelet3D_s2.npz
# Saved 120 frames from p27_fslice_skelet3D_s3.npy as data/120_frames/p27_fslice_skelet3D_s3.npz
# Saved 120 frames from p39_fslice_skelet3D_s2.npy as data/120_frames/p39_fslice_skelet3D_s2.npz
# Saved 120 frames from p40_fslice_skelet3D_s3.npy as data/120_frames/p40_fslice_skelet3D_s3.npz
# Saved 120 frames from p14_fslice_skelet3D_s3.npy as data/120_frames/p14_fslice_skelet3D_s3.npz
# Saved 120 frames from p27_fslice_skelet3D_s2.npy as data/120_frames/p27_fslice_skelet3D_s2.npz
# Saved 120 frames from p55_fslice_skelet3D_s2.npy as data/120_frames/p55_fslice_skelet3D_s2.npz

# %%
#eliminar pastas de videos do dataset desnecessárias para o projeto em questão
# !rm -r data/VIDEO_Depth data/VIDEO_Mask data/VIDEO_Skelet2D data/papers/
#eliminar pasta npy_videos uma vez que já foi usada
# !rm -r data/npy_videos
# Out:
# rm: cannot remove 'data/VIDEO_Depth': No such file or directory
# rm: cannot remove 'data/VIDEO_Mask': No such file or directory
# rm: cannot remove 'data/VIDEO_Skelet2D': No such file or directory
# rm: cannot remove 'data/npy_videos': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
def split_by_player(video_dir, output_dir, train_ratio=0.7, val_ratio=0.15, test_ratio=0.15):
    # Step 1: Get a list of all players
    players = set()  # Set to store unique players (assuming folder names represent players)

    for video_filename in os.listdir(video_dir):
        if video_filename.endswith(".npy"):  # Only process .npy files
            player_name = video_filename.split('_')[0]  # Assuming player info is in the filename
            players.add(player_name)

    # Step 2: Shuffle the list of players
    players = list(players)
    random.shuffle(players)

    # Step 3: Split players into train/val/test sets
    num_players = len(players)
    train_size = int(train_ratio * num_players)
    val_size = int(val_ratio * num_players)

    train_players = players[:train_size]
    val_players = players[train_size:train_size + val_size]
    test_players = players[train_size + val_size:]

    # Step 4: Create directories for train/val/test sets
    train_dir = os.path.join(output_dir, 'train')
    val_dir = os.path.join(output_dir, 'val')
    test_dir = os.path.join(output_dir, 'test')

    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    # Step 5: Move videos to their respective directories
    for video_filename in os.listdir(video_dir):
        if video_filename.endswith(".npy"):
            player_name = video_filename.split('_')[0]  # Get the player name
            src_path = os.path.join(video_dir, video_filename)

            if player_name in train_players:
                dst_dir = train_dir
            elif player_name in val_players:
                dst_dir = val_dir
            else:
                dst_dir = test_dir

            # Move the file to the appropriate directory
            shutil.copy(src_path, os.path.join(dst_dir, video_filename))
            #(f"Moved {video_filename} to {dst_dir}")

# Example usage:
video_dir = 'data/120_frames/'  # Directory containing all the .npy files
output_dir = 'data/splits/'  # Directory where train/val/test splits will be saved
os.makedirs(output_dir, exist_ok=True)

split_by_player(video_dir, output_dir)
# Out:
# Moved p20_fslice_skelet3D_s2.npy to data/splits/val
# Moved p30_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p44_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p20_serflat_skelet3D_s3.npy to data/splits/val
# Moved p29_serslice_skelet3D_s2.npy to data/splits/train
# Moved p55_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p10_bslice_skelet3D_s3.npy to data/splits/train
# Moved p48_backhand2h_skelet3D_s3.npy to data/splits/val
# Moved p24_serslice_skelet3D_s3.npy to data/splits/train
# Moved p37_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p25_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p12_serkick_skelet3D_s3.npy to data/splits/train
# Moved p3_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p9_smash_skelet3D_s2.npy to data/splits/train
# Moved p6_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p14_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p5_fvolley_skelet3D_s1.npy to data/splits/test
# Moved p9_serslice_skelet3D_s1.npy to data/splits/train
# Moved p9_bslice_skelet3D_s3.npy to data/splits/train
# Moved p3_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p46_backhand_skelet3D_s1.npy to data/splits/val
# Moved p9_serflat_skelet3D_s2.npy to data/splits/train
# Moved p54_bslice_skelet3D_s3.npy to data/splits/train
# Moved p28_backhand2h_skelet3D_s3.npy to data/splits/test
# Moved p45_fslice_skelet3D_s3.npy to data/splits/val
# Moved p41_backhand_skelet3D_s2.npy to data/splits/train
# Moved p8_smash_skelet3D_s2.npy to data/splits/train
# Moved p44_serflat_skelet3D_s2.npy to data/splits/train
# Moved p29_fslice_skelet3D_s3.npy to data/splits/train
# Moved p26_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p32_serslice_skelet3D_s2.npy to data/splits/train
# Moved p54_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p25_serflat_skelet3D_s2.npy to data/splits/train
# Moved p42_serflat_skelet3D_s2.npy to data/splits/train
# Moved p9_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p13_bvolley_skelet3D_s1.npy to data/splits/test
# Moved p32_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p35_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p21_serkick_skelet3D_s3.npy to data/splits/train
# Moved p19_serflat_skelet3D_s3.npy to data/splits/train
# Moved p39_serkick_skelet3D_s3.npy to data/splits/train
# Moved p53_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p12_serkick_skelet3D_s2.npy to data/splits/train
# Moved p18_serflat_skelet3D_s3.npy to data/splits/test
# Moved p42_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p33_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p19_fslice_skelet3D_s3.npy to data/splits/train
# Moved p45_foreopen_skelet3D_s3.npy to data/splits/val
# Moved p36_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p55_serslice_skelet3D_s3.npy to data/splits/train
# Moved p53_serflat_skelet3D_s3.npy to data/splits/train
# Moved p55_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p47_serkick_skelet3D_s3.npy to data/splits/train
# Moved p51_serslice_skelet3D_s3.npy to data/splits/test
# Moved p16_backhand_skelet3D_s3.npy to data/splits/train
# Moved p53_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p28_foreflat_skelet3D_s2.npy to data/splits/test
# Moved p54_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p45_serslice_skelet3D_s3.npy to data/splits/val
# Moved p18_foreflat_skelet3D_s3.npy to data/splits/test
# Moved p35_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p7_serkick_skelet3D_s2.npy to data/splits/train
# Moved p28_serslice_skelet3D_s2.npy to data/splits/test
# Moved p18_foreopen_skelet3D_s3.npy to data/splits/test
# Moved p41_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p54_serkick_skelet3D_s3.npy to data/splits/train
# Moved p44_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p49_serkick_skelet3D_s2.npy to data/splits/train
# Moved p38_serkick_skelet3D_s3.npy to data/splits/val
# Moved p48_smash_skelet3D_s2.npy to data/splits/val
# Moved p41_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p43_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p23_serkick_skelet3D_s3.npy to data/splits/train
# Moved p36_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p52_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p54_serflat_skelet3D_s1.npy to data/splits/train
# Moved p36_fslice_skelet3D_s2.npy to data/splits/train
# Moved p52_backhand_skelet3D_s3.npy to data/splits/train
# Moved p50_serkick_skelet3D_s3.npy to data/splits/train
# Moved p54_fslice_skelet3D_s2.npy to data/splits/train
# Moved p14_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p40_serkick_skelet3D_s3.npy to data/splits/test
# Moved p35_backhand_skelet3D_s3.npy to data/splits/train
# Moved p51_bslice_skelet3D_s2.npy to data/splits/test
# Moved p39_bslice_skelet3D_s3.npy to data/splits/train
# Moved p4_foreopen_skelet3D_s1.npy to data/splits/train
# Moved p43_serslice_skelet3D_s3.npy to data/splits/train
# Moved p3_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p5_fvolley_skelet3D_s3.npy to data/splits/test
# Moved p48_backhand2h_skelet3D_s2.npy to data/splits/val
# Moved p42_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p17_bslice_skelet3D_s3.npy to data/splits/val
# Moved p7_smash_skelet3D_s2.npy to data/splits/train
# Moved p10_serflat_skelet3D_s2.npy to data/splits/train
# Moved p46_fslice_skelet3D_s3.npy to data/splits/val
# Moved p1_serkick_skelet3D_s1.npy to data/splits/train
# Moved p39_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p48_smash_skelet3D_s3.npy to data/splits/val
# Moved p33_serkick_skelet3D_s3.npy to data/splits/train
# Moved p1_fslice_skelet3D_s1.npy to data/splits/train
# Moved p43_serslice_skelet3D_s2.npy to data/splits/train
# Moved p44_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p9_foreopen_skelet3D_s1.npy to data/splits/train
# Moved p40_bslice_skelet3D_s3.npy to data/splits/test
# Moved p7_bslice_skelet3D_s3.npy to data/splits/train
# Moved p13_fvolley_skelet3D_s3.npy to data/splits/test
# Moved p11_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p31_fvolley_skelet3D_s3.npy to data/splits/val
# Moved p52_fslice_skelet3D_s2.npy to data/splits/train
# Moved p33_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p53_fslice_skelet3D_s3.npy to data/splits/train
# Moved p20_serslice_skelet3D_s2.npy to data/splits/val
# Moved p9_backhand_skelet3D_s2.npy to data/splits/train
# Moved p26_smash_skelet3D_s3.npy to data/splits/train
# Moved p25_smash_skelet3D_s2.npy to data/splits/train
# Moved p6_bslice_skelet3D_s1.npy to data/splits/train
# Moved p15_bslice_skelet3D_s3.npy to data/splits/test
# Moved p33_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p28_serkick_skelet3D_s3.npy to data/splits/test
# Moved p9_serflat_skelet3D_s3.npy to data/splits/train
# Moved p48_bvolley_skelet3D_s3.npy to data/splits/val
# Moved p31_foreflat_skelet3D_s3.npy to data/splits/val
# Moved p5_smash_skelet3D_s1.npy to data/splits/test
# Moved p29_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p49_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p9_serslice_skelet3D_s2.npy to data/splits/train
# Moved p41_serflat_skelet3D_s3.npy to data/splits/train
# Moved p24_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p44_serslice_skelet3D_s2.npy to data/splits/train
# Moved p54_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p9_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p34_foreopen_skelet3D_s3.npy to data/splits/val
# Moved p2_bslice_skelet3D_s3.npy to data/splits/train
# Moved p46_backhand_skelet3D_s2.npy to data/splits/val
# Moved p25_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p20_foreopen_skelet3D_s3.npy to data/splits/val
# Moved p49_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p51_backhand2h_skelet3D_s3.npy to data/splits/test
# Moved p14_serflat_skelet3D_s2.npy to data/splits/train
# Moved p54_serflat_skelet3D_s2.npy to data/splits/train
# Moved p36_bslice_skelet3D_s3.npy to data/splits/train
# Moved p39_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p12_backhand_skelet3D_s3.npy to data/splits/train
# Moved p15_fslice_skelet3D_s2.npy to data/splits/test
# Moved p35_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p36_serslice_skelet3D_s3.npy to data/splits/train
# Moved p24_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p39_serslice_skelet3D_s2.npy to data/splits/train
# Moved p29_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p39_fslice_skelet3D_s3.npy to data/splits/train
# Moved p35_backhand_skelet3D_s2.npy to data/splits/train
# Moved p2_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p17_serslice_skelet3D_s2.npy to data/splits/val
# Moved p4_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p46_serkick_skelet3D_s3.npy to data/splits/val
# Moved p26_backhand_skelet3D_s3.npy to data/splits/train
# Moved p3_serslice_skelet3D_s2.npy to data/splits/train
# Moved p3_backhand_skelet3D_s3.npy to data/splits/train
# Moved p27_backhand_skelet3D_s3.npy to data/splits/test
# Moved p14_backhand_skelet3D_s3.npy to data/splits/train
# Moved p18_bvolley_skelet3D_s3.npy to data/splits/test
# Moved p9_bslice_skelet3D_s2.npy to data/splits/train
# Moved p31_serflat_skelet3D_s2.npy to data/splits/val
# Moved p50_smash_skelet3D_s2.npy to data/splits/train
# Moved p41_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p23_fslice_skelet3D_s3.npy to data/splits/train
# Moved p27_serkick_skelet3D_s3.npy to data/splits/test
# Moved p16_serflat_skelet3D_s3.npy to data/splits/train
# Moved p29_bslice_skelet3D_s3.npy to data/splits/train
# Moved p10_serflat_skelet3D_s3.npy to data/splits/train
# Moved p6_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p1_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p46_backhand_skelet3D_s3.npy to data/splits/val
# Moved p40_foreflat_skelet3D_s3.npy to data/splits/test
# Moved p3_serkick_skelet3D_s2.npy to data/splits/train
# Moved p24_serflat_skelet3D_s2.npy to data/splits/train
# Moved p35_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p17_foreopen_skelet3D_s2.npy to data/splits/val
# Moved p4_foreflat_skelet3D_s1.npy to data/splits/train
# Moved p3_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p22_foreflat_skelet3D_s3.npy to data/splits/test
# Moved p39_serflat_skelet3D_s3.npy to data/splits/train
# Moved p40_backhand2h_skelet3D_s3.npy to data/splits/test
# Moved p28_serflat_skelet3D_s2.npy to data/splits/test
# Moved p41_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p7_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p51_fvolley_skelet3D_s3.npy to data/splits/test
# Moved p37_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p41_fslice_skelet3D_s2.npy to data/splits/train
# Moved p4_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p38_serslice_skelet3D_s3.npy to data/splits/val
# Moved p3_serkick_skelet3D_s3.npy to data/splits/train
# Moved p19_serkick_skelet3D_s2.npy to data/splits/train
# Moved p9_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p28_fvolley_skelet3D_s3.npy to data/splits/test
# Moved p25_serkick_skelet3D_s3.npy to data/splits/train
# Moved p25_serkick_skelet3D_s2.npy to data/splits/train
# Moved p27_serflat_skelet3D_s3.npy to data/splits/test
# Moved p15_foreflat_skelet3D_s2.npy to data/splits/test
# Moved p48_serflat_skelet3D_s3.npy to data/splits/val
# Moved p20_backhand_skelet3D_s3.npy to data/splits/val
# Moved p44_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p44_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p51_backhand_skelet3D_s1.npy to data/splits/test
# Moved p45_fvolley_skelet3D_s2.npy to data/splits/val
# Moved p49_serflat_skelet3D_s2.npy to data/splits/train
# Moved p3_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p10_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p38_foreflat_skelet3D_s2.npy to data/splits/val
# Moved p6_backhand2h_skelet3D_s1.npy to data/splits/train
# Moved p16_smash_skelet3D_s2.npy to data/splits/train
# Moved p38_fvolley_skelet3D_s3.npy to data/splits/val
# Moved p16_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p24_fslice_skelet3D_s3.npy to data/splits/train
# Moved p5_foreopen_skelet3D_s2.npy to data/splits/test
# Moved p6_smash_skelet3D_s2.npy to data/splits/train
# Moved p49_smash_skelet3D_s3.npy to data/splits/train
# Moved p19_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p17_fvolley_skelet3D_s3.npy to data/splits/val
# Moved p4_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p15_backhand_skelet3D_s3.npy to data/splits/test
# Moved p40_serslice_skelet3D_s2.npy to data/splits/test
# Moved p45_backhand2h_skelet3D_s2.npy to data/splits/val
# Moved p51_serslice_skelet3D_s1.npy to data/splits/test
# Moved p41_fslice_skelet3D_s3.npy to data/splits/train
# Moved p1_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p31_serflat_skelet3D_s3.npy to data/splits/val
# Moved p26_serkick_skelet3D_s3.npy to data/splits/train
# Moved p3_backhand_skelet3D_s1.npy to data/splits/train
# Moved p40_foreopen_skelet3D_s3.npy to data/splits/test
# Moved p20_serslice_skelet3D_s3.npy to data/splits/val
# Moved p10_smash_skelet3D_s3.npy to data/splits/train
# Moved p11_fslice_skelet3D_s2.npy to data/splits/train
# Moved p10_serkick_skelet3D_s3.npy to data/splits/train
# Moved p2_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p15_fvolley_skelet3D_s3.npy to data/splits/test
# Moved p8_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p30_smash_skelet3D_s3.npy to data/splits/train
# Moved p11_serslice_skelet3D_s3.npy to data/splits/train
# Moved p5_fslice_skelet3D_s2.npy to data/splits/test
# Moved p17_serflat_skelet3D_s2.npy to data/splits/val
# Moved p14_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p28_serflat_skelet3D_s3.npy to data/splits/test
# Moved p30_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p43_serflat_skelet3D_s3.npy to data/splits/train
# Moved p25_serslice_skelet3D_s2.npy to data/splits/train
# Moved p46_smash_skelet3D_s3.npy to data/splits/val
# Moved p4_fslice_skelet3D_s2.npy to data/splits/train
# Moved p44_fslice_skelet3D_s3.npy to data/splits/train
# Moved p17_smash_skelet3D_s3.npy to data/splits/val
# Moved p20_fvolley_skelet3D_s2.npy to data/splits/val
# Moved p6_serslice_skelet3D_s3.npy to data/splits/train
# Moved p32_backhand_skelet3D_s3.npy to data/splits/train
# Moved p5_bslice_skelet3D_s3.npy to data/splits/test
# Moved p39_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p44_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p2_serflat_skelet3D_s2.npy to data/splits/train
# Moved p5_bvolley_skelet3D_s3.npy to data/splits/test
# Moved p15_backhand2h_skelet3D_s2.npy to data/splits/test
# Moved p16_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p36_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p33_serslice_skelet3D_s2.npy to data/splits/train
# Moved p22_fslice_skelet3D_s3.npy to data/splits/test
# Moved p4_serflat_skelet3D_s3.npy to data/splits/train
# Moved p49_backhand_skelet3D_s2.npy to data/splits/train
# Moved p41_smash_skelet3D_s2.npy to data/splits/train
# Moved p21_serflat_skelet3D_s3.npy to data/splits/train
# Moved p8_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p14_serkick_skelet3D_s2.npy to data/splits/train
# Moved p38_serflat_skelet3D_s3.npy to data/splits/val
# Moved p36_fslice_skelet3D_s3.npy to data/splits/train
# Moved p2_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p19_serslice_skelet3D_s3.npy to data/splits/train
# Moved p14_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p53_fslice_skelet3D_s2.npy to data/splits/train
# Moved p23_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p19_fslice_skelet3D_s2.npy to data/splits/train
# Moved p19_serflat_skelet3D_s2.npy to data/splits/train
# Moved p13_bvolley_skelet3D_s2.npy to data/splits/test
# Moved p30_fvolley_skelet3D_s1.npy to data/splits/train
# Moved p17_foreflat_skelet3D_s2.npy to data/splits/val
# Moved p41_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p21_bslice_skelet3D_s2.npy to data/splits/train
# Moved p26_serslice_skelet3D_s3.npy to data/splits/train
# Moved p14_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p10_serslice_skelet3D_s3.npy to data/splits/train
# Moved p40_serflat_skelet3D_s1.npy to data/splits/test
# Moved p47_bslice_skelet3D_s3.npy to data/splits/train
# Moved p34_backhand_skelet3D_s3.npy to data/splits/val
# Moved p34_bvolley_skelet3D_s3.npy to data/splits/val
# Moved p12_smash_skelet3D_s2.npy to data/splits/train
# Moved p50_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p48_fvolley_skelet3D_s3.npy to data/splits/val
# Moved p47_backhand_skelet3D_s3.npy to data/splits/train
# Moved p49_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p53_serslice_skelet3D_s2.npy to data/splits/train
# Moved p49_serslice_skelet3D_s3.npy to data/splits/train
# Moved p2_serflat_skelet3D_s1.npy to data/splits/train
# Moved p31_backhand2h_skelet3D_s1.npy to data/splits/val
# Moved p31_serkick_skelet3D_s1.npy to data/splits/val
# Moved p5_backhand2h_skelet3D_s2.npy to data/splits/test
# Moved p29_serkick_skelet3D_s2.npy to data/splits/train
# Moved p29_serflat_skelet3D_s3.npy to data/splits/train
# Moved p45_fvolley_skelet3D_s3.npy to data/splits/val
# Moved p19_smash_skelet3D_s3.npy to data/splits/train
# Moved p2_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p18_bslice_skelet3D_s3.npy to data/splits/test
# Moved p50_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p12_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p48_bvolley_skelet3D_s1.npy to data/splits/val
# Moved p34_serflat_skelet3D_s3.npy to data/splits/val
# Moved p18_serslice_skelet3D_s2.npy to data/splits/test
# Moved p11_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p32_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p54_smash_skelet3D_s3.npy to data/splits/train
# Moved p1_serflat_skelet3D_s3.npy to data/splits/train
# Moved p1_serkick_skelet3D_s2.npy to data/splits/train
# Moved p6_bslice_skelet3D_s3.npy to data/splits/train
# Moved p48_foreflat_skelet3D_s3.npy to data/splits/val
# Moved p20_fslice_skelet3D_s3.npy to data/splits/val
# Moved p39_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p16_bslice_skelet3D_s3.npy to data/splits/train
# Moved p11_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p47_fslice_skelet3D_s3.npy to data/splits/train
# Moved p13_fvolley_skelet3D_s2.npy to data/splits/test
# Moved p47_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p28_fslice_skelet3D_s3.npy to data/splits/test
# Moved p1_serslice_skelet3D_s3.npy to data/splits/train
# Moved p52_serkick_skelet3D_s2.npy to data/splits/train
# Moved p13_serkick_skelet3D_s3.npy to data/splits/test
# Moved p15_serflat_skelet3D_s3.npy to data/splits/test
# Moved p13_fslice_skelet3D_s3.npy to data/splits/test
# Moved p2_fslice_skelet3D_s3.npy to data/splits/train
# Moved p54_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p16_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p2_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p48_bvolley_skelet3D_s2.npy to data/splits/val
# Moved p5_serkick_skelet3D_s3.npy to data/splits/test
# Moved p5_fvolley_skelet3D_s2.npy to data/splits/test
# Moved p1_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p38_backhand2h_skelet3D_s3.npy to data/splits/val
# Moved p36_smash_skelet3D_s3.npy to data/splits/train
# Moved p21_serslice_skelet3D_s3.npy to data/splits/train
# Moved p10_fslice_skelet3D_s3.npy to data/splits/train
# Moved p5_backhand_skelet3D_s3.npy to data/splits/test
# Moved p26_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p23_smash_skelet3D_s3.npy to data/splits/train
# Moved p33_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p27_foreflat_skelet3D_s3.npy to data/splits/test
# Moved p51_backhand_skelet3D_s3.npy to data/splits/test
# Moved p16_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p51_fslice_skelet3D_s2.npy to data/splits/test
# Moved p11_serkick_skelet3D_s3.npy to data/splits/train
# Moved p2_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p34_backhand2h_skelet3D_s3.npy to data/splits/val
# Moved p42_bslice_skelet3D_s3.npy to data/splits/train
# Moved p13_smash_skelet3D_s2.npy to data/splits/test
# Moved p26_bslice_skelet3D_s2.npy to data/splits/train
# Moved p10_smash_skelet3D_s2.npy to data/splits/train
# Moved p54_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p11_serflat_skelet3D_s3.npy to data/splits/train
# Moved p18_foreopen_skelet3D_s2.npy to data/splits/test
# Moved p7_smash_skelet3D_s3.npy to data/splits/train
# Moved p7_serflat_skelet3D_s3.npy to data/splits/train
# Moved p52_serkick_skelet3D_s3.npy to data/splits/train
# Moved p18_bvolley_skelet3D_s2.npy to data/splits/test
# Moved p15_smash_skelet3D_s3.npy to data/splits/test
# Moved p52_bslice_skelet3D_s2.npy to data/splits/train
# Moved p55_smash_skelet3D_s3.npy to data/splits/train
# Moved p4_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p37_fslice_skelet3D_s2.npy to data/splits/train
# Moved p24_serkick_skelet3D_s2.npy to data/splits/train
# Moved p33_serslice_skelet3D_s3.npy to data/splits/train
# Moved p51_backhand2h_skelet3D_s2.npy to data/splits/test
# Moved p2_smash_skelet3D_s3.npy to data/splits/train
# Moved p32_serkick_skelet3D_s3.npy to data/splits/train
# Moved p12_fslice_skelet3D_s3.npy to data/splits/train
# Moved p1_serslice_skelet3D_s2.npy to data/splits/train
# Moved p9_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p16_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p26_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p22_bslice_skelet3D_s3.npy to data/splits/test
# Moved p53_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p53_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p46_serflat_skelet3D_s2.npy to data/splits/val
# Moved p52_fslice_skelet3D_s3.npy to data/splits/train
# Moved p40_bvolley_skelet3D_s3.npy to data/splits/test
# Moved p51_bvolley_skelet3D_s1.npy to data/splits/test
# Moved p12_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p43_backhand_skelet3D_s2.npy to data/splits/train
# Moved p46_foreflat_skelet3D_s3.npy to data/splits/val
# Moved p43_fslice_skelet3D_s3.npy to data/splits/train
# Moved p42_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p42_fslice_skelet3D_s2.npy to data/splits/train
# Moved p5_foreflat_skelet3D_s3.npy to data/splits/test
# Moved p18_serkick_skelet3D_s3.npy to data/splits/test
# Moved p4_serslice_skelet3D_s2.npy to data/splits/train
# Moved p37_bslice_skelet3D_s2.npy to data/splits/train
# Moved p30_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p20_smash_skelet3D_s3.npy to data/splits/val
# Moved p25_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p35_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p6_serflat_skelet3D_s2.npy to data/splits/train
# Moved p26_serflat_skelet3D_s2.npy to data/splits/train
# Moved p9_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p48_serkick_skelet3D_s3.npy to data/splits/val
# Moved p42_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p9_serkick_skelet3D_s3.npy to data/splits/train
# Moved p4_smash_skelet3D_s3.npy to data/splits/train
# Moved p53_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p25_bslice_skelet3D_s3.npy to data/splits/train
# Moved p2_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p50_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p7_fslice_skelet3D_s3.npy to data/splits/train
# Moved p30_serslice_skelet3D_s3.npy to data/splits/train
# Moved p11_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p49_serkick_skelet3D_s1.npy to data/splits/train
# Moved p54_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p48_bslice_skelet3D_s2.npy to data/splits/val
# Moved p29_serkick_skelet3D_s3.npy to data/splits/train
# Moved p21_serflat_skelet3D_s2.npy to data/splits/train
# Moved p12_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p40_smash_skelet3D_s2.npy to data/splits/test
# Moved p40_foreflat_skelet3D_s2.npy to data/splits/test
# Moved p40_fvolley_skelet3D_s2.npy to data/splits/test
# Moved p9_serslice_skelet3D_s3.npy to data/splits/train
# Moved p55_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p10_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p28_backhand2h_skelet3D_s2.npy to data/splits/test
# Moved p31_backhand2h_skelet3D_s2.npy to data/splits/val
# Moved p2_fslice_skelet3D_s2.npy to data/splits/train
# Moved p24_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p37_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p7_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p31_fslice_skelet3D_s2.npy to data/splits/val
# Moved p17_backhand2h_skelet3D_s2.npy to data/splits/val
# Moved p8_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p36_serkick_skelet3D_s2.npy to data/splits/train
# Moved p21_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p39_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p31_bvolley_skelet3D_s2.npy to data/splits/val
# Moved p49_serkick_skelet3D_s3.npy to data/splits/train
# Moved p50_bslice_skelet3D_s3.npy to data/splits/train
# Moved p13_backhand_skelet3D_s3.npy to data/splits/test
# Moved p18_serflat_skelet3D_s2.npy to data/splits/test
# Moved p5_backhand2h_skelet3D_s3.npy to data/splits/test
# Moved p3_foreopen_skelet3D_s1.npy to data/splits/train
# Moved p17_foreflat_skelet3D_s3.npy to data/splits/val
# Moved p31_foreopen_skelet3D_s2.npy to data/splits/val
# Moved p31_fvolley_skelet3D_s2.npy to data/splits/val
# Moved p44_smash_skelet3D_s2.npy to data/splits/train
# Moved p24_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p8_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p46_fvolley_skelet3D_s3.npy to data/splits/val
# Moved p39_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p13_fslice_skelet3D_s2.npy to data/splits/test
# Moved p5_foreopen_skelet3D_s3.npy to data/splits/test
# Moved p2_serkick_skelet3D_s3.npy to data/splits/train
# Moved p32_serflat_skelet3D_s2.npy to data/splits/train
# Moved p30_bslice_skelet3D_s2.npy to data/splits/train
# Moved p51_smash_skelet3D_s3.npy to data/splits/test
# Moved p48_foreflat_skelet3D_s2.npy to data/splits/val
# Moved p50_bslice_skelet3D_s2.npy to data/splits/train
# Moved p35_serkick_skelet3D_s3.npy to data/splits/train
# Moved p17_serkick_skelet3D_s2.npy to data/splits/val
# Moved p16_bslice_skelet3D_s2.npy to data/splits/train
# Moved p8_serflat_skelet3D_s2.npy to data/splits/train
# Moved p34_smash_skelet3D_s3.npy to data/splits/val
# Moved p25_serflat_skelet3D_s3.npy to data/splits/train
# Moved p21_serslice_skelet3D_s2.npy to data/splits/train
# Moved p27_backhand2h_skelet3D_s3.npy to data/splits/test
# Moved p47_serslice_skelet3D_s2.npy to data/splits/train
# Moved p29_smash_skelet3D_s2.npy to data/splits/train
# Moved p8_backhand_skelet3D_s3.npy to data/splits/train
# Moved p15_serslice_skelet3D_s3.npy to data/splits/test
# Moved p4_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p43_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p8_fslice_skelet3D_s2.npy to data/splits/train
# Moved p3_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p44_serkick_skelet3D_s1.npy to data/splits/train
# Moved p34_fvolley_skelet3D_s3.npy to data/splits/val
# Moved p33_fslice_skelet3D_s3.npy to data/splits/train
# Moved p48_bslice_skelet3D_s3.npy to data/splits/val
# Moved p13_bvolley_skelet3D_s3.npy to data/splits/test
# Moved p38_fslice_skelet3D_s2.npy to data/splits/val
# Moved p16_serslice_skelet3D_s2.npy to data/splits/train
# Moved p24_bslice_skelet3D_s3.npy to data/splits/train
# Moved p45_foreopen_skelet3D_s2.npy to data/splits/val
# Moved p16_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p47_smash_skelet3D_s2.npy to data/splits/train
# Moved p44_serkick_skelet3D_s3.npy to data/splits/train
# Moved p47_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p22_bvolley_skelet3D_s3.npy to data/splits/test
# Moved p53_backhand_skelet3D_s1.npy to data/splits/train
# Moved p49_bslice_skelet3D_s3.npy to data/splits/train
# Moved p5_smash_skelet3D_s3.npy to data/splits/test
# Moved p25_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p20_foreflat_skelet3D_s2.npy to data/splits/val
# Moved p21_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p44_smash_skelet3D_s3.npy to data/splits/train
# Moved p34_foreflat_skelet3D_s2.npy to data/splits/val
# Moved p48_fslice_skelet3D_s3.npy to data/splits/val
# Moved p53_serflat_skelet3D_s2.npy to data/splits/train
# Moved p16_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p42_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p39_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p17_bvolley_skelet3D_s3.npy to data/splits/val
# Moved p38_serkick_skelet3D_s2.npy to data/splits/val
# Moved p46_serslice_skelet3D_s2.npy to data/splits/val
# Moved p53_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p38_backhand2h_skelet3D_s2.npy to data/splits/val
# Moved p52_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p30_serkick_skelet3D_s3.npy to data/splits/train
# Moved p51_foreopen_skelet3D_s2.npy to data/splits/test
# Moved p39_backhand_skelet3D_s3.npy to data/splits/train
# Moved p36_backhand_skelet3D_s2.npy to data/splits/train
# Moved p42_fslice_skelet3D_s3.npy to data/splits/train
# Moved p30_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p23_fslice_skelet3D_s2.npy to data/splits/train
# Moved p23_serkick_skelet3D_s2.npy to data/splits/train
# Moved p22_backhand_skelet3D_s3.npy to data/splits/test
# Moved p31_fslice_skelet3D_s3.npy to data/splits/val
# Moved p48_serslice_skelet3D_s2.npy to data/splits/val
# Moved p28_bvolley_skelet3D_s3.npy to data/splits/test
# Moved p48_backhand_skelet3D_s2.npy to data/splits/val
# Moved p1_fslice_skelet3D_s2.npy to data/splits/train
# Moved p22_fvolley_skelet3D_s2.npy to data/splits/test
# Moved p1_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p22_bslice_skelet3D_s2.npy to data/splits/test
# Moved p35_serflat_skelet3D_s2.npy to data/splits/train
# Moved p52_backhand2h_skelet3D_s1.npy to data/splits/train
# Moved p45_serflat_skelet3D_s3.npy to data/splits/val
# Moved p38_smash_skelet3D_s2.npy to data/splits/val
# Moved p40_fvolley_skelet3D_s3.npy to data/splits/test
# Moved p53_bslice_skelet3D_s2.npy to data/splits/train
# Moved p30_serflat_skelet3D_s3.npy to data/splits/train
# Moved p34_fslice_skelet3D_s3.npy to data/splits/val
# Moved p23_serflat_skelet3D_s3.npy to data/splits/train
# Moved p21_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p52_smash_skelet3D_s2.npy to data/splits/train
# Moved p30_bslice_skelet3D_s3.npy to data/splits/train
# Moved p55_smash_skelet3D_s2.npy to data/splits/train
# Moved p4_serkick_skelet3D_s3.npy to data/splits/train
# Moved p48_serslice_skelet3D_s3.npy to data/splits/val
# Moved p24_backhand_skelet3D_s3.npy to data/splits/train
# Moved p9_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p34_bslice_skelet3D_s2.npy to data/splits/val
# Moved p3_bslice_skelet3D_s3.npy to data/splits/train
# Moved p29_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p55_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p47_backhand_skelet3D_s2.npy to data/splits/train
# Moved p43_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p13_serslice_skelet3D_s2.npy to data/splits/test
# Moved p24_bslice_skelet3D_s2.npy to data/splits/train
# Moved p32_fslice_skelet3D_s3.npy to data/splits/train
# Moved p3_serflat_skelet3D_s3.npy to data/splits/train
# Moved p13_serkick_skelet3D_s2.npy to data/splits/test
# Moved p46_bvolley_skelet3D_s2.npy to data/splits/val
# Moved p52_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p49_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p1_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p50_fslice_skelet3D_s3.npy to data/splits/train
# Moved p16_serflat_skelet3D_s2.npy to data/splits/train
# Moved p3_fslice_skelet3D_s3.npy to data/splits/train
# Moved p54_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p44_serslice_skelet3D_s3.npy to data/splits/train
# Moved p53_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p11_serkick_skelet3D_s1.npy to data/splits/train
# Moved p30_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p43_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p30_backhand_skelet3D_s3.npy to data/splits/train
# Moved p25_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p12_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p23_backhand_skelet3D_s2.npy to data/splits/train
# Moved p47_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p4_bslice_skelet3D_s2.npy to data/splits/train
# Moved p7_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p20_bslice_skelet3D_s3.npy to data/splits/val
# Moved p31_smash_skelet3D_s2.npy to data/splits/val
# Moved p26_smash_skelet3D_s2.npy to data/splits/train
# Moved p43_smash_skelet3D_s3.npy to data/splits/train
# Moved p26_backhand_skelet3D_s1.npy to data/splits/train
# Moved p7_serkick_skelet3D_s1.npy to data/splits/train
# Moved p5_fslice_skelet3D_s3.npy to data/splits/test
# Moved p35_smash_skelet3D_s2.npy to data/splits/train
# Moved p15_fslice_skelet3D_s3.npy to data/splits/test
# Moved p10_serslice_skelet3D_s2.npy to data/splits/train
# Moved p16_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p46_fvolley_skelet3D_s2.npy to data/splits/val
# Moved p34_serkick_skelet3D_s3.npy to data/splits/val
# Moved p29_backhand_skelet3D_s3.npy to data/splits/train
# Moved p15_fvolley_skelet3D_s2.npy to data/splits/test
# Moved p10_fslice_skelet3D_s2.npy to data/splits/train
# Moved p16_serkick_skelet3D_s2.npy to data/splits/train
# Moved p10_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p53_serkick_skelet3D_s2.npy to data/splits/train
# Moved p23_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p40_serflat_skelet3D_s3.npy to data/splits/test
# Moved p12_serflat_skelet3D_s3.npy to data/splits/train
# Moved p6_fslice_skelet3D_s3.npy to data/splits/train
# Moved p14_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p54_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p37_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p41_serslice_skelet3D_s3.npy to data/splits/train
# Moved p24_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p20_bslice_skelet3D_s1.npy to data/splits/val
# Moved p49_serflat_skelet3D_s3.npy to data/splits/train
# Moved p29_serslice_skelet3D_s3.npy to data/splits/train
# Moved p47_smash_skelet3D_s3.npy to data/splits/train
# Moved p50_serslice_skelet3D_s2.npy to data/splits/train
# Moved p6_backhand_skelet3D_s2.npy to data/splits/train
# Moved p11_backhand_skelet3D_s2.npy to data/splits/train
# Moved p3_smash_skelet3D_s3.npy to data/splits/train
# Moved p54_backhand_skelet3D_s1.npy to data/splits/train
# Moved p37_fslice_skelet3D_s3.npy to data/splits/train
# Moved p43_fslice_skelet3D_s2.npy to data/splits/train
# Moved p13_foreflat_skelet3D_s3.npy to data/splits/test
# Moved p41_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p28_foreflat_skelet3D_s3.npy to data/splits/test
# Moved p25_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p53_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p42_smash_skelet3D_s3.npy to data/splits/train
# Moved p41_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p25_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p53_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p23_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p51_serkick_skelet3D_s2.npy to data/splits/test
# Moved p20_bslice_skelet3D_s2.npy to data/splits/val
# Moved p4_bslice_skelet3D_s3.npy to data/splits/train
# Moved p54_serflat_skelet3D_s3.npy to data/splits/train
# Moved p19_backhand_skelet3D_s2.npy to data/splits/train
# Moved p54_backhand_skelet3D_s2.npy to data/splits/train
# Moved p36_bslice_skelet3D_s2.npy to data/splits/train
# Moved p3_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p23_serflat_skelet3D_s2.npy to data/splits/train
# Moved p14_bslice_skelet3D_s2.npy to data/splits/train
# Moved p52_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p1_bslice_skelet3D_s3.npy to data/splits/train
# Moved p1_fslice_skelet3D_s3.npy to data/splits/train
# Moved p21_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p22_fvolley_skelet3D_s3.npy to data/splits/test
# Moved p36_backhand_skelet3D_s3.npy to data/splits/train
# Moved p53_serkick_skelet3D_s3.npy to data/splits/train
# Moved p47_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p38_serslice_skelet3D_s2.npy to data/splits/val
# Moved p51_bvolley_skelet3D_s3.npy to data/splits/test
# Moved p31_backhand_skelet3D_s3.npy to data/splits/val
# Moved p28_fvolley_skelet3D_s2.npy to data/splits/test
# Moved p21_smash_skelet3D_s3.npy to data/splits/train
# Moved p7_fslice_skelet3D_s2.npy to data/splits/train
# Moved p44_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p53_foreopen_skelet3D_s1.npy to data/splits/train
# Moved p19_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p1_serkick_skelet3D_s3.npy to data/splits/train
# Moved p14_fslice_skelet3D_s2.npy to data/splits/train
# Moved p11_serkick_skelet3D_s2.npy to data/splits/train
# Moved p55_serkick_skelet3D_s2.npy to data/splits/train
# Moved p49_bslice_skelet3D_s2.npy to data/splits/train
# Moved p18_backhand_skelet3D_s3.npy to data/splits/test
# Moved p53_backhand_skelet3D_s3.npy to data/splits/train
# Moved p23_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p17_serslice_skelet3D_s3.npy to data/splits/val
# Moved p16_smash_skelet3D_s1.npy to data/splits/train
# Moved p32_serflat_skelet3D_s3.npy to data/splits/train
# Moved p8_fslice_skelet3D_s3.npy to data/splits/train
# Moved p10_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p29_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p16_serslice_skelet3D_s1.npy to data/splits/train
# Moved p17_fslice_skelet3D_s2.npy to data/splits/val
# Moved p4_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p19_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p12_smash_skelet3D_s3.npy to data/splits/train
# Moved p46_backhand2h_skelet3D_s2.npy to data/splits/val
# Moved p22_backhand2h_skelet3D_s2.npy to data/splits/test
# Moved p38_foreopen_skelet3D_s2.npy to data/splits/val
# Moved p43_backhand_skelet3D_s3.npy to data/splits/train
# Moved p10_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p28_bvolley_skelet3D_s2.npy to data/splits/test
# Moved p29_serflat_skelet3D_s2.npy to data/splits/train
# Moved p34_serflat_skelet3D_s2.npy to data/splits/val
# Moved p10_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p45_serkick_skelet3D_s3.npy to data/splits/val
# Moved p8_smash_skelet3D_s3.npy to data/splits/train
# Moved p1_smash_skelet3D_s2.npy to data/splits/train
# Moved p17_serflat_skelet3D_s3.npy to data/splits/val
# Moved p20_backhand2h_skelet3D_s3.npy to data/splits/val
# Moved p2_smash_skelet3D_s2.npy to data/splits/train
# Moved p16_serslice_skelet3D_s3.npy to data/splits/train
# Moved p32_serslice_skelet3D_s3.npy to data/splits/train
# Moved p8_serslice_skelet3D_s2.npy to data/splits/train
# Moved p4_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p42_serslice_skelet3D_s3.npy to data/splits/train
# Moved p52_backhand_skelet3D_s2.npy to data/splits/train
# Moved p52_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p3_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p18_backhand2h_skelet3D_s2.npy to data/splits/test
# Moved p38_serflat_skelet3D_s2.npy to data/splits/val
# Moved p35_smash_skelet3D_s3.npy to data/splits/train
# Moved p17_serkick_skelet3D_s1.npy to data/splits/val
# Moved p1_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p32_smash_skelet3D_s3.npy to data/splits/train
# Moved p34_serkick_skelet3D_s2.npy to data/splits/val
# Moved p7_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p49_foreflat_skelet3D_s1.npy to data/splits/train
# Moved p28_foreopen_skelet3D_s3.npy to data/splits/test
# Moved p43_serkick_skelet3D_s3.npy to data/splits/train
# Moved p4_serslice_skelet3D_s3.npy to data/splits/train
# Moved p46_backhand2h_skelet3D_s3.npy to data/splits/val
# Moved p16_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p18_fslice_skelet3D_s3.npy to data/splits/test
# Moved p14_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p13_bslice_skelet3D_s3.npy to data/splits/test
# Moved p15_foreopen_skelet3D_s3.npy to data/splits/test
# Moved p18_serkick_skelet3D_s2.npy to data/splits/test
# Moved p29_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p35_fslice_skelet3D_s3.npy to data/splits/train
# Moved p26_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p44_bslice_skelet3D_s3.npy to data/splits/train
# Moved p10_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p55_foreopen_skelet3D_s1.npy to data/splits/train
# Moved p43_serkick_skelet3D_s2.npy to data/splits/train
# Moved p38_smash_skelet3D_s3.npy to data/splits/val
# Moved p14_serslice_skelet3D_s2.npy to data/splits/train
# Moved p4_serkick_skelet3D_s2.npy to data/splits/train
# Moved p52_smash_skelet3D_s3.npy to data/splits/train
# Moved p37_backhand_skelet3D_s3.npy to data/splits/train
# Moved p20_foreopen_skelet3D_s2.npy to data/splits/val
# Moved p30_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p35_serslice_skelet3D_s2.npy to data/splits/train
# Moved p30_fslice_skelet3D_s3.npy to data/splits/train
# Moved p42_backhand_skelet3D_s3.npy to data/splits/train
# Moved p27_foreflat_skelet3D_s2.npy to data/splits/test
# Moved p18_bslice_skelet3D_s2.npy to data/splits/test
# Moved p3_fslice_skelet3D_s2.npy to data/splits/train
# Moved p18_fslice_skelet3D_s2.npy to data/splits/test
# Moved p19_bslice_skelet3D_s2.npy to data/splits/train
# Moved p46_bslice_skelet3D_s3.npy to data/splits/val
# Moved p34_serslice_skelet3D_s3.npy to data/splits/val
# Moved p25_fslice_skelet3D_s3.npy to data/splits/train
# Moved p41_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p55_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p20_foreflat_skelet3D_s3.npy to data/splits/val
# Moved p48_fvolley_skelet3D_s2.npy to data/splits/val
# Moved p51_serflat_skelet3D_s3.npy to data/splits/test
# Moved p35_serflat_skelet3D_s3.npy to data/splits/train
# Moved p38_foreflat_skelet3D_s3.npy to data/splits/val
# Moved p31_bvolley_skelet3D_s3.npy to data/splits/val
# Moved p30_serflat_skelet3D_s2.npy to data/splits/train
# Moved p49_fslice_skelet3D_s3.npy to data/splits/train
# Moved p14_smash_skelet3D_s3.npy to data/splits/train
# Moved p9_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p30_backhand_skelet3D_s2.npy to data/splits/train
# Moved p10_backhand_skelet3D_s2.npy to data/splits/train
# Moved p13_backhand2h_skelet3D_s3.npy to data/splits/test
# Moved p18_fvolley_skelet3D_s3.npy to data/splits/test
# Moved p48_backhand_skelet3D_s3.npy to data/splits/val
# Moved p32_serkick_skelet3D_s2.npy to data/splits/train
# Moved p23_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p20_serkick_skelet3D_s2.npy to data/splits/val
# Moved p20_backhand2h_skelet3D_s2.npy to data/splits/val
# Moved p27_backhand2h_skelet3D_s2.npy to data/splits/test
# Moved p17_fslice_skelet3D_s3.npy to data/splits/val
# Moved p36_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p42_backhand_skelet3D_s2.npy to data/splits/train
# Moved p20_bvolley_skelet3D_s2.npy to data/splits/val
# Moved p47_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p25_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p21_serslice_skelet3D_s1.npy to data/splits/train
# Moved p53_smash_skelet3D_s2.npy to data/splits/train
# Moved p51_foreopen_skelet3D_s3.npy to data/splits/test
# Moved p53_bslice_skelet3D_s3.npy to data/splits/train
# Moved p14_serkick_skelet3D_s3.npy to data/splits/train
# Moved p26_serslice_skelet3D_s2.npy to data/splits/train
# Moved p6_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p31_serslice_skelet3D_s3.npy to data/splits/val
# Moved p44_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p9_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p43_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p49_backhand_skelet3D_s3.npy to data/splits/train
# Moved p10_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p42_serslice_skelet3D_s2.npy to data/splits/train
# Moved p24_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p10_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p42_serkick_skelet3D_s3.npy to data/splits/train
# Moved p2_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p15_serkick_skelet3D_s2.npy to data/splits/test
# Moved p6_bslice_skelet3D_s2.npy to data/splits/train
# Moved p24_backhand_skelet3D_s2.npy to data/splits/train
# Moved p43_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p12_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p20_bvolley_skelet3D_s3.npy to data/splits/val
# Moved p30_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p31_foreflat_skelet3D_s1.npy to data/splits/val
# Moved p6_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p31_bslice_skelet3D_s2.npy to data/splits/val
# Moved p31_serkick_skelet3D_s2.npy to data/splits/val
# Moved p30_fslice_skelet3D_s2.npy to data/splits/train
# Moved p31_smash_skelet3D_s3.npy to data/splits/val
# Moved p33_bslice_skelet3D_s3.npy to data/splits/train
# Moved p46_bslice_skelet3D_s2.npy to data/splits/val
# Moved p50_backhand_skelet3D_s3.npy to data/splits/train
# Moved p14_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p26_serkick_skelet3D_s2.npy to data/splits/train
# Moved p8_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p19_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p6_serslice_skelet3D_s2.npy to data/splits/train
# Moved p1_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p23_backhand_skelet3D_s3.npy to data/splits/train
# Moved p35_bslice_skelet3D_s3.npy to data/splits/train
# Moved p46_serkick_skelet3D_s2.npy to data/splits/val
# Moved p27_backhand_skelet3D_s2.npy to data/splits/test
# Moved p39_smash_skelet3D_s2.npy to data/splits/train
# Moved p23_bslice_skelet3D_s2.npy to data/splits/train
# Moved p55_backhand_skelet3D_s2.npy to data/splits/train
# Moved p17_bvolley_skelet3D_s2.npy to data/splits/val
# Moved p44_serflat_skelet3D_s1.npy to data/splits/train
# Moved p40_foreopen_skelet3D_s2.npy to data/splits/test
# Moved p23_serslice_skelet3D_s2.npy to data/splits/train
# Moved p40_bslice_skelet3D_s2.npy to data/splits/test
# Moved p3_foreflat_skelet3D_s1.npy to data/splits/train
# Moved p26_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p19_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p45_bvolley_skelet3D_s3.npy to data/splits/val
# Moved p52_serflat_skelet3D_s2.npy to data/splits/train
# Moved p20_backhand_skelet3D_s2.npy to data/splits/val
# Moved p52_serslice_skelet3D_s3.npy to data/splits/train
# Moved p44_backhand_skelet3D_s3.npy to data/splits/train
# Moved p24_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p36_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p39_serkick_skelet3D_s2.npy to data/splits/train
# Moved p28_serslice_skelet3D_s3.npy to data/splits/test
# Moved p54_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p14_backhand_skelet3D_s2.npy to data/splits/train
# Moved p27_foreopen_skelet3D_s3.npy to data/splits/test
# Moved p33_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p14_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p20_serflat_skelet3D_s2.npy to data/splits/val
# Moved p2_backhand_skelet3D_s3.npy to data/splits/train
# Moved p1_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p31_backhand2h_skelet3D_s3.npy to data/splits/val
# Moved p55_serkick_skelet3D_s3.npy to data/splits/train
# Moved p26_serflat_skelet3D_s3.npy to data/splits/train
# Moved p35_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p36_serflat_skelet3D_s3.npy to data/splits/train
# Moved p33_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p29_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p48_foreopen_skelet3D_s3.npy to data/splits/val
# Moved p53_bslice_skelet3D_s1.npy to data/splits/train
# Moved p51_bslice_skelet3D_s3.npy to data/splits/test
# Moved p29_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p38_backhand_skelet3D_s2.npy to data/splits/val
# Moved p18_foreflat_skelet3D_s2.npy to data/splits/test
# Moved p49_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p19_backhand_skelet3D_s3.npy to data/splits/train
# Moved p3_bslice_skelet3D_s2.npy to data/splits/train
# Moved p54_serslice_skelet3D_s2.npy to data/splits/train
# Moved p37_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p33_bslice_skelet3D_s2.npy to data/splits/train
# Moved p21_backhand_skelet3D_s2.npy to data/splits/train
# Moved p13_foreopen_skelet3D_s2.npy to data/splits/test
# Moved p21_backhand_skelet3D_s3.npy to data/splits/train
# Moved p8_serslice_skelet3D_s3.npy to data/splits/train
# Moved p29_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p54_serslice_skelet3D_s3.npy to data/splits/train
# Moved p18_smash_skelet3D_s3.npy to data/splits/test
# Moved p38_bvolley_skelet3D_s2.npy to data/splits/val
# Moved p7_serkick_skelet3D_s3.npy to data/splits/train
# Moved p50_serkick_skelet3D_s2.npy to data/splits/train
# Moved p49_serslice_skelet3D_s2.npy to data/splits/train
# Moved p8_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p52_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p23_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p7_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p36_smash_skelet3D_s2.npy to data/splits/train
# Moved p24_serflat_skelet3D_s3.npy to data/splits/train
# Moved p52_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p51_foreflat_skelet3D_s3.npy to data/splits/test
# Moved p13_bslice_skelet3D_s2.npy to data/splits/test
# ...
# Moved p26_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p26_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p36_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p15_smash_skelet3D_s2.npy to data/splits/test
# Moved p37_backhand_skelet3D_s2.npy to data/splits/train
# Moved p42_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p24_smash_skelet3D_s2.npy to data/splits/train
# Moved p54_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p18_fvolley_skelet3D_s2.npy to data/splits/test
# Moved p4_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p42_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p23_backhand_skelet3D_s1.npy to data/splits/train
# Moved p25_fslice_skelet3D_s2.npy to data/splits/train
# Moved p21_fslice_skelet3D_s2.npy to data/splits/train
# Moved p28_smash_skelet3D_s1.npy to data/splits/test
# Moved p27_serslice_skelet3D_s3.npy to data/splits/test
# Moved p41_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p37_bslice_skelet3D_s3.npy to data/splits/train
# Moved p33_serflat_skelet3D_s3.npy to data/splits/train
# Moved p46_fslice_skelet3D_s2.npy to data/splits/val
# Moved p30_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p4_backhand_skelet3D_s2.npy to data/splits/train
# Moved p15_serflat_skelet3D_s2.npy to data/splits/test
# Moved p46_foreopen_skelet3D_s2.npy to data/splits/val
# Moved p40_backhand_skelet3D_s3.npy to data/splits/test
# Moved p42_serkick_skelet3D_s2.npy to data/splits/train
# Moved p5_foreflat_skelet3D_s2.npy to data/splits/test
# Moved p12_bslice_skelet3D_s3.npy to data/splits/train
# Moved p26_backhand_skelet3D_s2.npy to data/splits/train
# Moved p14_serflat_skelet3D_s3.npy to data/splits/train
# Moved p19_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p19_serkick_skelet3D_s3.npy to data/splits/train
# Moved p5_smash_skelet3D_s2.npy to data/splits/test
# Moved p38_bslice_skelet3D_s3.npy to data/splits/val
# Moved p17_backhand_skelet3D_s3.npy to data/splits/val
# Moved p27_bvolley_skelet3D_s3.npy to data/splits/test
# Moved p11_bslice_skelet3D_s3.npy to data/splits/train
# Moved p45_foreflat_skelet3D_s2.npy to data/splits/val
# Moved p40_serslice_skelet3D_s3.npy to data/splits/test
# Moved p16_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p13_smash_skelet3D_s3.npy to data/splits/test
# Moved p42_bslice_skelet3D_s2.npy to data/splits/train
# Moved p21_fslice_skelet3D_s3.npy to data/splits/train
# Moved p8_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p11_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p38_backhand_skelet3D_s3.npy to data/splits/val
# Moved p43_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p50_smash_skelet3D_s3.npy to data/splits/train
# Moved p25_smash_skelet3D_s3.npy to data/splits/train
# Moved p29_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p22_fslice_skelet3D_s2.npy to data/splits/test
# Moved p19_smash_skelet3D_s2.npy to data/splits/train
# Moved p6_smash_skelet3D_s3.npy to data/splits/train
# Moved p47_serkick_skelet3D_s2.npy to data/splits/train
# Moved p6_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p43_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p9_fslice_skelet3D_s3.npy to data/splits/train
# Moved p9_fslice_skelet3D_s2.npy to data/splits/train
# Moved p40_serflat_skelet3D_s2.npy to data/splits/test
# Moved p41_bvolley_skelet3D_s1.npy to data/splits/train
# Moved p4_fslice_skelet3D_s3.npy to data/splits/train
# Moved p1_backhand2h_skelet3D_s1.npy to data/splits/train
# Moved p18_serslice_skelet3D_s3.npy to data/splits/test
# Moved p49_smash_skelet3D_s2.npy to data/splits/train
# Moved p7_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p36_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p4_smash_skelet3D_s2.npy to data/splits/train
# Moved p16_fslice_skelet3D_s2.npy to data/splits/train
# Moved p47_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p35_serslice_skelet3D_s3.npy to data/splits/train
# Moved p25_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p22_foreopen_skelet3D_s3.npy to data/splits/test
# Moved p5_serslice_skelet3D_s3.npy to data/splits/test
# Moved p29_bslice_skelet3D_s2.npy to data/splits/train
# Moved p39_backhand_skelet3D_s2.npy to data/splits/train
# Moved p2_backhand_skelet3D_s1.npy to data/splits/train
# Moved p38_fslice_skelet3D_s3.npy to data/splits/val
# Moved p22_smash_skelet3D_s3.npy to data/splits/test
# Moved p34_bslice_skelet3D_s3.npy to data/splits/val
# Moved p46_foreopen_skelet3D_s3.npy to data/splits/val
# Moved p40_smash_skelet3D_s3.npy to data/splits/test
# Moved p25_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p6_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p54_bslice_skelet3D_s2.npy to data/splits/train
# Moved p20_smash_skelet3D_s2.npy to data/splits/val
# Moved p29_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p51_fslice_skelet3D_s3.npy to data/splits/test
# Moved p16_smash_skelet3D_s3.npy to data/splits/train
# Moved p13_foreflat_skelet3D_s2.npy to data/splits/test
# Moved p19_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p47_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p43_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p46_serslice_skelet3D_s3.npy to data/splits/val
# Moved p42_smash_skelet3D_s2.npy to data/splits/train
# Moved p16_serkick_skelet3D_s3.npy to data/splits/train
# Moved p24_serkick_skelet3D_s3.npy to data/splits/train
# Moved p1_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p6_serkick_skelet3D_s3.npy to data/splits/train
# Moved p17_backhand2h_skelet3D_s3.npy to data/splits/val
# Moved p39_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p20_fvolley_skelet3D_s3.npy to data/splits/val
# Moved p27_smash_skelet3D_s3.npy to data/splits/test
# Moved p39_bslice_skelet3D_s2.npy to data/splits/train
# Moved p35_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p31_bslice_skelet3D_s3.npy to data/splits/val
# Moved p16_backhand_skelet3D_s2.npy to data/splits/train
# Moved p1_bslice_skelet3D_s2.npy to data/splits/train
# Moved p21_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p46_serflat_skelet3D_s3.npy to data/splits/val
# Moved p54_backhand_skelet3D_s3.npy to data/splits/train
# Moved p19_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p25_backhand_skelet3D_s2.npy to data/splits/train
# Moved p43_serflat_skelet3D_s2.npy to data/splits/train
# Moved p29_fslice_skelet3D_s2.npy to data/splits/train
# Moved p6_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p2_backhand_skelet3D_s2.npy to data/splits/train
# Moved p45_bslice_skelet3D_s2.npy to data/splits/val
# Moved p4_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p35_bslice_skelet3D_s2.npy to data/splits/train
# Moved p42_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p17_smash_skelet3D_s2.npy to data/splits/val
# Moved p44_serflat_skelet3D_s3.npy to data/splits/train
# Moved p35_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p41_bslice_skelet3D_s3.npy to data/splits/train
# Moved p8_serflat_skelet3D_s3.npy to data/splits/train
# Moved p17_bslice_skelet3D_s2.npy to data/splits/val
# Moved p28_smash_skelet3D_s2.npy to data/splits/test
# Moved p12_serslice_skelet3D_s3.npy to data/splits/train
# Moved p21_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p15_bvolley_skelet3D_s3.npy to data/splits/test
# Moved p30_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p8_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p23_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p55_backhand_skelet3D_s3.npy to data/splits/train
# Moved p40_bvolley_skelet3D_s2.npy to data/splits/test
# Moved p27_foreopen_skelet3D_s2.npy to data/splits/test
# Moved p9_backhand_skelet3D_s3.npy to data/splits/train
# Moved p30_smash_skelet3D_s2.npy to data/splits/train
# Moved p1_backhand_skelet3D_s3.npy to data/splits/train
# Moved p34_backhand_skelet3D_s2.npy to data/splits/val
# Moved p8_foreflat_skelet3D_s1.npy to data/splits/train
# Moved p49_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p3_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p9_smash_skelet3D_s3.npy to data/splits/train
# Moved p11_bslice_skelet3D_s2.npy to data/splits/train
# Moved p38_foreopen_skelet3D_s3.npy to data/splits/val
# Moved p55_smash_skelet3D_s1.npy to data/splits/train
# Moved p52_bslice_skelet3D_s3.npy to data/splits/train
# Moved p5_serkick_skelet3D_s2.npy to data/splits/test
# Moved p31_foreopen_skelet3D_s3.npy to data/splits/val
# Moved p17_fvolley_skelet3D_s2.npy to data/splits/val
# Moved p55_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p28_smash_skelet3D_s3.npy to data/splits/test
# Moved p34_foreopen_skelet3D_s2.npy to data/splits/val
# Moved p11_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p39_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p25_backhand_skelet3D_s3.npy to data/splits/train
# Moved p46_foreflat_skelet3D_s2.npy to data/splits/val
# Moved p51_serkick_skelet3D_s3.npy to data/splits/test
# Moved p55_fslice_skelet3D_s1.npy to data/splits/train
# Moved p44_serkick_skelet3D_s2.npy to data/splits/train
# Moved p18_backhand2h_skelet3D_s3.npy to data/splits/test
# Moved p42_serflat_skelet3D_s3.npy to data/splits/train
# Moved p11_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p51_bvolley_skelet3D_s2.npy to data/splits/test
# Moved p5_serslice_skelet3D_s2.npy to data/splits/test
# Moved p32_bslice_skelet3D_s3.npy to data/splits/train
# Moved p24_serslice_skelet3D_s2.npy to data/splits/train
# Moved p21_smash_skelet3D_s2.npy to data/splits/train
# Moved p54_serkick_skelet3D_s2.npy to data/splits/train
# Moved p22_serkick_skelet3D_s3.npy to data/splits/test
# Moved p51_serslice_skelet3D_s2.npy to data/splits/test
# Moved p3_serslice_skelet3D_s3.npy to data/splits/train
# Moved p40_serkick_skelet3D_s2.npy to data/splits/test
# Moved p47_serflat_skelet3D_s3.npy to data/splits/train
# Moved p17_foreopen_skelet3D_s3.npy to data/splits/val
# Moved p5_serflat_skelet3D_s3.npy to data/splits/test
# Moved p32_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p12_fslice_skelet3D_s2.npy to data/splits/train
# Moved p16_fslice_skelet3D_s3.npy to data/splits/train
# Moved p41_serkick_skelet3D_s3.npy to data/splits/train
# Moved p8_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p37_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p34_serslice_skelet3D_s2.npy to data/splits/val
# Moved p26_bslice_skelet3D_s3.npy to data/splits/train
# Moved p13_foreopen_skelet3D_s3.npy to data/splits/test
# Moved p27_serflat_skelet3D_s2.npy to data/splits/test
# Moved p50_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p42_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p12_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p9_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p14_bslice_skelet3D_s3.npy to data/splits/train
# Moved p45_bslice_skelet3D_s3.npy to data/splits/val
# Moved p54_smash_skelet3D_s2.npy to data/splits/train
# Moved p39_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p32_bslice_skelet3D_s2.npy to data/splits/train
# Moved p11_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p40_backhand2h_skelet3D_s2.npy to data/splits/test
# Moved p33_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p28_bslice_skelet3D_s3.npy to data/splits/test
# Moved p11_fslice_skelet3D_s3.npy to data/splits/train
# Moved p14_serslice_skelet3D_s3.npy to data/splits/train
# Moved p44_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p13_serflat_skelet3D_s3.npy to data/splits/test
# Moved p26_fslice_skelet3D_s3.npy to data/splits/train
# Moved p1_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p4_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p26_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p26_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p50_foreflat_skelet3D_s3.npy to data/splits/train
# Moved p42_smash_skelet3D_s1.npy to data/splits/train
# Moved p24_smash_skelet3D_s3.npy to data/splits/train
# Moved p26_fslice_skelet3D_s2.npy to data/splits/train
# Moved p51_foreflat_skelet3D_s2.npy to data/splits/test
# Moved p23_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p48_serkick_skelet3D_s2.npy to data/splits/val
# Moved p10_serkick_skelet3D_s2.npy to data/splits/train
# Moved p37_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p55_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p27_fslice_skelet3D_s3.npy to data/splits/test
# Moved p24_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p7_serslice_skelet3D_s3.npy to data/splits/train
# Moved p15_bslice_skelet3D_s2.npy to data/splits/test
# Moved p46_bvolley_skelet3D_s3.npy to data/splits/val
# Moved p29_smash_skelet3D_s3.npy to data/splits/train
# Moved p18_smash_skelet3D_s2.npy to data/splits/test
# Moved p38_fvolley_skelet3D_s2.npy to data/splits/val
# Moved p27_serslice_skelet3D_s2.npy to data/splits/test
# Moved p14_smash_skelet3D_s2.npy to data/splits/train
# Moved p22_serslice_skelet3D_s3.npy to data/splits/test
# Moved p2_serkick_skelet3D_s2.npy to data/splits/train
# Moved p39_fslice_skelet3D_s2.npy to data/splits/train
# Moved p40_fslice_skelet3D_s3.npy to data/splits/test
# Moved p48_serkick_skelet3D_s1.npy to data/splits/val
# Moved p53_serkick_skelet3D_s1.npy to data/splits/train
# Moved p27_bslice_skelet3D_s3.npy to data/splits/test
# Moved p6_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p11_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p44_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p31_serkick_skelet3D_s3.npy to data/splits/val
# Moved p15_backhand_skelet3D_s2.npy to data/splits/test
# Moved p34_bvolley_skelet3D_s2.npy to data/splits/val
# Moved p30_serkick_skelet3D_s2.npy to data/splits/train
# Moved p8_serkick_skelet3D_s3.npy to data/splits/train
# Moved p41_backhand_skelet3D_s3.npy to data/splits/train
# Moved p47_fvolley_skelet3D_s2.npy to data/splits/train
# Moved p35_serkick_skelet3D_s2.npy to data/splits/train
# Moved p12_fvolley_skelet3D_s3.npy to data/splits/train
# Moved p47_bvolley_skelet3D_s2.npy to data/splits/train
# Moved p2_serslice_skelet3D_s3.npy to data/splits/train
# Moved p28_bslice_skelet3D_s2.npy to data/splits/test
# Moved p45_backhand2h_skelet3D_s3.npy to data/splits/val
# Moved p39_serflat_skelet3D_s2.npy to data/splits/train
# Moved p4_serflat_skelet3D_s2.npy to data/splits/train
# Moved p11_backhand_skelet3D_s3.npy to data/splits/train
# Moved p14_fslice_skelet3D_s3.npy to data/splits/train
# Moved p50_serslice_skelet3D_s3.npy to data/splits/train
# Moved p27_fslice_skelet3D_s2.npy to data/splits/test
# Moved p47_serflat_skelet3D_s2.npy to data/splits/train
# Moved p52_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p2_foreopen_skelet3D_s2.npy to data/splits/train
# Moved p55_bslice_skelet3D_s2.npy to data/splits/train
# Moved p8_backhand_skelet3D_s2.npy to data/splits/train
# Moved p1_smash_skelet3D_s3.npy to data/splits/train
# Moved p30_serslice_skelet3D_s2.npy to data/splits/train
# Moved p3_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p13_backhand2h_skelet3D_s2.npy to data/splits/test
# Moved p2_foreflat_skelet3D_s2.npy to data/splits/train
# Moved p13_serslice_skelet3D_s3.npy to data/splits/test
# Moved p6_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p9_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p36_serkick_skelet3D_s3.npy to data/splits/train
# Moved p42_foreopen_skelet3D_s3.npy to data/splits/train
# Moved p5_bslice_skelet3D_s2.npy to data/splits/test
# Moved p2_serflat_skelet3D_s3.npy to data/splits/train
# Moved p53_backhand_skelet3D_s2.npy to data/splits/train
# Moved p19_bvolley_skelet3D_s3.npy to data/splits/train
# Moved p24_backhand2h_skelet3D_s2.npy to data/splits/train
# Moved p44_backhand_skelet3D_s2.npy to data/splits/train
# Moved p52_serflat_skelet3D_s3.npy to data/splits/train
# Moved p22_foreflat_skelet3D_s2.npy to data/splits/test
# Moved p7_backhand2h_skelet3D_s3.npy to data/splits/train
# Moved p6_serflat_skelet3D_s3.npy to data/splits/train
# Moved p55_fslice_skelet3D_s2.npy to data/splits/train
# Moved p12_serflat_skelet3D_s2.npy to data/splits/train
# Moved p15_serkick_skelet3D_s3.npy to data/splits/test
# Moved p48_serflat_skelet3D_s2.npy to data/splits/val
# Moved p53_smash_skelet3D_s3.npy to data/splits/train
# Moved p47_serslice_skelet3D_s3.npy to data/splits/train
# Moved p43_bslice_skelet3D_s3.npy to data/splits/train
# Moved p20_serkick_skelet3D_s3.npy to data/splits/val
# Moved p34_foreflat_skelet3D_s3.npy to data/splits/val
# Moved p2_bvolley_skelet3D_s1.npy to data/splits/train

# %%
import numpy as np
sample = np.load("data/120_frames/p10_backhand2h_skelet3D_s2.npy")
print(sample.shape)
# Out:
# (120, 224, 224, 3)

# %%
# !git clone https://github.com/yysijie/st-gcn.git
# !cd st-gcn
# !pip install -r /content/st-gcn/requirements.txt
# Out:
# Cloning into 'st-gcn'...
# remote: Enumerating objects: 1523, done.
# remote: Total 1523 (delta 0), reused 0 (delta 0), pack-reused 1523 (from 1)
# Receiving objects: 100% (1523/1523), 57.17 MiB | 15.92 MiB/s, done.
# Resolving deltas: 100% (780/780), done.
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from -r /content/st-gcn/requirements.txt (line 1)) (6.0.2)
# Collecting argparse (from -r /content/st-gcn/requirements.txt (line 2))
#   Downloading argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r /content/st-gcn/requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from -r /content/st-gcn/requirements.txt (line 4)) (3.13.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from -r /content/st-gcn/requirements.txt (line 5)) (4.11.0.86)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from -r /content/st-gcn/requirements.txt (line 6)) (2.37.0)
# Collecting scikit-video (from -r /content/st-gcn/requirements.txt (line 7))
#   Downloading scikit_video-1.1.11-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from -r /content/st-gcn/requirements.txt (line 8)) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from -r /content/st-gcn/requirements.txt (line 9)) (0.21.0+cu124)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio->-r /content/st-gcn/requirements.txt (line 6)) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from scikit-video->-r /content/st-gcn/requirements.txt (line 7)) (1.15.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->-r /content/st-gcn/requirements.txt (line 8))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->-r /content/st-gcn/requirements.txt (line 8)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->-r /content/st-gcn/requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->-r /content/st-gcn/requirements.txt (line 8)) (3.0.2)
# Downloading argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Downloading scikit_video-1.1.11-py2.py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 76.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 35.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.7 MB/s eta 0:00:00
# Installing collected packages: argparse, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, scikit-video, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed argparse-1.4.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 scikit-video-1.1.11

# %%
# %cd /content/st-gcn
# Out:
# /content/st-gcn

# %%
ls /content/st-gcn/models/pose/coco
# Out:
# pose_deploy_linevec.prototxt*

# %%
# !grep -r "class Model" /content/st-gcn/
# Out:
# /content/st-gcn/net/st_gcn_twostream.py:class Model(nn.Module):
# /content/st-gcn/net/st_gcn.py:class Model(nn.Module):

# %%
# !python main.py recognition -c config/st_gcn/kinetics-skeleton/test.yaml
# Out:
# Traceback (most recent call last):
#   File "/content/st-gcn/main.py", line 7, in <module>
#     from torchlight import import_class
# ImportError: cannot import name 'import_class' from 'torchlight' (unknown location)

# %%
# !python main.py --config config/stgcn_kinetics.yaml
# Out:
# Traceback (most recent call last):
#   File "/content/st-gcn/main.py", line 7, in <module>
#     from torchlight import import_class
# ImportError: cannot import name 'import_class' from 'torchlight' (unknown location)

# %%
# !pip install scipy scikit-learn
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /usr/local/lib/python3.11/dist-packages (from scipy) (2.0.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
# !pip install stgcn
# Out:
# ERROR: Could not find a version that satisfies the requirement stgcn (from versions: none)
# ERROR: No matching distribution found for stgcn

# %%
import torch
from stgcn.net.st_gcn import Model  # Assuming stgcn.py is available from the implementation
from torch import nn

# Load a pre-trained ST-GCN model (Kinetics-Pretrained)
def load_stgcn_model(pretrained=True):
    # Assuming you're using a pre-trained model from Kinetics
    model = Model(num_class=60, num_point=18, in_channels=3, graph_size=18)  # Adjust as per your dataset
    if pretrained:
        model.load_state_dict(torch.load('path_to_pretrained_kinetics_model.pth'))
    model.eval()  # Set the model to evaluation mode
    return model

# Example usage:
stgcn_model = load_stgcn_model(pretrained=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-36-f04f81ad4ebc> in <cell line: 0>()
#       1 import torch
# ----> 2 from stgcn.net.st_gcn import Model  # Assuming stgcn.py is available from the implementation
#       3 from torch import nn
#       4
#       5 # Load a pre-trained ST-GCN model (Kinetics-Pretrained)
#
# ModuleNotFoundError: No module named 'stgcn'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
class KeypointDataset(Dataset):
    def __init__(self, npy_dir, split='train'):
        self.npy_dir = npy_dir
        self.split = split
        self.files = [f for f in os.listdir(npy_dir) if f.endswith('.npy')]

        # If you have a specific player split, apply that here (e.g., train/val/test)
        if self.split == 'train':
            # Load the train files
            self.files = [f for f in self.files if 'player1' in f or 'player2' in f]  # Example player-based split
        elif self.split == 'val':
            # Load the validation files
            self.files = [f for f in self.files if 'player3' in f or 'player4' in f]  # Example player-based split
        else:
            # Load the test files
            self.files = [f for f in self.files if 'player5' in f or 'player6' in f]  # Example player-based split

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        video_filename = self.files[idx]
        video_path = os.path.join(self.npy_dir, video_filename)

        # Load the video keypoints data
        frames = np.load(video_path)  # Shape (T, N, 3) => (120, num_keypoints, 3)

        # Normalize or preprocess data if needed
        frames = torch.tensor(frames, dtype=torch.float32)

        # Assume labels are stored in a dictionary or follow a certain convention
        label = get_label_from_filename(video_filename)  # You should define this function based on your dataset

        return frames, label

# Define the dataset and dataloaders
train_dataset = KeypointDataset(npy_dir='data/splits/train', split='train')
val_dataset = KeypointDataset(npy_dir='data/splits/val', split='val')
test_dataset = KeypointDataset(npy_dir='data/splits/test', split='test')

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-425a6fb203f1> in <cell line: 0>()
#      35
#      36 # Define the dataset and dataloaders
# ---> 37 train_dataset = KeypointDataset(npy_dir='data/splits/train', split='train')
#      38 val_dataset = KeypointDataset(npy_dir='data/splits/val', split='val')
#      39 test_dataset = KeypointDataset(npy_dir='data/splits/test', split='test')
#
# <ipython-input-37-425a6fb203f1> in __init__(self, npy_dir, split)
#       3         self.npy_dir = npy_dir
#       4         self.split = split
# ----> 5         self.files = [f for f in os.listdir(npy_dir) if f.endswith('.npy')]
#       6
#       7         # If you have a specific player split, apply that here (e.g., train/val/test)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/splits/train'

# %%
import torch.optim as optim
from sklearn.metrics import accuracy_score

def train_model(model, train_loader, val_loader, epochs=10, lr=1e-3):
    # Define optimizer and loss function
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()  # Assuming classification task

    best_val_acc = 0

    for epoch in range(epochs):
        model.train()
        train_loss = 0
        train_acc = 0
        train_samples = 0

        # Training loop
        for data, label in train_loader:
            optimizer.zero_grad()

            # Forward pass
            output = model(data)

            # Compute loss and backpropagate
            loss = criterion(output, label)
            loss.backward()
            optimizer.step()

            # Calculate accuracy
            _, predicted = torch.max(output, 1)
            train_acc += (predicted == label).sum().item()
            train_samples += label.size(0)

            train_loss += loss.item()

        # Calculate training accuracy
        train_acc /= train_samples
        print(f"Epoch [{epoch+1}/{epochs}], Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}")

        # Validation
        val_acc = validate_model(model, val_loader)
        print(f"Validation Accuracy: {val_acc:.4f}")

        # Save the best model based on validation accuracy
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), 'best_stgcn_model.pth')

def validate_model(model, val_loader):
    model.eval()
    val_acc = 0
    val_samples = 0

    with torch.no_grad():
        for data, label in val_loader:
            output = model(data)
            _, predicted = torch.max(output, 1)
            val_acc += (predicted == label).sum().item()
            val_samples += label.size(0)

    val_acc /= val_samples
    return val_acc



### BEFORE TRAINING.


DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
model.to(DEVICE)


# Start training
train_model(stgcn_model, train_loader, val_loader)

# %%
def test_model(model, test_loader):
    model.eval()
    test_acc = 0
    test_samples = 0

    with torch.no_grad():
        for data, label in test_loader:
            output = model(data)
            _, predicted = torch.max(output, 1)
            test_acc += (predicted == label).sum().item()
            test_samples += label.size(0)

    test_acc /= test_samples
    print(f"Test Accuracy: {test_acc:.4f}")

# Test the model
test_model(stgcn_model, test_loader)
