# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoDinga/DL_Project/blob/main/TRAIN__(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y torch torchvision torchao torchaudio torchtext torchdata
# !pip uninstall -y mmcv mmcv-full mmengine mmaction2 transformers
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# WARNING: Skipping torchtext as it is not installed.
# Found existing installation: torchdata 0.11.0
# Uninstalling torchdata-0.11.0:
#   Successfully uninstalled torchdata-0.11.0
# WARNING: Skipping mmcv as it is not installed.
# WARNING: Skipping mmcv-full as it is not installed.
# WARNING: Skipping mmengine as it is not installed.
# WARNING: Skipping mmaction2 as it is not installed.
# Found existing installation: transformers 4.51.3
# Uninstalling transformers-4.51.3:
#   Successfully uninstalled transformers-4.51.3

# %%
# !pip install protobuf==3.20.3
# !pip install mediapipe
# Out:
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.17.1 requires protobuf<6.0.0,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3
# Collecting mediapipe
#   Downloading mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (3.10.0)
# Collecting numpy<2 (from mediapipe)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.11.0.86)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.7-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Downloading mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 27.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 75.7 MB/s eta 0:00:00
# Downloading protobuf-4.25.7-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 23.1 MB/s eta 0:00:00
# Downloading sounddevice-0.5.2-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, numpy, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.19 requires torch<2.7,>=1.10, which is not installed.
# fastai 2.7.19 requires torchvision>=0.11, which is not installed.
# torchtune 0.6.1 requires torchdata==0.11.0, which is not installed.
# accelerate 1.6.0 requires torch>=2.0.0, which is not installed.
# peft 0.15.2 requires torch>=1.13.0, which is not installed.
# peft 0.15.2 requires transformers, which is not installed.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.7 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.7 which is incompatible.
# Successfully installed mediapipe-0.10.21 numpy-1.26.4 protobuf-4.25.7 sounddevice-0.5.2

# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install 'mmcv==2.1.0'
# !pip install torch==2.0.1 torchvision==0.15.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers==4.35.2
# !pip install mmaction2
# Out:
# Requirement already satisfied: openmim in /usr/local/lib/python3.11/dist-packages (0.3.9)
# Requirement already satisfied: Click in /usr/local/lib/python3.11/dist-packages (from openmim) (8.2.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from openmim) (0.4.6)
# Requirement already satisfied: model-index in /usr/local/lib/python3.11/dist-packages (from openmim) (0.1.11)
# Requirement already satisfied: opendatalab in /usr/local/lib/python3.11/dist-packages (from openmim) (0.0.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.11/dist-packages (from openmim) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from openmim) (2.28.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from openmim) (13.4.2)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (3.8)
# Requirement already satisfied: ordered-set in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (4.1.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (3.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (4.65.2)
# Requirement already satisfied: openxlab in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.17.0)
# Requirement already satisfied: filelock~=3.14.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (3.14.0)
# Requirement already satisfied: oss2~=2.17.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (2.17.0)
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (24.2)
# Requirement already satisfied: setuptools~=60.2.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (60.2.0)
# Requirement already satisfied: crcmod>=1.7 in /usr/local/lib/python3.11/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.5)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /usr/local/lib/python3.11/dist-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim) (2.16.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (0.10.0)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Traceback (most recent call last):
#   File "/usr/local/bin/mim", line 8, in <module>
#     sys.exit(cli())
#              ^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1442, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1363, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1830, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1226, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 794, in invoke
#     return callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 72, in cli
#     exit_code = install(list(args), index_url=index_url, is_yes=is_yes)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 128, in install
#     install_args += ['-f', get_mmcv_full_find_link(mmcv_base_url)]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 165, in get_mmcv_full_find_link
#     torch_v, cuda_v = get_torch_cuda_version()
#                       ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/utils/utils.py", line 340, in get_torch_cuda_version
#     raise err
#   File "/usr/local/lib/python3.11/dist-packages/mim/utils/utils.py", line 338, in get_torch_cuda_version
#     import torch
# ModuleNotFoundError: No module named 'torch'
# Traceback (most recent call last):
#   File "/usr/local/bin/mim", line 8, in <module>
#     sys.exit(cli())
#              ^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1442, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1363, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1830, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1226, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 794, in invoke
#     return callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 72, in cli
#     exit_code = install(list(args), index_url=index_url, is_yes=is_yes)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 128, in install
#     install_args += ['-f', get_mmcv_full_find_link(mmcv_base_url)]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 165, in get_mmcv_full_find_link
#     torch_v, cuda_v = get_torch_cuda_version()
#                       ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/utils/utils.py", line 340, in get_torch_cuda_version
#     raise err
#   File "/usr/local/lib/python3.11/dist-packages/mim/utils/utils.py", line 338, in get_torch_cuda_version
#     import torch
# ModuleNotFoundError: No module named 'torch'
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp311-cp311-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 626.4 kB/s eta 0:00:00
# Collecting torchvision==0.15.2
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp311-cp311-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 108.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.1.6)
# Collecting triton==2.0.0 (from torch==2.0.1)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (2.28.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (11.2.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (3.31.6)
# Collecting lit (from triton==2.0.0->torch==2.0.1)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 13.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=90004 sha256=330b7b00517538ca57f522f88c78fcc6ea87f685a42afbadc1524aef5e3e23cf
#   Stored in directory: /root/.cache/pip/wheels/fc/5d/45/34fe9945d5e45e261134e72284395be36c2d4828af38e2b0fe
# Successfully built lit
# Installing collected packages: lit, triton, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, which is not installed.
# peft 0.15.2 requires transformers, which is not installed.
# Successfully installed lit-15.0.7 torch-2.0.1+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting transformers==4.35.2
#   Downloading transformers-4.35.2-py3-none-any.whl.metadata (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (2.28.2)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.35.2)
#   Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (4.65.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.35.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.35.2) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.35.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.35.2) (2025.4.26)
# Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 106.1 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 110.8 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtune 0.6.1 requires torchdata==0.11.0, which is not installed.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.35.2 which is incompatible.
# Successfully installed tokenizers-0.15.2 transformers-4.35.2
# Collecting mmaction2
#   Downloading mmaction2-1.2.0-py2.py3-none-any.whl.metadata (29 kB)
# Collecting decord>=0.4.1 (from mmaction2)
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from mmaction2) (0.8.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmaction2) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmaction2) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mmaction2) (4.11.0.86)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmaction2) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmaction2) (1.15.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from mmaction2) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.3->mmaction2) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.3->mmaction2) (15.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmaction2) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->mmaction2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.3->mmaction2) (1.3.0)
# Downloading mmaction2-1.2.0-py2.py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 27.0 MB/s eta 0:00:00
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 24.9 MB/s eta 0:00:00
# Installing collected packages: decord, mmaction2
# Successfully installed decord-0.6.0 mmaction2-1.2.0

# %%
import numpy as np

# %%
# verifica se tens o GPU ativado. Tem de dizer TRUE
import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"CUDA Version used by PyTorch: {torch.version.cuda}")
# Out:
# PyTorch Version: 2.0.1+cu118
# CUDA Available: True
# CUDA Version used by PyTorch: 11.8

# %%
from google.colab import files
import numpy as np
# uploaded = files.upload()
# data = np.load("/content/all_keypoints.npz", allow_pickle=True)
# print(data.files)  # Para ver o que está lá dentro

# Caminho para o ficheiro de keypoints
keypoints_path = "/content/all_keypoints.npz"

# Carregar os keypoints do ficheiro npz e reconstruir o dicionário
data = np.load(keypoints_path)
all_keypoints = {}
for key in data.files:
    action, video_file = key.split("__", 1)
    if action not in all_keypoints:
        all_keypoints[action] = {}
    all_keypoints[action][video_file] = data[key]
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-7-9b5e0e72c89f> in <cell line: 0>()
#       9
#      10 # Carregar os keypoints do ficheiro npz e reconstruir o dicionário
# ---> 11 data = np.load(keypoints_path)
#      12 all_keypoints = {}
#      13 for key in data.files:
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     442             # Potentially transfer file ownership to NpzFile
#     443             stack.pop_all()
# --> 444             ret = NpzFile(fid, own_fid=own_fid, allow_pickle=allow_pickle,
#     445                           pickle_kwargs=pickle_kwargs,
#     446                           max_header_size=max_header_size)
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/npyio.py in __init__(self, fid, own_fid, allow_pickle, pickle_kwargs, max_header_size)
#     188         # Import is postponed to here since zipfile depends on gzip, an
#     189         # optional component of the so-called standard library.
# --> 190         _zip = zipfile_factory(fid)
#     191         self._files = _zip.namelist()
#     192         self.files = []
#
# /usr/local/lib/python3.11/dist-packages/numpy/lib/npyio.py in zipfile_factory(file, *args, **kwargs)
#     101     import zipfile
#     102     kwargs['allowZip64'] = True
# --> 103     return zipfile.ZipFile(file, *args, **kwargs)
#     104
#     105
#
# /usr/lib/python3.11/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1311         try:
#    1312             if mode == 'r':
# -> 1313                 self._RealGetContents()
#    1314             elif mode in ('w', 'x'):
#    1315                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.11/zipfile.py in _RealGetContents(self)
#    1378             raise BadZipFile("File is not a zip file")
#    1379         if not endrec:
# -> 1380             raise BadZipFile("File is not a zip file")
#    1381         if self.debug > 1:
#    1382             print(endrec)
#
# BadZipFile: File is not a zip file

# %% [markdown]
# # tens de tranferir a pasta all_keypoints.npz

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load keypoints
keypoints_path = "/content/all_keypoints.npz"
data = np.load(keypoints_path)

# Rebuild dictionary
all_keypoints = {}
for key in data.files:
    action, video_file = key.split("__", 1)
    if action not in all_keypoints:
        all_keypoints[action] = {}
    all_keypoints[action][video_file] = data[key]

# Select one example
first_action = list(all_keypoints.keys())[0]
first_video = list(all_keypoints[first_action].keys())[0]
frame_idx = 0

points = all_keypoints[first_action][first_video][frame_idx]  # shape: (num_joints, 3)

# === Define anatomical connections and colors ===
anatomical_connections = {
    'head': [
        (0, 1), (1, 2), (2, 3),
        (0, 4), (4, 5), (5, 6),
        (3, 7), (6, 8),
        (0, 9), (9, 10)
    ],
    'left_arm': [(11, 13), (13, 15), (15, 17), (15, 19), (15, 21)],
    'right_arm': [(12, 14), (14, 16), (16, 18), (16, 20), (16, 22)],
    'torso': [(11, 12), (23, 24), (11, 23), (12, 24)],
    'left_leg': [(23, 25), (25, 27), (27, 29), (29, 31)],
    'right_leg': [(24, 26), (26, 28), (28, 30), (30, 32)],
}

colors = {
    'head': 'gray',
    'left_arm': 'red',
    'right_arm': 'blue',
    'torso': 'orange',
    'left_leg': 'green',
    'right_leg': 'purple',
}

# === Plotting ===
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(points[:, 0], points[:, 1], points[:, 2], c='black', s=20)

for part, connections in anatomical_connections.items():
    for i, j in connections:
        if i < len(points) and j < len(points):  # ensure valid index
            ax.plot(
                [points[i, 0], points[j, 0]],
                [points[i, 1], points[j, 1]],
                [points[i, 2], points[j, 2]],
                color=colors[part], linewidth=2
            )

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title(f"3D Skeleton - Frame {frame_idx} - {first_video}")
ax.view_init(elev=20, azim=-70)
plt.tight_layout()
plt.show()

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
pip install np
# Out:
# Collecting np
#   Downloading np-1.0.2.tar.gz (7.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: np
#   Building wheel for np (setup.py) ... done
#   Created wheel for np: filename=np-1.0.2-py3-none-any.whl size=13676 sha256=d1d9e697e6ea333d6dad59a49f2be7309dfefbcff7a1cd14f79fe8f6189cd80d
#   Stored in directory: /root/.cache/pip/wheels/19/20/42/6ee214e617f78123903f603524d662ac6fa14154c3027fd992
# Successfully built np
# Installing collected packages: np
# Successfully installed np-1.0.2

# %%
from collections import defaultdict
import numpy as np
#from sklearn.model_selection import train_test_split
import random


def extract_player_id(filename):
    # Example: 'player1_video1.npy' → 'player1'
    return filename.split('_')[0]

# Organize videos by player
player_video_map = defaultdict(list)
for action, videos in all_keypoints.items():
    for video_file in videos:
        player_id = extract_player_id(video_file)
        player_video_map[player_id].append((action, video_file))

# Split player IDs
players = list(player_video_map.keys())
random.shuffle(players)

train_end = int(len(players) * 0.7)
val_end = int(len(players) * 0.85)

train_players = players[:train_end]
val_players = players[train_end:val_end]
test_players = players[val_end:]

def collect_by_players(player_ids):
    dataset = []
    for pid in player_ids:
        for action, filename in player_video_map[pid]:
            keypoints = all_keypoints[action][filename]
            dataset.append((keypoints, action))
    return dataset

train_set = collect_by_players(train_players)
val_set = collect_by_players(val_players)
test_set = collect_by_players(test_players)

print(f"Train: {len(train_set)}, Val: {len(val_set)}, Test: {len(test_set)}")
# Out:
# Train: 1368, Val: 288, Test: 324

# %%
# N = number of samples, # C = 3 (x, y, z), # T = 120 (our fixed number of frames), # V = 33 (MediaPipe joints), # M = number of people
#Prepare data to STGCN (Store keypoints in a numpy array with the shape [N, C, T, V, M])
#Save the labels as integers in a separate pkl file.

import pickle

ntu_joints_in_mediapipe = [
    0,   # Nose
    11,  # Left Shoulder
    12,  # Right Shoulder
    13,  # Left Elbow
    14,  # Right Elbow
    15,  # Left Wrist
    16,  # Right Wrist
    23,  # Left Hip
    24,  # Right Hip
    25,  # Left Knee
    26,  # Right Knee
    27,  # Left Ankle
    28,  # Right Ankle
    5,   # Right Eye
    2,   # Left Eye
    7,   # Left Ear
    8,   # Right Ear
    17,  # Left Pinky
    18,  # Right Pinky
    19,  # Left Index
    20,  # Right Index
    21,  # Left Thumb
    22,  # Right Thumb
    29,  # Left Foot Index
    30   # Right Foot Index
]

def filter_to_ntu_joints(keypoints): #para usar layout NTU RGB+D
    # keypoints: (T, 33, C)
    return keypoints[:, ntu_joints_in_mediapipe, :]

def prepare_stgcn_data(dataset, label_map):
    data_list = []
    for i, (keypoints, action_name) in enumerate(dataset):
        keypoints = np.array(keypoints)  # (T, 33, C)
        keypoints = filter_to_ntu_joints(keypoints)  # (T, 25, C)
        num_frames, num_joints, channels = keypoints.shape
        # Se só tem 1 pessoa por sample:
        keypoints = keypoints[np.newaxis, ...]  # (M=1, T, V, C)
        # Se tiver keypoint_score, pode adicionar aqui
        sample = {
            'frame_dir': f'sample_{i}',
            'label': label_map[action_name],
            'img_shape': None,           # ou (H, W) se souber
            'total_frames': num_frames,
            'keypoint': keypoints,       # (M, T, V, C)
            # 'keypoint_score': np.ones_like(keypoints[..., 0]),  # opcional
        }
        data_list.append(sample)
    return data_list

# Crie o label_map como já fazia
label_map = {name: idx for idx, name in enumerate(sorted(set(a for _, a in train_set + val_set + test_set)))}

# Prepare os dados no formato correto
train_data = prepare_stgcn_data(train_set, label_map)
val_data = prepare_stgcn_data(val_set, label_map)
test_data = prepare_stgcn_data(test_set, label_map)

with open('/content/train_labels.pkl', 'wb') as f:
    pickle.dump(train_data, f)

with open('/content/val_labels.pkl', 'wb') as f:
    pickle.dump(val_data, f)


with open('/content/test_labels.pkl', 'wb') as f:
    pickle.dump(test_data, f)

print("Data saved successfully!")
# Out:
# Data saved successfully!

# %%
# Exemplo para MMAction2
# !git clone https://github.com/open-mmlab/mmaction2.git mmaction2 #alterei
# %cd mmaction2
# !pip install -e .
# Out:
# Cloning into 'mmaction2'...
# remote: Enumerating objects: 22864, done.
# remote: Total 22864 (delta 0), reused 0 (delta 0), pack-reused 22864 (from 1)
# Receiving objects: 100% (22864/22864), 69.62 MiB | 36.82 MiB/s, done.
# Resolving deltas: 100% (16120/16120), done.
# /content/mmaction2
# Obtaining file:///content/mmaction2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: decord>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (0.6.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (0.8.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (4.11.0.86)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (1.15.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.3->mmaction2==1.2.0) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.3->mmaction2==1.2.0) (15.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmaction2==1.2.0) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->mmaction2==1.2.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.3->mmaction2==1.2.0) (1.3.0)
# Installing collected packages: mmaction2
#   Attempting uninstall: mmaction2
#     Found existing installation: mmaction2 1.2.0
#     Uninstalling mmaction2-1.2.0:
#       Successfully uninstalled mmaction2-1.2.0
#   Running setup.py develop for mmaction2
# Successfully installed mmaction2-1.2.0

# %%
# !mim install 'mmcv==2.1.0'
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv==2.1.0
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv-2.1.0-cp311-cp311-manylinux1_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 9.8 MB/s eta 0:00:00
# Collecting addict (from mmcv==2.1.0)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv==2.1.0)
#   Downloading mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (11.2.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (6.0.2)
# Collecting yapf (from mmcv==2.1.0)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.1.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv==2.1.0) (4.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.17.0)
# Downloading mmengine-0.10.7-py3-none-any.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 24.6 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 18.8 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, mmengine, mmcv
# Successfully installed addict-2.4.0 mmcv-2.1.0 mmengine-0.10.7 yapf-0.43.0

# %%
import torch
import mmcv
import mmengine
import mmaction2

# %%
import sys
sys.path.append('mmaction2')

# %%
### original diana

config_code = """

_base_ = ['/content/mmaction2/configs/_base_/default_runtime.py']

# Modelo ST-GCN com keypoints 3D
model = dict(
    type='RecognizerGCN',
    backbone=dict(
        type='STGCN',
        graph_cfg=dict(
            layout='nturgb+d',  # usa o layout NTU para dados 3D
            mode='spatial'),
        in_channels=3  # keypoints 3D: x, y, z
    ),
    cls_head=dict(
        type='GCNHead',
        in_channels=256,
        num_classes=12,  # <- alterado para o teu número de classes
        loss_cls=dict(type='CrossEntropyLoss'),
    ),
)

train_pipeline = [
    dict(type='PreNormalize3D'),
    dict(type='GenSkeFeat', dataset='nturgb+d', feats=['j']),
    dict(type='UniformSampleFrames', clip_len=100),
    dict(type='PoseDecode'),
    dict(type='FormatGCNInput', num_person=1),
    dict(type='PackActionInputs')
]
val_pipeline = [
    dict(type='PreNormalize3D'),
    dict(type='GenSkeFeat', dataset='nturgb+d', feats=['j']),
    dict(
        type='UniformSampleFrames', clip_len=100, num_clips=1, test_mode=True),
    dict(type='PoseDecode'),
    dict(type='FormatGCNInput', num_person=1),
    dict(type='PackActionInputs')
]
test_pipeline = [
    dict(type='PreNormalize3D'),
    dict(type='GenSkeFeat', dataset='nturgb+d', feats=['j']),
    dict(
        type='UniformSampleFrames', clip_len=100, num_clips=1,
        test_mode=True),
    dict(type='PoseDecode'),
    dict(type='FormatGCNInput', num_person=1),
    dict(type='PackActionInputs')
]

train_dataloader = dict(
    batch_size=64,  # ALTERADO: era 16, agora 4 para teste rápido
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=True),
    dataset=dict(
        type='PoseDataset',
        ann_file='/content/train_labels.pkl',  # ALTERADO: caminho absoluto, antes era 'train_labels.pkl'
        pipeline=train_pipeline
    )
)
val_dataloader = dict(
    batch_size=64,  # ALTERADO: era 16, agora 4 para teste rápido
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=False),
    dataset=dict(
        type='PoseDataset',
        ann_file='/content/val_labels.pkl',  # ALTERADO: caminho absoluto, antes era 'val_labels.pkl'
        pipeline=val_pipeline
    )
)
test_dataloader = dict(
    batch_size=64,  # ALTERADO: era 16, agora 4 para teste rápido
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=False),
    dataset=dict(
        type='PoseDataset',
        ann_file='/content/test_labels.pkl',  # ALTERADO: caminho absoluto, antes era 'test_labels.pkl'
        pipeline=test_pipeline
    )
)

# val_evaluator = dict(type='AccMetric')
# test_evaluator = val_evaluator

val_evaluator = dict(
    type='AccMetric',
    metric_list=('top_k_accuracy', 'mean_class_accuracy')
)
test_evaluator = val_evaluator

# Wrapper do otimizador
optim_wrapper = dict(
    type='OptimWrapper',
    optimizer=dict(type='Adam', lr=0.001, weight_decay=0.0001)
)


# Treino
train_cfg = dict(
    type='EpochBasedTrainLoop', max_epochs=50, val_interval=2
)


# Avaliação
val_cfg = dict(type='ValLoop')
test_cfg = dict(type='TestLoop')


# evaluation = dict(
#     interval=5,
#     metrics=['top_k_accuracy', 'mean_class_accuracy']
# )

# evaluation = dict(
#     interval=2,
#     metrics=['top_k_accuracy', 'mean_class_accuracy'],
#     topk=(1, 3, 5)
# )



evaluation = dict(
    interval=2,
    metrics=['top_k_accuracy']
)





# Salvar checkpoints, logs, etc.
work_dir = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino'   # ALTERADO: era './work_dirs/stgcn_3d_custom_test'

load_from = 'https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth'







"""



# Gravar para o ficheiro na pasta configs/stgcn/
with open('/content/mmaction2/configs/stgcn_3d_custom.py', 'w') as f:
    f.write(config_code)

# %%
# configuração mais precisa


config_code = """

_base_ = ['/content/mmaction2/configs/_base_/default_runtime.py']
model = dict(
    type='RecognizerGCN',
    backbone=dict(
        type='STGCN',
        graph_cfg=dict(layout='nturgb+d', mode='stgcn_spatial'),
        in_channels=3
    ),
    cls_head=dict(type='GCNHead', num_classes=12, in_channels=256)
)

train_pipeline = [
    dict(type='PreNormalize3D'),
    dict(type='GenSkeFeat', dataset='nturgb+d', feats=['j']),
    dict(type='UniformSampleFrames', clip_len=100),
    dict(type='PoseDecode'),
    dict(type='FormatGCNInput', num_person=1),
    dict(type='PackActionInputs')
]
val_pipeline = [
    dict(type='PreNormalize3D'),
    dict(type='GenSkeFeat', dataset='nturgb+d', feats=['j']),
    dict(type='UniformSampleFrames', clip_len=100, num_clips=1, test_mode=True),
    dict(type='PoseDecode'),
    dict(type='FormatGCNInput', num_person=1),
    dict(type='PackActionInputs')
]
test_pipeline = [
    dict(type='PreNormalize3D'),
    dict(type='GenSkeFeat', dataset='nturgb+d', feats=['j']),
    dict(type='UniformSampleFrames', clip_len=100, num_clips=1, test_mode=True),
    dict(type='PoseDecode'),
    dict(type='FormatGCNInput', num_person=1),
    dict(type='PackActionInputs')
]

train_dataloader = dict(
    batch_size=64,  # ALTERADO: era 16, agora 4 para teste rápido
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=True),
    dataset=dict(
        type='PoseDataset',
        ann_file='/content/train_labels.pkl',  # ALTERADO: caminho absoluto, antes era 'train_labels.pkl'
        pipeline=train_pipeline
    )
  )

val_dataloader = dict(
    batch_size=64,  # ALTERADO: era 16, agora 4 para teste rápido
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=False),
    dataset=dict(
        type='PoseDataset',
        ann_file='/content/val_labels.pkl',  # ALTERADO: caminho absoluto, antes era 'val_labels.pkl'
        pipeline=val_pipeline
    )
)
test_dataloader = dict(
    batch_size=64,  # ALTERADO: era 16, agora 4 para teste rápido
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=False),
    dataset=dict(
        type='PoseDataset',
        ann_file='/content/test_labels.pkl',  # ALTERADO: caminho absoluto, antes era 'test_labels.pkl'
        pipeline=test_pipeline
    )
)



param_scheduler = [
    dict(
        type='CosineAnnealingLR',
        eta_min=0,
        T_max=16,
        by_epoch=True,
        convert_to_iter_based=True)
]

evaluation = dict(
    interval=2,
    metrics=['top_k_accuracy']
)

val_evaluator = [dict(type='AccMetric')]
test_evaluator = val_evaluator



train_cfg = dict(
    type='EpochBasedTrainLoop', max_epochs=50, val_begin=1, val_interval=1)
val_cfg = dict(type='ValLoop')
test_cfg = dict(type='TestLoop')


optim_wrapper = dict(
    optimizer=dict(
        type='SGD', lr=0.1, momentum=0.9, weight_decay=0.0005, nesterov=True)
)


# Salvar checkpoints, logs, etc.
work_dir = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino'   # ALTERADO: era './work_dirs/stgcn_3d_custom_test'

load_from = 'https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth'



"""

# Gravar para o ficheiro na pasta configs/stgcn/
with open('/content/mmaction2/configs/stgcn_3d_custom.py', 'w') as f:
    f.write(config_code)

# Ajusta os dataloaders e paths conforme o teu dataset

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')


save_path = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino'
os.makedirs(save_path, exist_ok=True)




# os.makedirs('/content/drive/MyDrive/mmaction2_work_dir/tensorboard_logs', exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
# !python /content/mmaction2/tools/train.py /content/mmaction2/configs/stgcn_3d_custom.py
# Out:
# 05/26 10:27:33 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 63617522
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.5, V12.5.82
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.11.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 63617522
#     diff_rank_seed: False
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 05/26 10:27:34 - mmengine - INFO - Config:
# default_hooks = dict(
#     checkpoint=dict(interval=1, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=False, interval=20, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(
#     interval=2, metrics=[
#         'top_k_accuracy',
#     ])
# launcher = 'none'
# load_from = 'https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         graph_cfg=dict(layout='nturgb+d', mode='stgcn_spatial'),
#         in_channels=3,
#         type='STGCN'),
#     cls_head=dict(in_channels=256, num_classes=12, type='GCNHead'),
#     type='RecognizerGCN')
# optim_wrapper = dict(
#     optimizer=dict(
#         lr=0.1, momentum=0.9, nesterov=True, type='SGD', weight_decay=0.0005))
# param_scheduler = [
#     dict(
#         T_max=16,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         eta_min=0,
#         type='CosineAnnealingLR'),
# ]
# randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/test_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(
#                 clip_len=100,
#                 num_clips=1,
#                 test_mode=True,
#                 type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = [
#     dict(type='AccMetric'),
# ]
# test_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(
#         clip_len=100, num_clips=1, test_mode=True, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(
#     max_epochs=50, type='EpochBasedTrainLoop', val_begin=1, val_interval=1)
# train_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/train_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(clip_len=100, type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(clip_len=100, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/val_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(
#                 clip_len=100,
#                 num_clips=1,
#                 test_mode=True,
#                 type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = [
#     dict(type='AccMetric'),
# ]
# val_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(
#         clip_len=100, num_clips=1, test_mode=True, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino'
#
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 05/26 10:27:39 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 05/26 10:27:39 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 05/26 10:27:42 - mmengine - INFO - 1368 videos remain after valid thresholding
# 05/26 10:27:42 - mmengine - INFO - 288 videos remain after valid thresholding
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth
# Downloading: "https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth" to /root/.cache/torch/hub/checkpoints/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth
# 100% 12.0M/12.0M [00:00<00:00, 28.8MB/s]
# The model and loaded state dict do not match exactly
#
# size mismatch for cls_head.fc.weight: copying a param with shape torch.Size([60, 256]) from checkpoint, the shape in current model is torch.Size([12, 256]).
# size mismatch for cls_head.fc.bias: copying a param with shape torch.Size([60]) from checkpoint, the shape in current model is torch.Size([12]).
# 05/26 10:27:43 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth
# 05/26 10:27:43 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 05/26 10:27:43 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 05/26 10:27:43 - mmengine - INFO - Checkpoints will be saved to /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino.
# 05/26 10:27:57 - mmengine - INFO - Epoch(train)  [1][20/22]  lr: 9.9283e-02  eta: 0:12:37  time: 0.7013  data_time: 0.1232  memory: 5449  loss: 2.1088  top1_acc: 0.3125  top5_acc: 0.8750  loss_cls: 2.1088
# 05/26 10:27:58 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:27:58 - mmengine - INFO - Epoch(train)  [1][22/22]  lr: 9.9124e-02  eta: 0:12:05  time: 0.5873  data_time: 0.0750  memory: 5449  loss: 2.0123  top1_acc: 0.2917  top5_acc: 1.0000  loss_cls: 2.0123
# 05/26 10:27:58 - mmengine - INFO - Saving checkpoint at 1 epochs
# 05/26 10:28:01 - mmengine - INFO - Epoch(val) [1][5/5]    acc/top1: 0.2014  acc/top5: 0.6806  acc/mean1: 0.2014  data_time: 0.2907  time: 0.4474
# 05/26 10:28:01 - mmengine - INFO - The best checkpoint with 0.2014 acc/top1 at 1 epoch is saved to best_acc_top1_epoch_1.pth.
# 05/26 10:28:15 - mmengine - INFO - Epoch(train)  [2][20/22]  lr: 9.6690e-02  eta: 0:11:52  time: 0.6740  data_time: 0.1408  memory: 5449  loss: 1.4124  top1_acc: 0.4844  top5_acc: 0.9844  loss_cls: 1.4124
# 05/26 10:28:15 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:28:15 - mmengine - INFO - Epoch(train)  [2][22/22]  lr: 9.6363e-02  eta: 0:11:37  time: 0.5951  data_time: 0.0809  memory: 5449  loss: 1.3549  top1_acc: 0.5417  top5_acc: 0.9167  loss_cls: 1.3549
# 05/26 10:28:15 - mmengine - INFO - Saving checkpoint at 2 epochs
# 05/26 10:28:18 - mmengine - INFO - Epoch(val) [2][5/5]    acc/top1: 0.1840  acc/top5: 0.6979  acc/mean1: 0.1840  data_time: 0.3373  time: 0.4687
# 05/26 10:28:31 - mmengine - INFO - Epoch(train)  [3][20/22]  lr: 9.2302e-02  eta: 0:11:21  time: 0.6511  data_time: 0.1122  memory: 5449  loss: 1.2242  top1_acc: 0.5156  top5_acc: 0.9844  loss_cls: 1.2242
# 05/26 10:28:32 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:28:32 - mmengine - INFO - Epoch(train)  [3][22/22]  lr: 9.1820e-02  eta: 0:11:12  time: 0.5873  data_time: 0.0672  memory: 5449  loss: 1.2041  top1_acc: 0.5000  top5_acc: 1.0000  loss_cls: 1.2041
# 05/26 10:28:32 - mmengine - INFO - Saving checkpoint at 3 epochs
# 05/26 10:28:35 - mmengine - INFO - Epoch(val) [3][5/5]    acc/top1: 0.2188  acc/top5: 0.6632  acc/mean1: 0.2188  data_time: 0.2449  time: 0.3688
# 05/26 10:28:35 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_1.pth is removed
# 05/26 10:28:35 - mmengine - INFO - The best checkpoint with 0.2188 acc/top1 at 3 epoch is saved to best_acc_top1_epoch_3.pth.
# 05/26 10:28:48 - mmengine - INFO - Epoch(train)  [4][20/22]  lr: 8.6289e-02  eta: 0:11:04  time: 0.6731  data_time: 0.1252  memory: 5449  loss: 1.0062  top1_acc: 0.5938  top5_acc: 1.0000  loss_cls: 1.0062
# 05/26 10:28:49 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:28:49 - mmengine - INFO - Epoch(train)  [4][22/22]  lr: 8.5669e-02  eta: 0:10:57  time: 0.6127  data_time: 0.0837  memory: 5449  loss: 1.0009  top1_acc: 0.5000  top5_acc: 1.0000  loss_cls: 1.0009
# 05/26 10:28:49 - mmengine - INFO - Saving checkpoint at 4 epochs
# 05/26 10:28:51 - mmengine - INFO - Epoch(val) [4][5/5]    acc/top1: 0.3993  acc/top5: 0.8785  acc/mean1: 0.3993  data_time: 0.2232  time: 0.3493
# 05/26 10:28:51 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_3.pth is removed
# 05/26 10:28:51 - mmengine - INFO - The best checkpoint with 0.3993 acc/top1 at 4 epoch is saved to best_acc_top1_epoch_4.pth.
# 05/26 10:29:05 - mmengine - INFO - Epoch(train)  [5][20/22]  lr: 7.8882e-02  eta: 0:10:50  time: 0.6827  data_time: 0.1250  memory: 5449  loss: 0.8741  top1_acc: 0.6250  top5_acc: 1.0000  loss_cls: 0.8741
# 05/26 10:29:06 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:29:06 - mmengine - INFO - Epoch(train)  [5][22/22]  lr: 7.8148e-02  eta: 0:10:44  time: 0.6268  data_time: 0.0879  memory: 5449  loss: 0.8794  top1_acc: 0.5417  top5_acc: 0.9583  loss_cls: 0.8794
# 05/26 10:29:06 - mmengine - INFO - Saving checkpoint at 5 epochs
# 05/26 10:29:09 - mmengine - INFO - Epoch(val) [5][5/5]    acc/top1: 0.3854  acc/top5: 0.8924  acc/mean1: 0.3854  data_time: 0.2210  time: 0.3512
# 05/26 10:29:22 - mmengine - INFO - Epoch(train)  [6][20/22]  lr: 7.0364e-02  eta: 0:10:36  time: 0.6816  data_time: 0.1225  memory: 5449  loss: 0.7843  top1_acc: 0.6250  top5_acc: 1.0000  loss_cls: 0.7843
# 05/26 10:29:23 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:29:23 - mmengine - INFO - Epoch(train)  [6][22/22]  lr: 6.9546e-02  eta: 0:10:31  time: 0.6237  data_time: 0.0832  memory: 5449  loss: 0.7836  top1_acc: 0.5000  top5_acc: 1.0000  loss_cls: 0.7836
# 05/26 10:29:23 - mmengine - INFO - Saving checkpoint at 6 epochs
# 05/26 10:29:25 - mmengine - INFO - Epoch(val) [6][5/5]    acc/top1: 0.4826  acc/top5: 0.9479  acc/mean1: 0.4826  data_time: 0.2119  time: 0.3419
# 05/26 10:29:25 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_4.pth is removed
# 05/26 10:29:26 - mmengine - INFO - The best checkpoint with 0.4826 acc/top1 at 6 epoch is saved to best_acc_top1_epoch_6.pth.
# 05/26 10:29:40 - mmengine - INFO - Epoch(train)  [7][20/22]  lr: 6.1064e-02  eta: 0:10:25  time: 0.7091  data_time: 0.1450  memory: 5449  loss: 0.7252  top1_acc: 0.8281  top5_acc: 1.0000  loss_cls: 0.7252
# 05/26 10:29:41 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:29:41 - mmengine - INFO - Epoch(train)  [7][22/22]  lr: 6.0192e-02  eta: 0:10:21  time: 0.6387  data_time: 0.0946  memory: 5449  loss: 0.7165  top1_acc: 0.5833  top5_acc: 1.0000  loss_cls: 0.7165
# 05/26 10:29:41 - mmengine - INFO - Saving checkpoint at 7 epochs
# 05/26 10:29:43 - mmengine - INFO - Epoch(val) [7][5/5]    acc/top1: 0.5104  acc/top5: 0.9618  acc/mean1: 0.5104  data_time: 0.2800  time: 0.4185
# 05/26 10:29:43 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_6.pth is removed
# 05/26 10:29:44 - mmengine - INFO - The best checkpoint with 0.5104 acc/top1 at 7 epoch is saved to best_acc_top1_epoch_7.pth.
# 05/26 10:29:58 - mmengine - INFO - Epoch(train)  [8][20/22]  lr: 5.1339e-02  eta: 0:10:13  time: 0.7103  data_time: 0.1394  memory: 5449  loss: 0.5899  top1_acc: 0.7031  top5_acc: 1.0000  loss_cls: 0.5899
# 05/26 10:29:59 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:29:59 - mmengine - INFO - Epoch(train)  [8][22/22]  lr: 5.0446e-02  eta: 0:10:09  time: 0.6092  data_time: 0.0614  memory: 5449  loss: 0.5846  top1_acc: 0.7917  top5_acc: 1.0000  loss_cls: 0.5846
# 05/26 10:29:59 - mmengine - INFO - Saving checkpoint at 8 epochs
# 05/26 10:30:01 - mmengine - INFO - Epoch(val) [8][5/5]    acc/top1: 0.5347  acc/top5: 0.9549  acc/mean1: 0.5347  data_time: 0.2518  time: 0.3839
# 05/26 10:30:01 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_7.pth is removed
# 05/26 10:30:02 - mmengine - INFO - The best checkpoint with 0.5347 acc/top1 at 8 epoch is saved to best_acc_top1_epoch_8.pth.
# 05/26 10:30:16 - mmengine - INFO - Epoch(train)  [9][20/22]  lr: 4.1562e-02  eta: 0:09:59  time: 0.6926  data_time: 0.1224  memory: 5449  loss: 0.4888  top1_acc: 0.8594  top5_acc: 1.0000  loss_cls: 0.4888
# 05/26 10:30:16 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:30:16 - mmengine - INFO - Epoch(train)  [9][22/22]  lr: 4.0684e-02  eta: 0:09:56  time: 0.6298  data_time: 0.0801  memory: 5449  loss: 0.5026  top1_acc: 0.7083  top5_acc: 1.0000  loss_cls: 0.5026
# 05/26 10:30:16 - mmengine - INFO - Saving checkpoint at 9 epochs
# 05/26 10:30:19 - mmengine - INFO - Epoch(val) [9][5/5]    acc/top1: 0.4965  acc/top5: 0.9549  acc/mean1: 0.4965  data_time: 0.2267  time: 0.3587
# 05/26 10:30:33 - mmengine - INFO - Epoch(train) [10][20/22]  lr: 3.2109e-02  eta: 0:09:46  time: 0.7047  data_time: 0.1375  memory: 5449  loss: 0.4638  top1_acc: 0.8594  top5_acc: 1.0000  loss_cls: 0.4638
# 05/26 10:30:34 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:30:34 - mmengine - INFO - Epoch(train) [10][22/22]  lr: 3.1279e-02  eta: 0:09:43  time: 0.6344  data_time: 0.0877  memory: 5449  loss: 0.4454  top1_acc: 0.9167  top5_acc: 1.0000  loss_cls: 0.4454
# 05/26 10:30:34 - mmengine - INFO - Saving checkpoint at 10 epochs
# 05/26 10:30:36 - mmengine - INFO - Epoch(val) [10][5/5]    acc/top1: 0.5833  acc/top5: 0.9549  acc/mean1: 0.5833  data_time: 0.2308  time: 0.3623
# 05/26 10:30:36 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_8.pth is removed
# 05/26 10:30:36 - mmengine - INFO - The best checkpoint with 0.5833 acc/top1 at 10 epoch is saved to best_acc_top1_epoch_10.pth.
# 05/26 10:30:51 - mmengine - INFO - Epoch(train) [11][20/22]  lr: 2.3344e-02  eta: 0:09:32  time: 0.7036  data_time: 0.1351  memory: 5449  loss: 0.3137  top1_acc: 0.9531  top5_acc: 1.0000  loss_cls: 0.3137
# 05/26 10:30:51 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:30:51 - mmengine - INFO - Epoch(train) [11][22/22]  lr: 2.2594e-02  eta: 0:09:29  time: 0.6372  data_time: 0.0900  memory: 5449  loss: 0.3222  top1_acc: 0.7917  top5_acc: 1.0000  loss_cls: 0.3222
# 05/26 10:30:51 - mmengine - INFO - Saving checkpoint at 11 epochs
# 05/26 10:30:54 - mmengine - INFO - Epoch(val) [11][5/5]    acc/top1: 0.5868  acc/top5: 0.9549  acc/mean1: 0.5868  data_time: 0.2176  time: 0.3484
# 05/26 10:30:54 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_10.pth is removed
# 05/26 10:30:54 - mmengine - INFO - The best checkpoint with 0.5868 acc/top1 at 11 epoch is saved to best_acc_top1_epoch_11.pth.
# 05/26 10:31:08 - mmengine - INFO - Epoch(train) [12][20/22]  lr: 1.5604e-02  eta: 0:09:19  time: 0.7128  data_time: 0.1446  memory: 5449  loss: 0.2232  top1_acc: 0.9375  top5_acc: 1.0000  loss_cls: 0.2232
# 05/26 10:31:09 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:31:09 - mmengine - INFO - Epoch(train) [12][22/22]  lr: 1.4962e-02  eta: 0:09:16  time: 0.6399  data_time: 0.0924  memory: 5449  loss: 0.2220  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.2220
# 05/26 10:31:09 - mmengine - INFO - Saving checkpoint at 12 epochs
# 05/26 10:31:12 - mmengine - INFO - Epoch(val) [12][5/5]    acc/top1: 0.5799  acc/top5: 0.9549  acc/mean1: 0.5799  data_time: 0.3184  time: 0.4624
# 05/26 10:31:26 - mmengine - INFO - Epoch(train) [13][20/22]  lr: 9.1851e-03  eta: 0:09:05  time: 0.6957  data_time: 0.1296  memory: 5449  loss: 0.1615  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.1615
# 05/26 10:31:27 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:31:27 - mmengine - INFO - Epoch(train) [13][22/22]  lr: 8.6761e-03  eta: 0:09:02  time: 0.6143  data_time: 0.0682  memory: 5449  loss: 0.1715  top1_acc: 0.7917  top5_acc: 1.0000  loss_cls: 0.1715
# 05/26 10:31:27 - mmengine - INFO - Saving checkpoint at 13 epochs
# 05/26 10:31:29 - mmengine - INFO - Epoch(val) [13][5/5]    acc/top1: 0.5799  acc/top5: 0.9479  acc/mean1: 0.5799  data_time: 0.2506  time: 0.3827
# 05/26 10:31:43 - mmengine - INFO - Epoch(train) [14][20/22]  lr: 4.3348e-03  eta: 0:08:50  time: 0.6880  data_time: 0.1176  memory: 5449  loss: 0.1133  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.1133
# 05/26 10:31:44 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:31:44 - mmengine - INFO - Epoch(train) [14][22/22]  lr: 3.9786e-03  eta: 0:08:47  time: 0.6291  data_time: 0.0790  memory: 5449  loss: 0.1155  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.1155
# 05/26 10:31:44 - mmengine - INFO - Saving checkpoint at 14 epochs
# 05/26 10:31:46 - mmengine - INFO - Epoch(val) [14][5/5]    acc/top1: 0.5799  acc/top5: 0.9583  acc/mean1: 0.5799  data_time: 0.2285  time: 0.3583
# 05/26 10:32:00 - mmengine - INFO - Epoch(train) [15][20/22]  lr: 1.2395e-03  eta: 0:08:35  time: 0.6995  data_time: 0.1301  memory: 5449  loss: 0.0955  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0955
# 05/26 10:32:01 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:32:01 - mmengine - INFO - Epoch(train) [15][22/22]  lr: 1.0497e-03  eta: 0:08:33  time: 0.6330  data_time: 0.0837  memory: 5449  loss: 0.0971  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0971
# 05/26 10:32:01 - mmengine - INFO - Saving checkpoint at 15 epochs
# 05/26 10:32:03 - mmengine - INFO - Epoch(val) [15][5/5]    acc/top1: 0.5799  acc/top5: 0.9514  acc/mean1: 0.5799  data_time: 0.2270  time: 0.3568
# 05/26 10:32:17 - mmengine - INFO - Epoch(train) [16][20/22]  lr: 1.7921e-05  eta: 0:08:21  time: 0.7125  data_time: 0.1424  memory: 5449  loss: 0.0863  top1_acc: 0.9688  top5_acc: 1.0000  loss_cls: 0.0863
# 05/26 10:32:18 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:32:18 - mmengine - INFO - Epoch(train) [16][22/22]  lr: 1.9914e-06  eta: 0:08:19  time: 0.6427  data_time: 0.0931  memory: 5449  loss: 0.0851  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0851
# 05/26 10:32:18 - mmengine - INFO - Saving checkpoint at 16 epochs
# 05/26 10:32:20 - mmengine - INFO - Epoch(val) [16][5/5]    acc/top1: 0.5799  acc/top5: 0.9514  acc/mean1: 0.5799  data_time: 0.2467  time: 0.3762
# 05/26 10:32:35 - mmengine - INFO - Epoch(train) [17][20/22]  lr: 7.1717e-04  eta: 0:08:08  time: 0.7238  data_time: 0.1487  memory: 5449  loss: 0.0784  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0784
# 05/26 10:32:36 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:32:36 - mmengine - INFO - Epoch(train) [17][22/22]  lr: 8.7563e-04  eta: 0:08:05  time: 0.6570  data_time: 0.1042  memory: 5449  loss: 0.0777  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0777
# 05/26 10:32:36 - mmengine - INFO - Saving checkpoint at 17 epochs
# 05/26 10:32:39 - mmengine - INFO - Epoch(val) [17][5/5]    acc/top1: 0.5694  acc/top5: 0.9479  acc/mean1: 0.5694  data_time: 0.3248  time: 0.4643
# 05/26 10:32:53 - mmengine - INFO - Epoch(train) [18][20/22]  lr: 3.3103e-03  eta: 0:07:54  time: 0.7337  data_time: 0.1657  memory: 5449  loss: 0.0804  top1_acc: 0.9688  top5_acc: 1.0000  loss_cls: 0.0804
# 05/26 10:32:54 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:32:54 - mmengine - INFO - Epoch(train) [18][22/22]  lr: 3.6371e-03  eta: 0:07:52  time: 0.6507  data_time: 0.1047  memory: 5449  loss: 0.0827  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0827
# 05/26 10:32:54 - mmengine - INFO - Saving checkpoint at 18 epochs
# 05/26 10:32:57 - mmengine - INFO - Epoch(val) [18][5/5]    acc/top1: 0.5799  acc/top5: 0.9549  acc/mean1: 0.5799  data_time: 0.3299  time: 0.4667
# 05/26 10:33:11 - mmengine - INFO - Epoch(train) [19][20/22]  lr: 7.6977e-03  eta: 0:07:40  time: 0.7023  data_time: 0.1328  memory: 5449  loss: 0.0719  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0719
# 05/26 10:33:12 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:33:12 - mmengine - INFO - Epoch(train) [19][22/22]  lr: 8.1803e-03  eta: 0:07:38  time: 0.6311  data_time: 0.0822  memory: 5449  loss: 0.0728  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0728
# 05/26 10:33:12 - mmengine - INFO - Saving checkpoint at 19 epochs
# 05/26 10:33:14 - mmengine - INFO - Epoch(val) [19][5/5]    acc/top1: 0.5694  acc/top5: 0.9479  acc/mean1: 0.5694  data_time: 0.2566  time: 0.3893
# 05/26 10:33:29 - mmengine - INFO - Epoch(train) [20][20/22]  lr: 1.3711e-02  eta: 0:07:26  time: 0.7252  data_time: 0.1520  memory: 5449  loss: 0.0701  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0701
# 05/26 10:33:30 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:33:30 - mmengine - INFO - Epoch(train) [20][22/22]  lr: 1.4331e-02  eta: 0:07:24  time: 0.6564  data_time: 0.1035  memory: 5449  loss: 0.0692  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0692
# 05/26 10:33:30 - mmengine - INFO - Saving checkpoint at 20 epochs
# 05/26 10:33:32 - mmengine - INFO - Epoch(val) [20][5/5]    acc/top1: 0.5625  acc/top5: 0.9444  acc/mean1: 0.5625  data_time: 0.2389  time: 0.3748
# 05/26 10:33:47 - mmengine - INFO - Epoch(train) [21][20/22]  lr: 2.1118e-02  eta: 0:07:12  time: 0.7383  data_time: 0.1642  memory: 5449  loss: 0.0717  top1_acc: 0.9375  top5_acc: 1.0000  loss_cls: 0.0717
# 05/26 10:33:48 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:33:48 - mmengine - INFO - Epoch(train) [21][22/22]  lr: 2.1852e-02  eta: 0:07:10  time: 0.6556  data_time: 0.1022  memory: 5449  loss: 0.0771  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0771
# 05/26 10:33:48 - mmengine - INFO - Saving checkpoint at 21 epochs
# 05/26 10:33:50 - mmengine - INFO - Epoch(val) [21][5/5]    acc/top1: 0.5556  acc/top5: 0.9444  acc/mean1: 0.5556  data_time: 0.2610  time: 0.3920
# 05/26 10:34:05 - mmengine - INFO - Epoch(train) [22][20/22]  lr: 2.9636e-02  eta: 0:06:58  time: 0.7275  data_time: 0.1568  memory: 5449  loss: 0.1830  top1_acc: 0.8594  top5_acc: 1.0000  loss_cls: 0.1830
# 05/26 10:34:06 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:34:06 - mmengine - INFO - Epoch(train) [22][22/22]  lr: 3.0454e-02  eta: 0:06:56  time: 0.6621  data_time: 0.1114  memory: 5449  loss: 0.2081  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.2081
# 05/26 10:34:06 - mmengine - INFO - Saving checkpoint at 22 epochs
# 05/26 10:34:08 - mmengine - INFO - Epoch(val) [22][5/5]    acc/top1: 0.5417  acc/top5: 0.9375  acc/mean1: 0.5417  data_time: 0.2432  time: 0.3889
# 05/26 10:34:23 - mmengine - INFO - Epoch(train) [23][20/22]  lr: 3.8936e-02  eta: 0:06:44  time: 0.7427  data_time: 0.1717  memory: 5449  loss: 0.3161  top1_acc: 0.8594  top5_acc: 1.0000  loss_cls: 0.3161
# 05/26 10:34:24 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:34:24 - mmengine - INFO - Epoch(train) [23][22/22]  lr: 3.9808e-02  eta: 0:06:42  time: 0.6550  data_time: 0.1065  memory: 5449  loss: 0.3366  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.3366
# 05/26 10:34:24 - mmengine - INFO - Saving checkpoint at 23 epochs
# 05/26 10:34:27 - mmengine - INFO - Epoch(val) [23][5/5]    acc/top1: 0.4896  acc/top5: 0.9514  acc/mean1: 0.4896  data_time: 0.3884  time: 0.5282
# 05/26 10:34:41 - mmengine - INFO - Epoch(train) [24][20/22]  lr: 4.8661e-02  eta: 0:06:29  time: 0.7008  data_time: 0.1330  memory: 5449  loss: 0.3937  top1_acc: 0.8594  top5_acc: 1.0000  loss_cls: 0.3937
# 05/26 10:34:42 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:34:42 - mmengine - INFO - Epoch(train) [24][22/22]  lr: 4.9554e-02  eta: 0:06:27  time: 0.6285  data_time: 0.0805  memory: 5449  loss: 0.4166  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.4166
# 05/26 10:34:42 - mmengine - INFO - Saving checkpoint at 24 epochs
# 05/26 10:34:44 - mmengine - INFO - Epoch(val) [24][5/5]    acc/top1: 0.4826  acc/top5: 0.9236  acc/mean1: 0.4826  data_time: 0.2566  time: 0.3918
# 05/26 10:34:59 - mmengine - INFO - Epoch(train) [25][20/22]  lr: 5.8438e-02  eta: 0:06:14  time: 0.7229  data_time: 0.1537  memory: 5449  loss: 0.5000  top1_acc: 0.8438  top5_acc: 1.0000  loss_cls: 0.5000
# 05/26 10:35:00 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:35:00 - mmengine - INFO - Epoch(train) [25][22/22]  lr: 5.9316e-02  eta: 0:06:12  time: 0.6419  data_time: 0.0928  memory: 5449  loss: 0.5225  top1_acc: 0.8333  top5_acc: 1.0000  loss_cls: 0.5225
# 05/26 10:35:00 - mmengine - INFO - Saving checkpoint at 25 epochs
# 05/26 10:35:02 - mmengine - INFO - Epoch(val) [25][5/5]    acc/top1: 0.4965  acc/top5: 0.9271  acc/mean1: 0.4965  data_time: 0.2585  time: 0.3909
# 05/26 10:35:17 - mmengine - INFO - Epoch(train) [26][20/22]  lr: 6.7891e-02  eta: 0:06:00  time: 0.7364  data_time: 0.1617  memory: 5449  loss: 0.4684  top1_acc: 0.7969  top5_acc: 0.9688  loss_cls: 0.4684
# 05/26 10:35:18 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:35:18 - mmengine - INFO - Epoch(train) [26][22/22]  lr: 6.8721e-02  eta: 0:05:58  time: 0.6555  data_time: 0.1011  memory: 5449  loss: 0.4798  top1_acc: 0.8333  top5_acc: 1.0000  loss_cls: 0.4798
# 05/26 10:35:18 - mmengine - INFO - Saving checkpoint at 26 epochs
# 05/26 10:35:20 - mmengine - INFO - Epoch(val) [26][5/5]    acc/top1: 0.4792  acc/top5: 0.9132  acc/mean1: 0.4792  data_time: 0.2821  time: 0.4109
# 05/26 10:35:35 - mmengine - INFO - Epoch(train) [27][20/22]  lr: 7.6656e-02  eta: 0:05:45  time: 0.7276  data_time: 0.1545  memory: 5449  loss: 0.5586  top1_acc: 0.7344  top5_acc: 1.0000  loss_cls: 0.5586
# 05/26 10:35:36 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:35:36 - mmengine - INFO - Epoch(train) [27][22/22]  lr: 7.7406e-02  eta: 0:05:44  time: 0.6472  data_time: 0.0947  memory: 5449  loss: 0.5583  top1_acc: 0.7500  top5_acc: 1.0000  loss_cls: 0.5583
# 05/26 10:35:36 - mmengine - INFO - Saving checkpoint at 27 epochs
# 05/26 10:35:38 - mmengine - INFO - Epoch(val) [27][5/5]    acc/top1: 0.3160  acc/top5: 0.8333  acc/mean1: 0.3160  data_time: 0.2650  time: 0.3947
# 05/26 10:35:53 - mmengine - INFO - Epoch(train) [28][20/22]  lr: 8.4396e-02  eta: 0:05:31  time: 0.7527  data_time: 0.1851  memory: 5449  loss: 0.5367  top1_acc: 0.7188  top5_acc: 1.0000  loss_cls: 0.5367
# 05/26 10:35:54 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:35:54 - mmengine - INFO - Epoch(train) [28][22/22]  lr: 8.5038e-02  eta: 0:05:29  time: 0.6727  data_time: 0.1255  memory: 5449  loss: 0.5144  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.5144
# 05/26 10:35:54 - mmengine - INFO - Saving checkpoint at 28 epochs
# 05/26 10:35:58 - mmengine - INFO - Epoch(val) [28][5/5]    acc/top1: 0.4479  acc/top5: 0.9097  acc/mean1: 0.4479  data_time: 0.3863  time: 0.5365
# 05/26 10:36:11 - mmengine - INFO - Epoch(train) [29][20/22]  lr: 9.0815e-02  eta: 0:05:16  time: 0.6923  data_time: 0.1245  memory: 5449  loss: 0.4198  top1_acc: 0.9375  top5_acc: 0.9844  loss_cls: 0.4198
# 05/26 10:36:12 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:36:12 - mmengine - INFO - Epoch(train) [29][22/22]  lr: 9.1324e-02  eta: 0:05:14  time: 0.6242  data_time: 0.0767  memory: 5449  loss: 0.4256  top1_acc: 0.8333  top5_acc: 1.0000  loss_cls: 0.4256
# 05/26 10:36:12 - mmengine - INFO - Saving checkpoint at 29 epochs
# 05/26 10:36:15 - mmengine - INFO - Epoch(val) [29][5/5]    acc/top1: 0.4132  acc/top5: 0.7743  acc/mean1: 0.4132  data_time: 0.2597  time: 0.3921
# 05/26 10:36:29 - mmengine - INFO - Epoch(train) [30][20/22]  lr: 9.5665e-02  eta: 0:05:01  time: 0.7331  data_time: 0.1600  memory: 5449  loss: 0.5330  top1_acc: 0.7344  top5_acc: 1.0000  loss_cls: 0.5330
# 05/26 10:36:30 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:36:30 - mmengine - INFO - Epoch(train) [30][22/22]  lr: 9.6021e-02  eta: 0:05:00  time: 0.6568  data_time: 0.1047  memory: 5449  loss: 0.5414  top1_acc: 0.7917  top5_acc: 1.0000  loss_cls: 0.5414
# 05/26 10:36:30 - mmengine - INFO - Saving checkpoint at 30 epochs
# 05/26 10:36:33 - mmengine - INFO - Epoch(val) [30][5/5]    acc/top1: 0.3299  acc/top5: 0.8125  acc/mean1: 0.3299  data_time: 0.2584  time: 0.3907
# 05/26 10:36:48 - mmengine - INFO - Epoch(train) [31][20/22]  lr: 9.8761e-02  eta: 0:04:47  time: 0.7422  data_time: 0.1656  memory: 5449  loss: 0.5002  top1_acc: 0.7969  top5_acc: 1.0000  loss_cls: 0.5002
# 05/26 10:36:48 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:36:48 - mmengine - INFO - Epoch(train) [31][22/22]  lr: 9.8950e-02  eta: 0:04:45  time: 0.6754  data_time: 0.1189  memory: 5449  loss: 0.4976  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.4976
# 05/26 10:36:48 - mmengine - INFO - Saving checkpoint at 31 epochs
# 05/26 10:36:51 - mmengine - INFO - Epoch(val) [31][5/5]    acc/top1: 0.3750  acc/top5: 0.8333  acc/mean1: 0.3750  data_time: 0.2569  time: 0.3885
# 05/26 10:37:05 - mmengine - INFO - Epoch(train) [32][20/22]  lr: 9.9982e-02  eta: 0:04:32  time: 0.7292  data_time: 0.1565  memory: 5449  loss: 0.4020  top1_acc: 0.8594  top5_acc: 1.0000  loss_cls: 0.4020
# 05/26 10:37:06 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:37:06 - mmengine - INFO - Epoch(train) [32][22/22]  lr: 9.9998e-02  eta: 0:04:30  time: 0.6553  data_time: 0.1027  memory: 5449  loss: 0.4164  top1_acc: 0.5833  top5_acc: 1.0000  loss_cls: 0.4164
# 05/26 10:37:06 - mmengine - INFO - Saving checkpoint at 32 epochs
# 05/26 10:37:09 - mmengine - INFO - Epoch(val) [32][5/5]    acc/top1: 0.5278  acc/top5: 0.9236  acc/mean1: 0.5278  data_time: 0.2427  time: 0.3757
# 05/26 10:37:24 - mmengine - INFO - Epoch(train) [33][20/22]  lr: 9.9283e-02  eta: 0:04:17  time: 0.7492  data_time: 0.1781  memory: 5449  loss: 0.4279  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.4279
# 05/26 10:37:25 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:37:25 - mmengine - INFO - Epoch(train) [33][22/22]  lr: 9.9124e-02  eta: 0:04:16  time: 0.6753  data_time: 0.1256  memory: 5449  loss: 0.4362  top1_acc: 0.6667  top5_acc: 1.0000  loss_cls: 0.4362
# 05/26 10:37:25 - mmengine - INFO - Saving checkpoint at 33 epochs
# 05/26 10:37:28 - mmengine - INFO - Epoch(val) [33][5/5]    acc/top1: 0.4792  acc/top5: 0.9306  acc/mean1: 0.4792  data_time: 0.3676  time: 0.5094
# 05/26 10:37:42 - mmengine - INFO - Epoch(train) [34][20/22]  lr: 9.6690e-02  eta: 0:04:02  time: 0.7304  data_time: 0.1620  memory: 5449  loss: 0.3115  top1_acc: 0.8281  top5_acc: 1.0000  loss_cls: 0.3115
# 05/26 10:37:43 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:37:43 - mmengine - INFO - Epoch(train) [34][22/22]  lr: 9.6363e-02  eta: 0:04:01  time: 0.6185  data_time: 0.0724  memory: 5449  loss: 0.3173  top1_acc: 0.9167  top5_acc: 1.0000  loss_cls: 0.3173
# 05/26 10:37:43 - mmengine - INFO - Saving checkpoint at 34 epochs
# 05/26 10:37:46 - mmengine - INFO - Epoch(val) [34][5/5]    acc/top1: 0.4479  acc/top5: 0.9236  acc/mean1: 0.4479  data_time: 0.3027  time: 0.4373
# 05/26 10:38:01 - mmengine - INFO - Epoch(train) [35][20/22]  lr: 9.2302e-02  eta: 0:03:47  time: 0.7187  data_time: 0.1480  memory: 5449  loss: 0.4980  top1_acc: 0.7656  top5_acc: 1.0000  loss_cls: 0.4980
# 05/26 10:38:01 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:38:01 - mmengine - INFO - Epoch(train) [35][22/22]  lr: 9.1820e-02  eta: 0:03:46  time: 0.6413  data_time: 0.0918  memory: 5449  loss: 0.4997  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.4997
# 05/26 10:38:01 - mmengine - INFO - Saving checkpoint at 35 epochs
# 05/26 10:38:04 - mmengine - INFO - Epoch(val) [35][5/5]    acc/top1: 0.4514  acc/top5: 0.8854  acc/mean1: 0.4514  data_time: 0.2515  time: 0.4124
# 05/26 10:38:19 - mmengine - INFO - Epoch(train) [36][20/22]  lr: 8.6289e-02  eta: 0:03:32  time: 0.7320  data_time: 0.1580  memory: 5449  loss: 0.2978  top1_acc: 0.8594  top5_acc: 1.0000  loss_cls: 0.2978
# 05/26 10:38:19 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:38:19 - mmengine - INFO - Epoch(train) [36][22/22]  lr: 8.5669e-02  eta: 0:03:31  time: 0.6565  data_time: 0.1027  memory: 5449  loss: 0.2816  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.2816
# 05/26 10:38:19 - mmengine - INFO - Saving checkpoint at 36 epochs
# 05/26 10:38:22 - mmengine - INFO - Epoch(val) [36][5/5]    acc/top1: 0.5208  acc/top5: 0.9201  acc/mean1: 0.5208  data_time: 0.2589  time: 0.3928
# 05/26 10:38:37 - mmengine - INFO - Epoch(train) [37][20/22]  lr: 7.8882e-02  eta: 0:03:17  time: 0.7437  data_time: 0.1731  memory: 5449  loss: 0.2111  top1_acc: 0.9375  top5_acc: 1.0000  loss_cls: 0.2111
# 05/26 10:38:38 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:38:38 - mmengine - INFO - Epoch(train) [37][22/22]  lr: 7.8148e-02  eta: 0:03:16  time: 0.6612  data_time: 0.1112  memory: 5449  loss: 0.2219  top1_acc: 0.9167  top5_acc: 1.0000  loss_cls: 0.2219
# 05/26 10:38:38 - mmengine - INFO - Saving checkpoint at 37 epochs
# 05/26 10:38:40 - mmengine - INFO - Epoch(val) [37][5/5]    acc/top1: 0.5035  acc/top5: 0.9132  acc/mean1: 0.5035  data_time: 0.2579  time: 0.3890
# 05/26 10:38:55 - mmengine - INFO - Epoch(train) [38][20/22]  lr: 7.0364e-02  eta: 0:03:03  time: 0.7548  data_time: 0.1844  memory: 5449  loss: 0.2081  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.2081
# 05/26 10:38:56 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:38:56 - mmengine - INFO - Epoch(train) [38][22/22]  lr: 6.9546e-02  eta: 0:03:01  time: 0.6558  data_time: 0.1060  memory: 5449  loss: 0.2134  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.2134
# 05/26 10:38:56 - mmengine - INFO - Saving checkpoint at 38 epochs
# 05/26 10:38:59 - mmengine - INFO - Epoch(val) [38][5/5]    acc/top1: 0.5069  acc/top5: 0.9028  acc/mean1: 0.5069  data_time: 0.3566  time: 0.4969
# 05/26 10:39:14 - mmengine - INFO - Epoch(train) [39][20/22]  lr: 6.1064e-02  eta: 0:02:47  time: 0.7214  data_time: 0.1526  memory: 5449  loss: 0.1362  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.1362
# 05/26 10:39:14 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:39:14 - mmengine - INFO - Epoch(train) [39][22/22]  lr: 6.0192e-02  eta: 0:02:46  time: 0.6165  data_time: 0.0700  memory: 5449  loss: 0.1359  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.1359
# 05/26 10:39:14 - mmengine - INFO - Saving checkpoint at 39 epochs
# 05/26 10:39:18 - mmengine - INFO - Epoch(val) [39][5/5]    acc/top1: 0.6076  acc/top5: 0.9583  acc/mean1: 0.6076  data_time: 0.3519  time: 0.4938
# 05/26 10:39:18 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_11.pth is removed
# 05/26 10:39:18 - mmengine - INFO - The best checkpoint with 0.6076 acc/top1 at 39 epoch is saved to best_acc_top1_epoch_39.pth.
# 05/26 10:39:32 - mmengine - INFO - Epoch(train) [40][20/22]  lr: 5.1339e-02  eta: 0:02:32  time: 0.7246  data_time: 0.1503  memory: 5449  loss: 0.0714  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0714
# 05/26 10:39:33 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:39:33 - mmengine - INFO - Epoch(train) [40][22/22]  lr: 5.0446e-02  eta: 0:02:31  time: 0.6609  data_time: 0.1069  memory: 5449  loss: 0.0630  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0630
# 05/26 10:39:33 - mmengine - INFO - Saving checkpoint at 40 epochs
# 05/26 10:39:36 - mmengine - INFO - Epoch(val) [40][5/5]    acc/top1: 0.5382  acc/top5: 0.9132  acc/mean1: 0.5382  data_time: 0.2508  time: 0.3857
# 05/26 10:39:50 - mmengine - INFO - Epoch(train) [41][20/22]  lr: 4.1562e-02  eta: 0:02:17  time: 0.7333  data_time: 0.1602  memory: 5449  loss: 0.0358  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.0358
# 05/26 10:39:51 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:39:51 - mmengine - INFO - Epoch(train) [41][22/22]  lr: 4.0684e-02  eta: 0:02:16  time: 0.6694  data_time: 0.1159  memory: 5449  loss: 0.0366  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0366
# 05/26 10:39:51 - mmengine - INFO - Saving checkpoint at 41 epochs
# 05/26 10:39:54 - mmengine - INFO - Epoch(val) [41][5/5]    acc/top1: 0.5660  acc/top5: 0.9306  acc/mean1: 0.5660  data_time: 0.2573  time: 0.3893
# 05/26 10:40:08 - mmengine - INFO - Epoch(train) [42][20/22]  lr: 3.2109e-02  eta: 0:02:02  time: 0.7296  data_time: 0.1561  memory: 5449  loss: 0.0168  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0168
# 05/26 10:40:09 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:40:09 - mmengine - INFO - Epoch(train) [42][22/22]  lr: 3.1279e-02  eta: 0:02:01  time: 0.6686  data_time: 0.1154  memory: 5449  loss: 0.0208  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0208
# 05/26 10:40:09 - mmengine - INFO - Saving checkpoint at 42 epochs
# 05/26 10:40:12 - mmengine - INFO - Epoch(val) [42][5/5]    acc/top1: 0.5833  acc/top5: 0.9340  acc/mean1: 0.5833  data_time: 0.2539  time: 0.3879
# 05/26 10:40:26 - mmengine - INFO - Epoch(train) [43][20/22]  lr: 2.3344e-02  eta: 0:01:47  time: 0.7407  data_time: 0.1665  memory: 5449  loss: 0.0239  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0239
# 05/26 10:40:27 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:40:27 - mmengine - INFO - Epoch(train) [43][22/22]  lr: 2.2594e-02  eta: 0:01:46  time: 0.6538  data_time: 0.1009  memory: 5449  loss: 0.0286  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0286
# 05/26 10:40:27 - mmengine - INFO - Saving checkpoint at 43 epochs
# 05/26 10:40:31 - mmengine - INFO - Epoch(val) [43][5/5]    acc/top1: 0.5799  acc/top5: 0.9306  acc/mean1: 0.5799  data_time: 0.4049  time: 0.5428
# 05/26 10:40:45 - mmengine - INFO - Epoch(train) [44][20/22]  lr: 1.5604e-02  eta: 0:01:32  time: 0.7253  data_time: 0.1566  memory: 5449  loss: 0.0134  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0134
# 05/26 10:40:46 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:40:46 - mmengine - INFO - Epoch(train) [44][22/22]  lr: 1.4962e-02  eta: 0:01:31  time: 0.6224  data_time: 0.0759  memory: 5449  loss: 0.0132  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0132
# 05/26 10:40:46 - mmengine - INFO - Saving checkpoint at 44 epochs
# 05/26 10:40:49 - mmengine - INFO - Epoch(val) [44][5/5]    acc/top1: 0.5764  acc/top5: 0.9340  acc/mean1: 0.5764  data_time: 0.2922  time: 0.4250
# 05/26 10:41:03 - mmengine - INFO - Epoch(train) [45][20/22]  lr: 9.1851e-03  eta: 0:01:17  time: 0.7054  data_time: 0.1347  memory: 5449  loss: 0.0068  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0068
# 05/26 10:41:04 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:41:04 - mmengine - INFO - Epoch(train) [45][22/22]  lr: 8.6761e-03  eta: 0:01:15  time: 0.6383  data_time: 0.0878  memory: 5449  loss: 0.0065  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0065
# 05/26 10:41:04 - mmengine - INFO - Saving checkpoint at 45 epochs
# 05/26 10:41:06 - mmengine - INFO - Epoch(val) [45][5/5]    acc/top1: 0.5833  acc/top5: 0.9444  acc/mean1: 0.5833  data_time: 0.2454  time: 0.3761
# 05/26 10:41:14 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:41:21 - mmengine - INFO - Epoch(train) [46][20/22]  lr: 4.3348e-03  eta: 0:01:02  time: 0.7457  data_time: 0.1706  memory: 5449  loss: 0.0060  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0060
# 05/26 10:41:22 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:41:22 - mmengine - INFO - Epoch(train) [46][22/22]  lr: 3.9786e-03  eta: 0:01:00  time: 0.6585  data_time: 0.1039  memory: 5449  loss: 0.0062  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0062
# 05/26 10:41:22 - mmengine - INFO - Saving checkpoint at 46 epochs
# 05/26 10:41:24 - mmengine - INFO - Epoch(val) [46][5/5]    acc/top1: 0.5903  acc/top5: 0.9410  acc/mean1: 0.5903  data_time: 0.2557  time: 0.3889
# 05/26 10:41:39 - mmengine - INFO - Epoch(train) [47][20/22]  lr: 1.2395e-03  eta: 0:00:46  time: 0.7391  data_time: 0.1643  memory: 5449  loss: 0.0051  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0051
# 05/26 10:41:40 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:41:40 - mmengine - INFO - Epoch(train) [47][22/22]  lr: 1.0497e-03  eta: 0:00:45  time: 0.6645  data_time: 0.1111  memory: 5449  loss: 0.0053  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0053
# 05/26 10:41:40 - mmengine - INFO - Saving checkpoint at 47 epochs
# 05/26 10:41:42 - mmengine - INFO - Epoch(val) [47][5/5]    acc/top1: 0.5833  acc/top5: 0.9410  acc/mean1: 0.5833  data_time: 0.2490  time: 0.3836
# 05/26 10:41:57 - mmengine - INFO - Epoch(train) [48][20/22]  lr: 1.7921e-05  eta: 0:00:31  time: 0.7500  data_time: 0.1775  memory: 5449  loss: 0.0067  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0067
# 05/26 10:41:58 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:41:58 - mmengine - INFO - Epoch(train) [48][22/22]  lr: 1.9914e-06  eta: 0:00:30  time: 0.6629  data_time: 0.1122  memory: 5449  loss: 0.0080  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0080
# 05/26 10:41:58 - mmengine - INFO - Saving checkpoint at 48 epochs
# 05/26 10:42:01 - mmengine - INFO - Epoch(val) [48][5/5]    acc/top1: 0.5799  acc/top5: 0.9306  acc/mean1: 0.5799  data_time: 0.2576  time: 0.3983
# 05/26 10:42:16 - mmengine - INFO - Epoch(train) [49][20/22]  lr: 7.1717e-04  eta: 0:00:16  time: 0.7467  data_time: 0.1747  memory: 5449  loss: 0.0051  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0051
# 05/26 10:42:16 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:42:16 - mmengine - INFO - Epoch(train) [49][22/22]  lr: 8.7563e-04  eta: 0:00:15  time: 0.6249  data_time: 0.0772  memory: 5449  loss: 0.0052  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0052
# 05/26 10:42:16 - mmengine - INFO - Saving checkpoint at 49 epochs
# 05/26 10:42:20 - mmengine - INFO - Epoch(val) [49][5/5]    acc/top1: 0.5833  acc/top5: 0.9340  acc/mean1: 0.5833  data_time: 0.3886  time: 0.5295
# 05/26 10:42:34 - mmengine - INFO - Epoch(train) [50][20/22]  lr: 3.3103e-03  eta: 0:00:01  time: 0.7151  data_time: 0.1463  memory: 5449  loss: 0.0054  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0054
# 05/26 10:42:35 - mmengine - INFO - Exp name: stgcn_3d_custom_20250526_102732
# 05/26 10:42:35 - mmengine - INFO - Epoch(train) [50][22/22]  lr: 3.6371e-03  eta: 0:00:00  time: 0.6397  data_time: 0.0909  memory: 5449  loss: 0.0059  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0059
# 05/26 10:42:35 - mmengine - INFO - Saving checkpoint at 50 epochs
# 05/26 10:42:37 - mmengine - INFO - Epoch(val) [50][5/5]    acc/top1: 0.5868  acc/top5: 0.9340  acc/mean1: 0.5868  data_time: 0.2581  time: 0.3905

# %%
# !python tools/test.py configs/stgcn_3d_custom.py /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/epoch_50.pth --dump /content/drive/MyDrive/mmaction2_work_dir/stgcn_test_50/results.pkl
# Out:
# 05/26 10:43:39 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1678751027
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.5, V12.5.82
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.11.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1678751027
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 05/26 10:43:39 - mmengine - INFO - Config:
# default_hooks = dict(
#     checkpoint=dict(interval=1, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=False, interval=20, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(
#     interval=2, metrics=[
#         'top_k_accuracy',
#     ])
# launcher = 'none'
# load_from = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/epoch_50.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         graph_cfg=dict(layout='nturgb+d', mode='stgcn_spatial'),
#         in_channels=3,
#         type='STGCN'),
#     cls_head=dict(in_channels=256, num_classes=12, type='GCNHead'),
#     type='RecognizerGCN')
# optim_wrapper = dict(
#     optimizer=dict(
#         lr=0.1, momentum=0.9, nesterov=True, type='SGD', weight_decay=0.0005))
# param_scheduler = [
#     dict(
#         T_max=16,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         eta_min=0,
#         type='CosineAnnealingLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/test_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(
#                 clip_len=100,
#                 num_clips=1,
#                 test_mode=True,
#                 type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = [
#     dict(type='AccMetric'),
#     dict(
#         out_file_path=
#         '/content/drive/MyDrive/mmaction2_work_dir/stgcn_test_50/results.pkl',
#         type='DumpResults'),
# ]
# test_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(
#         clip_len=100, num_clips=1, test_mode=True, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(
#     max_epochs=50, type='EpochBasedTrainLoop', val_begin=1, val_interval=1)
# train_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/train_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(clip_len=100, type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(clip_len=100, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/val_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(
#                 clip_len=100,
#                 num_clips=1,
#                 test_mode=True,
#                 type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = [
#     dict(type='AccMetric'),
# ]
# val_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(
#         clip_len=100, num_clips=1, test_mode=True, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino'
#
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 05/26 10:43:41 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 05/26 10:43:41 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 05/26 10:43:43 - mmengine - INFO - 324 videos remain after valid thresholding
# 05/26 10:43:43 - mmengine - WARNING - The prefix is not set in metric class DumpResults.
# Loads checkpoint by local backend from path: /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/epoch_50.pth
# 05/26 10:43:43 - mmengine - INFO - Load checkpoint from /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/epoch_50.pth
# 05/26 10:43:46 - mmengine - INFO - Results has been saved to /content/drive/MyDrive/mmaction2_work_dir/stgcn_test_50/results.pkl.
# 05/26 10:43:46 - mmengine - INFO - Epoch(test) [6/6]    acc/top1: 0.5247  acc/top5: 0.9198  acc/mean1: 0.5247  data_time: 0.2008  time: 0.4759

# %%
# !pip install pickle

# %%
import pickle
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Caminho para o ficheiro de resultados
results_path = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_test_50/results.pkl'

# Carrega as predições
with open(results_path, 'rb') as f:
    results = pickle.load(f)

# results é normalmente uma lista de arrays de scores por classe
# Para cada amostra, o índice do maior score é a predição do modelo
#y_pred = [np.argmax(r) for r in results]

y_pred = [int(r['pred_label'].item()) if hasattr(r['pred_label'], 'item') else int(r['pred_label']) for r in results]


# Agora precisas dos rótulos verdadeiros (labels do dataset de teste)
# Supondo que tens um ficheiro ann_file com os labels:
import mmcv
ann_file = '/content/test_labels.pkl'

import pickle

with open('/content/test_labels.pkl', 'rb') as f:
    data_infos = pickle.load(f)


# y_true = [info['label'] for info in data_infos]
y_true = [int(r['gt_label'].item()) if hasattr(r['gt_label'], 'item') else int(r['gt_label']) for r in results]


# Calcula a matriz de confusão
cm = confusion_matrix(y_true, y_pred)

class_labels = [
'backhand_volley', 'backhand2hands', 'forehand_openstands', 'kick_service', 'forehand_volley', 'backhand', 'forehand_slice', 'backhand_slice', 'flat_service', 'forehand_flat', 'slice_service', 'smash']

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_labels,
    yticklabels=class_labels
)
plt.xlabel('Classe Predita')
plt.ylabel('Classe Verdadeira')
plt.title('Matriz de Confusão')
plt.show()

# %% [markdown]
# ### TESTES

# %%
print(len(results))         # Deve dar 324
print(len(y_true))          # Deve dar 324
# Out:
# 324
# 324

# %%
unique, counts = np.unique(y_pred, return_counts=True)
print(dict(zip(unique, counts)))
# Out:
# {0: 324}

# %%
# unique, counts = np.unique([info['label'] for info in train_infos], return_counts=True)
# print(dict(zip(unique, counts)))

# %%
import pickle

with open('/content/drive/MyDrive/mmaction2_work_dir/stgcn_test_50/results.pkl', 'rb') as f:
    results = pickle.load(f)

print(type(results))
print(len(results))
# Out:
# <class 'list'>
# 324

# %%
print(type(results[0]))
print(results[0])
# Out:
# <class 'dict'>
# {'num_classes': 12, 'img_shape': None, 'pred_label': tensor([6]), 'gt_label': tensor([2]), 'pred_score': tensor([1.2900e-03, 7.0100e-04, 1.8975e-04, 1.1077e-02, 6.3551e-04, 3.5482e-01,
#         6.2507e-01, 1.0179e-04, 6.8166e-05, 2.8591e-05, 1.8551e-04, 5.8389e-03])}

# %%
import pickle
import numpy as np

# Carrega os dados de treino e teste
with open('/content/train_labels.pkl', 'rb') as f:
    train_infos = pickle.load(f)
with open('/content/test_labels.pkl', 'rb') as f:
    test_infos = pickle.load(f)

# Extrai os labels
y_train = [info['label'] for info in train_infos]
y_test = [info['label'] for info in test_infos]

# Mostra as primeiras labels e verifica a distribuição
print("Primeiras labels treino:", y_train[:10])
print("Primeiras labels teste:", y_test[:10])
print("Labels únicas treino:", np.unique(y_train))
print("Labels únicas teste:", np.unique(y_test))

# %%
import matplotlib.pyplot as plt

# Conta exemplos por classe
def plot_class_distribution(labels, title):
    unique, counts = np.unique(labels, return_counts=True)
    plt.bar(unique, counts)
    plt.xlabel('Classe')
    plt.ylabel('Número de exemplos')
    plt.title(title)
    plt.show()
    print(dict(zip(unique, counts)))

plot_class_distribution(y_train, "Distribuição das classes - Treino")
plot_class_distribution(y_test, "Distribuição das classes - Teste")

# %%
for i, (true, pred) in enumerate(zip(y_true, y_pred)):
    if true != pred:
        print(f"Exemplo {i}: Verdadeiro={true}, Predito={pred}")
# Out:
# Exemplo 0: Verdadeiro=2, Predito=0
# Exemplo 1: Verdadeiro=2, Predito=0
# Exemplo 2: Verdadeiro=2, Predito=0
# Exemplo 3: Verdadeiro=8, Predito=0
# Exemplo 4: Verdadeiro=8, Predito=0
# Exemplo 5: Verdadeiro=8, Predito=0
# Exemplo 6: Verdadeiro=3, Predito=0
# Exemplo 7: Verdadeiro=3, Predito=0
# Exemplo 8: Verdadeiro=3, Predito=0
# Exemplo 9: Verdadeiro=9, Predito=0
# Exemplo 10: Verdadeiro=9, Predito=0
# Exemplo 11: Verdadeiro=9, Predito=0
# Exemplo 12: Verdadeiro=10, Predito=0
# Exemplo 13: Verdadeiro=10, Predito=0
# Exemplo 14: Verdadeiro=10, Predito=0
# Exemplo 15: Verdadeiro=11, Predito=0
# Exemplo 16: Verdadeiro=11, Predito=0
# Exemplo 17: Verdadeiro=11, Predito=0
# Exemplo 21: Verdadeiro=4, Predito=0
# Exemplo 22: Verdadeiro=4, Predito=0
# Exemplo 23: Verdadeiro=4, Predito=0
# Exemplo 24: Verdadeiro=6, Predito=0
# Exemplo 25: Verdadeiro=6, Predito=0
# Exemplo 26: Verdadeiro=6, Predito=0
# Exemplo 27: Verdadeiro=5, Predito=0
# Exemplo 28: Verdadeiro=5, Predito=0
# Exemplo 29: Verdadeiro=5, Predito=0
# Exemplo 30: Verdadeiro=1, Predito=0
# Exemplo 31: Verdadeiro=1, Predito=0
# Exemplo 32: Verdadeiro=1, Predito=0
# Exemplo 33: Verdadeiro=7, Predito=0
# Exemplo 34: Verdadeiro=7, Predito=0
# Exemplo 35: Verdadeiro=7, Predito=0
# Exemplo 36: Verdadeiro=2, Predito=0
# Exemplo 37: Verdadeiro=2, Predito=0
# Exemplo 38: Verdadeiro=2, Predito=0
# Exemplo 39: Verdadeiro=8, Predito=0
# Exemplo 40: Verdadeiro=8, Predito=0
# Exemplo 41: Verdadeiro=8, Predito=0
# Exemplo 42: Verdadeiro=3, Predito=0
# Exemplo 43: Verdadeiro=3, Predito=0
# Exemplo 44: Verdadeiro=3, Predito=0
# Exemplo 45: Verdadeiro=9, Predito=0
# Exemplo 46: Verdadeiro=9, Predito=0
# Exemplo 47: Verdadeiro=9, Predito=0
# Exemplo 48: Verdadeiro=10, Predito=0
# Exemplo 49: Verdadeiro=10, Predito=0
# Exemplo 50: Verdadeiro=10, Predito=0
# Exemplo 51: Verdadeiro=11, Predito=0
# Exemplo 52: Verdadeiro=11, Predito=0
# Exemplo 53: Verdadeiro=11, Predito=0
# Exemplo 57: Verdadeiro=4, Predito=0
# Exemplo 58: Verdadeiro=4, Predito=0
# Exemplo 59: Verdadeiro=4, Predito=0
# Exemplo 60: Verdadeiro=6, Predito=0
# Exemplo 61: Verdadeiro=6, Predito=0
# Exemplo 62: Verdadeiro=6, Predito=0
# Exemplo 63: Verdadeiro=5, Predito=0
# Exemplo 64: Verdadeiro=5, Predito=0
# Exemplo 65: Verdadeiro=5, Predito=0
# Exemplo 66: Verdadeiro=1, Predito=0
# Exemplo 67: Verdadeiro=1, Predito=0
# Exemplo 68: Verdadeiro=1, Predito=0
# Exemplo 69: Verdadeiro=7, Predito=0
# Exemplo 70: Verdadeiro=7, Predito=0
# Exemplo 71: Verdadeiro=7, Predito=0
# Exemplo 72: Verdadeiro=2, Predito=0
# Exemplo 73: Verdadeiro=2, Predito=0
# Exemplo 74: Verdadeiro=2, Predito=0
# Exemplo 75: Verdadeiro=8, Predito=0
# Exemplo 76: Verdadeiro=8, Predito=0
# Exemplo 77: Verdadeiro=8, Predito=0
# Exemplo 78: Verdadeiro=3, Predito=0
# Exemplo 79: Verdadeiro=3, Predito=0
# Exemplo 80: Verdadeiro=3, Predito=0
# Exemplo 81: Verdadeiro=9, Predito=0
# Exemplo 82: Verdadeiro=9, Predito=0
# Exemplo 83: Verdadeiro=9, Predito=0
# Exemplo 84: Verdadeiro=10, Predito=0
# Exemplo 85: Verdadeiro=10, Predito=0
# Exemplo 86: Verdadeiro=10, Predito=0
# Exemplo 87: Verdadeiro=11, Predito=0
# Exemplo 88: Verdadeiro=11, Predito=0
# Exemplo 89: Verdadeiro=11, Predito=0
# Exemplo 93: Verdadeiro=4, Predito=0
# Exemplo 94: Verdadeiro=4, Predito=0
# Exemplo 95: Verdadeiro=4, Predito=0
# Exemplo 96: Verdadeiro=6, Predito=0
# Exemplo 97: Verdadeiro=6, Predito=0
# Exemplo 98: Verdadeiro=6, Predito=0
# Exemplo 99: Verdadeiro=5, Predito=0
# Exemplo 100: Verdadeiro=5, Predito=0
# Exemplo 101: Verdadeiro=5, Predito=0
# Exemplo 102: Verdadeiro=1, Predito=0
# Exemplo 103: Verdadeiro=1, Predito=0
# Exemplo 104: Verdadeiro=1, Predito=0
# Exemplo 105: Verdadeiro=7, Predito=0
# Exemplo 106: Verdadeiro=7, Predito=0
# Exemplo 107: Verdadeiro=7, Predito=0
# Exemplo 108: Verdadeiro=2, Predito=0
# Exemplo 109: Verdadeiro=2, Predito=0
# Exemplo 110: Verdadeiro=2, Predito=0
# Exemplo 111: Verdadeiro=8, Predito=0
# Exemplo 112: Verdadeiro=8, Predito=0
# Exemplo 113: Verdadeiro=8, Predito=0
# Exemplo 114: Verdadeiro=3, Predito=0
# Exemplo 115: Verdadeiro=3, Predito=0
# Exemplo 116: Verdadeiro=3, Predito=0
# Exemplo 117: Verdadeiro=9, Predito=0
# Exemplo 118: Verdadeiro=9, Predito=0
# Exemplo 119: Verdadeiro=9, Predito=0
# Exemplo 120: Verdadeiro=10, Predito=0
# Exemplo 121: Verdadeiro=10, Predito=0
# Exemplo 122: Verdadeiro=10, Predito=0
# Exemplo 123: Verdadeiro=11, Predito=0
# Exemplo 124: Verdadeiro=11, Predito=0
# Exemplo 125: Verdadeiro=11, Predito=0
# Exemplo 129: Verdadeiro=4, Predito=0
# Exemplo 130: Verdadeiro=4, Predito=0
# Exemplo 131: Verdadeiro=4, Predito=0
# Exemplo 132: Verdadeiro=6, Predito=0
# Exemplo 133: Verdadeiro=6, Predito=0
# Exemplo 134: Verdadeiro=6, Predito=0
# Exemplo 135: Verdadeiro=5, Predito=0
# Exemplo 136: Verdadeiro=5, Predito=0
# Exemplo 137: Verdadeiro=5, Predito=0
# Exemplo 138: Verdadeiro=1, Predito=0
# Exemplo 139: Verdadeiro=1, Predito=0
# Exemplo 140: Verdadeiro=1, Predito=0
# Exemplo 141: Verdadeiro=7, Predito=0
# Exemplo 142: Verdadeiro=7, Predito=0
# Exemplo 143: Verdadeiro=7, Predito=0
# Exemplo 144: Verdadeiro=2, Predito=0
# Exemplo 145: Verdadeiro=2, Predito=0
# Exemplo 146: Verdadeiro=2, Predito=0
# Exemplo 147: Verdadeiro=8, Predito=0
# Exemplo 148: Verdadeiro=8, Predito=0
# Exemplo 149: Verdadeiro=8, Predito=0
# Exemplo 150: Verdadeiro=3, Predito=0
# Exemplo 151: Verdadeiro=3, Predito=0
# Exemplo 152: Verdadeiro=3, Predito=0
# Exemplo 153: Verdadeiro=9, Predito=0
# Exemplo 154: Verdadeiro=9, Predito=0
# Exemplo 155: Verdadeiro=9, Predito=0
# Exemplo 156: Verdadeiro=10, Predito=0
# Exemplo 157: Verdadeiro=10, Predito=0
# Exemplo 158: Verdadeiro=10, Predito=0
# Exemplo 159: Verdadeiro=11, Predito=0
# Exemplo 160: Verdadeiro=11, Predito=0
# Exemplo 161: Verdadeiro=11, Predito=0
# Exemplo 165: Verdadeiro=4, Predito=0
# Exemplo 166: Verdadeiro=4, Predito=0
# Exemplo 167: Verdadeiro=4, Predito=0
# Exemplo 168: Verdadeiro=6, Predito=0
# Exemplo 169: Verdadeiro=6, Predito=0
# Exemplo 170: Verdadeiro=6, Predito=0
# Exemplo 171: Verdadeiro=5, Predito=0
# Exemplo 172: Verdadeiro=5, Predito=0
# Exemplo 173: Verdadeiro=5, Predito=0
# Exemplo 174: Verdadeiro=1, Predito=0
# Exemplo 175: Verdadeiro=1, Predito=0
# Exemplo 176: Verdadeiro=1, Predito=0
# Exemplo 177: Verdadeiro=7, Predito=0
# Exemplo 178: Verdadeiro=7, Predito=0
# Exemplo 179: Verdadeiro=7, Predito=0
# Exemplo 180: Verdadeiro=2, Predito=0
# Exemplo 181: Verdadeiro=2, Predito=0
# Exemplo 182: Verdadeiro=2, Predito=0
# Exemplo 183: Verdadeiro=8, Predito=0
# Exemplo 184: Verdadeiro=8, Predito=0
# Exemplo 185: Verdadeiro=8, Predito=0
# Exemplo 186: Verdadeiro=3, Predito=0
# Exemplo 187: Verdadeiro=3, Predito=0
# Exemplo 188: Verdadeiro=3, Predito=0
# Exemplo 189: Verdadeiro=9, Predito=0
# Exemplo 190: Verdadeiro=9, Predito=0
# Exemplo 191: Verdadeiro=9, Predito=0
# Exemplo 192: Verdadeiro=10, Predito=0
# Exemplo 193: Verdadeiro=10, Predito=0
# Exemplo 194: Verdadeiro=10, Predito=0
# Exemplo 195: Verdadeiro=11, Predito=0
# Exemplo 196: Verdadeiro=11, Predito=0
# Exemplo 197: Verdadeiro=11, Predito=0
# Exemplo 201: Verdadeiro=4, Predito=0
# Exemplo 202: Verdadeiro=4, Predito=0
# Exemplo 203: Verdadeiro=4, Predito=0
# Exemplo 204: Verdadeiro=6, Predito=0
# Exemplo 205: Verdadeiro=6, Predito=0
# Exemplo 206: Verdadeiro=6, Predito=0
# Exemplo 207: Verdadeiro=5, Predito=0
# Exemplo 208: Verdadeiro=5, Predito=0
# Exemplo 209: Verdadeiro=5, Predito=0
# Exemplo 210: Verdadeiro=1, Predito=0
# Exemplo 211: Verdadeiro=1, Predito=0
# Exemplo 212: Verdadeiro=1, Predito=0
# Exemplo 213: Verdadeiro=7, Predito=0
# Exemplo 214: Verdadeiro=7, Predito=0
# Exemplo 215: Verdadeiro=7, Predito=0
# Exemplo 216: Verdadeiro=2, Predito=0
# Exemplo 217: Verdadeiro=2, Predito=0
# Exemplo 218: Verdadeiro=2, Predito=0
# Exemplo 219: Verdadeiro=8, Predito=0
# Exemplo 220: Verdadeiro=8, Predito=0
# Exemplo 221: Verdadeiro=8, Predito=0
# Exemplo 222: Verdadeiro=3, Predito=0
# Exemplo 223: Verdadeiro=3, Predito=0
# Exemplo 224: Verdadeiro=3, Predito=0
# Exemplo 225: Verdadeiro=9, Predito=0
# Exemplo 226: Verdadeiro=9, Predito=0
# Exemplo 227: Verdadeiro=9, Predito=0
# Exemplo 228: Verdadeiro=10, Predito=0
# Exemplo 229: Verdadeiro=10, Predito=0
# Exemplo 230: Verdadeiro=10, Predito=0
# Exemplo 231: Verdadeiro=11, Predito=0
# Exemplo 232: Verdadeiro=11, Predito=0
# Exemplo 233: Verdadeiro=11, Predito=0
# Exemplo 237: Verdadeiro=4, Predito=0
# Exemplo 238: Verdadeiro=4, Predito=0
# Exemplo 239: Verdadeiro=4, Predito=0
# Exemplo 240: Verdadeiro=6, Predito=0
# Exemplo 241: Verdadeiro=6, Predito=0
# Exemplo 242: Verdadeiro=6, Predito=0
# Exemplo 243: Verdadeiro=5, Predito=0
# Exemplo 244: Verdadeiro=5, Predito=0
# Exemplo 245: Verdadeiro=5, Predito=0
# Exemplo 246: Verdadeiro=1, Predito=0
# Exemplo 247: Verdadeiro=1, Predito=0
# Exemplo 248: Verdadeiro=1, Predito=0
# Exemplo 249: Verdadeiro=7, Predito=0
# Exemplo 250: Verdadeiro=7, Predito=0
# Exemplo 251: Verdadeiro=7, Predito=0
# Exemplo 252: Verdadeiro=2, Predito=0
# Exemplo 253: Verdadeiro=2, Predito=0
# Exemplo 254: Verdadeiro=2, Predito=0
# Exemplo 255: Verdadeiro=8, Predito=0
# Exemplo 256: Verdadeiro=8, Predito=0
# Exemplo 257: Verdadeiro=8, Predito=0
# Exemplo 258: Verdadeiro=3, Predito=0
# Exemplo 259: Verdadeiro=3, Predito=0
# Exemplo 260: Verdadeiro=3, Predito=0
# Exemplo 261: Verdadeiro=9, Predito=0
# Exemplo 262: Verdadeiro=9, Predito=0
# Exemplo 263: Verdadeiro=9, Predito=0
# Exemplo 264: Verdadeiro=10, Predito=0
# Exemplo 265: Verdadeiro=10, Predito=0
# Exemplo 266: Verdadeiro=10, Predito=0
# Exemplo 267: Verdadeiro=11, Predito=0
# Exemplo 268: Verdadeiro=11, Predito=0
# Exemplo 269: Verdadeiro=11, Predito=0
# Exemplo 273: Verdadeiro=4, Predito=0
# Exemplo 274: Verdadeiro=4, Predito=0
# Exemplo 275: Verdadeiro=4, Predito=0
# Exemplo 276: Verdadeiro=6, Predito=0
# Exemplo 277: Verdadeiro=6, Predito=0
# Exemplo 278: Verdadeiro=6, Predito=0
# Exemplo 279: Verdadeiro=5, Predito=0
# Exemplo 280: Verdadeiro=5, Predito=0
# Exemplo 281: Verdadeiro=5, Predito=0
# Exemplo 282: Verdadeiro=1, Predito=0
# Exemplo 283: Verdadeiro=1, Predito=0
# Exemplo 284: Verdadeiro=1, Predito=0
# Exemplo 285: Verdadeiro=7, Predito=0
# Exemplo 286: Verdadeiro=7, Predito=0
# Exemplo 287: Verdadeiro=7, Predito=0
# Exemplo 288: Verdadeiro=2, Predito=0
# Exemplo 289: Verdadeiro=2, Predito=0
# Exemplo 290: Verdadeiro=2, Predito=0
# Exemplo 291: Verdadeiro=8, Predito=0
# Exemplo 292: Verdadeiro=8, Predito=0
# Exemplo 293: Verdadeiro=8, Predito=0
# Exemplo 294: Verdadeiro=3, Predito=0
# Exemplo 295: Verdadeiro=3, Predito=0
# Exemplo 296: Verdadeiro=3, Predito=0
# Exemplo 297: Verdadeiro=9, Predito=0
# Exemplo 298: Verdadeiro=9, Predito=0
# Exemplo 299: Verdadeiro=9, Predito=0
# Exemplo 300: Verdadeiro=10, Predito=0
# Exemplo 301: Verdadeiro=10, Predito=0
# Exemplo 302: Verdadeiro=10, Predito=0
# Exemplo 303: Verdadeiro=11, Predito=0
# Exemplo 304: Verdadeiro=11, Predito=0
# Exemplo 305: Verdadeiro=11, Predito=0
# Exemplo 309: Verdadeiro=4, Predito=0
# Exemplo 310: Verdadeiro=4, Predito=0
# Exemplo 311: Verdadeiro=4, Predito=0
# Exemplo 312: Verdadeiro=6, Predito=0
# Exemplo 313: Verdadeiro=6, Predito=0
# Exemplo 314: Verdadeiro=6, Predito=0
# Exemplo 315: Verdadeiro=5, Predito=0
# Exemplo 316: Verdadeiro=5, Predito=0
# Exemplo 317: Verdadeiro=5, Predito=0
# Exemplo 318: Verdadeiro=1, Predito=0
# Exemplo 319: Verdadeiro=1, Predito=0
# Exemplo 320: Verdadeiro=1, Predito=0
# Exemplo 321: Verdadeiro=7, Predito=0
# Exemplo 322: Verdadeiro=7, Predito=0
# Exemplo 323: Verdadeiro=7, Predito=0
