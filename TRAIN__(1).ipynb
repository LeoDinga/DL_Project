# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoDinga/DL_Project/blob/main/TRAIN__(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y torch torchvision torchao torchaudio torchtext torchdata
# !pip uninstall -y mmcv mmcv-full mmengine mmaction2 transformers
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchao 0.10.0
# Uninstalling torchao-0.10.0:
#   Successfully uninstalled torchao-0.10.0
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# WARNING: Skipping torchtext as it is not installed.
# Found existing installation: torchdata 0.11.0
# Uninstalling torchdata-0.11.0:
#   Successfully uninstalled torchdata-0.11.0
# WARNING: Skipping mmcv as it is not installed.
# WARNING: Skipping mmcv-full as it is not installed.
# WARNING: Skipping mmengine as it is not installed.
# WARNING: Skipping mmaction2 as it is not installed.
# Found existing installation: transformers 4.51.3
# Uninstalling transformers-4.51.3:
#   Successfully uninstalled transformers-4.51.3

# %%
# !pip install protobuf==3.20.3
# !pip install mediapipe
# Out:
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.17.1 requires protobuf<6.0.0,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed protobuf-3.20.3
# Collecting mediapipe
#   Downloading mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (3.10.0)
# Collecting numpy<2 (from mediapipe)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.11.0.86)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.7-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.5.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)
# Downloading mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 19.6 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 109.3 MB/s eta 0:00:00
# Downloading protobuf-4.25.7-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 22.9 MB/s eta 0:00:00
# Downloading sounddevice-0.5.2-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, numpy, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.19 requires torch<2.7,>=1.10, which is not installed.
# fastai 2.7.19 requires torchvision>=0.11, which is not installed.
# torchtune 0.6.1 requires torchdata==0.11.0, which is not installed.
# accelerate 1.6.0 requires torch>=2.0.0, which is not installed.
# peft 0.15.2 requires torch>=1.13.0, which is not installed.
# peft 0.15.2 requires transformers, which is not installed.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.7 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.7 which is incompatible.
# Successfully installed mediapipe-0.10.21 numpy-1.26.4 protobuf-4.25.7 sounddevice-0.5.2

# %%
# !pip install -U openmim
# !mim install mmengine
# !mim install 'mmcv==2.1.0'
# !pip install torch==2.0.1 torchvision==0.15.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers==4.35.2
# !pip install mmaction2
# Out:
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.11/dist-packages (from openmim) (8.2.0)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from openmim) (2.2.2)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.11/dist-packages (from openmim) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from openmim) (13.9.4)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (3.8)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (4.67.1)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (2025.4.26)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.17.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 10.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (24.2)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 6.2 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.9 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 23.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 4.9 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.2-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 27.9 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 6.0 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 14.6 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 25.5 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.4 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 8.7 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 53.2 MB/s eta 0:00:00
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 52.0 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 9.9 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112371 sha256=8092d61a2435d9ea1e19d8b2091f0b285c71d4d42826f690942a28c58b0cd66c
#   Stored in directory: /root/.cache/pip/wheels/42/79/aa/3671e313c27de35211d345d7a9d8ccb7dde515cf05edba75df
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535315 sha256=08194d56ff662ad6e9aa6ba4d886ba0ce2557f7001f8c8189601f7defbbe60ee
#   Stored in directory: /root/.cache/pip/wheels/2b/9a/95/60f111d2a488c5f7f7ed2a96ce407ea57ec7393ddfdec8c956
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp311-cp311-linux_x86_64.whl size=31660 sha256=e44da354f1b6e985483b863192effd0622d431bfb1c9a2a913e7b6f4edd44993
#   Stored in directory: /root/.cache/pip/wheels/23/94/7a/8cb7d14597e6395ce969933f01aed9ea8fa5f5b4d4c8a61e99
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: pytz, crcmod, urllib3, tqdm, setuptools, pycryptodome, ordered-set, jmespath, filelock, colorama, rich, requests, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.18.0
#     Uninstalling filelock-3.18.0:
#       Successfully uninstalled filelock-3.18.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.7.19 requires torch<2.7,>=1.10, which is not installed.
# fastai 2.7.19 requires torchvision>=0.11, which is not installed.
# torchtune 0.6.1 requires torchdata==0.11.0, which is not installed.
# accelerate 1.6.0 requires torch>=2.0.0, which is not installed.
# sentence-transformers 4.1.0 requires torch>=1.11.0, which is not installed.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, which is not installed.
# timm 1.0.15 requires torch, which is not installed.
# timm 1.0.15 requires torchvision, which is not installed.
# peft 0.15.2 requires torch>=1.13.0, which is not installed.
# peft 0.15.2 requires transformers, which is not installed.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.2 which is incompatible.
# yfinance 0.2.61 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# pymc 5.22.0 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# pytensor 2.30.3 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# sphinx 8.2.3 requires requests>=2.30.0, but you have requests 2.28.2 which is incompatible.
# dataproc-spark-connect 0.7.3 requires tqdm>=4.67, but you have tqdm 4.65.2 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 colorama-0.4.6 crcmod-1.7 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.2 ordered-set-4.1.0 oss2-2.17.0 pycryptodome-3.23.0 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2 urllib3-1.26.20
# Traceback (most recent call last):
#   File "/usr/local/bin/mim", line 8, in <module>
#     sys.exit(cli())
#              ^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1442, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1363, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1830, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1226, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 794, in invoke
#     return callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 72, in cli
#     exit_code = install(list(args), index_url=index_url, is_yes=is_yes)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 128, in install
#     install_args += ['-f', get_mmcv_full_find_link(mmcv_base_url)]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 165, in get_mmcv_full_find_link
#     torch_v, cuda_v = get_torch_cuda_version()
#                       ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/utils/utils.py", line 340, in get_torch_cuda_version
#     raise err
#   File "/usr/local/lib/python3.11/dist-packages/mim/utils/utils.py", line 338, in get_torch_cuda_version
#     import torch
# ModuleNotFoundError: No module named 'torch'
# Traceback (most recent call last):
#   File "/usr/local/bin/mim", line 8, in <module>
#     sys.exit(cli())
#              ^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1442, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1363, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1830, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 1226, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/click/core.py", line 794, in invoke
#     return callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 72, in cli
#     exit_code = install(list(args), index_url=index_url, is_yes=is_yes)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 128, in install
#     install_args += ['-f', get_mmcv_full_find_link(mmcv_base_url)]
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/commands/install.py", line 165, in get_mmcv_full_find_link
#     torch_v, cuda_v = get_torch_cuda_version()
#                       ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/mim/utils/utils.py", line 340, in get_torch_cuda_version
#     raise err
#   File "/usr/local/lib/python3.11/dist-packages/mim/utils/utils.py", line 338, in get_torch_cuda_version
#     import torch
# ModuleNotFoundError: No module named 'torch'
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.0.1
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.0.1%2Bcu118-cp311-cp311-linux_x86_64.whl (2267.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 736.5 kB/s eta 0:00:00
# Collecting torchvision==0.15.2
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.15.2%2Bcu118-cp311-cp311-linux_x86_64.whl (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 37.7 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.1.6)
# Collecting triton==2.0.0 (from torch==2.0.1)
#   Downloading https://download.pytorch.org/whl/triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (2.28.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision==0.15.2) (11.2.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (3.31.6)
# Collecting lit (from triton==2.0.0->torch==2.0.1)
#   Downloading https://download.pytorch.org/whl/lit-15.0.7.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchvision==0.15.2) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1) (1.3.0)
# Building wheels for collected packages: lit
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-15.0.7-py3-none-any.whl size=90004 sha256=28bd25444b5a07814daac26ecf200de0a17120f337d4d06c93ebbc334fac2701
#   Stored in directory: /root/.cache/pip/wheels/fc/5d/45/34fe9945d5e45e261134e72284395be36c2d4828af38e2b0fe
# Successfully built lit
# Installing collected packages: lit, triton, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, which is not installed.
# peft 0.15.2 requires transformers, which is not installed.
# Successfully installed lit-15.0.7 torch-2.0.1+cu118 torchvision-0.15.2+cu118 triton-2.0.0
# Collecting transformers==4.35.2
#   Downloading transformers-4.35.2-py3-none-any.whl.metadata (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (0.31.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (2.28.2)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.35.2)
#   Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.35.2) (4.65.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2) (2025.3.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.35.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.35.2) (3.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.35.2) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.35.2) (2025.4.26)
# Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 94.9 MB/s eta 0:00:00
# Downloading tokenizers-0.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 111.1 MB/s eta 0:00:00
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtune 0.6.1 requires torchdata==0.11.0, which is not installed.
# sentence-transformers 4.1.0 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.35.2 which is incompatible.
# Successfully installed tokenizers-0.15.2 transformers-4.35.2
# Collecting mmaction2
#   Downloading mmaction2-1.2.0-py2.py3-none-any.whl.metadata (29 kB)
# Collecting decord>=0.4.1 (from mmaction2)
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl.metadata (422 bytes)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from mmaction2) (0.8.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmaction2) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmaction2) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mmaction2) (4.11.0.86)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmaction2) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmaction2) (1.15.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from mmaction2) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.3->mmaction2) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.3->mmaction2) (15.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmaction2) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->mmaction2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.3->mmaction2) (1.3.0)
# Downloading mmaction2-1.2.0-py2.py3-none-any.whl (882 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 20.0 MB/s eta 0:00:00
# Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 118.6 MB/s eta 0:00:00
# Installing collected packages: decord, mmaction2
# Successfully installed decord-0.6.0 mmaction2-1.2.0

# %%
import numpy as np

# %%
# verifica se tens o GPU ativado. Tem de dizer TRUE
import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"CUDA Version used by PyTorch: {torch.version.cuda}")
# Out:
# PyTorch Version: 2.0.1+cu118
# CUDA Available: True
# CUDA Version used by PyTorch: 11.8

# %%
from google.colab import files
import numpy as np
# uploaded = files.upload()
# data = np.load("/content/all_keypoints.npz", allow_pickle=True)
# print(data.files)  # Para ver o que está lá dentro

# Caminho para o ficheiro de keypoints
keypoints_path = "all_keypoints.npz"

# Carregar os keypoints do ficheiro npz e reconstruir o dicionário
data = np.load(keypoints_path)
all_keypoints = {}
for key in data.files:
    action, video_file = key.split("__", 1)
    if action not in all_keypoints:
        all_keypoints[action] = {}
    all_keypoints[action][video_file] = data[key]

# %% [markdown]
# # tens de tranferir a pasta all_keypoints.npz

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load keypoints
keypoints_path = "/content/all_keypoints.npz"
data = np.load(keypoints_path)

# Rebuild dictionary
all_keypoints = {}
for key in data.files:
    action, video_file = key.split("__", 1)
    if action not in all_keypoints:
        all_keypoints[action] = {}
    all_keypoints[action][video_file] = data[key]

# Select one example
first_action = list(all_keypoints.keys())[0]
first_video = list(all_keypoints[first_action].keys())[0]
frame_idx = 0

points = all_keypoints[first_action][first_video][frame_idx]  # shape: (num_joints, 3)

# === Define anatomical connections and colors ===
anatomical_connections = {
    'head': [
        (0, 1), (1, 2), (2, 3),
        (0, 4), (4, 5), (5, 6),
        (3, 7), (6, 8),
        (0, 9), (9, 10)
    ],
    'left_arm': [(11, 13), (13, 15), (15, 17), (15, 19), (15, 21)],
    'right_arm': [(12, 14), (14, 16), (16, 18), (16, 20), (16, 22)],
    'torso': [(11, 12), (23, 24), (11, 23), (12, 24)],
    'left_leg': [(23, 25), (25, 27), (27, 29), (29, 31)],
    'right_leg': [(24, 26), (26, 28), (28, 30), (30, 32)],
}

colors = {
    'head': 'gray',
    'left_arm': 'red',
    'right_arm': 'blue',
    'torso': 'orange',
    'left_leg': 'green',
    'right_leg': 'purple',
}

# === Plotting ===
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(points[:, 0], points[:, 1], points[:, 2], c='black', s=20)

for part, connections in anatomical_connections.items():
    for i, j in connections:
        if i < len(points) and j < len(points):  # ensure valid index
            ax.plot(
                [points[i, 0], points[j, 0]],
                [points[i, 1], points[j, 1]],
                [points[i, 2], points[j, 2]],
                color=colors[part], linewidth=2
            )

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title(f"3D Skeleton - Frame {frame_idx} - {first_video}")
ax.view_init(elev=20, azim=-70)
plt.tight_layout()
plt.show()

# %%
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %%
pip install np
# Out:
# Collecting np
#   Downloading np-1.0.2.tar.gz (7.4 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: np
#   Building wheel for np (setup.py) ... done
#   Created wheel for np: filename=np-1.0.2-py3-none-any.whl size=13676 sha256=073caea84ad4f87abf8aff5fa4fca457d5298954bd64fab6d8798f553295c30e
#   Stored in directory: /root/.cache/pip/wheels/19/20/42/6ee214e617f78123903f603524d662ac6fa14154c3027fd992
# Successfully built np
# Installing collected packages: np
# Successfully installed np-1.0.2

# %%
from collections import defaultdict
import numpy as np
#from sklearn.model_selection import train_test_split
import random


def extract_player_id(filename):
    # Example: 'player1_video1.npy' → 'player1'
    return filename.split('_')[0]

# Organize videos by player
player_video_map = defaultdict(list)
for action, videos in all_keypoints.items():
    for video_file in videos:
        player_id = extract_player_id(video_file)
        player_video_map[player_id].append((action, video_file))

# Split player IDs
players = list(player_video_map.keys())
random.shuffle(players)

train_end = int(len(players) * 0.7)
val_end = int(len(players) * 0.85)

train_players = players[:train_end]
val_players = players[train_end:val_end]
test_players = players[val_end:]

def collect_by_players(player_ids):
    dataset = []
    for pid in player_ids:
        for action, filename in player_video_map[pid]:
            keypoints = all_keypoints[action][filename]
            dataset.append((keypoints, action))
    return dataset

train_set = collect_by_players(train_players)
val_set = collect_by_players(val_players)
test_set = collect_by_players(test_players)

print(f"Train: {len(train_set)}, Val: {len(val_set)}, Test: {len(test_set)}")
# Out:
# Train: 1368, Val: 288, Test: 324

# %%
# N = number of samples, # C = 3 (x, y, z), # T = 120 (our fixed number of frames), # V = 33 (MediaPipe joints), # M = number of people
#Prepare data to STGCN (Store keypoints in a numpy array with the shape [N, C, T, V, M])
#Save the labels as integers in a separate pkl file.

import pickle

ntu_joints_in_mediapipe = [
    0,   # Nose
    11,  # Left Shoulder
    12,  # Right Shoulder
    13,  # Left Elbow
    14,  # Right Elbow
    15,  # Left Wrist
    16,  # Right Wrist
    23,  # Left Hip
    24,  # Right Hip
    25,  # Left Knee
    26,  # Right Knee
    27,  # Left Ankle
    28,  # Right Ankle
    5,   # Right Eye
    2,   # Left Eye
    7,   # Left Ear
    8,   # Right Ear
    17,  # Left Pinky
    18,  # Right Pinky
    19,  # Left Index
    20,  # Right Index
    21,  # Left Thumb
    22,  # Right Thumb
    29,  # Left Foot Index
    30   # Right Foot Index
]

def filter_to_ntu_joints(keypoints): #para usar layout NTU RGB+D
    # keypoints: (T, 33, C)
    return keypoints[:, ntu_joints_in_mediapipe, :]

def prepare_stgcn_data(dataset, label_map):
    data_list = []
    for i, (keypoints, action_name) in enumerate(dataset):
        keypoints = np.array(keypoints)  # (T, 33, C)
        keypoints = filter_to_ntu_joints(keypoints)  # (T, 25, C)
        num_frames, num_joints, channels = keypoints.shape
        # Se só tem 1 pessoa por sample:
        keypoints = keypoints[np.newaxis, ...]  # (M=1, T, V, C)
        # Se tiver keypoint_score, pode adicionar aqui
        sample = {
            'frame_dir': f'sample_{i}',
            'label': label_map[action_name],
            'img_shape': None,           # ou (H, W) se souber
            'total_frames': num_frames,
            'keypoint': keypoints,       # (M, T, V, C)
            # 'keypoint_score': np.ones_like(keypoints[..., 0]),  # opcional
        }
        data_list.append(sample)
    return data_list

# Crie o label_map como já fazia
label_map = {name: idx for idx, name in enumerate(sorted(set(a for _, a in train_set + val_set + test_set)))}

# Prepare os dados no formato correto
train_data = prepare_stgcn_data(train_set, label_map)
val_data = prepare_stgcn_data(val_set, label_map)
test_data = prepare_stgcn_data(test_set, label_map)

with open('/content/train_labels.pkl', 'wb') as f:
    pickle.dump(train_data, f)

with open('/content/val_labels.pkl', 'wb') as f:
    pickle.dump(val_data, f)


with open('/content/test_labels.pkl', 'wb') as f:
    pickle.dump(test_data, f)

print("Data saved successfully!")
# Out:
# Data saved successfully!

# %%
# Exemplo para MMAction2
# !git clone https://github.com/open-mmlab/mmaction2.git mmaction2 #alterei
# %cd mmaction2
# !pip install -e .
# Out:
# Cloning into 'mmaction2'...
# remote: Enumerating objects: 22864, done.
# remote: Total 22864 (delta 0), reused 0 (delta 0), pack-reused 22864 (from 1)
# Receiving objects: 100% (22864/22864), 69.65 MiB | 16.18 MiB/s, done.
# Resolving deltas: 100% (16122/16122), done.
# /content/mmaction2
# Obtaining file:///content/mmaction2
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: decord>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (0.6.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (0.8.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (4.11.0.86)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (11.2.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (1.15.3)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.11/dist-packages (from mmaction2==1.2.0) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.14.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.3->mmaction2==1.2.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.3->mmaction2==1.2.0) (3.31.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch>=1.3->mmaction2==1.2.0) (15.0.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmaction2==1.2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmaction2==1.2.0) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.3->mmaction2==1.2.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch>=1.3->mmaction2==1.2.0) (1.3.0)
# Installing collected packages: mmaction2
#   Attempting uninstall: mmaction2
#     Found existing installation: mmaction2 1.2.0
#     Uninstalling mmaction2-1.2.0:
#       Successfully uninstalled mmaction2-1.2.0
#   Running setup.py develop for mmaction2
# Successfully installed mmaction2-1.2.0

# %%
# !mim install 'mmcv==2.1.0'
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/index.html
# Collecting mmcv==2.1.0
#   Downloading https://download.openmmlab.com/mmcv/dist/cu118/torch2.0.0/mmcv-2.1.0-cp311-cp311-manylinux1_x86_64.whl (98.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 MB 8.2 MB/s eta 0:00:00
# Collecting addict (from mmcv==2.1.0)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Collecting mmengine>=0.3.0 (from mmcv==2.1.0)
#   Downloading mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (11.2.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (6.0.2)
# Collecting yapf (from mmcv==2.1.0)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmcv==2.1.0) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.10.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv==2.1.0) (3.1.0)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv==2.1.0) (4.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv==2.1.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv==2.1.0) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv==2.1.0) (1.17.0)
# Downloading mmengine-0.10.7-py3-none-any.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 16.6 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 24.1 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, mmengine, mmcv
# Successfully installed addict-2.4.0 mmcv-2.1.0 mmengine-0.10.7 yapf-0.43.0

# %%
import torch
import mmcv
import mmengine
import mmaction2

# %%
import sys
sys.path.append('mmaction2')

# %%
### original diana

config_code = """

_base_ = ['/content/mmaction2/configs/_base_/default_runtime.py']

# Modelo ST-GCN com keypoints 3D
model = dict(
    type='RecognizerGCN',
    backbone=dict(
        type='STGCN',
        graph_cfg=dict(
            layout='nturgb+d',  # usa o layout NTU para dados 3D
            mode='spatial'),
        in_channels=3  # keypoints 3D: x, y, z
    ),
    cls_head=dict(
        type='GCNHead',
        in_channels=256,
        num_classes=12,  # <- alterado para o teu número de classes
        loss_cls=dict(type='CrossEntropyLoss'),
    ),
)

train_pipeline = [
    dict(type='PreNormalize3D'),
    dict(type='GenSkeFeat', dataset='nturgb+d', feats=['j']),
    dict(type='UniformSampleFrames', clip_len=100),
    dict(type='PoseDecode'),
    dict(type='FormatGCNInput', num_person=1),
    dict(type='PackActionInputs')
]
val_pipeline = [
    dict(type='PreNormalize3D'),
    dict(type='GenSkeFeat', dataset='nturgb+d', feats=['j']),
    dict(
        type='UniformSampleFrames', clip_len=100, num_clips=1, test_mode=True),
    dict(type='PoseDecode'),
    dict(type='FormatGCNInput', num_person=1),
    dict(type='PackActionInputs')
]
test_pipeline = [
    dict(type='PreNormalize3D'),
    dict(type='GenSkeFeat', dataset='nturgb+d', feats=['j']),
    dict(
        type='UniformSampleFrames', clip_len=100, num_clips=1,
        test_mode=True),
    dict(type='PoseDecode'),
    dict(type='FormatGCNInput', num_person=1),
    dict(type='PackActionInputs')
]

train_dataloader = dict(
    batch_size=64,  # ALTERADO: era 16, agora 4 para teste rápido
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=True),
    dataset=dict(
        type='PoseDataset',
        ann_file='/content/train_labels.pkl',  # ALTERADO: caminho absoluto, antes era 'train_labels.pkl'
        pipeline=train_pipeline
    )
)
val_dataloader = dict(
    batch_size=64,  # ALTERADO: era 16, agora 4 para teste rápido
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=False),
    dataset=dict(
        type='PoseDataset',
        ann_file='/content/val_labels.pkl',  # ALTERADO: caminho absoluto, antes era 'val_labels.pkl'
        pipeline=val_pipeline
    )
)
test_dataloader = dict(
    batch_size=64,  # ALTERADO: era 16, agora 4 para teste rápido
    num_workers=2,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=False),
    dataset=dict(
        type='PoseDataset',
        ann_file='/content/test_labels.pkl',  # ALTERADO: caminho absoluto, antes era 'test_labels.pkl'
        pipeline=test_pipeline
    )
)

# val_evaluator = dict(type='AccMetric')
# test_evaluator = val_evaluator

val_evaluator = dict(
    type='AccMetric',
    metric_list=('top_k_accuracy', 'mean_class_accuracy')
)
test_evaluator = val_evaluator

# Wrapper do otimizador
optim_wrapper = dict(
    type='OptimWrapper',
    optimizer=dict(type='Adam', lr=0.0005, weight_decay=0.0001)
)


# Treino
train_cfg = dict(
    type='EpochBasedTrainLoop', max_epochs=50, val_interval=2  # ALTERADO: max_epochs era 80 (ou valor maior), agora 10; val_interval era 5, agora 2
)


# Avaliação
val_cfg = dict(type='ValLoop')
test_cfg = dict(type='TestLoop')


# evaluation = dict(
#     interval=5,
#     metrics=['top_k_accuracy', 'mean_class_accuracy']
# )

# evaluation = dict(
#     interval=2,
#     metrics=['top_k_accuracy', 'mean_class_accuracy'],
#     topk=(1, 3, 5)
# )



evaluation = dict(
    interval=2,
    metrics=['top_k_accuracy', 'mean_class_accuracy'],
    metric_options=dict(top_k_accuracy=dict(topk=(1, 3, 5)))
)




# Salvar checkpoints, logs, etc.
work_dir = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino'   # ALTERADO: era './work_dirs/stgcn_3d_custom_test'

load_from = 'https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth'







"""



# Gravar para o ficheiro na pasta configs/stgcn/
with open('/content/mmaction2/configs/stgcn_3d_custom.py', 'w') as f:
    f.write(config_code)

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')


save_path = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino'
os.makedirs(save_path, exist_ok=True)




# os.makedirs('/content/drive/MyDrive/mmaction2_work_dir/tensorboard_logs', exist_ok=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python /content/mmaction2/tools/train.py /content/mmaction2/configs/stgcn_3d_custom.py
# Out:
# 05/25 11:37:52 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1810194939
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.5, V12.5.82
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.11.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1810194939
#     diff_rank_seed: False
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 05/25 11:37:52 - mmengine - INFO - Config:
# default_hooks = dict(
#     checkpoint=dict(interval=1, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=False, interval=20, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(
#     interval=2,
#     metric_options=dict(top_k_accuracy=dict(topk=(
#         1,
#         3,
#         5,
#     ))),
#     metrics=[
#         'top_k_accuracy',
#         'mean_class_accuracy',
#     ])
# launcher = 'none'
# load_from = 'https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         graph_cfg=dict(layout='nturgb+d', mode='spatial'),
#         in_channels=3,
#         type='STGCN'),
#     cls_head=dict(
#         in_channels=256,
#         loss_cls=dict(type='CrossEntropyLoss'),
#         num_classes=12,
#         type='GCNHead'),
#     type='RecognizerGCN')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0005, type='Adam', weight_decay=0.0001),
#     type='OptimWrapper')
# randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/test_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(
#                 clip_len=100,
#                 num_clips=1,
#                 test_mode=True,
#                 type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     metric_list=(
#         'top_k_accuracy',
#         'mean_class_accuracy',
#     ), type='AccMetric')
# test_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(
#         clip_len=100, num_clips=1, test_mode=True, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(max_epochs=50, type='EpochBasedTrainLoop', val_interval=2)
# train_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/train_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(clip_len=100, type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(clip_len=100, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/val_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(
#                 clip_len=100,
#                 num_clips=1,
#                 test_mode=True,
#                 type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     metric_list=(
#         'top_k_accuracy',
#         'mean_class_accuracy',
#     ), type='AccMetric')
# val_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(
#         clip_len=100, num_clips=1, test_mode=True, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino'
#
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 05/25 11:37:55 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 05/25 11:37:55 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 05/25 11:37:56 - mmengine - INFO - 1368 videos remain after valid thresholding
# 05/25 11:37:57 - mmengine - INFO - 288 videos remain after valid thresholding
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth
# The model and loaded state dict do not match exactly
#
# size mismatch for cls_head.fc.weight: copying a param with shape torch.Size([60, 256]) from checkpoint, the shape in current model is torch.Size([12, 256]).
# size mismatch for cls_head.fc.bias: copying a param with shape torch.Size([60]) from checkpoint, the shape in current model is torch.Size([12]).
# 05/25 11:37:57 - mmengine - INFO - Load checkpoint from https://download.openmmlab.com/mmaction/v1.0/skeleton/stgcn/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d/stgcn_8xb16-joint-u100-80e_ntu60-xsub-keypoint-3d_20221129-850308e1.pth
# 05/25 11:37:57 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 05/25 11:37:57 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 05/25 11:37:57 - mmengine - INFO - Checkpoints will be saved to /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino.
# 05/25 11:38:11 - mmengine - INFO - Epoch(train)  [1][20/22]  lr: 5.0000e-04  eta: 0:12:14  time: 0.6800  data_time: 0.1214  memory: 5461  loss: 2.1886  top1_acc: 0.3750  top5_acc: 0.9219  loss_cls: 2.1886
# 05/25 11:38:12 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:38:12 - mmengine - INFO - Epoch(train)  [1][22/22]  lr: 5.0000e-04  eta: 0:11:44  time: 0.5879  data_time: 0.0810  memory: 5461  loss: 2.1196  top1_acc: 0.3333  top5_acc: 0.7917  loss_cls: 2.1196
# 05/25 11:38:12 - mmengine - INFO - Saving checkpoint at 1 epochs
# 05/25 11:38:12 - mmengine - WARNING - `save_param_scheduler` is True but `self.param_schedulers` is None, so skip saving parameter schedulers
# 05/25 11:38:25 - mmengine - INFO - Epoch(train)  [2][20/22]  lr: 5.0000e-04  eta: 0:11:26  time: 0.6435  data_time: 0.1099  memory: 5461  loss: 1.4946  top1_acc: 0.5625  top5_acc: 0.9844  loss_cls: 1.4946
# 05/25 11:38:26 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:38:26 - mmengine - INFO - Epoch(train)  [2][22/22]  lr: 5.0000e-04  eta: 0:11:12  time: 0.5881  data_time: 0.0741  memory: 5461  loss: 1.4637  top1_acc: 0.5000  top5_acc: 0.9167  loss_cls: 1.4637
# 05/25 11:38:26 - mmengine - INFO - Saving checkpoint at 2 epochs
# 05/25 11:38:28 - mmengine - INFO - Epoch(val) [2][5/5]    acc/top1: 0.4861  acc/top5: 0.9479  acc/mean1: 0.4861  data_time: 0.2778  time: 0.4324
# 05/25 11:38:28 - mmengine - INFO - The best checkpoint with 0.4861 acc/top1 at 2 epoch is saved to best_acc_top1_epoch_2.pth.
# 05/25 11:38:42 - mmengine - INFO - Epoch(train)  [3][20/22]  lr: 5.0000e-04  eta: 0:11:09  time: 0.6653  data_time: 0.1249  memory: 5461  loss: 1.0589  top1_acc: 0.5469  top5_acc: 1.0000  loss_cls: 1.0589
# 05/25 11:38:42 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:38:43 - mmengine - INFO - Epoch(train)  [3][22/22]  lr: 5.0000e-04  eta: 0:10:59  time: 0.6138  data_time: 0.0916  memory: 5461  loss: 1.0631  top1_acc: 0.5000  top5_acc: 1.0000  loss_cls: 1.0631
# 05/25 11:38:43 - mmengine - INFO - Saving checkpoint at 3 epochs
# 05/25 11:38:56 - mmengine - INFO - Epoch(train)  [4][20/22]  lr: 5.0000e-04  eta: 0:10:52  time: 0.6622  data_time: 0.1181  memory: 5461  loss: 0.8199  top1_acc: 0.7188  top5_acc: 1.0000  loss_cls: 0.8199
# 05/25 11:38:57 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:38:57 - mmengine - INFO - Epoch(train)  [4][22/22]  lr: 5.0000e-04  eta: 0:10:45  time: 0.6052  data_time: 0.0812  memory: 5461  loss: 0.8222  top1_acc: 0.7500  top5_acc: 1.0000  loss_cls: 0.8222
# 05/25 11:38:57 - mmengine - INFO - Saving checkpoint at 4 epochs
# 05/25 11:38:59 - mmengine - INFO - Epoch(val) [4][5/5]    acc/top1: 0.4896  acc/top5: 0.9757  acc/mean1: 0.4896  data_time: 0.2165  time: 0.3463
# 05/25 11:38:59 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_2.pth is removed
# 05/25 11:38:59 - mmengine - INFO - The best checkpoint with 0.4896 acc/top1 at 4 epoch is saved to best_acc_top1_epoch_4.pth.
# 05/25 11:39:13 - mmengine - INFO - Epoch(train)  [5][20/22]  lr: 5.0000e-04  eta: 0:10:42  time: 0.6898  data_time: 0.1329  memory: 5461  loss: 0.6859  top1_acc: 0.5625  top5_acc: 1.0000  loss_cls: 0.6859
# 05/25 11:39:14 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:39:14 - mmengine - INFO - Epoch(train)  [5][22/22]  lr: 5.0000e-04  eta: 0:10:36  time: 0.6219  data_time: 0.0852  memory: 5461  loss: 0.6951  top1_acc: 0.7500  top5_acc: 1.0000  loss_cls: 0.6951
# 05/25 11:39:14 - mmengine - INFO - Saving checkpoint at 5 epochs
# 05/25 11:39:28 - mmengine - INFO - Epoch(train)  [6][20/22]  lr: 5.0000e-04  eta: 0:10:28  time: 0.6755  data_time: 0.1150  memory: 5461  loss: 0.5424  top1_acc: 0.7969  top5_acc: 1.0000  loss_cls: 0.5424
# 05/25 11:39:29 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:39:29 - mmengine - INFO - Epoch(train)  [6][22/22]  lr: 5.0000e-04  eta: 0:10:24  time: 0.6208  data_time: 0.0794  memory: 5461  loss: 0.5441  top1_acc: 0.7917  top5_acc: 1.0000  loss_cls: 0.5441
# 05/25 11:39:29 - mmengine - INFO - Saving checkpoint at 6 epochs
# 05/25 11:39:31 - mmengine - INFO - Epoch(val) [6][5/5]    acc/top1: 0.4861  acc/top5: 0.9583  acc/mean1: 0.4861  data_time: 0.2018  time: 0.4072
# 05/25 11:39:45 - mmengine - INFO - Epoch(train)  [7][20/22]  lr: 5.0000e-04  eta: 0:10:17  time: 0.6982  data_time: 0.1309  memory: 5461  loss: 0.4620  top1_acc: 0.9062  top5_acc: 1.0000  loss_cls: 0.4620
# 05/25 11:39:46 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:39:46 - mmengine - INFO - Epoch(train)  [7][22/22]  lr: 5.0000e-04  eta: 0:10:13  time: 0.6363  data_time: 0.0882  memory: 5461  loss: 0.4732  top1_acc: 0.6667  top5_acc: 1.0000  loss_cls: 0.4732
# 05/25 11:39:46 - mmengine - INFO - Saving checkpoint at 7 epochs
# 05/25 11:40:01 - mmengine - INFO - Epoch(train)  [8][20/22]  lr: 5.0000e-04  eta: 0:10:07  time: 0.7165  data_time: 0.1396  memory: 5461  loss: 0.4264  top1_acc: 0.8438  top5_acc: 1.0000  loss_cls: 0.4264
# 05/25 11:40:02 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:40:02 - mmengine - INFO - Epoch(train)  [8][22/22]  lr: 5.0000e-04  eta: 0:10:04  time: 0.6384  data_time: 0.0826  memory: 5461  loss: 0.4379  top1_acc: 0.7500  top5_acc: 1.0000  loss_cls: 0.4379
# 05/25 11:40:02 - mmengine - INFO - Saving checkpoint at 8 epochs
# 05/25 11:40:05 - mmengine - INFO - Epoch(val) [8][5/5]    acc/top1: 0.5521  acc/top5: 0.9618  acc/mean1: 0.5521  data_time: 0.3385  time: 0.4763
# 05/25 11:40:05 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_4.pth is removed
# 05/25 11:40:05 - mmengine - INFO - The best checkpoint with 0.5521 acc/top1 at 8 epoch is saved to best_acc_top1_epoch_8.pth.
# 05/25 11:40:19 - mmengine - INFO - Epoch(train)  [9][20/22]  lr: 5.0000e-04  eta: 0:09:55  time: 0.7006  data_time: 0.1123  memory: 5461  loss: 0.3392  top1_acc: 0.8906  top5_acc: 1.0000  loss_cls: 0.3392
# 05/25 11:40:20 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:40:20 - mmengine - INFO - Epoch(train)  [9][22/22]  lr: 5.0000e-04  eta: 0:09:51  time: 0.6370  data_time: 0.0681  memory: 5461  loss: 0.3380  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.3380
# 05/25 11:40:20 - mmengine - INFO - Saving checkpoint at 9 epochs
# 05/25 11:40:35 - mmengine - INFO - Epoch(train) [10][20/22]  lr: 5.0000e-04  eta: 0:09:43  time: 0.7129  data_time: 0.1208  memory: 5461  loss: 0.3090  top1_acc: 0.7812  top5_acc: 1.0000  loss_cls: 0.3090
# 05/25 11:40:35 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:40:35 - mmengine - INFO - Epoch(train) [10][22/22]  lr: 5.0000e-04  eta: 0:09:40  time: 0.6377  data_time: 0.0678  memory: 5461  loss: 0.3213  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.3213
# 05/25 11:40:35 - mmengine - INFO - Saving checkpoint at 10 epochs
# 05/25 11:40:38 - mmengine - INFO - Epoch(val) [10][5/5]    acc/top1: 0.4826  acc/top5: 0.9583  acc/mean1: 0.4826  data_time: 0.2156  time: 0.3468
# 05/25 11:40:52 - mmengine - INFO - Epoch(train) [11][20/22]  lr: 5.0000e-04  eta: 0:09:30  time: 0.7070  data_time: 0.1241  memory: 5461  loss: 0.2590  top1_acc: 0.9219  top5_acc: 1.0000  loss_cls: 0.2590
# 05/25 11:40:53 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:40:53 - mmengine - INFO - Epoch(train) [11][22/22]  lr: 5.0000e-04  eta: 0:09:27  time: 0.6429  data_time: 0.0813  memory: 5461  loss: 0.2614  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.2614
# 05/25 11:40:53 - mmengine - INFO - Saving checkpoint at 11 epochs
# 05/25 11:41:07 - mmengine - INFO - Epoch(train) [12][20/22]  lr: 5.0000e-04  eta: 0:09:16  time: 0.6996  data_time: 0.1214  memory: 5461  loss: 0.1854  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1854
# 05/25 11:41:08 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:41:08 - mmengine - INFO - Epoch(train) [12][22/22]  lr: 5.0000e-04  eta: 0:09:13  time: 0.6455  data_time: 0.0875  memory: 5461  loss: 0.1875  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.1875
# 05/25 11:41:08 - mmengine - INFO - Saving checkpoint at 12 epochs
# 05/25 11:41:10 - mmengine - INFO - Epoch(val) [12][5/5]    acc/top1: 0.5278  acc/top5: 0.9479  acc/mean1: 0.5278  data_time: 0.2194  time: 0.3486
# 05/25 11:41:24 - mmengine - INFO - Epoch(train) [13][20/22]  lr: 5.0000e-04  eta: 0:09:02  time: 0.6988  data_time: 0.1214  memory: 5461  loss: 0.1656  top1_acc: 0.9688  top5_acc: 1.0000  loss_cls: 0.1656
# 05/25 11:41:25 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:41:25 - mmengine - INFO - Epoch(train) [13][22/22]  lr: 5.0000e-04  eta: 0:08:59  time: 0.6324  data_time: 0.0756  memory: 5461  loss: 0.1712  top1_acc: 0.9167  top5_acc: 1.0000  loss_cls: 0.1712
# 05/25 11:41:25 - mmengine - INFO - Saving checkpoint at 13 epochs
# 05/25 11:41:39 - mmengine - INFO - Epoch(train) [14][20/22]  lr: 5.0000e-04  eta: 0:08:48  time: 0.6998  data_time: 0.1198  memory: 5461  loss: 0.2043  top1_acc: 0.9688  top5_acc: 1.0000  loss_cls: 0.2043
# 05/25 11:41:40 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:41:40 - mmengine - INFO - Epoch(train) [14][22/22]  lr: 5.0000e-04  eta: 0:08:45  time: 0.6417  data_time: 0.0817  memory: 5461  loss: 0.2040  top1_acc: 0.8333  top5_acc: 1.0000  loss_cls: 0.2040
# 05/25 11:41:40 - mmengine - INFO - Saving checkpoint at 14 epochs
# 05/25 11:41:42 - mmengine - INFO - Epoch(val) [14][5/5]    acc/top1: 0.5451  acc/top5: 0.9583  acc/mean1: 0.5451  data_time: 0.2030  time: 0.3350
# 05/25 11:41:57 - mmengine - INFO - Epoch(train) [15][20/22]  lr: 5.0000e-04  eta: 0:08:34  time: 0.7114  data_time: 0.1288  memory: 5461  loss: 0.1422  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.1422
# 05/25 11:41:57 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:41:57 - mmengine - INFO - Epoch(train) [15][22/22]  lr: 5.0000e-04  eta: 0:08:32  time: 0.6351  data_time: 0.0726  memory: 5461  loss: 0.1428  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.1428
# 05/25 11:41:57 - mmengine - INFO - Saving checkpoint at 15 epochs
# 05/25 11:42:12 - mmengine - INFO - Epoch(train) [16][20/22]  lr: 5.0000e-04  eta: 0:08:20  time: 0.7090  data_time: 0.1267  memory: 5461  loss: 0.0953  top1_acc: 0.9688  top5_acc: 1.0000  loss_cls: 0.0953
# 05/25 11:42:13 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:42:13 - mmengine - INFO - Epoch(train) [16][22/22]  lr: 5.0000e-04  eta: 0:08:18  time: 0.6191  data_time: 0.0580  memory: 5461  loss: 0.0998  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0998
# 05/25 11:42:13 - mmengine - INFO - Saving checkpoint at 16 epochs
# 05/25 11:42:15 - mmengine - INFO - Epoch(val) [16][5/5]    acc/top1: 0.5312  acc/top5: 0.9444  acc/mean1: 0.5312  data_time: 0.2369  time: 0.3695
# 05/25 11:42:29 - mmengine - INFO - Epoch(train) [17][20/22]  lr: 5.0000e-04  eta: 0:08:06  time: 0.6984  data_time: 0.1202  memory: 5461  loss: 0.0624  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.0624
# 05/25 11:42:30 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:42:30 - mmengine - INFO - Epoch(train) [17][22/22]  lr: 5.0000e-04  eta: 0:08:04  time: 0.6338  data_time: 0.0759  memory: 5461  loss: 0.0772  top1_acc: 0.9167  top5_acc: 1.0000  loss_cls: 0.0772
# 05/25 11:42:30 - mmengine - INFO - Saving checkpoint at 17 epochs
# 05/25 11:42:44 - mmengine - INFO - Epoch(train) [18][20/22]  lr: 5.0000e-04  eta: 0:07:52  time: 0.7020  data_time: 0.1224  memory: 5461  loss: 0.0658  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0658
# 05/25 11:42:45 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:42:45 - mmengine - INFO - Epoch(train) [18][22/22]  lr: 5.0000e-04  eta: 0:07:49  time: 0.6427  data_time: 0.0831  memory: 5461  loss: 0.0675  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0675
# 05/25 11:42:45 - mmengine - INFO - Saving checkpoint at 18 epochs
# 05/25 11:42:48 - mmengine - INFO - Epoch(val) [18][5/5]    acc/top1: 0.5590  acc/top5: 0.9653  acc/mean1: 0.5590  data_time: 0.2026  time: 0.3373
# 05/25 11:42:48 - mmengine - INFO - The previous best checkpoint /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/best_acc_top1_epoch_8.pth is removed
# 05/25 11:42:48 - mmengine - INFO - The best checkpoint with 0.5590 acc/top1 at 18 epoch is saved to best_acc_top1_epoch_18.pth.
# 05/25 11:43:02 - mmengine - INFO - Epoch(train) [19][20/22]  lr: 5.0000e-04  eta: 0:07:37  time: 0.7096  data_time: 0.1294  memory: 5461  loss: 0.0362  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0362
# 05/25 11:43:03 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:43:03 - mmengine - INFO - Epoch(train) [19][22/22]  lr: 5.0000e-04  eta: 0:07:35  time: 0.6518  data_time: 0.0918  memory: 5461  loss: 0.0423  top1_acc: 0.9167  top5_acc: 1.0000  loss_cls: 0.0423
# 05/25 11:43:03 - mmengine - INFO - Saving checkpoint at 19 epochs
# 05/25 11:43:17 - mmengine - INFO - Epoch(train) [20][20/22]  lr: 5.0000e-04  eta: 0:07:23  time: 0.7002  data_time: 0.1178  memory: 5461  loss: 0.0502  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.0502
# 05/25 11:43:18 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:43:18 - mmengine - INFO - Epoch(train) [20][22/22]  lr: 5.0000e-04  eta: 0:07:21  time: 0.6478  data_time: 0.0857  memory: 5461  loss: 0.0736  top1_acc: 0.8333  top5_acc: 1.0000  loss_cls: 0.0736
# 05/25 11:43:18 - mmengine - INFO - Saving checkpoint at 20 epochs
# 05/25 11:43:20 - mmengine - INFO - Epoch(val) [20][5/5]    acc/top1: 0.4826  acc/top5: 0.9479  acc/mean1: 0.4826  data_time: 0.2195  time: 0.3538
# 05/25 11:43:34 - mmengine - INFO - Epoch(train) [21][20/22]  lr: 5.0000e-04  eta: 0:07:08  time: 0.7034  data_time: 0.1227  memory: 5461  loss: 0.1184  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.1184
# 05/25 11:43:35 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:43:35 - mmengine - INFO - Epoch(train) [21][22/22]  lr: 5.0000e-04  eta: 0:07:06  time: 0.6464  data_time: 0.0850  memory: 5461  loss: 0.1306  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.1306
# 05/25 11:43:35 - mmengine - INFO - Saving checkpoint at 21 epochs
# 05/25 11:43:50 - mmengine - INFO - Epoch(train) [22][20/22]  lr: 5.0000e-04  eta: 0:06:54  time: 0.7136  data_time: 0.1311  memory: 5461  loss: 0.0911  top1_acc: 0.9375  top5_acc: 1.0000  loss_cls: 0.0911
# 05/25 11:43:51 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:43:51 - mmengine - INFO - Epoch(train) [22][22/22]  lr: 5.0000e-04  eta: 0:06:52  time: 0.6319  data_time: 0.0709  memory: 5461  loss: 0.0868  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0868
# 05/25 11:43:51 - mmengine - INFO - Saving checkpoint at 22 epochs
# 05/25 11:43:54 - mmengine - INFO - Epoch(val) [22][5/5]    acc/top1: 0.5417  acc/top5: 0.9410  acc/mean1: 0.5417  data_time: 0.2736  time: 0.4135
# 05/25 11:44:08 - mmengine - INFO - Epoch(train) [23][20/22]  lr: 5.0000e-04  eta: 0:06:40  time: 0.7036  data_time: 0.1235  memory: 5461  loss: 0.0705  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0705
# 05/25 11:44:08 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:44:08 - mmengine - INFO - Epoch(train) [23][22/22]  lr: 5.0000e-04  eta: 0:06:38  time: 0.6207  data_time: 0.0624  memory: 5461  loss: 0.0647  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0647
# 05/25 11:44:09 - mmengine - INFO - Saving checkpoint at 23 epochs
# 05/25 11:44:23 - mmengine - INFO - Epoch(train) [24][20/22]  lr: 5.0000e-04  eta: 0:06:25  time: 0.6910  data_time: 0.1138  memory: 5461  loss: 0.0399  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0399
# 05/25 11:44:24 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:44:24 - mmengine - INFO - Epoch(train) [24][22/22]  lr: 5.0000e-04  eta: 0:06:23  time: 0.6151  data_time: 0.0573  memory: 5461  loss: 0.0415  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0415
# 05/25 11:44:24 - mmengine - INFO - Saving checkpoint at 24 epochs
# 05/25 11:44:26 - mmengine - INFO - Epoch(val) [24][5/5]    acc/top1: 0.5208  acc/top5: 0.9618  acc/mean1: 0.5208  data_time: 0.2159  time: 0.3453
# 05/25 11:44:40 - mmengine - INFO - Epoch(train) [25][20/22]  lr: 5.0000e-04  eta: 0:06:10  time: 0.7086  data_time: 0.1289  memory: 5461  loss: 0.0237  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.0237
# 05/25 11:44:41 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:44:41 - mmengine - INFO - Epoch(train) [25][22/22]  lr: 5.0000e-04  eta: 0:06:08  time: 0.6316  data_time: 0.0728  memory: 5461  loss: 0.0232  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0232
# 05/25 11:44:41 - mmengine - INFO - Saving checkpoint at 25 epochs
# 05/25 11:44:55 - mmengine - INFO - Epoch(train) [26][20/22]  lr: 5.0000e-04  eta: 0:05:56  time: 0.7032  data_time: 0.1215  memory: 5461  loss: 0.0133  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0133
# 05/25 11:44:56 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:44:56 - mmengine - INFO - Epoch(train) [26][22/22]  lr: 5.0000e-04  eta: 0:05:54  time: 0.6333  data_time: 0.0729  memory: 5461  loss: 0.0127  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0127
# 05/25 11:44:56 - mmengine - INFO - Saving checkpoint at 26 epochs
# 05/25 11:44:58 - mmengine - INFO - Epoch(val) [26][5/5]    acc/top1: 0.5347  acc/top5: 0.9618  acc/mean1: 0.5347  data_time: 0.2089  time: 0.3417
# 05/25 11:45:12 - mmengine - INFO - Epoch(train) [27][20/22]  lr: 5.0000e-04  eta: 0:05:41  time: 0.6977  data_time: 0.1149  memory: 5461  loss: 0.0075  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0075
# 05/25 11:45:13 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:45:13 - mmengine - INFO - Epoch(train) [27][22/22]  lr: 5.0000e-04  eta: 0:05:39  time: 0.6398  data_time: 0.0786  memory: 5461  loss: 0.0088  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0088
# 05/25 11:45:13 - mmengine - INFO - Saving checkpoint at 27 epochs
# 05/25 11:45:27 - mmengine - INFO - Epoch(train) [28][20/22]  lr: 5.0000e-04  eta: 0:05:26  time: 0.6969  data_time: 0.1161  memory: 5461  loss: 0.0050  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0050
# 05/25 11:45:28 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:45:28 - mmengine - INFO - Epoch(train) [28][22/22]  lr: 5.0000e-04  eta: 0:05:24  time: 0.6378  data_time: 0.0773  memory: 5461  loss: 0.0057  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0057
# 05/25 11:45:28 - mmengine - INFO - Saving checkpoint at 28 epochs
# 05/25 11:45:30 - mmengine - INFO - Epoch(val) [28][5/5]    acc/top1: 0.5417  acc/top5: 0.9757  acc/mean1: 0.5417  data_time: 0.2184  time: 0.3479
# 05/25 11:45:44 - mmengine - INFO - Epoch(train) [29][20/22]  lr: 5.0000e-04  eta: 0:05:11  time: 0.7005  data_time: 0.1221  memory: 5461  loss: 0.0050  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0050
# 05/25 11:45:45 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:45:45 - mmengine - INFO - Epoch(train) [29][22/22]  lr: 5.0000e-04  eta: 0:05:10  time: 0.6317  data_time: 0.0737  memory: 5461  loss: 0.0047  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0047
# 05/25 11:45:45 - mmengine - INFO - Saving checkpoint at 29 epochs
# 05/25 11:46:00 - mmengine - INFO - Epoch(train) [30][20/22]  lr: 5.0000e-04  eta: 0:04:57  time: 0.7087  data_time: 0.1258  memory: 5461  loss: 0.0034  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0034
# 05/25 11:46:00 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:46:00 - mmengine - INFO - Epoch(train) [30][22/22]  lr: 5.0000e-04  eta: 0:04:55  time: 0.6414  data_time: 0.0805  memory: 5461  loss: 0.0034  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0034
# 05/25 11:46:00 - mmengine - INFO - Saving checkpoint at 30 epochs
# 05/25 11:46:03 - mmengine - INFO - Epoch(val) [30][5/5]    acc/top1: 0.5417  acc/top5: 0.9722  acc/mean1: 0.5417  data_time: 0.3135  time: 0.4626
# 05/25 11:46:17 - mmengine - INFO - Epoch(train) [31][20/22]  lr: 5.0000e-04  eta: 0:04:42  time: 0.7016  data_time: 0.1230  memory: 5461  loss: 0.0027  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0027
# 05/25 11:46:18 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:46:18 - mmengine - INFO - Epoch(train) [31][22/22]  lr: 5.0000e-04  eta: 0:04:40  time: 0.6164  data_time: 0.0599  memory: 5461  loss: 0.0030  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0030
# 05/25 11:46:18 - mmengine - INFO - Saving checkpoint at 31 epochs
# 05/25 11:46:33 - mmengine - INFO - Epoch(train) [32][20/22]  lr: 5.0000e-04  eta: 0:04:27  time: 0.7038  data_time: 0.1228  memory: 5461  loss: 0.0030  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0030
# 05/25 11:46:34 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:46:34 - mmengine - INFO - Epoch(train) [32][22/22]  lr: 5.0000e-04  eta: 0:04:26  time: 0.6308  data_time: 0.0713  memory: 5461  loss: 0.0031  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0031
# 05/25 11:46:34 - mmengine - INFO - Saving checkpoint at 32 epochs
# 05/25 11:46:36 - mmengine - INFO - Epoch(val) [32][5/5]    acc/top1: 0.5451  acc/top5: 0.9722  acc/mean1: 0.5451  data_time: 0.2128  time: 0.3450
# 05/25 11:46:50 - mmengine - INFO - Epoch(train) [33][20/22]  lr: 5.0000e-04  eta: 0:04:12  time: 0.7013  data_time: 0.1176  memory: 5461  loss: 0.0027  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0027
# 05/25 11:46:51 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:46:51 - mmengine - INFO - Epoch(train) [33][22/22]  lr: 5.0000e-04  eta: 0:04:11  time: 0.6436  data_time: 0.0807  memory: 5461  loss: 0.0028  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0028
# 05/25 11:46:51 - mmengine - INFO - Saving checkpoint at 33 epochs
# 05/25 11:47:05 - mmengine - INFO - Epoch(train) [34][20/22]  lr: 5.0000e-04  eta: 0:03:58  time: 0.7041  data_time: 0.1219  memory: 5461  loss: 0.0028  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0028
# 05/25 11:47:06 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:47:06 - mmengine - INFO - Epoch(train) [34][22/22]  lr: 5.0000e-04  eta: 0:03:56  time: 0.6388  data_time: 0.0760  memory: 5461  loss: 0.0029  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0029
# 05/25 11:47:06 - mmengine - INFO - Saving checkpoint at 34 epochs
# 05/25 11:47:08 - mmengine - INFO - Epoch(val) [34][5/5]    acc/top1: 0.5417  acc/top5: 0.9653  acc/mean1: 0.5417  data_time: 0.2210  time: 0.3523
# 05/25 11:47:22 - mmengine - INFO - Epoch(train) [35][20/22]  lr: 5.0000e-04  eta: 0:03:43  time: 0.6992  data_time: 0.1186  memory: 5461  loss: 0.0020  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0020
# 05/25 11:47:23 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:47:23 - mmengine - INFO - Epoch(train) [35][22/22]  lr: 5.0000e-04  eta: 0:03:41  time: 0.6425  data_time: 0.0818  memory: 5461  loss: 0.0021  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0021
# 05/25 11:47:23 - mmengine - INFO - Saving checkpoint at 35 epochs
# 05/25 11:47:38 - mmengine - INFO - Epoch(train) [36][20/22]  lr: 5.0000e-04  eta: 0:03:28  time: 0.7048  data_time: 0.1239  memory: 5461  loss: 0.0023  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0023
# 05/25 11:47:38 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:47:38 - mmengine - INFO - Epoch(train) [36][22/22]  lr: 5.0000e-04  eta: 0:03:27  time: 0.6338  data_time: 0.0745  memory: 5461  loss: 0.0025  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0025
# 05/25 11:47:38 - mmengine - INFO - Saving checkpoint at 36 epochs
# 05/25 11:47:41 - mmengine - INFO - Epoch(val) [36][5/5]    acc/top1: 0.5451  acc/top5: 0.9688  acc/mean1: 0.5451  data_time: 0.2055  time: 0.3381
# 05/25 11:47:55 - mmengine - INFO - Epoch(train) [37][20/22]  lr: 5.0000e-04  eta: 0:03:14  time: 0.7291  data_time: 0.1464  memory: 5461  loss: 0.0021  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0021
# 05/25 11:47:56 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:47:56 - mmengine - INFO - Epoch(train) [37][22/22]  lr: 5.0000e-04  eta: 0:03:12  time: 0.6537  data_time: 0.0924  memory: 5461  loss: 0.0020  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0020
# 05/25 11:47:56 - mmengine - INFO - Saving checkpoint at 37 epochs
# 05/25 11:48:11 - mmengine - INFO - Epoch(train) [38][20/22]  lr: 5.0000e-04  eta: 0:02:59  time: 0.7227  data_time: 0.1425  memory: 5461  loss: 0.0020  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0020
# 05/25 11:48:12 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:48:12 - mmengine - INFO - Epoch(train) [38][22/22]  lr: 5.0000e-04  eta: 0:02:57  time: 0.6359  data_time: 0.0766  memory: 5461  loss: 0.0021  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0021
# 05/25 11:48:12 - mmengine - INFO - Saving checkpoint at 38 epochs
# 05/25 11:48:14 - mmengine - INFO - Epoch(val) [38][5/5]    acc/top1: 0.5556  acc/top5: 0.9688  acc/mean1: 0.5556  data_time: 0.2524  time: 0.3829
# 05/25 11:48:29 - mmengine - INFO - Epoch(train) [39][20/22]  lr: 5.0000e-04  eta: 0:02:44  time: 0.7067  data_time: 0.1275  memory: 5461  loss: 0.0020  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0020
# 05/25 11:48:29 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:48:29 - mmengine - INFO - Epoch(train) [39][22/22]  lr: 5.0000e-04  eta: 0:02:43  time: 0.6417  data_time: 0.0823  memory: 5461  loss: 0.0020  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0020
# 05/25 11:48:29 - mmengine - INFO - Saving checkpoint at 39 epochs
# 05/25 11:48:44 - mmengine - INFO - Epoch(train) [40][20/22]  lr: 5.0000e-04  eta: 0:02:29  time: 0.7014  data_time: 0.1216  memory: 5461  loss: 0.0020  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0020
# 05/25 11:48:45 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:48:45 - mmengine - INFO - Epoch(train) [40][22/22]  lr: 5.0000e-04  eta: 0:02:28  time: 0.6444  data_time: 0.0850  memory: 5461  loss: 0.0026  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0026
# 05/25 11:48:45 - mmengine - INFO - Saving checkpoint at 40 epochs
# 05/25 11:48:47 - mmengine - INFO - Epoch(val) [40][5/5]    acc/top1: 0.5521  acc/top5: 0.9722  acc/mean1: 0.5521  data_time: 0.2179  time: 0.3484
# 05/25 11:49:01 - mmengine - INFO - Epoch(train) [41][20/22]  lr: 5.0000e-04  eta: 0:02:14  time: 0.6972  data_time: 0.1154  memory: 5461  loss: 0.0017  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0017
# 05/25 11:49:02 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:49:02 - mmengine - INFO - Epoch(train) [41][22/22]  lr: 5.0000e-04  eta: 0:02:13  time: 0.6409  data_time: 0.0798  memory: 5461  loss: 0.0025  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0025
# 05/25 11:49:02 - mmengine - INFO - Saving checkpoint at 41 epochs
# 05/25 11:49:16 - mmengine - INFO - Epoch(train) [42][20/22]  lr: 5.0000e-04  eta: 0:02:00  time: 0.7009  data_time: 0.1215  memory: 5461  loss: 0.0282  top1_acc: 0.9531  top5_acc: 1.0000  loss_cls: 0.0282
# 05/25 11:49:17 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:49:17 - mmengine - INFO - Epoch(train) [42][22/22]  lr: 5.0000e-04  eta: 0:01:58  time: 0.6392  data_time: 0.0808  memory: 5461  loss: 0.0382  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0382
# 05/25 11:49:17 - mmengine - INFO - Saving checkpoint at 42 epochs
# 05/25 11:49:19 - mmengine - INFO - Epoch(val) [42][5/5]    acc/top1: 0.5243  acc/top5: 0.9583  acc/mean1: 0.5243  data_time: 0.2122  time: 0.3431
# 05/25 11:49:33 - mmengine - INFO - Epoch(train) [43][20/22]  lr: 5.0000e-04  eta: 0:01:45  time: 0.6947  data_time: 0.1158  memory: 5461  loss: 0.0692  top1_acc: 1.0000  top5_acc: 1.0000  loss_cls: 0.0692
# 05/25 11:49:34 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:49:34 - mmengine - INFO - Epoch(train) [43][22/22]  lr: 5.0000e-04  eta: 0:01:43  time: 0.6429  data_time: 0.0837  memory: 5461  loss: 0.0757  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.0757
# 05/25 11:49:34 - mmengine - INFO - Saving checkpoint at 43 epochs
# 05/25 11:49:48 - mmengine - INFO - Epoch(train) [44][20/22]  lr: 5.0000e-04  eta: 0:01:30  time: 0.7025  data_time: 0.1203  memory: 5461  loss: 0.0978  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.0978
# 05/25 11:49:49 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:49:49 - mmengine - INFO - Epoch(train) [44][22/22]  lr: 5.0000e-04  eta: 0:01:28  time: 0.6353  data_time: 0.0746  memory: 5461  loss: 0.1112  top1_acc: 0.9167  top5_acc: 1.0000  loss_cls: 0.1112
# 05/25 11:49:49 - mmengine - INFO - Saving checkpoint at 44 epochs
# 05/25 11:49:52 - mmengine - INFO - Epoch(val) [44][5/5]    acc/top1: 0.4826  acc/top5: 0.9410  acc/mean1: 0.4826  data_time: 0.2495  time: 0.3863
# 05/25 11:50:06 - mmengine - INFO - Epoch(train) [45][20/22]  lr: 5.0000e-04  eta: 0:01:15  time: 0.7225  data_time: 0.1410  memory: 5461  loss: 0.2109  top1_acc: 0.8906  top5_acc: 1.0000  loss_cls: 0.2109
# 05/25 11:50:07 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:50:07 - mmengine - INFO - Epoch(train) [45][22/22]  lr: 5.0000e-04  eta: 0:01:14  time: 0.6206  data_time: 0.0613  memory: 5461  loss: 0.2292  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.2292
# 05/25 11:50:07 - mmengine - INFO - Saving checkpoint at 45 epochs
# 05/25 11:50:15 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:50:21 - mmengine - INFO - Epoch(train) [46][20/22]  lr: 5.0000e-04  eta: 0:01:00  time: 0.7022  data_time: 0.1230  memory: 5461  loss: 0.2223  top1_acc: 0.9375  top5_acc: 1.0000  loss_cls: 0.2223
# 05/25 11:50:22 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:50:22 - mmengine - INFO - Epoch(train) [46][22/22]  lr: 5.0000e-04  eta: 0:00:59  time: 0.6232  data_time: 0.0638  memory: 5461  loss: 0.2195  top1_acc: 0.9167  top5_acc: 1.0000  loss_cls: 0.2195
# 05/25 11:50:22 - mmengine - INFO - Saving checkpoint at 46 epochs
# 05/25 11:50:24 - mmengine - INFO - Epoch(val) [46][5/5]    acc/top1: 0.4965  acc/top5: 0.9236  acc/mean1: 0.4965  data_time: 0.2161  time: 0.3464
# 05/25 11:50:38 - mmengine - INFO - Epoch(train) [47][20/22]  lr: 5.0000e-04  eta: 0:00:45  time: 0.7029  data_time: 0.1249  memory: 5461  loss: 0.1651  top1_acc: 0.9531  top5_acc: 1.0000  loss_cls: 0.1651
# 05/25 11:50:39 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:50:39 - mmengine - INFO - Epoch(train) [47][22/22]  lr: 5.0000e-04  eta: 0:00:44  time: 0.6351  data_time: 0.0773  memory: 5461  loss: 0.1701  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.1701
# 05/25 11:50:39 - mmengine - INFO - Saving checkpoint at 47 epochs
# 05/25 11:50:54 - mmengine - INFO - Epoch(train) [48][20/22]  lr: 5.0000e-04  eta: 0:00:31  time: 0.7093  data_time: 0.1285  memory: 5461  loss: 0.1379  top1_acc: 0.9531  top5_acc: 1.0000  loss_cls: 0.1379
# 05/25 11:50:55 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:50:55 - mmengine - INFO - Epoch(train) [48][22/22]  lr: 5.0000e-04  eta: 0:00:29  time: 0.6380  data_time: 0.0788  memory: 5461  loss: 0.1282  top1_acc: 0.9583  top5_acc: 1.0000  loss_cls: 0.1282
# 05/25 11:50:55 - mmengine - INFO - Saving checkpoint at 48 epochs
# 05/25 11:50:57 - mmengine - INFO - Epoch(val) [48][5/5]    acc/top1: 0.5278  acc/top5: 0.9549  acc/mean1: 0.5278  data_time: 0.2120  time: 0.3473
# 05/25 11:51:11 - mmengine - INFO - Epoch(train) [49][20/22]  lr: 5.0000e-04  eta: 0:00:16  time: 0.6974  data_time: 0.1187  memory: 5461  loss: 0.0723  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.0723
# 05/25 11:51:12 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:51:12 - mmengine - INFO - Epoch(train) [49][22/22]  lr: 5.0000e-04  eta: 0:00:14  time: 0.6433  data_time: 0.0850  memory: 5461  loss: 0.0928  top1_acc: 0.8333  top5_acc: 1.0000  loss_cls: 0.0928
# 05/25 11:51:12 - mmengine - INFO - Saving checkpoint at 49 epochs
# 05/25 11:51:26 - mmengine - INFO - Epoch(train) [50][20/22]  lr: 5.0000e-04  eta: 0:00:01  time: 0.6954  data_time: 0.1133  memory: 5461  loss: 0.1048  top1_acc: 0.9844  top5_acc: 1.0000  loss_cls: 0.1048
# 05/25 11:51:27 - mmengine - INFO - Exp name: stgcn_3d_custom_20250525_113751
# 05/25 11:51:27 - mmengine - INFO - Epoch(train) [50][22/22]  lr: 5.0000e-04  eta: 0:00:00  time: 0.6403  data_time: 0.0786  memory: 5461  loss: 0.1188  top1_acc: 0.8750  top5_acc: 1.0000  loss_cls: 0.1188
# 05/25 11:51:27 - mmengine - INFO - Saving checkpoint at 50 epochs
# 05/25 11:51:29 - mmengine - INFO - Epoch(val) [50][5/5]    acc/top1: 0.5208  acc/top5: 0.9479  acc/mean1: 0.5208  data_time: 0.2578  time: 0.3865

# %%
# !python tools/test.py configs/stgcn_3d_custom.py /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/epoch_50.pth --dump /content/drive/MyDrive/mmaction2_work_dir/stgcn_test_50/results.pkl
# Out:
# 05/25 12:14:41 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 522127509
#     GPU 0: Tesla T4
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.5, V12.5.82
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.0.1+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.7.3 (Git Hash 6dbeffbae1f23cbbeae17adb7b5b13f1f37c080e)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.8
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.7
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.8, CUDNN_VERSION=8.7.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wunused-local-typedefs -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.0.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.15.2+cu118
#     OpenCV: 4.11.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 522127509
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 05/25 12:14:41 - mmengine - INFO - Config:
# default_hooks = dict(
#     checkpoint=dict(interval=1, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=False, interval=20, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# evaluation = dict(
#     interval=2,
#     metric_options=dict(top_k_accuracy=dict(topk=(
#         1,
#         3,
#         5,
#     ))),
#     metrics=[
#         'top_k_accuracy',
#         'mean_class_accuracy',
#     ])
# launcher = 'none'
# load_from = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/epoch_50.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         graph_cfg=dict(layout='nturgb+d', mode='spatial'),
#         in_channels=3,
#         type='STGCN'),
#     cls_head=dict(
#         in_channels=256,
#         loss_cls=dict(type='CrossEntropyLoss'),
#         num_classes=12,
#         type='GCNHead'),
#     type='RecognizerGCN')
# optim_wrapper = dict(
#     optimizer=dict(lr=0.0005, type='Adam', weight_decay=0.0001),
#     type='OptimWrapper')
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/test_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(
#                 clip_len=100,
#                 num_clips=1,
#                 test_mode=True,
#                 type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = [
#     dict(
#         metric_list=(
#             'top_k_accuracy',
#             'mean_class_accuracy',
#         ),
#         type='AccMetric'),
#     dict(
#         out_file_path=
#         '/content/drive/MyDrive/mmaction2_work_dir/stgcn_test_50/results.pkl',
#         type='DumpResults'),
# ]
# test_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(
#         clip_len=100, num_clips=1, test_mode=True, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(max_epochs=50, type='EpochBasedTrainLoop', val_interval=2)
# train_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/train_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(clip_len=100, type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(clip_len=100, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=64,
#     dataset=dict(
#         ann_file='/content/val_labels.pkl',
#         pipeline=[
#             dict(type='PreNormalize3D'),
#             dict(dataset='nturgb+d', feats=[
#                 'j',
#             ], type='GenSkeFeat'),
#             dict(
#                 clip_len=100,
#                 num_clips=1,
#                 test_mode=True,
#                 type='UniformSampleFrames'),
#             dict(type='PoseDecode'),
#             dict(num_person=1, type='FormatGCNInput'),
#             dict(type='PackActionInputs'),
#         ],
#         type='PoseDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     metric_list=(
#         'top_k_accuracy',
#         'mean_class_accuracy',
#     ), type='AccMetric')
# val_pipeline = [
#     dict(type='PreNormalize3D'),
#     dict(dataset='nturgb+d', feats=[
#         'j',
#     ], type='GenSkeFeat'),
#     dict(
#         clip_len=100, num_clips=1, test_mode=True, type='UniformSampleFrames'),
#     dict(type='PoseDecode'),
#     dict(num_person=1, type='FormatGCNInput'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_treino'
#
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# 05/25 12:14:44 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 05/25 12:14:44 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 05/25 12:14:45 - mmengine - INFO - 324 videos remain after valid thresholding
# 05/25 12:14:45 - mmengine - WARNING - The prefix is not set in metric class DumpResults.
# Loads checkpoint by local backend from path: /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/epoch_50.pth
# 05/25 12:14:45 - mmengine - INFO - Load checkpoint from /content/drive/MyDrive/mmaction2_work_dir/stgcn_treino/epoch_50.pth
# 05/25 12:14:49 - mmengine - INFO - Results has been saved to /content/drive/MyDrive/mmaction2_work_dir/stgcn_test_50/results.pkl.
# 05/25 12:14:49 - mmengine - INFO - Epoch(test) [6/6]    acc/top1: 0.4414  acc/top5: 0.8858  acc/mean1: 0.4414  data_time: 0.2465  time: 0.5514

# %%
print(len(results))         # Deve dar 324
print(len(y_true))          # Deve dar 324
# Out:
# 324
# 324

# %%
# !pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
import pickle
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Caminho para o ficheiro de resultados
results_path = '/content/drive/MyDrive/mmaction2_work_dir/stgcn_test_50/results.pkl'

# Carrega as predições
with open(results_path, 'rb') as f:
    results = pickle.load(f)

# results é normalmente uma lista de arrays de scores por classe
# Para cada amostra, o índice do maior score é a predição do modelo
y_pred = [np.argmax(r) for r in results]

# Agora precisas dos rótulos verdadeiros (labels do dataset de teste)
# Supondo que tens um ficheiro ann_file com os labels:
import mmcv
ann_file = '/content/test_labels.pkl'

import pickle

with open('/content/test_labels.pkl', 'rb') as f:
    data_infos = pickle.load(f)


y_true = [info['label'] for info in data_infos]

# Calcula a matriz de confusão
cm = confusion_matrix(y_true, y_pred)

class_labels = [
'backhand_volley', 'backhand2hands', 'forehand_openstands', 'kick_service', 'forehand_volley', 'backhand', 'forehand_slice', 'backhand_slice', 'flat_service', 'forehand_flat', 'slice_service', 'smash']

plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues',
    xticklabels=class_labels,
    yticklabels=class_labels
)
plt.xlabel('Classe Predita')
plt.ylabel('Classe Verdadeira')
plt.title('Matriz de Confusão')
plt.show()
